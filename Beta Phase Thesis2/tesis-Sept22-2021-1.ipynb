# %% [markdown]
# # Egg Quality Classification Based on its Shell Visual Property through Image Processing and Deep Learning

# %% [markdown]
# Group CGM: <br>
#
# Caguioa, JV Bryan <br>
# Guinto, Ryhle Nodnyhlson <br>
# Mesias, Lee Reuben

# %% [markdown]
# # References

# %% [markdown]
# https://thedatafrog.com/en/articles/image-recognition-transfer-learning/ <br>
# https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538 <br>
# https://www.datacamp.com/community/tutorials/convolutional-neural-networks-python

# %% [markdown]
# ## Imports

# %%
# for image name
import random

# define and move to dataset and model directory
import os
# the directory where the data is stored
directory = "C:/Users/user/Desktop/Dataset"
#directory where set of models per training are stored
gen_dir = "C:/Users/user/Desktop/Model"

# duplicate combined image to other directory and delete directory with its content
import shutil

#for stopping code if not the right amount of images
import sys

#histograph/confusion matrix
import matplotlib.pyplot as plt
import seaborn as sn

#model creation
import tensorflow.keras as keras

import numpy as np

# data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#k-fold cross validation
import pandas as pd                                     #store all images and their class/label
from sklearn.model_selection import StratifiedKFold     
#from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split    #split the dataset to train-test
import tensorflow as tf                                 #for callbacks

#for model evaluation
from tensorflow.keras.preprocessing import image as im                   #load image
from tensorflow.keras.applications.resnet50 import preprocess_input      #preprocess image                                                               
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
#from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

#validating misclassified images
import cv2     #load the image

# %% [markdown]
# ## Put Dataset in a Dataframe

# %% [markdown]
# The directory of the images are put in a dataframe in order to prepare for splitting the dataset into train and test set.

# %%
totaldsdirect = directory + "/TotalCombined"

image = []

if not os.path.exists(totaldsdirect):
    print("Directory does not exist. Please run the code on data cleaning notebook.")
    sys.exit()

for x in os.listdir(totaldsdirect):
    totaldsdirect2 = totaldsdirect + "/" + x
    for y in os.listdir(totaldsdirect2):
        if x == "Balut-penoy4":
            lbl = "0"
        elif x == "Salted egg4":
            lbl = "1"
        else:
            lbl = "2"
                 
        #append to image array
        image.append([totaldsdirect2 + "/" + y,lbl])

# %%
df = pd.DataFrame(image,columns=['filename','label'])
df
# Out:
#                                               filename label
# 0    C:/Users/user/Desktop/Dataset/TotalCombined/Ba...     0
# 1    C:/Users/user/Desktop/Dataset/TotalCombined/Ba...     0
# 2    C:/Users/user/Desktop/Dataset/TotalCombined/Ba...     0
# 3    C:/Users/user/Desktop/Dataset/TotalCombined/Ba...     0
# 4    C:/Users/user/Desktop/Dataset/TotalCombined/Ba...     0
# ..                                                 ...   ...
# 892  C:/Users/user/Desktop/Dataset/TotalCombined/Ta...     2
# 893  C:/Users/user/Desktop/Dataset/TotalCombined/Ta...     2
# 894  C:/Users/user/Desktop/Dataset/TotalCombined/Ta...     2
# 895  C:/Users/user/Desktop/Dataset/TotalCombined/Ta...     2
# 896  C:/Users/user/Desktop/Dataset/TotalCombined/Ta...     2
#
# [897 rows x 2 columns]

# %%
print(df['label'].unique())
# Out:
# ['0' '1' '2']

# %%
print(df.isna().any())
# Out:
# filename    False
# label       False
# dtype: bool

# %% [markdown]
# ## Split Data to train and test set

# %% [markdown]
# We will need to split the dataset to train and test set. Only the train set will be used for transfer learning with K-fold validation. Test set will be used for model prediction and use that for model evaluation. Stratify is used in order to split the data in equal numbers under the classes specified.

# %%
## Split the data to train and test
X = df[['filename']]
y = df[['label']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# %% [markdown]
# Save the split sets to train and test set folders.

# %%
#folder to store the train and test set folders
fortraintest = directory + "/ToBeUsed"
if not os.path.exists(fortraintest):
    os.makedirs(fortraintest)

#train set folder
tr = fortraintest + "/train_set"
if not os.path.exists(tr):
    os.makedirs(tr)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr)
    os.makedirs(tr)
    
#test set folder
te = fortraintest + "/test_set"
if not os.path.exists(te):
    os.makedirs(te)
else:
    #remove previous folder and create new one
    shutil.rmtree(te)
    os.makedirs(te)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    trcpy = shutil.copy2(row['filename'], tr)
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_test.iterrows():
    tecpy = shutil.copy2(row['filename'], te)
    X_test.loc[X_test['filename']==row['filename'],'filename']=tecpy #change to directory where image is copiedb
# Out:
# C:\Users\user\anaconda3\envs\tensorflow25\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\user\anaconda3\envs\tensorflow25\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df2 = pd.concat([X_train,y_train],axis=1)
df2
# Out:
#                                               filename label
# 707  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 536  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 691  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 274  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 804  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# ..                                                 ...   ...
# 420  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 481  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 372  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 607  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 503  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
#
# [807 rows x 2 columns]

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# We will apply data augmentation of the dataset per epoch in order to increase the accuracy of the models

# %%
resnet50 = keras.applications.resnet50

imgdatagen = ImageDataGenerator(
        preprocessing_function = resnet50.preprocess_input,
        horizontal_flip = True,
        vertical_flip = True,
        rotation_range = 3,
    )

# %% [markdown]
# ## Create Plot History

# %% [markdown]
# Plot history will display the training and validation accuracy, and training and validation loss in every epoch in a fold.

# %%
def plot_history(history, yrange):
    '''Plot loss and accuracy as a function of the epoch,
    for the training and validation datasets.
    '''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    # Plot training and validation accuracy per epoch
    plt.plot(epochs, acc)
    plt.plot(epochs, val_acc)
    plt.title('Training and validation accuracy')
    plt.legend(['train_accuracy','val_accuracy'])
    plt.ylim(yrange)
    
    # Plot training and validation loss per epoch
    plt.figure()

    plt.plot(epochs, loss)
    plt.plot(epochs, val_loss)
    plt.title('Training and validation loss')
    plt.legend(['train_loss','val_loss'])
    
    plt.show()

# %% [markdown]
# ## Save Models

# %% [markdown]
# K-fold cross validation will be used in training the model.The set of models produced per fold will be saved in an automatic generated folder. Every training will generated another folder to save the new set of models.

# %%
save_cur = ""  #check if there is any saved_models folders

svnum = 0
svnum2 = 0

for x in os.listdir(gen_dir):
    if "saved_models" in x:
        save_cur = x
        if not save_cur == "":
            for word in save_cur.split("_"):
                if word.isdigit():
                    svnum2 = int(word)
                    if svnum < svnum2:
                        svnum = svnum2
            

#save_dir is where the created models using the current set of parameters are added        
if save_cur == "":
    save_dir = gen_dir + "/saved_models_1"
    #print(save_dir)
    os.makedirs(save_dir)
else:
    save_dir = gen_dir + "/saved_models_" + str(svnum + 1)
    #print(save_dir)
    os.makedirs(save_dir)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# The model will be based on ResNet50 Architecture. The classifier block will be changed to suit to our dataset.

# %%
conv_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

for layer in conv_model.layers:
    layer.trainable = False

"""
#print(conv_model.output_shape)
x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
x = keras.layers.Dense(512, activation='relu')(x)
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dropout(0.5)(x) #to further reduce overfitting
"""
x = keras.layers.Flatten()(conv_model.output)
#x = keras.layers.Dense(256, activation='relu')(x)
#x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
#x = keras.layers.BatchNormalization()(x)

x = keras.layers.Dropout(0.2)(x) #to further reduce overfitting

predictions = keras.layers.Dense(3, activation='softmax')(x)
full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

full_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100352)       0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          10035300    flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       dense[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            303         dropout[0][0]
# ==================================================================================================
# Total params: 33,633,415
# Trainable params: 10,045,703
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Parameters

# %% [markdown]
# We will initialize the model parameters here so that it is easier to change when training multiple times to get the ideal results.

# %%
#kfold parameters
Y = df2[['label']]
skf = StratifiedKFold(n_splits = 5, random_state = 42, shuffle = True)

#print(Y['label'].value_counts())
#print(Y['label'].unique())

#initialize parameters
VALIDATION_ACCURACY = []                          #store all validation_accuracy
VALIDATION_LOSS = []                              #store all validation_loss
image_dir = directory + "/ToBeUsed/train_set"     #where the train set images are stored
batch_size = 32                                   #batch size
fold_var = 1                                      #number of fold of the model
n = len(df2)                                      #number of data in train set
num_epochs = 20                                    #number of epochs
dim = (224,224)                                   #required dimensions for process_unit (ResNet50)
lr = 0.00001                                      #learning rate Adamax

# %% [markdown]
# ## Model Training

# %% [markdown]
# We will now train the model. K-fold cross validation is used to train the model.

# %%
for train_index, val_index in skf.split(np.zeros(n),Y):
    
    training_data = df2.iloc[train_index]
    validation_data = df2.iloc[val_index]
    
    train_data_generator = imgdatagen.flow_from_dataframe(training_data, directory = image_dir,
                               x_col = "filename", y_col = "label",
                              class_mode = "categorical", target_size = dim, batch_size = batch_size,
                                shuffle = False)
    valid_data_generator  = imgdatagen.flow_from_dataframe(validation_data, directory = image_dir,
                            x_col = "filename", y_col = "label",
                            class_mode = "categorical", target_size = dim, batch_size = batch_size,
                                shuffle = False)
    
    # COMPILE NEW MODEL
    full_model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.Adamax(learning_rate=lr),
                  metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

    # CREATE CALLBACKS
    checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "model_" + str(fold_var) + ".h5"), 
                            monitor='val_accuracy', verbose=1, 
                            save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    # There can be other callbacks, but just showing one because it involves the model name
    # This saves the best model
   
    print("Fold number " + str(fold_var))

    # FIT THE MODEL
    history = full_model.fit(train_data_generator,
                             epochs=num_epochs,
                             callbacks=callbacks_list,
                             validation_data=valid_data_generator)
    
    #PLOT HISTORY
    plot_history(history, yrange=(0.2,1))

    # LOAD BEST MODEL to evaluate the performance of the model
    full_model.load_weights(save_dir+"/model_"+str(fold_var)+".h5")
    
    results = full_model.evaluate(valid_data_generator)
    results = dict(zip(full_model.metrics_names,results))
    
    print(results)
    
    VALIDATION_ACCURACY.append(results['accuracy'])
    VALIDATION_LOSS.append(results['loss'])

    tf.keras.backend.clear_session()

    fold_var += 1
# Out:
# Found 645 validated image filenames belonging to 3 classes.
# Found 162 validated image filenames belonging to 3 classes.
# Fold number 1
# Epoch 1/20
# 21/21 [==============================] - 19s 643ms/step - loss: 1.0899 - accuracy: 0.5008 - val_loss: 0.8608 - val_accuracy: 0.5617
#
# Epoch 00001: val_accuracy improved from -inf to 0.56173, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# C:\Users\user\anaconda3\envs\tensorflow25\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/20
# 21/21 [==============================] - 10s 449ms/step - loss: 0.8656 - accuracy: 0.5845 - val_loss: 0.7288 - val_accuracy: 0.6235
#
# Epoch 00002: val_accuracy improved from 0.56173 to 0.62346, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 3/20
# 21/21 [==============================] - 10s 461ms/step - loss: 0.7682 - accuracy: 0.6481 - val_loss: 0.7141 - val_accuracy: 0.6914
#
# Epoch 00003: val_accuracy improved from 0.62346 to 0.69136, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 4/20
# 21/21 [==============================] - 11s 511ms/step - loss: 0.7166 - accuracy: 0.6729 - val_loss: 0.6604 - val_accuracy: 0.7346
#
# Epoch 00004: val_accuracy improved from 0.69136 to 0.73457, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 5/20
# 21/21 [==============================] - 10s 448ms/step - loss: 0.6764 - accuracy: 0.6992 - val_loss: 0.6426 - val_accuracy: 0.7284
#
# Epoch 00005: val_accuracy did not improve from 0.73457
# Epoch 6/20
# 21/21 [==============================] - 10s 470ms/step - loss: 0.6046 - accuracy: 0.7380 - val_loss: 0.6585 - val_accuracy: 0.7160
#
# Epoch 00006: val_accuracy did not improve from 0.73457
# Epoch 7/20
# 21/21 [==============================] - 10s 480ms/step - loss: 0.6134 - accuracy: 0.7333 - val_loss: 0.6007 - val_accuracy: 0.7469
#
# Epoch 00007: val_accuracy improved from 0.73457 to 0.74691, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 8/20
# 21/21 [==============================] - 11s 502ms/step - loss: 0.6101 - accuracy: 0.7380 - val_loss: 0.5895 - val_accuracy: 0.7469
#
# Epoch 00008: val_accuracy did not improve from 0.74691
# Epoch 9/20
# 21/21 [==============================] - 10s 495ms/step - loss: 0.5892 - accuracy: 0.7364 - val_loss: 0.5819 - val_accuracy: 0.7531
#
# Epoch 00009: val_accuracy improved from 0.74691 to 0.75309, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 10/20
# 21/21 [==============================] - 12s 547ms/step - loss: 0.5534 - accuracy: 0.7643 - val_loss: 0.5654 - val_accuracy: 0.7469
#
# Epoch 00010: val_accuracy did not improve from 0.75309
# Epoch 11/20
# 21/21 [==============================] - 12s 560ms/step - loss: 0.5311 - accuracy: 0.7891 - val_loss: 0.5376 - val_accuracy: 0.7901
#
# Epoch 00011: val_accuracy improved from 0.75309 to 0.79012, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 12/20
# 21/21 [==============================] - 11s 500ms/step - loss: 0.5289 - accuracy: 0.7907 - val_loss: 0.5289 - val_accuracy: 0.7778
#
# Epoch 00012: val_accuracy did not improve from 0.79012
# Epoch 13/20
# 21/21 [==============================] - 11s 525ms/step - loss: 0.5077 - accuracy: 0.7938 - val_loss: 0.4918 - val_accuracy: 0.7840
#
# Epoch 00013: val_accuracy did not improve from 0.79012
# Epoch 14/20
# 21/21 [==============================] - 12s 569ms/step - loss: 0.4820 - accuracy: 0.7969 - val_loss: 0.5177 - val_accuracy: 0.7963
#
# Epoch 00014: val_accuracy improved from 0.79012 to 0.79630, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 15/20
# 21/21 [==============================] - 11s 515ms/step - loss: 0.4605 - accuracy: 0.8202 - val_loss: 0.4786 - val_accuracy: 0.8148
#
# Epoch 00015: val_accuracy improved from 0.79630 to 0.81481, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 16/20
# 21/21 [==============================] - 10s 485ms/step - loss: 0.4801 - accuracy: 0.8031 - val_loss: 0.4764 - val_accuracy: 0.8395
#
# Epoch 00016: val_accuracy improved from 0.81481 to 0.83951, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_1.h5
# Epoch 17/20
# 21/21 [==============================] - 10s 466ms/step - loss: 0.4438 - accuracy: 0.8217 - val_loss: 0.4577 - val_accuracy: 0.7963
#
# Epoch 00017: val_accuracy did not improve from 0.83951
# Epoch 18/20
# 21/21 [==============================] - 12s 574ms/step - loss: 0.4422 - accuracy: 0.8248 - val_loss: 0.4330 - val_accuracy: 0.8333
#
# Epoch 00018: val_accuracy did not improve from 0.83951
# Epoch 19/20
# 21/21 [==============================] - 11s 510ms/step - loss: 0.4407 - accuracy: 0.8310 - val_loss: 0.4305 - val_accuracy: 0.8210
#
# Epoch 00019: val_accuracy did not improve from 0.83951
# Epoch 20/20
# 21/21 [==============================] - 12s 555ms/step - loss: 0.4307 - accuracy: 0.8233 - val_loss: 0.4456 - val_accuracy: 0.8025
#
# Epoch 00020: val_accuracy did not improve from 0.83951
# 6/6 [==============================] - 2s 318ms/step - loss: 0.4584 - accuracy: 0.8333
# {'loss': 0.45842644572257996, 'accuracy': 0.8333333134651184}
# Found 645 validated image filenames belonging to 3 classes.
# Found 162 validated image filenames belonging to 3 classes.
# Fold number 2
# Epoch 1/20
# 21/21 [==============================] - 17s 683ms/step - loss: 0.5194 - accuracy: 0.7783 - val_loss: 0.4014 - val_accuracy: 0.8704
#
# Epoch 00001: val_accuracy improved from -inf to 0.87037, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_2.h5
# Epoch 2/20
# 21/21 [==============================] - 12s 560ms/step - loss: 0.4453 - accuracy: 0.8248 - val_loss: 0.3787 - val_accuracy: 0.8580
#
# Epoch 00002: val_accuracy did not improve from 0.87037
# Epoch 3/20
# 21/21 [==============================] - 12s 568ms/step - loss: 0.4183 - accuracy: 0.8527 - val_loss: 0.3827 - val_accuracy: 0.8519
#
# Epoch 00003: val_accuracy did not improve from 0.87037
# Epoch 4/20
# 21/21 [==============================] - 13s 617ms/step - loss: 0.4063 - accuracy: 0.8496 - val_loss: 0.3880 - val_accuracy: 0.8272
#
# Epoch 00004: val_accuracy did not improve from 0.87037
# Epoch 5/20
# 21/21 [==============================] - 11s 545ms/step - loss: 0.4065 - accuracy: 0.8388 - val_loss: 0.3663 - val_accuracy: 0.8519
#
# Epoch 00005: val_accuracy did not improve from 0.87037
# Epoch 6/20
# 21/21 [==============================] - 11s 519ms/step - loss: 0.3937 - accuracy: 0.8527 - val_loss: 0.3284 - val_accuracy: 0.8889
#
# Epoch 00006: val_accuracy improved from 0.87037 to 0.88889, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_2.h5
# Epoch 7/20
# 21/21 [==============================] - 11s 504ms/step - loss: 0.3848 - accuracy: 0.8636 - val_loss: 0.3619 - val_accuracy: 0.8519
#
# Epoch 00007: val_accuracy did not improve from 0.88889
# Epoch 8/20
# 21/21 [==============================] - 11s 496ms/step - loss: 0.3505 - accuracy: 0.8605 - val_loss: 0.3842 - val_accuracy: 0.8395
#
# Epoch 00008: val_accuracy did not improve from 0.88889
# Epoch 9/20
# 21/21 [==============================] - 11s 533ms/step - loss: 0.3376 - accuracy: 0.8713 - val_loss: 0.3569 - val_accuracy: 0.8580
#
# Epoch 00009: val_accuracy did not improve from 0.88889
# Epoch 10/20
# 21/21 [==============================] - 14s 643ms/step - loss: 0.3127 - accuracy: 0.8915 - val_loss: 0.3453 - val_accuracy: 0.8457
#
# Epoch 00010: val_accuracy did not improve from 0.88889
# Epoch 11/20
# 21/21 [==============================] - 12s 560ms/step - loss: 0.3233 - accuracy: 0.8744 - val_loss: 0.3259 - val_accuracy: 0.8642
#
# Epoch 00011: val_accuracy did not improve from 0.88889
# Epoch 12/20
# 21/21 [==============================] - 13s 575ms/step - loss: 0.3256 - accuracy: 0.8775 - val_loss: 0.3103 - val_accuracy: 0.8827
#
# Epoch 00012: val_accuracy did not improve from 0.88889
# Epoch 13/20
# 21/21 [==============================] - 12s 568ms/step - loss: 0.3468 - accuracy: 0.8698 - val_loss: 0.3325 - val_accuracy: 0.8519
#
# Epoch 00013: val_accuracy did not improve from 0.88889
# Epoch 14/20
# 21/21 [==============================] - 11s 530ms/step - loss: 0.3047 - accuracy: 0.8930 - val_loss: 0.3194 - val_accuracy: 0.8704
#
# Epoch 00014: val_accuracy did not improve from 0.88889
# Epoch 15/20
# 21/21 [==============================] - 11s 536ms/step - loss: 0.3143 - accuracy: 0.8884 - val_loss: 0.3096 - val_accuracy: 0.8827
#
# Epoch 00015: val_accuracy did not improve from 0.88889
# Epoch 16/20
# 21/21 [==============================] - 12s 551ms/step - loss: 0.3005 - accuracy: 0.8930 - val_loss: 0.3058 - val_accuracy: 0.8642
#
# Epoch 00016: val_accuracy did not improve from 0.88889
# Epoch 17/20
# 21/21 [==============================] - 11s 515ms/step - loss: 0.2805 - accuracy: 0.9008 - val_loss: 0.3012 - val_accuracy: 0.8457
#
# Epoch 00017: val_accuracy did not improve from 0.88889
# Epoch 18/20
# 21/21 [==============================] - 10s 477ms/step - loss: 0.3072 - accuracy: 0.8698 - val_loss: 0.2998 - val_accuracy: 0.8765
#
# Epoch 00018: val_accuracy did not improve from 0.88889
# Epoch 19/20
# 21/21 [==============================] - 10s 488ms/step - loss: 0.2924 - accuracy: 0.8961 - val_loss: 0.2837 - val_accuracy: 0.9012
#
# Epoch 00019: val_accuracy improved from 0.88889 to 0.90123, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_2.h5
# Epoch 20/20
# 21/21 [==============================] - 12s 579ms/step - loss: 0.2723 - accuracy: 0.8930 - val_loss: 0.2840 - val_accuracy: 0.9012
#
# Epoch 00020: val_accuracy did not improve from 0.90123
# 6/6 [==============================] - 2s 337ms/step - loss: 0.2992 - accuracy: 0.8642
# {'loss': 0.2992403507232666, 'accuracy': 0.8641975522041321}
# Found 646 validated image filenames belonging to 3 classes.
# Found 161 validated image filenames belonging to 3 classes.
# Fold number 3
# Epoch 1/20
# 21/21 [==============================] - 16s 628ms/step - loss: 0.3379 - accuracy: 0.8591 - val_loss: 0.2130 - val_accuracy: 0.9317
#
# Epoch 00001: val_accuracy improved from -inf to 0.93168, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_3.h5
# Epoch 2/20
# 21/21 [==============================] - 12s 550ms/step - loss: 0.2996 - accuracy: 0.8854 - val_loss: 0.1686 - val_accuracy: 0.9503
#
# Epoch 00002: val_accuracy improved from 0.93168 to 0.95031, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_3.h5
# Epoch 3/20
# 21/21 [==============================] - 10s 477ms/step - loss: 0.2787 - accuracy: 0.8901 - val_loss: 0.1836 - val_accuracy: 0.9627
#
# Epoch 00003: val_accuracy improved from 0.95031 to 0.96273, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_3.h5
# Epoch 4/20
# 21/21 [==============================] - 12s 545ms/step - loss: 0.2925 - accuracy: 0.8885 - val_loss: 0.1881 - val_accuracy: 0.9689
#
# Epoch 00004: val_accuracy improved from 0.96273 to 0.96894, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_3.h5
# Epoch 5/20
# 21/21 [==============================] - 11s 533ms/step - loss: 0.2691 - accuracy: 0.8947 - val_loss: 0.1964 - val_accuracy: 0.9565
#
# Epoch 00005: val_accuracy did not improve from 0.96894
# Epoch 6/20
# 21/21 [==============================] - 10s 487ms/step - loss: 0.2711 - accuracy: 0.9009 - val_loss: 0.1911 - val_accuracy: 0.9441
#
# Epoch 00006: val_accuracy did not improve from 0.96894
# Epoch 7/20
# 21/21 [==============================] - 11s 536ms/step - loss: 0.2679 - accuracy: 0.9040 - val_loss: 0.1993 - val_accuracy: 0.9193
#
# Epoch 00007: val_accuracy did not improve from 0.96894
# Epoch 8/20
# 21/21 [==============================] - 10s 476ms/step - loss: 0.2442 - accuracy: 0.9118 - val_loss: 0.1724 - val_accuracy: 0.9565
#
# Epoch 00008: val_accuracy did not improve from 0.96894
# Epoch 9/20
# 21/21 [==============================] - 11s 521ms/step - loss: 0.2581 - accuracy: 0.8916 - val_loss: 0.1651 - val_accuracy: 0.9627
#
# Epoch 00009: val_accuracy did not improve from 0.96894
# Epoch 10/20
# 21/21 [==============================] - 13s 599ms/step - loss: 0.2515 - accuracy: 0.9118 - val_loss: 0.1633 - val_accuracy: 0.9689
#
# Epoch 00010: val_accuracy did not improve from 0.96894
# Epoch 11/20
# 21/21 [==============================] - 11s 538ms/step - loss: 0.2460 - accuracy: 0.9195 - val_loss: 0.1733 - val_accuracy: 0.9441
#
# Epoch 00011: val_accuracy did not improve from 0.96894
# Epoch 12/20
# 21/21 [==============================] - 11s 520ms/step - loss: 0.2431 - accuracy: 0.9040 - val_loss: 0.1794 - val_accuracy: 0.9689
#
# Epoch 00012: val_accuracy did not improve from 0.96894
# Epoch 13/20
# 21/21 [==============================] - 13s 604ms/step - loss: 0.2460 - accuracy: 0.9133 - val_loss: 0.1650 - val_accuracy: 0.9689
#
# Epoch 00013: val_accuracy did not improve from 0.96894
# Epoch 14/20
# 21/21 [==============================] - 10s 488ms/step - loss: 0.2339 - accuracy: 0.9303 - val_loss: 0.1483 - val_accuracy: 0.9752
#
# Epoch 00014: val_accuracy improved from 0.96894 to 0.97516, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_3.h5
# Epoch 15/20
# 21/21 [==============================] - 10s 488ms/step - loss: 0.2262 - accuracy: 0.9319 - val_loss: 0.1537 - val_accuracy: 0.9689
#
# Epoch 00015: val_accuracy did not improve from 0.97516
# Epoch 16/20
# 21/21 [==============================] - 11s 556ms/step - loss: 0.2295 - accuracy: 0.9288 - val_loss: 0.1650 - val_accuracy: 0.9627
#
# Epoch 00016: val_accuracy did not improve from 0.97516
# Epoch 17/20
# 21/21 [==============================] - 11s 514ms/step - loss: 0.2120 - accuracy: 0.9365 - val_loss: 0.1494 - val_accuracy: 0.9689
#
# Epoch 00017: val_accuracy did not improve from 0.97516
# Epoch 18/20
# 21/21 [==============================] - 11s 522ms/step - loss: 0.2100 - accuracy: 0.9350 - val_loss: 0.1564 - val_accuracy: 0.9565
#
# Epoch 00018: val_accuracy did not improve from 0.97516
# Epoch 19/20
# 21/21 [==============================] - 10s 493ms/step - loss: 0.2173 - accuracy: 0.9319 - val_loss: 0.1600 - val_accuracy: 0.9441
#
# Epoch 00019: val_accuracy did not improve from 0.97516
# Epoch 20/20
# 21/21 [==============================] - 12s 562ms/step - loss: 0.1994 - accuracy: 0.9272 - val_loss: 0.1620 - val_accuracy: 0.9627
#
# Epoch 00020: val_accuracy did not improve from 0.97516
# 6/6 [==============================] - 3s 424ms/step - loss: 0.1535 - accuracy: 0.9752
# {'loss': 0.15353041887283325, 'accuracy': 0.9751552939414978}
# Found 646 validated image filenames belonging to 3 classes.
# Found 161 validated image filenames belonging to 3 classes.
# Fold number 4
# Epoch 1/20
# 21/21 [==============================] - 16s 599ms/step - loss: 0.2521 - accuracy: 0.9040 - val_loss: 0.2424 - val_accuracy: 0.9193
#
# Epoch 00001: val_accuracy improved from -inf to 0.91925, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_4.h5
# Epoch 2/20
# 21/21 [==============================] - 11s 530ms/step - loss: 0.2227 - accuracy: 0.9226 - val_loss: 0.1821 - val_accuracy: 0.9441
#
# Epoch 00002: val_accuracy improved from 0.91925 to 0.94410, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_4.h5
# Epoch 3/20
# 21/21 [==============================] - 10s 465ms/step - loss: 0.2154 - accuracy: 0.9195 - val_loss: 0.1964 - val_accuracy: 0.9317
#
# Epoch 00003: val_accuracy did not improve from 0.94410
# Epoch 4/20
# 21/21 [==============================] - 10s 489ms/step - loss: 0.1900 - accuracy: 0.9319 - val_loss: 0.1896 - val_accuracy: 0.9503
#
# Epoch 00004: val_accuracy improved from 0.94410 to 0.95031, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_4.h5
# Epoch 5/20
# 21/21 [==============================] - 13s 608ms/step - loss: 0.1993 - accuracy: 0.9272 - val_loss: 0.2032 - val_accuracy: 0.9255
#
# Epoch 00005: val_accuracy did not improve from 0.95031
# Epoch 6/20
# 21/21 [==============================] - 11s 507ms/step - loss: 0.1950 - accuracy: 0.9319 - val_loss: 0.1942 - val_accuracy: 0.9441
#
# Epoch 00006: val_accuracy did not improve from 0.95031
# Epoch 7/20
# 21/21 [==============================] - 11s 560ms/step - loss: 0.1760 - accuracy: 0.9381 - val_loss: 0.1914 - val_accuracy: 0.9565
#
# Epoch 00007: val_accuracy improved from 0.95031 to 0.95652, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_4.h5
# Epoch 8/20
# 21/21 [==============================] - 11s 513ms/step - loss: 0.1756 - accuracy: 0.9520 - val_loss: 0.1758 - val_accuracy: 0.9503
#
# Epoch 00008: val_accuracy did not improve from 0.95652
# Epoch 9/20
# 21/21 [==============================] - 13s 631ms/step - loss: 0.1627 - accuracy: 0.9505 - val_loss: 0.1657 - val_accuracy: 0.9689
#
# Epoch 00009: val_accuracy improved from 0.95652 to 0.96894, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_4.h5
# Epoch 10/20
# 21/21 [==============================] - 12s 539ms/step - loss: 0.1516 - accuracy: 0.9582 - val_loss: 0.1809 - val_accuracy: 0.9627
#
# Epoch 00010: val_accuracy did not improve from 0.96894
# Epoch 11/20
# 21/21 [==============================] - 10s 443ms/step - loss: 0.1764 - accuracy: 0.9412 - val_loss: 0.1668 - val_accuracy: 0.9627
#
# Epoch 00011: val_accuracy did not improve from 0.96894
# Epoch 12/20
# 21/21 [==============================] - 12s 566ms/step - loss: 0.1651 - accuracy: 0.9489 - val_loss: 0.1820 - val_accuracy: 0.9503
#
# Epoch 00012: val_accuracy did not improve from 0.96894
# Epoch 13/20
# 21/21 [==============================] - 12s 583ms/step - loss: 0.1592 - accuracy: 0.9520 - val_loss: 0.1784 - val_accuracy: 0.9689
#
# Epoch 00013: val_accuracy did not improve from 0.96894
# Epoch 14/20
# 21/21 [==============================] - 11s 531ms/step - loss: 0.1547 - accuracy: 0.9505 - val_loss: 0.1890 - val_accuracy: 0.9379
#
# Epoch 00014: val_accuracy did not improve from 0.96894
# Epoch 15/20
# 21/21 [==============================] - 12s 546ms/step - loss: 0.1658 - accuracy: 0.9489 - val_loss: 0.1763 - val_accuracy: 0.9565
#
# Epoch 00015: val_accuracy did not improve from 0.96894
# Epoch 16/20
# 21/21 [==============================] - 11s 506ms/step - loss: 0.1642 - accuracy: 0.9443 - val_loss: 0.1793 - val_accuracy: 0.9317
#
# Epoch 00016: val_accuracy did not improve from 0.96894
# Epoch 17/20
# 21/21 [==============================] - 10s 462ms/step - loss: 0.1407 - accuracy: 0.9489 - val_loss: 0.1653 - val_accuracy: 0.9565
#
# Epoch 00017: val_accuracy did not improve from 0.96894
# Epoch 18/20
# 21/21 [==============================] - 10s 482ms/step - loss: 0.1587 - accuracy: 0.9505 - val_loss: 0.1656 - val_accuracy: 0.9565
#
# Epoch 00018: val_accuracy did not improve from 0.96894
# Epoch 19/20
# 21/21 [==============================] - 12s 568ms/step - loss: 0.1477 - accuracy: 0.9567 - val_loss: 0.1719 - val_accuracy: 0.9441
#
# Epoch 00019: val_accuracy did not improve from 0.96894
# Epoch 20/20
# 21/21 [==============================] - 10s 486ms/step - loss: 0.1518 - accuracy: 0.9551 - val_loss: 0.1656 - val_accuracy: 0.9627
#
# Epoch 00020: val_accuracy did not improve from 0.96894
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1838 - accuracy: 0.9565
# {'loss': 0.1838380992412567, 'accuracy': 0.95652174949646}
# Found 646 validated image filenames belonging to 3 classes.
# Found 161 validated image filenames belonging to 3 classes.
# Fold number 5
# Epoch 1/20
# 21/21 [==============================] - 15s 567ms/step - loss: 0.1907 - accuracy: 0.9350 - val_loss: 0.1229 - val_accuracy: 0.9752
#
# Epoch 00001: val_accuracy improved from -inf to 0.97516, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_5.h5
# Epoch 2/20
# 21/21 [==============================] - 9s 437ms/step - loss: 0.1855 - accuracy: 0.9303 - val_loss: 0.1104 - val_accuracy: 0.9752
#
# Epoch 00002: val_accuracy did not improve from 0.97516
# Epoch 3/20
# 21/21 [==============================] - 9s 438ms/step - loss: 0.1851 - accuracy: 0.9396 - val_loss: 0.1236 - val_accuracy: 0.9565
#
# Epoch 00003: val_accuracy did not improve from 0.97516
# Epoch 4/20
# 21/21 [==============================] - 10s 491ms/step - loss: 0.1640 - accuracy: 0.9536 - val_loss: 0.0901 - val_accuracy: 1.0000
#
# Epoch 00004: val_accuracy improved from 0.97516 to 1.00000, saving model to C:/Users/user/Desktop/Model/saved_models_3\model_5.h5
# Epoch 5/20
# 21/21 [==============================] - 12s 572ms/step - loss: 0.1682 - accuracy: 0.9381 - val_loss: 0.1234 - val_accuracy: 0.9689
#
# Epoch 00005: val_accuracy did not improve from 1.00000
# Epoch 6/20
# 21/21 [==============================] - 10s 466ms/step - loss: 0.1638 - accuracy: 0.9505 - val_loss: 0.1180 - val_accuracy: 0.9752
#
# Epoch 00006: val_accuracy did not improve from 1.00000
# Epoch 7/20
# 21/21 [==============================] - 10s 474ms/step - loss: 0.1544 - accuracy: 0.9551 - val_loss: 0.1198 - val_accuracy: 0.9689
#
# Epoch 00007: val_accuracy did not improve from 1.00000
# Epoch 8/20
# 21/21 [==============================] - 10s 458ms/step - loss: 0.1686 - accuracy: 0.9520 - val_loss: 0.1048 - val_accuracy: 0.9814
#
# Epoch 00008: val_accuracy did not improve from 1.00000
# Epoch 9/20
# 21/21 [==============================] - 10s 464ms/step - loss: 0.1706 - accuracy: 0.9412 - val_loss: 0.1088 - val_accuracy: 0.9814
#
# Epoch 00009: val_accuracy did not improve from 1.00000
# Epoch 10/20
# 21/21 [==============================] - 11s 519ms/step - loss: 0.1689 - accuracy: 0.9458 - val_loss: 0.1174 - val_accuracy: 0.9689
#
# Epoch 00010: val_accuracy did not improve from 1.00000
# Epoch 11/20
# 21/21 [==============================] - 11s 531ms/step - loss: 0.1416 - accuracy: 0.9628 - val_loss: 0.1125 - val_accuracy: 0.9876
#
# Epoch 00011: val_accuracy did not improve from 1.00000
# Epoch 12/20
# 21/21 [==============================] - 11s 509ms/step - loss: 0.1459 - accuracy: 0.9582 - val_loss: 0.1148 - val_accuracy: 0.9752
#
# Epoch 00012: val_accuracy did not improve from 1.00000
# Epoch 13/20
# 21/21 [==============================] - 10s 477ms/step - loss: 0.1446 - accuracy: 0.9598 - val_loss: 0.1052 - val_accuracy: 0.9814
#
# Epoch 00013: val_accuracy did not improve from 1.00000
# Epoch 14/20
# 21/21 [==============================] - 11s 507ms/step - loss: 0.1514 - accuracy: 0.9644 - val_loss: 0.1180 - val_accuracy: 0.9752
#
# Epoch 00014: val_accuracy did not improve from 1.00000
# Epoch 15/20
# 21/21 [==============================] - 10s 476ms/step - loss: 0.1465 - accuracy: 0.9644 - val_loss: 0.0986 - val_accuracy: 0.9814
#
# Epoch 00015: val_accuracy did not improve from 1.00000
# Epoch 16/20
# 21/21 [==============================] - 12s 551ms/step - loss: 0.1397 - accuracy: 0.9613 - val_loss: 0.1004 - val_accuracy: 0.9814
#
# Epoch 00016: val_accuracy did not improve from 1.00000
# Epoch 17/20
# 21/21 [==============================] - 10s 445ms/step - loss: 0.1296 - accuracy: 0.9598 - val_loss: 0.1150 - val_accuracy: 0.9689
#
# Epoch 00017: val_accuracy did not improve from 1.00000
# Epoch 18/20
# 21/21 [==============================] - 10s 452ms/step - loss: 0.1360 - accuracy: 0.9505 - val_loss: 0.1016 - val_accuracy: 0.9814
#
# Epoch 00018: val_accuracy did not improve from 1.00000
# Epoch 19/20
# 21/21 [==============================] - 10s 466ms/step - loss: 0.1354 - accuracy: 0.9598 - val_loss: 0.0866 - val_accuracy: 0.9876
#
# Epoch 00019: val_accuracy did not improve from 1.00000
# Epoch 20/20
# 21/21 [==============================] - 9s 438ms/step - loss: 0.1252 - accuracy: 0.9737 - val_loss: 0.1014 - val_accuracy: 0.9814
#
# Epoch 00020: val_accuracy did not improve from 1.00000
# 6/6 [==============================] - 2s 287ms/step - loss: 0.1299 - accuracy: 0.9565
# {'loss': 0.12993308901786804, 'accuracy': 0.95652174949646}

# %% [markdown]
# ## Kfold Evaluation Results

# %% [markdown]
# Below are the validation accuracy and validation loss per fold and their average.

# %%
print("Validation Accuracy of All Folds:")
n = 1
for x in VALIDATION_ACCURACY:
    print("Fold "+ str(n) +" Accuracy:",x)
    n=n+1    
print("Mean Validation Accuracy: " + str(np.mean(VALIDATION_ACCURACY)))

print("")

print("Validation Loss of All Folds:")
n=1
for x in VALIDATION_LOSS:
    print("Fold "+ str(n) +" Loss:",x)
    n=n+1    
print("Mean Validation Loss: " + str(np.mean(VALIDATION_LOSS)))
# Out:
# Validation Accuracy of All Folds:
# Fold 1 Accuracy: 0.8333333134651184
# Fold 2 Accuracy: 0.8641975522041321
# Fold 3 Accuracy: 0.9751552939414978
# Fold 4 Accuracy: 0.95652174949646
# Fold 5 Accuracy: 0.95652174949646
# Mean Validation Accuracy: 0.9171459317207337
#
# Validation Loss of All Folds:
# Fold 1 Loss: 0.45842644572257996
# Fold 2 Loss: 0.2992403507232666
# Fold 3 Loss: 0.15353041887283325
# Fold 4 Loss: 0.1838380992412567
# Fold 5 Loss: 0.12993308901786804
# Mean Validation Loss: 0.2449936807155609

# %%
bobo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17968/2698370793.py in <module>
# ----> 1 bobo
#
# NameError: name 'bobo' is not defined

# %% [markdown]
# ## Model Prediction

# %% [markdown]
# Load the images in the test set and predict what class it is by using the model. There are three values of probability. The one with the highest probability is the predicted class of the image. The order of classes is [0 1 2].

# %%
#load the weights of bet model
model_dir = gen_dir + "/saved_models_1/model_4.h5"
full_model.load_weights(model_dir)

test_set = directory + "/ToBeUsed/test_set"

testX = []

for img_path in X_test['filename']:
    img = im.load_img(img_path, target_size=(224,224))
    x = im.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    x = x.reshape(224,224,3)
    testX.append(x)

testX = np.array(testX)    
        
# predict probabilities for test set, y_test
yhat_probs = full_model.predict(testX, verbose=0)

# predict crisp classes for test set
yhat_classes = yhat_probs.argmax(axis=-1)

print(yhat_probs)
print("")
print(yhat_classes)
# Out:
# [[0.00534276 0.9822634  0.0123938 ]
#  [0.69961673 0.21452521 0.08585803]
#  [0.05120721 0.60745347 0.3413393 ]
#  [0.6154488  0.34783718 0.03671404]
#  [0.00452316 0.22987463 0.7656022 ]
#  [0.9773817  0.01296092 0.00965746]
#  [0.00908722 0.9793423  0.01157053]
#  [0.8487592  0.07868916 0.07255157]
#  [0.00884914 0.91272    0.07843079]
#  [0.02075688 0.42968595 0.5495571 ]
#  [0.00425542 0.9589601  0.0367845 ]
#  [0.52748734 0.112877   0.35963568]
#  [0.01760916 0.13824725 0.8441436 ]
#  [0.02938303 0.40914962 0.56146735]
#  [0.87960887 0.06744947 0.05294159]
#  [0.9448794  0.03515993 0.0199607 ]
#  [0.99156463 0.00533776 0.0030976 ]
#  [0.00807198 0.8356508  0.1562772 ]
#  [0.025312   0.16477756 0.8099104 ]
#  [0.9149397  0.07162242 0.01343786]
#  [0.9873948  0.00879074 0.00381443]
#  [0.29313686 0.2692154  0.43764776]
#  [0.01949415 0.29536548 0.6851404 ]
#  [0.05062536 0.7984979  0.15087667]
#  [0.01398167 0.38405108 0.6019672 ]
#  [0.84557545 0.05086189 0.10356272]
#  [0.01270536 0.12764995 0.8596447 ]
#  [0.00876795 0.978693   0.01253904]
#  [0.03335059 0.63026893 0.33638045]
#  [0.0160888  0.27789715 0.7060141 ]
#  [0.02379963 0.2872843  0.6889161 ]
#  [0.9351224  0.02217429 0.04270329]
#  [0.01714427 0.7627907  0.22006509]
#  [0.00852342 0.97193146 0.01954523]
#  [0.00568623 0.97780985 0.01650389]
#  [0.86402553 0.09115195 0.04482248]
#  [0.00849671 0.9383423  0.05316103]
#  [0.08873771 0.74250335 0.168759  ]
#  [0.80504805 0.16135912 0.03359284]
#  [0.8815557  0.06326544 0.05517884]
#  [0.30199373 0.22184584 0.47616044]
#  [0.00852342 0.97193146 0.01954523]
#  [0.01111019 0.29030448 0.6985853 ]
#  [0.02464395 0.59638983 0.3789662 ]
#  [0.00513918 0.9795538  0.01530702]
#  [0.02046299 0.910234   0.06930305]
#  [0.01415087 0.8437639  0.14208528]
#  [0.91523147 0.07007673 0.01469185]
#  [0.00738478 0.42906603 0.5635491 ]
#  [0.01456565 0.33700833 0.648426  ]
#  [0.7001728  0.12209629 0.17773096]
#  [0.01330874 0.26845378 0.71823746]
#  [0.8517785  0.0735824  0.07463901]
#  [0.00538462 0.06666973 0.9279456 ]
#  [0.10772382 0.19679894 0.6954773 ]
#  [0.00819282 0.43460515 0.55720204]
#  [0.96142215 0.02910032 0.00947761]
#  [0.1109755  0.588478   0.30054653]
#  [0.01698865 0.3303393  0.65267205]
#  [0.9730014  0.01785112 0.00914754]
#  [0.50335103 0.3589898  0.13765919]
#  [0.9073088  0.07829712 0.01439412]
#  [0.28753567 0.38061285 0.33185145]
#  [0.65505606 0.27141267 0.07353129]
#  [0.01093152 0.75218016 0.23688826]
#  [0.0038844  0.9919579  0.0041577 ]
#  [0.0225688  0.90149057 0.0759406 ]
#  [0.00418369 0.03083629 0.96498   ]
#  [0.06510756 0.6062591  0.3286333 ]
#  [0.08517452 0.44919974 0.46562567]
#  [0.01234167 0.01434292 0.97331536]
#  [0.44547832 0.37701488 0.1775068 ]
#  [0.8212916  0.08079597 0.0979123 ]
#  [0.09434411 0.17383437 0.73182154]
#  [0.53124833 0.0956097  0.37314197]
#  [0.88900703 0.08554627 0.02544666]
#  [0.01058121 0.08862697 0.9007919 ]
#  [0.97537214 0.02089656 0.00373127]
#  [0.2975776  0.09626228 0.60616016]
#  [0.01315268 0.7011921  0.28565517]
#  [0.00568623 0.97780985 0.01650389]
#  [0.0150731  0.85464853 0.13027827]
#  [0.93139344 0.05406376 0.01454286]
#  [0.8487592  0.07868916 0.07255157]
#  [0.03335199 0.31085745 0.65579057]
#  [0.00961279 0.5743543  0.41603288]
#  [0.8407679  0.08340015 0.07583194]
#  [0.8286988  0.08485155 0.08644966]
#  [0.02868924 0.6955233  0.2757874 ]
#  [0.6833308  0.19730596 0.1193632 ]]
#
# [1 0 1 0 2 0 1 0 1 2 1 0 2 2 0 0 0 1 2 0 0 2 2 1 2 0 2 1 1 2 2 0 1 1 1 0 1
#  1 0 0 2 1 2 1 1 1 1 0 2 2 0 2 0 2 2 2 0 1 2 0 0 0 1 0 1 1 1 2 1 2 2 0 0 2
#  0 0 2 0 2 1 1 1 0 0 2 1 0 0 1 0]

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# The prediction will be used in order to do model evaluation.

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
#yhat_classes is already 1d

#make the labels to integer to get the model metrics
yt = pd.to_numeric(y_test['label'])

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(yt, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(yt, yhat_classes, average="weighted")
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(yt, yhat_classes, average="weighted")
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(yt, yhat_classes, average="weighted")
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.888889
# Precision: 0.888215
# Recall: 0.888889
# F1 score: 0.887051

# %%
matrix = confusion_matrix(yt, yhat_classes)
df_cm = pd.DataFrame(matrix, range(matrix.shape[0]), range(matrix.shape[1]))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()

# %% [markdown]
# ## Validating Misclassified Images

# %%
yhat_probs.shape, y_test.shape
# Out:
# ((90,), (90, 1))

# %% [markdown]
# Note that we did a preprocessing on the images. We will use the image directories in the X_test and read it using cv2. This will convert the images into a numpy array. To convert back to its original rgb image form, we will use cv2.cvtColor.

# %%
testX2 = []

for img_path in X_test['filename']:
    img = cv2.imread(img_path)
    testX2.append(img)

testX2 = np.array(testX2)

# %%
correct = np.where(yhat_classes==yt)[0]

print ("Found %d correct labels" % len(correct))

for i, correct in enumerate(correct[:9]):
    plt.figure(figsize=(10,10))
    #plt.subplot(3,3,i+1)
    RGB_img = cv2.cvtColor(testX2[correct], cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img) #, interpolation='nearest') #, cmap='gray')
    plt.title("Predict {0}, Class {1}".format(str(yhat_classes[correct]),str(yt.values[correct])))
    plt.tight_layout()
# Out:
# Found 80 correct labels

# %%
incorrect = np.where(yhat_classes!=yt)[0]
print ("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[:9]):
    plt.figure(figsize=(10,10))
    #plt.subplot(3,3,i+1)
    RGB_img = cv2.cvtColor(testX2[incorrect], cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img) #, interpolation='nearest') #, cmap='gray')
    plt.title("Predicted {0}, Class {1}".format(str(yhat_classes[incorrect]), str(yt.values[incorrect])))
    plt.tight_layout()
# Out:
# Found 10 incorrect labels
