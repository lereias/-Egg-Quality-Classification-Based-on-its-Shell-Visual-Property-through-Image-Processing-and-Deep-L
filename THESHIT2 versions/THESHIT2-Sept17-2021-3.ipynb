# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8471554236006595397
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2912380519
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13506204049084539420
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Transfer Learning Thesis

# %% [markdown]
# https://thedatafrog.com/en/articles/image-recognition-transfer-learning/

# %% [markdown]
# ## Imports

# %%
# openCV to concatenate
import cv2

# for image name
import random

# define and move to dataset directory
import os
# the directory where the data is stored
directory = "C:/Users/user/Desktop/Dataset"
os.chdir(directory)

# duplicate combined image to other directory
import shutil

#for stopping code if not the right amount of images
import sys

#histograph/confusion matrix
import matplotlib.pyplot as plt
import seaborn as sn
#import matplotlib.image as img

#model creation
import tensorflow.keras as keras

import numpy as np

# data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#k-fold cross validation
import pandas as pd                                     #store all images and their class/label
from sklearn.model_selection import StratifiedKFold     
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split    #split the dataset to train-test
import tensorflow as tf                                 #for callbacks

#for model evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
#from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# ## Crop Image to Reduce Background

# %% [markdown]
# We shall crop the image in order to reduce the background so that the egg in the image would be more focused on. The cropping procedure will not affect the size diference of the eggs from one another.

# %% [markdown]
# https://stackoverflow.com/questions/61927877/how-to-crop-opencv-image-from-center

# %%
tadirect = directory + "/TwoAngleEggs"
#crop width and height
width = 3600
height = 3600

for x in os.listdir(tadirect):
    directory2 = ""
    directory2 = tadirect + "/" + x     #images to be cropped
    #print(directory2)
    
    curdir = os.listdir(directory2)
    
    for z in curdir:
        tempim1 = directory2 + "/" + z
        
        im1 = cv2.imread(tempim1)
        
        center = (im1.shape[0] / 2, im1.shape[1] / 2)
        #print(center)
        x = center[0] - width/2
        y = center[1] - height/2

        #print(x)
        #print(y)
        
        #slicing to perform cropping
        print("cropping " + z + " in dimensions (" + str(width) + "," + str(height) + ")")
        crop_img = im1[int(y):int(y+width), int(x):int(x+height)]
        
        #save and replace the image
        cv2.imwrite(tempim1, crop_img)
        print("crop finish " + z)

print("\nAll finished")

# %% [markdown]
# ## Concatenate two angles of egg

# %% [markdown]
# two images of an egg are taken, one at its front and one at its back.

# %%
#"""
tadirect = directory + "/TwoAngleEggs"

#check if there is the right amount of images (1 for each angle of egg)
for w in os.listdir(tadirect):
    directory2 = ""
    directory2 = tadirect + "/" + w
    curdir = os.listdir(directory2)

    #number of files in directory
    filecnt = len([name for name in curdir])
    
    if filecnt%2 == 1:
        print("ERROR (" + w + "): Incorrect number of images.")
        sys.exit()

for x in os.listdir(tadirect):
    directory2 = ""
    directory2 = tadirect + "/" + x                            #where the two images of two angles of egg is stored
    directory3 = directory  + "/CombinedTwoAngleEggs/" + x     #where to put the combined image of the angles
    #directory4 = directory  + "/ToBeUsed/" + x                 #where combined and data augmented of the image are stored
    #print(directory2)
    
    curdir = os.listdir(directory2)
    #print(curdir)
    
    #number of files in directory
    filecnt = len([name for name in curdir])
    
    for y in range(filecnt):
        if y%2 == 0:
            #print(directory2 + "/" + curdir[y])
            tempim1 = directory2 + "/" + curdir[y]
            im1 = cv2.imread(tempim1)
            #im1 = cv2.cvtColor(im1, cv2.COLOR_RGB2GRAY)
            
            #print(directory2 + "/" + curdir[y+1])
            tempim2 = directory2 + "/" + curdir[y+1]
            im2 = cv2.imread(tempim2)
            
            # vertically concatenates images 
            # of same width 
            
            #resize for ResNet50
            width = 224
            height = 224

            dim = (width,height)
            
            im_v = cv2.vconcat([cv2.resize(im1, dim), cv2.resize(im2, dim)])
            #im_v = cv2.vconcat(im1,im2)
            
            # show the output image
            #cv2.imshow("image",im_v)
            #save image
            
            #create folder to store concatenated images if not existing
            newpath = directory3 + "2"
            if not os.path.exists(newpath):
                os.makedirs(newpath)
            """    
            newpath2 = directory4 + "3"
            if not os.path.exists(newpath2):
                os.makedirs(newpath2)
            """
            
            combine_img = newpath + "/IMG_" + str(random.randint(0,99999999)) + "_" + str(random.randint(0,999999)) + ".jpg"
            
            cv2.imwrite(combine_img,cv2.resize(im_v, dim))
            #shutil.copy2(combine_img, newpath2)bv
            
            print(curdir[y] + " and " + curdir[y+1] + " combined.")

print("All finished")
#"""
           
"""
im1 = cv2.imread("C:/Users/user/Desktop/Dataset/Balut-penoy/IMG_20210902_081744.jpg")
im2 = cv2.imread("C:/Users/user/Desktop/Dataset/Balut-penoy/IMG_20210902_081801.jpg")
#im1 = cv2.cvtColor(im1, cv2.COLOR_RGB2GRAY)

width = 224
height = 224

dim = (width,height)

im_v = cv2.vconcat([cv2.resize(im1, dim), cv2.resize(im2, dim)])

cv2.imshow("wew",im_v)
cv2.waitKey()

#create a new image from the images
#cv2.imwrite('C:/Users/user/Desktop/Dataset/Balut-penoy/Lolo3.jpg', im_v)
"""

print()

# %% [markdown]
# ## Put Dataset in a Dataframe

# %% [markdown]
# The directory of the images are put in a dataframe for preparation of splitting into train and test set.

# %%
combdirect = directory + "/CombinedTwoAngleEggs"
#fulldataset = directory + "/ToBeUsed"

#if not os.path.exists(fulldataset):
#    os.makedirs(fulldataset)

#needed for k-fold validation later on
image = []

if not os.path.exists(combdirect):
    print("Folder does not exist. Run the code above.")
    sys.exit()

for x in os.listdir(combdirect):
    combdirect2 = combdirect + "/" + x
    for y in os.listdir(combdirect2):
        if x == "Balut-penoy2":
            lbl = "0"
        elif x == "Salted egg2":
            lbl = "1"
        else:
            lbl = "2"
         
        #print(combdirect2 + "/" + y)
        
        #copy that image to the full dataset folder
        #shutil.copy2(combdirect2 + "/" + y, fulldataset)
        
        #append to image array
        image.append([combdirect2 + "/" + y,lbl])

# %%
df = pd.DataFrame(image,columns=['filename','label'])
df
# Out:
#                                               filename label
# 0    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 1    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 2    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 3    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 4    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# ..                                                 ...   ...
# 295  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 296  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 297  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 298  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 299  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
#
# [300 rows x 2 columns]

# %%
print(df['label'].unique())
# Out:
# ['0' '1' '2']

# %%
print(df.isna().any())
# Out:
# filename    False
# label       False
# dtype: bool

# %% [markdown]
# ## Split Data to train and test set

# %% [markdown]
# We will need to split the dataset to train and test set. Only the train set will be used for transfer learning with K-fold validation. Test set will be used for model prediction. Stratify is used in order to split the data in equal numbers under the classes specified.

# %%
## Split the data to train and test
X = df[['filename']]
y = df[['label']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# Save the split sets to train and test set folders.

# %%
#folder to store the train and test set folders
fortraintest = directory + "/ToBeUsed"
if not os.path.exists(fortraintest):
    os.makedirs(fortraintest)

#train set folder
tr = fortraintest + "/train_set"
if not os.path.exists(tr):
    os.makedirs(tr)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr)
    os.makedirs(tr)
    
#test set folder
te = fortraintest + "/test_set"
if not os.path.exists(te):
    os.makedirs(te)
else:
    #remove previous folder and create new one
    shutil.rmtree(te)
    os.makedirs(te)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    trcpy = shutil.copy2(row['filename'], tr)
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_test.iterrows():
    tecpy = shutil.copy2(row['filename'], te)
    X_test.loc[X_test['filename']==row['filename'],'filename']=tecpy #change to directory where image is copiedb
# Out:
# C:\Users\user\anaconda3\envs\tensorflow25\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\user\anaconda3\envs\tensorflow25\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df2 = pd.concat([X_train,y_train],axis=1)
df2
# Out:
#                                               filename label
# 41   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 165  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 246  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 179  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 192  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# ..                                                 ...   ...
# 163  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 222  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 157  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 203  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 211  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
#
# [240 rows x 2 columns]

# %% [markdown]
# ## K-fold validation on train set

# %% [markdown]
# https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538

# %%
Y = df2[['label']]

kf = KFold(n_splits = 10, random_state = 7, shuffle = True)
                         
skf = StratifiedKFold(n_splits = 10, random_state = 7, shuffle = True)

# %%
print(Y['label'].value_counts())
# Out:
# 0    80
# 1    80
# 2    80
# Name: label, dtype: int64

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# We will apply data augmentation of the dataset per epoch in order to increase the accuracy of the model

# %%
resnet50 = keras.applications.resnet50

imgdatagen = ImageDataGenerator(
        preprocessing_function = resnet50.preprocess_input,
        horizontal_flip = True,
        vertical_flip = True,
    )

# %% [markdown]
# ## Create Plot History

# %% [markdown]
# Plot history will display the training and validation accuracy, and training and validation loss in every epoch in a fold.

# %%
def plot_history(history, yrange):
    '''Plot loss and accuracy as a function of the epoch,
    for the training and validation datasets.
    '''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    # Plot training and validation accuracy per epoch
    plt.plot(epochs, acc)
    plt.plot(epochs, val_acc)
    plt.title('Training and validation accuracy')
    plt.legend(['train_accuracy','val_accuracy'])
    plt.ylim(yrange)
    
    # Plot training and validation loss per epoch
    plt.figure()

    plt.plot(epochs, loss)
    plt.plot(epochs, val_loss)
    plt.title('Training and validation loss')
    plt.legend(['train_loss','val_loss'])
    
    plt.show()

# %% [markdown]
# ## Train Model

# %% [markdown]
# train the model with K-fold Cross Validation. Parameters can be set each and every training to get the best accuracy as possible. Data generators are needed in order to do data augmentation through the use of the ImageDataGenerator stated above.

# %%
#initialize parameters
VALIDATION_ACCURACY = []                          #store all validation_accuracy
VALIDATION_LOSS = []                              #store all validation_loss
image_dir = directory + "/ToBeUsed/train_set"     #where the train set images are stored
batch_size = 32                                   #batch size
fold_var = 1                                      #number of fold of the model
n = len(df2)                                      #number of data in train set
num_epochs = 100                                  #number of epochs
dim = (224,224)                                   #required dimensions for process_unit (ResNet50)
lr = 0.00001                                      #learning rate Adamax

#===========if exist, create new one for another set of models with new parameters======================

#directory where models per set parameters are stored
gen_dir = "C:/Users/user/Desktop"

save_cur = ""  #check if there is any saved_models folders

svnum = 0
svnum2 = 0

for x in os.listdir(gen_dir):
    if "saved_models" in x:
        #print(x)
        save_cur = x
        if not save_cur == "":
            for word in save_cur.split("_"):
                if word.isdigit():
                    svnum2 = int(word)
                    if svnum < svnum2:
                        svnum = svnum2
            #print(svnum)
            

#save_dir is where the created models using the current set of parameters are added        

if save_cur == "":
    save_dir = gen_dir + "/saved_models_1"
    #print(save_dir)
    os.makedirs(save_dir)
else:
    save_dir = gen_dir + "/saved_models_" + str(svnum + 1)
    #print(save_dir)
    os.makedirs(save_dir)

#=========================================================================================================    
    
for train_index, val_index in kf.split(np.zeros(n),Y):
    #print(train_index)
    #print(val_index)
    training_data = df2.iloc[train_index]
    
    #print(training_data)
    
    validation_data = df2.iloc[val_index]
    
    #print(validation_data)

    train_data_generator = imgdatagen.flow_from_dataframe(training_data, directory = image_dir,
                               x_col = "filename", y_col = "label",
                              class_mode = "categorical", target_size = dim, batch_size = batch_size,
                                shuffle = False)
    valid_data_generator  = imgdatagen.flow_from_dataframe(validation_data, directory = image_dir,
                            x_col = "filename", y_col = "label",
                            class_mode = "categorical", target_size = dim, batch_size = batch_size,
                                shuffle = False)

    # CREATE NEW MODEL
    conv_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
    for layer in conv_model.layers:
        layer.trainable = False
    
    """
    #print(conv_model.output_shape)
    x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
    x = keras.layers.Dense(512, activation='relu')(x)
    x = keras.layers.Dense(256, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.5)(x) #to further reduce overfitting
    """
    x = keras.layers.Flatten()(conv_model.output)
    x = keras.layers.Dense(100, activation='relu')(x)
    x = keras.layers.Dense(100, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dropout(0.5)(x) #to further reduce overfitting
    
    predictions = keras.layers.Dense(3, activation='softmax')(x)
    full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)
    
    #full_model.summary()
    
    # COMPILE NEW MODEL
    full_model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.Adamax(learning_rate=lr),
                  metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

    # CREATE CALLBACKS
    checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "model_" + str(fold_var) + ".h5"), 
                            monitor='val_accuracy', verbose=1, 
                            save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    # There can be other callbacks, but just showing one because it involves the model name
    # This saves the best model
   
    print("Fold number " + str(fold_var))

    # FIT THE MODEL
    history = full_model.fit(train_data_generator,
                             epochs=num_epochs,
                             callbacks=callbacks_list,
                             validation_data=valid_data_generator)
    
    #PLOT HISTORY
    plot_history(history, yrange=(0.2,1))

    # LOAD BEST MODEL to evaluate the performance of the model
    full_model.load_weights(save_dir+"/model_"+str(fold_var)+".h5")
    
    results = full_model.evaluate(valid_data_generator)
    results = dict(zip(full_model.metrics_names,results))
    
    print(results)
    
    VALIDATION_ACCURACY.append(results['accuracy'])
    VALIDATION_LOSS.append(results['loss'])

    tf.keras.backend.clear_session()

    fold_var += 1
# Out:
# Found 216 validated image filenames belonging to 3 classes.
# Found 24 validated image filenames belonging to 3 classes.
# Fold number 1
# Epoch 1/100
# 7/7 [==============================] - 6s 481ms/step - loss: 1.8464 - accuracy: 0.3333 - val_loss: 2.2392 - val_accuracy: 0.2083
#
# Epoch 00001: val_accuracy improved from -inf to 0.20833, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 2/100
# 7/7 [==============================] - 2s 308ms/step - loss: 1.5193 - accuracy: 0.4352 - val_loss: 2.0210 - val_accuracy: 0.1667
#
# Epoch 00002: val_accuracy did not improve from 0.20833
# Epoch 3/100
# 7/7 [==============================] - 2s 303ms/step - loss: 1.2431 - accuracy: 0.5093 - val_loss: 1.7049 - val_accuracy: 0.2083
#
# Epoch 00003: val_accuracy did not improve from 0.20833
# Epoch 4/100
# 7/7 [==============================] - 2s 301ms/step - loss: 1.1949 - accuracy: 0.5231 - val_loss: 1.4410 - val_accuracy: 0.2917
#
# Epoch 00004: val_accuracy improved from 0.20833 to 0.29167, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 5/100
# 7/7 [==============================] - 2s 308ms/step - loss: 1.1327 - accuracy: 0.5463 - val_loss: 1.2346 - val_accuracy: 0.4583
#
# Epoch 00005: val_accuracy improved from 0.29167 to 0.45833, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 6/100
# 7/7 [==============================] - 3s 391ms/step - loss: 1.0639 - accuracy: 0.5556 - val_loss: 1.1594 - val_accuracy: 0.4583
#
# Epoch 00006: val_accuracy did not improve from 0.45833
# Epoch 7/100
# 7/7 [==============================] - 2s 310ms/step - loss: 1.1853 - accuracy: 0.5602 - val_loss: 1.1076 - val_accuracy: 0.5000
#
# Epoch 00007: val_accuracy improved from 0.45833 to 0.50000, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 8/100
# 7/7 [==============================] - 2s 316ms/step - loss: 1.0605 - accuracy: 0.6389 - val_loss: 1.1221 - val_accuracy: 0.3750
#
# Epoch 00008: val_accuracy did not improve from 0.50000
# Epoch 9/100
# 7/7 [==============================] - 2s 304ms/step - loss: 1.0501 - accuracy: 0.5602 - val_loss: 0.9056 - val_accuracy: 0.6250
#
# Epoch 00009: val_accuracy improved from 0.50000 to 0.62500, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 10/100
# 7/7 [==============================] - 2s 303ms/step - loss: 1.0468 - accuracy: 0.5602 - val_loss: 1.0311 - val_accuracy: 0.5833
#
# Epoch 00010: val_accuracy did not improve from 0.62500
# Epoch 11/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.8257 - accuracy: 0.6806 - val_loss: 0.8925 - val_accuracy: 0.6667
#
# Epoch 00011: val_accuracy improved from 0.62500 to 0.66667, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 12/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.8996 - accuracy: 0.6574 - val_loss: 0.7330 - val_accuracy: 0.6250
#
# Epoch 00012: val_accuracy did not improve from 0.66667
# Epoch 13/100
# 7/7 [==============================] - 2s 353ms/step - loss: 0.8630 - accuracy: 0.6157 - val_loss: 0.9564 - val_accuracy: 0.5833
#
# Epoch 00013: val_accuracy did not improve from 0.66667
# Epoch 14/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.8772 - accuracy: 0.6343 - val_loss: 0.9158 - val_accuracy: 0.6250
#
# Epoch 00014: val_accuracy did not improve from 0.66667
# Epoch 15/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.8549 - accuracy: 0.6759 - val_loss: 0.7038 - val_accuracy: 0.6250
#
# Epoch 00015: val_accuracy did not improve from 0.66667
# Epoch 16/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.8407 - accuracy: 0.6667 - val_loss: 0.8985 - val_accuracy: 0.5000
#
# Epoch 00016: val_accuracy did not improve from 0.66667
# Epoch 17/100
# 7/7 [==============================] - 2s 307ms/step - loss: 0.7315 - accuracy: 0.7176 - val_loss: 0.7387 - val_accuracy: 0.6667
#
# Epoch 00017: val_accuracy did not improve from 0.66667
# Epoch 18/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.7486 - accuracy: 0.6991 - val_loss: 0.7849 - val_accuracy: 0.7083
#
# Epoch 00018: val_accuracy improved from 0.66667 to 0.70833, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 19/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.6719 - accuracy: 0.7130 - val_loss: 0.8206 - val_accuracy: 0.6250
#
# Epoch 00019: val_accuracy did not improve from 0.70833
# Epoch 20/100
# 7/7 [==============================] - 2s 306ms/step - loss: 0.6863 - accuracy: 0.6944 - val_loss: 0.5901 - val_accuracy: 0.7500
#
# Epoch 00020: val_accuracy improved from 0.70833 to 0.75000, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 21/100
# 7/7 [==============================] - 2s 304ms/step - loss: 0.6539 - accuracy: 0.6944 - val_loss: 0.4854 - val_accuracy: 0.7917
#
# Epoch 00021: val_accuracy improved from 0.75000 to 0.79167, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 22/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.6969 - accuracy: 0.7083 - val_loss: 0.6863 - val_accuracy: 0.7083
#
# Epoch 00022: val_accuracy did not improve from 0.79167
# Epoch 23/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.6610 - accuracy: 0.7222 - val_loss: 0.7374 - val_accuracy: 0.7083
#
# Epoch 00023: val_accuracy did not improve from 0.79167
# Epoch 24/100
# 7/7 [==============================] - 2s 304ms/step - loss: 0.6200 - accuracy: 0.7500 - val_loss: 0.5025 - val_accuracy: 0.7917
#
# Epoch 00024: val_accuracy did not improve from 0.79167
# Epoch 25/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.5816 - accuracy: 0.7407 - val_loss: 0.5388 - val_accuracy: 0.7917
#
# Epoch 00025: val_accuracy did not improve from 0.79167
# Epoch 26/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.5651 - accuracy: 0.7731 - val_loss: 0.5614 - val_accuracy: 0.8333
#
# Epoch 00026: val_accuracy improved from 0.79167 to 0.83333, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 27/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.6299 - accuracy: 0.7269 - val_loss: 0.4461 - val_accuracy: 0.8750
#
# Epoch 00027: val_accuracy improved from 0.83333 to 0.87500, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 28/100
# 7/7 [==============================] - 2s 323ms/step - loss: 0.5949 - accuracy: 0.7315 - val_loss: 0.5773 - val_accuracy: 0.7083
#
# Epoch 00028: val_accuracy did not improve from 0.87500
# Epoch 29/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.5506 - accuracy: 0.7824 - val_loss: 0.6731 - val_accuracy: 0.7083
#
# Epoch 00029: val_accuracy did not improve from 0.87500
# Epoch 30/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.5971 - accuracy: 0.7546 - val_loss: 0.5579 - val_accuracy: 0.7917
#
# Epoch 00030: val_accuracy did not improve from 0.87500
# Epoch 31/100
# 7/7 [==============================] - 2s 343ms/step - loss: 0.5449 - accuracy: 0.7500 - val_loss: 0.5372 - val_accuracy: 0.7917
#
# Epoch 00031: val_accuracy did not improve from 0.87500
# Epoch 32/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.6099 - accuracy: 0.7454 - val_loss: 0.4276 - val_accuracy: 0.8750
#
# Epoch 00032: val_accuracy did not improve from 0.87500
# Epoch 33/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.5621 - accuracy: 0.7407 - val_loss: 0.4896 - val_accuracy: 0.8333
#
# Epoch 00033: val_accuracy did not improve from 0.87500
# Epoch 34/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.5204 - accuracy: 0.7870 - val_loss: 0.4097 - val_accuracy: 0.8750
#
# Epoch 00034: val_accuracy did not improve from 0.87500
# Epoch 35/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.5094 - accuracy: 0.8056 - val_loss: 0.4788 - val_accuracy: 0.7917
#
# Epoch 00035: val_accuracy did not improve from 0.87500
# Epoch 36/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.5795 - accuracy: 0.7778 - val_loss: 0.4597 - val_accuracy: 0.8750
#
# Epoch 00036: val_accuracy did not improve from 0.87500
# Epoch 37/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.4951 - accuracy: 0.7778 - val_loss: 0.4977 - val_accuracy: 0.8333
#
# Epoch 00037: val_accuracy did not improve from 0.87500
# Epoch 38/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.4824 - accuracy: 0.8287 - val_loss: 0.4642 - val_accuracy: 0.8750
#
# Epoch 00038: val_accuracy did not improve from 0.87500
# Epoch 39/100
# 7/7 [==============================] - 2s 366ms/step - loss: 0.5391 - accuracy: 0.7917 - val_loss: 0.5012 - val_accuracy: 0.8333
#
# Epoch 00039: val_accuracy did not improve from 0.87500
# Epoch 40/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.5014 - accuracy: 0.8009 - val_loss: 0.6096 - val_accuracy: 0.7500
#
# Epoch 00040: val_accuracy did not improve from 0.87500
# Epoch 41/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.5533 - accuracy: 0.7870 - val_loss: 0.4992 - val_accuracy: 0.8333
#
# Epoch 00041: val_accuracy did not improve from 0.87500
# Epoch 42/100
# 7/7 [==============================] - 3s 385ms/step - loss: 0.5229 - accuracy: 0.7963 - val_loss: 0.3683 - val_accuracy: 0.8333
#
# Epoch 00042: val_accuracy did not improve from 0.87500
# Epoch 43/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.5155 - accuracy: 0.7639 - val_loss: 0.4769 - val_accuracy: 0.7500
#
# Epoch 00043: val_accuracy did not improve from 0.87500
# Epoch 44/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.4460 - accuracy: 0.8380 - val_loss: 0.5288 - val_accuracy: 0.7500
#
# Epoch 00044: val_accuracy did not improve from 0.87500
# Epoch 45/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.4482 - accuracy: 0.8194 - val_loss: 0.5313 - val_accuracy: 0.7500
#
# Epoch 00045: val_accuracy did not improve from 0.87500
# Epoch 46/100
# 7/7 [==============================] - 3s 369ms/step - loss: 0.4717 - accuracy: 0.8009 - val_loss: 0.4997 - val_accuracy: 0.7917
#
# Epoch 00046: val_accuracy did not improve from 0.87500
# Epoch 47/100
# 7/7 [==============================] - 2s 323ms/step - loss: 0.4774 - accuracy: 0.7870 - val_loss: 0.2674 - val_accuracy: 0.8750
#
# Epoch 00047: val_accuracy did not improve from 0.87500
# Epoch 48/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.4909 - accuracy: 0.7731 - val_loss: 0.3955 - val_accuracy: 0.8333
#
# Epoch 00048: val_accuracy did not improve from 0.87500
# Epoch 49/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3933 - accuracy: 0.8333 - val_loss: 0.5556 - val_accuracy: 0.7500
#
# Epoch 00049: val_accuracy did not improve from 0.87500
# Epoch 50/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3655 - accuracy: 0.8333 - val_loss: 0.5487 - val_accuracy: 0.7500
#
# Epoch 00050: val_accuracy did not improve from 0.87500
# Epoch 51/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.4721 - accuracy: 0.7917 - val_loss: 0.3920 - val_accuracy: 0.7917
#
# Epoch 00051: val_accuracy did not improve from 0.87500
# Epoch 52/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.4663 - accuracy: 0.7778 - val_loss: 0.3461 - val_accuracy: 0.8750
#
# Epoch 00052: val_accuracy did not improve from 0.87500
# Epoch 53/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.3831 - accuracy: 0.8750 - val_loss: 0.5979 - val_accuracy: 0.7917
#
# Epoch 00053: val_accuracy did not improve from 0.87500
# Epoch 54/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3859 - accuracy: 0.8611 - val_loss: 0.3868 - val_accuracy: 0.8750
#
# Epoch 00054: val_accuracy did not improve from 0.87500
# Epoch 55/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.4478 - accuracy: 0.8102 - val_loss: 0.5478 - val_accuracy: 0.7500
#
# Epoch 00055: val_accuracy did not improve from 0.87500
# Epoch 56/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.4051 - accuracy: 0.8287 - val_loss: 0.4921 - val_accuracy: 0.7500
#
# Epoch 00056: val_accuracy did not improve from 0.87500
# Epoch 57/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3943 - accuracy: 0.8426 - val_loss: 0.5298 - val_accuracy: 0.7917
#
# Epoch 00057: val_accuracy did not improve from 0.87500
# Epoch 58/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.3675 - accuracy: 0.8287 - val_loss: 0.4666 - val_accuracy: 0.8750
#
# Epoch 00058: val_accuracy did not improve from 0.87500
# Epoch 59/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.3272 - accuracy: 0.8750 - val_loss: 0.5178 - val_accuracy: 0.8750
#
# Epoch 00059: val_accuracy did not improve from 0.87500
# Epoch 60/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.3900 - accuracy: 0.8287 - val_loss: 0.4283 - val_accuracy: 0.9167
#
# Epoch 00060: val_accuracy improved from 0.87500 to 0.91667, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 61/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.4095 - accuracy: 0.8056 - val_loss: 0.3955 - val_accuracy: 0.7917
#
# Epoch 00061: val_accuracy did not improve from 0.91667
# Epoch 62/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.4007 - accuracy: 0.8148 - val_loss: 0.4558 - val_accuracy: 0.8333
#
# Epoch 00062: val_accuracy did not improve from 0.91667
# Epoch 63/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.3546 - accuracy: 0.8704 - val_loss: 0.4917 - val_accuracy: 0.8333
#
# Epoch 00063: val_accuracy did not improve from 0.91667
# Epoch 64/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3107 - accuracy: 0.8472 - val_loss: 0.4684 - val_accuracy: 0.8333
#
# Epoch 00064: val_accuracy did not improve from 0.91667
# Epoch 65/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.3035 - accuracy: 0.8750 - val_loss: 0.3864 - val_accuracy: 0.7917
#
# Epoch 00065: val_accuracy did not improve from 0.91667
# Epoch 66/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3238 - accuracy: 0.8565 - val_loss: 0.3401 - val_accuracy: 0.8333
#
# Epoch 00066: val_accuracy did not improve from 0.91667
# Epoch 67/100
# 7/7 [==============================] - 2s 328ms/step - loss: 0.3369 - accuracy: 0.8611 - val_loss: 0.4781 - val_accuracy: 0.7500
#
# Epoch 00067: val_accuracy did not improve from 0.91667
# Epoch 68/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.3377 - accuracy: 0.8565 - val_loss: 0.4514 - val_accuracy: 0.8333
#
# Epoch 00068: val_accuracy did not improve from 0.91667
# Epoch 69/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3168 - accuracy: 0.8750 - val_loss: 0.4185 - val_accuracy: 0.8333
#
# Epoch 00069: val_accuracy did not improve from 0.91667
# Epoch 70/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3523 - accuracy: 0.8611 - val_loss: 0.3390 - val_accuracy: 0.9167
#
# Epoch 00070: val_accuracy did not improve from 0.91667
# Epoch 71/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3703 - accuracy: 0.8472 - val_loss: 0.4443 - val_accuracy: 0.9167
#
# Epoch 00071: val_accuracy did not improve from 0.91667
# Epoch 72/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3021 - accuracy: 0.8750 - val_loss: 0.5595 - val_accuracy: 0.8333
#
# Epoch 00072: val_accuracy did not improve from 0.91667
# Epoch 73/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.3284 - accuracy: 0.8704 - val_loss: 0.4741 - val_accuracy: 0.8750
#
# Epoch 00073: val_accuracy did not improve from 0.91667
# Epoch 74/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.2992 - accuracy: 0.8796 - val_loss: 0.3701 - val_accuracy: 0.8333
#
# Epoch 00074: val_accuracy did not improve from 0.91667
# Epoch 75/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.2780 - accuracy: 0.8935 - val_loss: 0.4745 - val_accuracy: 0.8333
#
# Epoch 00075: val_accuracy did not improve from 0.91667
# Epoch 76/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.2987 - accuracy: 0.8750 - val_loss: 0.4928 - val_accuracy: 0.8333
#
# Epoch 00076: val_accuracy did not improve from 0.91667
# Epoch 77/100
# 7/7 [==============================] - 2s 332ms/step - loss: 0.3779 - accuracy: 0.8519 - val_loss: 0.4667 - val_accuracy: 0.9167
#
# Epoch 00077: val_accuracy did not improve from 0.91667
# Epoch 78/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3283 - accuracy: 0.8796 - val_loss: 0.4618 - val_accuracy: 0.7500
#
# Epoch 00078: val_accuracy did not improve from 0.91667
# Epoch 79/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.3300 - accuracy: 0.8565 - val_loss: 0.3793 - val_accuracy: 0.7917
#
# Epoch 00079: val_accuracy did not improve from 0.91667
# Epoch 80/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.2912 - accuracy: 0.8981 - val_loss: 0.4180 - val_accuracy: 0.8333
#
# Epoch 00080: val_accuracy did not improve from 0.91667
# Epoch 81/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.3190 - accuracy: 0.8704 - val_loss: 0.4663 - val_accuracy: 0.7917
#
# Epoch 00081: val_accuracy did not improve from 0.91667
# Epoch 82/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.2830 - accuracy: 0.9120 - val_loss: 0.4645 - val_accuracy: 0.8750
#
# Epoch 00082: val_accuracy did not improve from 0.91667
# Epoch 83/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.2300 - accuracy: 0.9028 - val_loss: 0.4652 - val_accuracy: 0.8750
#
# Epoch 00083: val_accuracy did not improve from 0.91667
# Epoch 84/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.2709 - accuracy: 0.8981 - val_loss: 0.5280 - val_accuracy: 0.8333
#
# Epoch 00084: val_accuracy did not improve from 0.91667
# Epoch 85/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.3101 - accuracy: 0.8657 - val_loss: 0.4133 - val_accuracy: 0.8333
#
# Epoch 00085: val_accuracy did not improve from 0.91667
# Epoch 86/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.2679 - accuracy: 0.9074 - val_loss: 0.3487 - val_accuracy: 0.7917
#
# Epoch 00086: val_accuracy did not improve from 0.91667
# Epoch 87/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.3108 - accuracy: 0.8704 - val_loss: 0.4047 - val_accuracy: 0.8333
#
# Epoch 00087: val_accuracy did not improve from 0.91667
# Epoch 88/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.2912 - accuracy: 0.9120 - val_loss: 0.3975 - val_accuracy: 0.8333
#
# Epoch 00088: val_accuracy did not improve from 0.91667
# Epoch 89/100
# 7/7 [==============================] - 2s 335ms/step - loss: 0.2368 - accuracy: 0.9120 - val_loss: 0.3342 - val_accuracy: 0.8333
#
# Epoch 00089: val_accuracy did not improve from 0.91667
# Epoch 90/100
# 7/7 [==============================] - 2s 334ms/step - loss: 0.2482 - accuracy: 0.9074 - val_loss: 0.2955 - val_accuracy: 0.8333
#
# Epoch 00090: val_accuracy did not improve from 0.91667
# Epoch 91/100
# 7/7 [==============================] - 2s 334ms/step - loss: 0.2454 - accuracy: 0.9028 - val_loss: 0.4481 - val_accuracy: 0.8333
#
# Epoch 00091: val_accuracy did not improve from 0.91667
# Epoch 92/100
# 7/7 [==============================] - 2s 340ms/step - loss: 0.2862 - accuracy: 0.9028 - val_loss: 0.3113 - val_accuracy: 0.9583
#
# Epoch 00092: val_accuracy improved from 0.91667 to 0.95833, saving model to C:/Users/user/Desktop/saved_models_4\model_1.h5
# Epoch 93/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.2530 - accuracy: 0.9074 - val_loss: 0.2976 - val_accuracy: 0.8333
#
# Epoch 00093: val_accuracy did not improve from 0.95833
# Epoch 94/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.2435 - accuracy: 0.9028 - val_loss: 0.2768 - val_accuracy: 0.8750
#
# Epoch 00094: val_accuracy did not improve from 0.95833
# Epoch 95/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.2280 - accuracy: 0.9120 - val_loss: 0.4504 - val_accuracy: 0.8333
#
# Epoch 00095: val_accuracy did not improve from 0.95833
# Epoch 96/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.2665 - accuracy: 0.9074 - val_loss: 0.4240 - val_accuracy: 0.9167
#
# Epoch 00096: val_accuracy did not improve from 0.95833
# Epoch 97/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.2318 - accuracy: 0.9259 - val_loss: 0.4395 - val_accuracy: 0.8333
#
# Epoch 00097: val_accuracy did not improve from 0.95833
# Epoch 98/100
# 7/7 [==============================] - 2s 328ms/step - loss: 0.2354 - accuracy: 0.9213 - val_loss: 0.4359 - val_accuracy: 0.8333
#
# Epoch 00098: val_accuracy did not improve from 0.95833
# Epoch 99/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.2560 - accuracy: 0.8889 - val_loss: 0.5977 - val_accuracy: 0.7500
#
# Epoch 00099: val_accuracy did not improve from 0.95833
# Epoch 100/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.2395 - accuracy: 0.9074 - val_loss: 0.4315 - val_accuracy: 0.9167
#
# Epoch 00100: val_accuracy did not improve from 0.95833
# 1/1 [==============================] - 0s 299ms/step - loss: 0.2940 - accuracy: 0.8750
# {'loss': 0.29400864243507385, 'accuracy': 0.875}
# Found 216 validated image filenames belonging to 3 classes.
# Found 24 validated image filenames belonging to 3 classes.
# Fold number 2
# Epoch 1/100
# 7/7 [==============================] - 7s 556ms/step - loss: 1.4480 - accuracy: 0.4352 - val_loss: 1.5497 - val_accuracy: 0.3750
#
# Epoch 00001: val_accuracy improved from -inf to 0.37500, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 2/100
# 7/7 [==============================] - 2s 309ms/step - loss: 1.1236 - accuracy: 0.5602 - val_loss: 1.7433 - val_accuracy: 0.3333
#
# Epoch 00002: val_accuracy did not improve from 0.37500
# Epoch 3/100
# 7/7 [==============================] - 2s 317ms/step - loss: 1.1551 - accuracy: 0.5278 - val_loss: 1.6701 - val_accuracy: 0.4167
#
# Epoch 00003: val_accuracy improved from 0.37500 to 0.41667, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 4/100
# 7/7 [==============================] - 2s 310ms/step - loss: 1.0603 - accuracy: 0.5926 - val_loss: 1.6878 - val_accuracy: 0.3750
#
# Epoch 00004: val_accuracy did not improve from 0.41667
# Epoch 5/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.9319 - accuracy: 0.6204 - val_loss: 1.3258 - val_accuracy: 0.3750
#
# Epoch 00005: val_accuracy did not improve from 0.41667
# Epoch 6/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.9867 - accuracy: 0.5741 - val_loss: 1.5152 - val_accuracy: 0.4167
#
# Epoch 00006: val_accuracy did not improve from 0.41667
# Epoch 7/100
# 7/7 [==============================] - 2s 334ms/step - loss: 0.9977 - accuracy: 0.5787 - val_loss: 1.3604 - val_accuracy: 0.4167
#
# Epoch 00007: val_accuracy did not improve from 0.41667
# Epoch 8/100
# 7/7 [==============================] - 2s 311ms/step - loss: 0.8776 - accuracy: 0.6343 - val_loss: 1.2804 - val_accuracy: 0.3750
#
# Epoch 00008: val_accuracy did not improve from 0.41667
# Epoch 9/100
# 7/7 [==============================] - 2s 345ms/step - loss: 0.8597 - accuracy: 0.6528 - val_loss: 1.3422 - val_accuracy: 0.4583
#
# Epoch 00009: val_accuracy improved from 0.41667 to 0.45833, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 10/100
# 7/7 [==============================] - 2s 346ms/step - loss: 0.7490 - accuracy: 0.6852 - val_loss: 1.1549 - val_accuracy: 0.5000
#
# Epoch 00010: val_accuracy improved from 0.45833 to 0.50000, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 11/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.8566 - accuracy: 0.6852 - val_loss: 1.3170 - val_accuracy: 0.4167
#
# Epoch 00011: val_accuracy did not improve from 0.50000
# Epoch 12/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.7054 - accuracy: 0.6991 - val_loss: 1.2814 - val_accuracy: 0.4583
#
# Epoch 00012: val_accuracy did not improve from 0.50000
# Epoch 13/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.6843 - accuracy: 0.6759 - val_loss: 1.1391 - val_accuracy: 0.4583
#
# Epoch 00013: val_accuracy did not improve from 0.50000
# Epoch 14/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.7530 - accuracy: 0.6713 - val_loss: 1.1033 - val_accuracy: 0.5000
#
# Epoch 00014: val_accuracy did not improve from 0.50000
# Epoch 15/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.7033 - accuracy: 0.6806 - val_loss: 1.2622 - val_accuracy: 0.5000
#
# Epoch 00015: val_accuracy did not improve from 0.50000
# Epoch 16/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.7287 - accuracy: 0.6852 - val_loss: 1.0817 - val_accuracy: 0.4583
#
# Epoch 00016: val_accuracy did not improve from 0.50000
# Epoch 17/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.7485 - accuracy: 0.6898 - val_loss: 0.9220 - val_accuracy: 0.6250
#
# Epoch 00017: val_accuracy improved from 0.50000 to 0.62500, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 18/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.6900 - accuracy: 0.6806 - val_loss: 0.8589 - val_accuracy: 0.5417
#
# Epoch 00018: val_accuracy did not improve from 0.62500
# Epoch 19/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.7116 - accuracy: 0.6806 - val_loss: 0.9171 - val_accuracy: 0.5833
#
# Epoch 00019: val_accuracy did not improve from 0.62500
# Epoch 20/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.6379 - accuracy: 0.7454 - val_loss: 0.9027 - val_accuracy: 0.5417
#
# Epoch 00020: val_accuracy did not improve from 0.62500
# Epoch 21/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.6772 - accuracy: 0.7083 - val_loss: 0.7337 - val_accuracy: 0.6667
#
# Epoch 00021: val_accuracy improved from 0.62500 to 0.66667, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 22/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.6666 - accuracy: 0.7222 - val_loss: 0.9376 - val_accuracy: 0.5417
#
# Epoch 00022: val_accuracy did not improve from 0.66667
# Epoch 23/100
# 7/7 [==============================] - 2s 331ms/step - loss: 0.6421 - accuracy: 0.7500 - val_loss: 0.8085 - val_accuracy: 0.6250
#
# Epoch 00023: val_accuracy did not improve from 0.66667
# Epoch 24/100
# 7/7 [==============================] - 2s 336ms/step - loss: 0.6457 - accuracy: 0.7639 - val_loss: 0.6332 - val_accuracy: 0.6667
#
# Epoch 00024: val_accuracy did not improve from 0.66667
# Epoch 25/100
# 7/7 [==============================] - 2s 349ms/step - loss: 0.5757 - accuracy: 0.7824 - val_loss: 0.5843 - val_accuracy: 0.6667
#
# Epoch 00025: val_accuracy did not improve from 0.66667
# Epoch 26/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.5237 - accuracy: 0.7685 - val_loss: 0.6934 - val_accuracy: 0.6667
#
# Epoch 00026: val_accuracy did not improve from 0.66667
# Epoch 27/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.6079 - accuracy: 0.7407 - val_loss: 0.6867 - val_accuracy: 0.6667
#
# Epoch 00027: val_accuracy did not improve from 0.66667
# Epoch 28/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.5997 - accuracy: 0.7500 - val_loss: 0.6514 - val_accuracy: 0.7083
#
# Epoch 00028: val_accuracy improved from 0.66667 to 0.70833, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 29/100
# 7/7 [==============================] - 3s 365ms/step - loss: 0.5147 - accuracy: 0.7824 - val_loss: 0.5715 - val_accuracy: 0.7083
#
# Epoch 00029: val_accuracy did not improve from 0.70833
# Epoch 30/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.6140 - accuracy: 0.7731 - val_loss: 0.5499 - val_accuracy: 0.8333
#
# Epoch 00030: val_accuracy improved from 0.70833 to 0.83333, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 31/100
# 7/7 [==============================] - 2s 347ms/step - loss: 0.5459 - accuracy: 0.7685 - val_loss: 0.5878 - val_accuracy: 0.7917
#
# Epoch 00031: val_accuracy did not improve from 0.83333
# Epoch 32/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.5046 - accuracy: 0.7824 - val_loss: 0.6299 - val_accuracy: 0.7500
#
# Epoch 00032: val_accuracy did not improve from 0.83333
# Epoch 33/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.5172 - accuracy: 0.7917 - val_loss: 0.4972 - val_accuracy: 0.7917
#
# Epoch 00033: val_accuracy did not improve from 0.83333
# Epoch 34/100
# 7/7 [==============================] - 3s 364ms/step - loss: 0.5530 - accuracy: 0.7870 - val_loss: 0.6155 - val_accuracy: 0.7500
#
# Epoch 00034: val_accuracy did not improve from 0.83333
# Epoch 35/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.4573 - accuracy: 0.8102 - val_loss: 0.6391 - val_accuracy: 0.7917
#
# Epoch 00035: val_accuracy did not improve from 0.83333
# Epoch 36/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.4453 - accuracy: 0.8380 - val_loss: 0.5037 - val_accuracy: 0.7917
#
# Epoch 00036: val_accuracy did not improve from 0.83333
# Epoch 37/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.5003 - accuracy: 0.7870 - val_loss: 0.5592 - val_accuracy: 0.7500
#
# Epoch 00037: val_accuracy did not improve from 0.83333
# Epoch 38/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.4507 - accuracy: 0.7824 - val_loss: 0.5126 - val_accuracy: 0.7500
#
# Epoch 00038: val_accuracy did not improve from 0.83333
# Epoch 39/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.4752 - accuracy: 0.7824 - val_loss: 0.4449 - val_accuracy: 0.7500
#
# Epoch 00039: val_accuracy did not improve from 0.83333
# Epoch 40/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.4298 - accuracy: 0.8148 - val_loss: 0.5563 - val_accuracy: 0.7500
#
# Epoch 00040: val_accuracy did not improve from 0.83333
# Epoch 41/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.4686 - accuracy: 0.8056 - val_loss: 0.5581 - val_accuracy: 0.7917
#
# Epoch 00041: val_accuracy did not improve from 0.83333
# Epoch 42/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.4317 - accuracy: 0.8102 - val_loss: 0.6311 - val_accuracy: 0.7500
#
# Epoch 00042: val_accuracy did not improve from 0.83333
# Epoch 43/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.4852 - accuracy: 0.7639 - val_loss: 0.5156 - val_accuracy: 0.7917
#
# Epoch 00043: val_accuracy did not improve from 0.83333
# Epoch 44/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.5007 - accuracy: 0.7731 - val_loss: 0.5285 - val_accuracy: 0.7917
#
# Epoch 00044: val_accuracy did not improve from 0.83333
# Epoch 45/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.4767 - accuracy: 0.8287 - val_loss: 0.5783 - val_accuracy: 0.7917
#
# Epoch 00045: val_accuracy did not improve from 0.83333
# Epoch 46/100
# 7/7 [==============================] - 2s 336ms/step - loss: 0.4444 - accuracy: 0.8333 - val_loss: 0.5586 - val_accuracy: 0.7917
#
# Epoch 00046: val_accuracy did not improve from 0.83333
# Epoch 47/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.4063 - accuracy: 0.8102 - val_loss: 0.5165 - val_accuracy: 0.8333
#
# Epoch 00047: val_accuracy did not improve from 0.83333
# Epoch 48/100
# 7/7 [==============================] - 3s 393ms/step - loss: 0.3694 - accuracy: 0.8519 - val_loss: 0.5472 - val_accuracy: 0.7083
#
# Epoch 00048: val_accuracy did not improve from 0.83333
# Epoch 49/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.4422 - accuracy: 0.8009 - val_loss: 0.4282 - val_accuracy: 0.8333
#
# Epoch 00049: val_accuracy did not improve from 0.83333
# Epoch 50/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.3797 - accuracy: 0.8287 - val_loss: 0.3360 - val_accuracy: 0.9167
#
# Epoch 00050: val_accuracy improved from 0.83333 to 0.91667, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 51/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.4638 - accuracy: 0.8241 - val_loss: 0.4531 - val_accuracy: 0.8333
#
# Epoch 00051: val_accuracy did not improve from 0.91667
# Epoch 52/100
# 7/7 [==============================] - 3s 359ms/step - loss: 0.3790 - accuracy: 0.8472 - val_loss: 0.4700 - val_accuracy: 0.8333
#
# Epoch 00052: val_accuracy did not improve from 0.91667
# Epoch 53/100
# 7/7 [==============================] - 2s 311ms/step - loss: 0.3632 - accuracy: 0.8750 - val_loss: 0.4972 - val_accuracy: 0.7917
#
# Epoch 00053: val_accuracy did not improve from 0.91667
# Epoch 54/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.4271 - accuracy: 0.8194 - val_loss: 0.4820 - val_accuracy: 0.8750
#
# Epoch 00054: val_accuracy did not improve from 0.91667
# Epoch 55/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.3947 - accuracy: 0.8380 - val_loss: 0.4770 - val_accuracy: 0.8750
#
# Epoch 00055: val_accuracy did not improve from 0.91667
# Epoch 56/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.4160 - accuracy: 0.8333 - val_loss: 0.5374 - val_accuracy: 0.7917
#
# Epoch 00056: val_accuracy did not improve from 0.91667
# Epoch 57/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.4373 - accuracy: 0.8287 - val_loss: 0.4659 - val_accuracy: 0.8750
#
# Epoch 00057: val_accuracy did not improve from 0.91667
# Epoch 58/100
# 7/7 [==============================] - 2s 350ms/step - loss: 0.4055 - accuracy: 0.8333 - val_loss: 0.4738 - val_accuracy: 0.8750
#
# Epoch 00058: val_accuracy did not improve from 0.91667
# Epoch 59/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.4037 - accuracy: 0.8194 - val_loss: 0.4265 - val_accuracy: 0.8333
#
# Epoch 00059: val_accuracy did not improve from 0.91667
# Epoch 60/100
# 7/7 [==============================] - 2s 346ms/step - loss: 0.3723 - accuracy: 0.8426 - val_loss: 0.4707 - val_accuracy: 0.7500
#
# Epoch 00060: val_accuracy did not improve from 0.91667
# Epoch 61/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.4010 - accuracy: 0.8333 - val_loss: 0.4886 - val_accuracy: 0.7917
#
# Epoch 00061: val_accuracy did not improve from 0.91667
# Epoch 62/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.3414 - accuracy: 0.8657 - val_loss: 0.3565 - val_accuracy: 0.8750
#
# Epoch 00062: val_accuracy did not improve from 0.91667
# Epoch 63/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.3638 - accuracy: 0.8565 - val_loss: 0.3975 - val_accuracy: 0.7917
#
# Epoch 00063: val_accuracy did not improve from 0.91667
# Epoch 64/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.3177 - accuracy: 0.8981 - val_loss: 0.4136 - val_accuracy: 0.8333
#
# Epoch 00064: val_accuracy did not improve from 0.91667
# Epoch 65/100
# 7/7 [==============================] - 2s 337ms/step - loss: 0.3344 - accuracy: 0.8796 - val_loss: 0.4720 - val_accuracy: 0.8750
#
# Epoch 00065: val_accuracy did not improve from 0.91667
# Epoch 66/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.3722 - accuracy: 0.8472 - val_loss: 0.4076 - val_accuracy: 0.8750
#
# Epoch 00066: val_accuracy did not improve from 0.91667
# Epoch 67/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.3829 - accuracy: 0.8287 - val_loss: 0.3731 - val_accuracy: 0.8750
#
# Epoch 00067: val_accuracy did not improve from 0.91667
# Epoch 68/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.3006 - accuracy: 0.8519 - val_loss: 0.3288 - val_accuracy: 0.8750
#
# Epoch 00068: val_accuracy did not improve from 0.91667
# Epoch 69/100
# 7/7 [==============================] - 2s 325ms/step - loss: 0.3463 - accuracy: 0.8472 - val_loss: 0.3240 - val_accuracy: 0.9167
#
# Epoch 00069: val_accuracy did not improve from 0.91667
# Epoch 70/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.2992 - accuracy: 0.8935 - val_loss: 0.3681 - val_accuracy: 0.8333
#
# Epoch 00070: val_accuracy did not improve from 0.91667
# Epoch 71/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3780 - accuracy: 0.8519 - val_loss: 0.4250 - val_accuracy: 0.8333
#
# Epoch 00071: val_accuracy did not improve from 0.91667
# Epoch 72/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.3553 - accuracy: 0.8472 - val_loss: 0.3032 - val_accuracy: 0.9167
#
# Epoch 00072: val_accuracy did not improve from 0.91667
# Epoch 73/100
# 7/7 [==============================] - 2s 332ms/step - loss: 0.2676 - accuracy: 0.9028 - val_loss: 0.3885 - val_accuracy: 0.9167
#
# Epoch 00073: val_accuracy did not improve from 0.91667
# Epoch 74/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.3071 - accuracy: 0.8796 - val_loss: 0.4118 - val_accuracy: 0.9167
#
# Epoch 00074: val_accuracy did not improve from 0.91667
# Epoch 75/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.3284 - accuracy: 0.8657 - val_loss: 0.3668 - val_accuracy: 0.9583
#
# Epoch 00075: val_accuracy improved from 0.91667 to 0.95833, saving model to C:/Users/user/Desktop/saved_models_4\model_2.h5
# Epoch 76/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.3050 - accuracy: 0.8889 - val_loss: 0.3258 - val_accuracy: 0.8750
#
# Epoch 00076: val_accuracy did not improve from 0.95833
# Epoch 77/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.2977 - accuracy: 0.8981 - val_loss: 0.3391 - val_accuracy: 0.9167
#
# Epoch 00077: val_accuracy did not improve from 0.95833
# Epoch 78/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.2821 - accuracy: 0.9028 - val_loss: 0.3441 - val_accuracy: 0.9167
#
# Epoch 00078: val_accuracy did not improve from 0.95833
# Epoch 79/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.3302 - accuracy: 0.8843 - val_loss: 0.3940 - val_accuracy: 0.9167
#
# Epoch 00079: val_accuracy did not improve from 0.95833
# Epoch 80/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.2963 - accuracy: 0.8935 - val_loss: 0.3643 - val_accuracy: 0.8750
#
# Epoch 00080: val_accuracy did not improve from 0.95833
# Epoch 81/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.2636 - accuracy: 0.9074 - val_loss: 0.4271 - val_accuracy: 0.8750
#
# Epoch 00081: val_accuracy did not improve from 0.95833
# Epoch 82/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.3311 - accuracy: 0.8565 - val_loss: 0.2881 - val_accuracy: 0.9167
#
# Epoch 00082: val_accuracy did not improve from 0.95833
# Epoch 83/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.3124 - accuracy: 0.8843 - val_loss: 0.3657 - val_accuracy: 0.7917
#
# Epoch 00083: val_accuracy did not improve from 0.95833
# Epoch 84/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.2993 - accuracy: 0.8657 - val_loss: 0.3036 - val_accuracy: 0.9167
#
# Epoch 00084: val_accuracy did not improve from 0.95833
# Epoch 85/100
# 7/7 [==============================] - 2s 356ms/step - loss: 0.2645 - accuracy: 0.8935 - val_loss: 0.4030 - val_accuracy: 0.8750
#
# Epoch 00085: val_accuracy did not improve from 0.95833
# Epoch 86/100
# 7/7 [==============================] - 2s 352ms/step - loss: 0.2968 - accuracy: 0.8981 - val_loss: 0.4422 - val_accuracy: 0.8750
#
# Epoch 00086: val_accuracy did not improve from 0.95833
# Epoch 87/100
# 7/7 [==============================] - 3s 368ms/step - loss: 0.3134 - accuracy: 0.8750 - val_loss: 0.3059 - val_accuracy: 0.8750
#
# Epoch 00087: val_accuracy did not improve from 0.95833
# Epoch 88/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.2586 - accuracy: 0.9167 - val_loss: 0.3668 - val_accuracy: 0.9167
#
# Epoch 00088: val_accuracy did not improve from 0.95833
# Epoch 89/100
# 7/7 [==============================] - 3s 382ms/step - loss: 0.2381 - accuracy: 0.9306 - val_loss: 0.5018 - val_accuracy: 0.7917
#
# Epoch 00089: val_accuracy did not improve from 0.95833
# Epoch 90/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.2815 - accuracy: 0.8981 - val_loss: 0.3145 - val_accuracy: 0.9167
#
# Epoch 00090: val_accuracy did not improve from 0.95833
# Epoch 91/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.2804 - accuracy: 0.8981 - val_loss: 0.3360 - val_accuracy: 0.9167
#
# Epoch 00091: val_accuracy did not improve from 0.95833
# Epoch 92/100
# 7/7 [==============================] - 2s 319ms/step - loss: 0.2548 - accuracy: 0.8981 - val_loss: 0.3870 - val_accuracy: 0.9583
#
# Epoch 00092: val_accuracy did not improve from 0.95833
# Epoch 93/100
# 7/7 [==============================] - 3s 376ms/step - loss: 0.2878 - accuracy: 0.9074 - val_loss: 0.4017 - val_accuracy: 0.8750
#
# Epoch 00093: val_accuracy did not improve from 0.95833
# Epoch 94/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.1873 - accuracy: 0.9537 - val_loss: 0.3490 - val_accuracy: 0.9167
#
# Epoch 00094: val_accuracy did not improve from 0.95833
# Epoch 95/100
# 7/7 [==============================] - 2s 325ms/step - loss: 0.2851 - accuracy: 0.8981 - val_loss: 0.3476 - val_accuracy: 0.9167
#
# Epoch 00095: val_accuracy did not improve from 0.95833
# Epoch 96/100
# 7/7 [==============================] - 2s 340ms/step - loss: 0.2373 - accuracy: 0.9306 - val_loss: 0.2385 - val_accuracy: 0.9583
#
# Epoch 00096: val_accuracy did not improve from 0.95833
# Epoch 97/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.2496 - accuracy: 0.9074 - val_loss: 0.3107 - val_accuracy: 0.9167
#
# Epoch 00097: val_accuracy did not improve from 0.95833
# Epoch 98/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.2668 - accuracy: 0.9120 - val_loss: 0.3923 - val_accuracy: 0.9167
#
# Epoch 00098: val_accuracy did not improve from 0.95833
# Epoch 99/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.2578 - accuracy: 0.8981 - val_loss: 0.3566 - val_accuracy: 0.9167
#
# Epoch 00099: val_accuracy did not improve from 0.95833
# Epoch 100/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.2653 - accuracy: 0.8981 - val_loss: 0.3758 - val_accuracy: 0.8750
#
# Epoch 00100: val_accuracy did not improve from 0.95833
# 1/1 [==============================] - 0s 320ms/step - loss: 0.4310 - accuracy: 0.8333
# {'loss': 0.4309910237789154, 'accuracy': 0.8333333134651184}
# Found 216 validated image filenames belonging to 3 classes.
# Found 24 validated image filenames belonging to 3 classes.
# Fold number 3
# Epoch 1/100
# 7/7 [==============================] - 8s 607ms/step - loss: 1.3468 - accuracy: 0.4954 - val_loss: 1.8216 - val_accuracy: 0.3333
#
# Epoch 00001: val_accuracy improved from -inf to 0.33333, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 2/100
# 7/7 [==============================] - 2s 342ms/step - loss: 1.0886 - accuracy: 0.5602 - val_loss: 2.0622 - val_accuracy: 0.2917
#
# Epoch 00002: val_accuracy did not improve from 0.33333
# Epoch 3/100
# 7/7 [==============================] - 2s 339ms/step - loss: 0.9604 - accuracy: 0.5787 - val_loss: 1.5972 - val_accuracy: 0.3750
#
# Epoch 00003: val_accuracy improved from 0.33333 to 0.37500, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 4/100
# 7/7 [==============================] - 2s 312ms/step - loss: 1.0022 - accuracy: 0.5880 - val_loss: 1.6385 - val_accuracy: 0.2917
#
# Epoch 00004: val_accuracy did not improve from 0.37500
# Epoch 5/100
# 7/7 [==============================] - 3s 393ms/step - loss: 0.9645 - accuracy: 0.6528 - val_loss: 1.6476 - val_accuracy: 0.3333
#
# Epoch 00005: val_accuracy did not improve from 0.37500
# Epoch 6/100
# 7/7 [==============================] - 2s 311ms/step - loss: 0.7230 - accuracy: 0.7037 - val_loss: 1.5715 - val_accuracy: 0.3750
#
# Epoch 00006: val_accuracy did not improve from 0.37500
# Epoch 7/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.7792 - accuracy: 0.6759 - val_loss: 1.4176 - val_accuracy: 0.3750
#
# Epoch 00007: val_accuracy did not improve from 0.37500
# Epoch 8/100
# 7/7 [==============================] - 2s 307ms/step - loss: 0.7256 - accuracy: 0.6944 - val_loss: 1.4097 - val_accuracy: 0.4167
#
# Epoch 00008: val_accuracy improved from 0.37500 to 0.41667, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 9/100
# 7/7 [==============================] - 2s 363ms/step - loss: 0.7503 - accuracy: 0.6713 - val_loss: 1.2166 - val_accuracy: 0.3750
#
# Epoch 00009: val_accuracy did not improve from 0.41667
# Epoch 10/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.7859 - accuracy: 0.6713 - val_loss: 1.2366 - val_accuracy: 0.3750
#
# Epoch 00010: val_accuracy did not improve from 0.41667
# Epoch 11/100
# 7/7 [==============================] - 3s 353ms/step - loss: 0.7661 - accuracy: 0.7037 - val_loss: 1.0843 - val_accuracy: 0.4583
#
# Epoch 00011: val_accuracy improved from 0.41667 to 0.45833, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 12/100
# 7/7 [==============================] - 2s 335ms/step - loss: 0.6291 - accuracy: 0.7500 - val_loss: 0.9871 - val_accuracy: 0.5417
#
# Epoch 00012: val_accuracy improved from 0.45833 to 0.54167, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 13/100
# 7/7 [==============================] - 2s 354ms/step - loss: 0.6463 - accuracy: 0.7222 - val_loss: 1.1370 - val_accuracy: 0.5417
#
# Epoch 00013: val_accuracy did not improve from 0.54167
# Epoch 14/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.6340 - accuracy: 0.7176 - val_loss: 0.9910 - val_accuracy: 0.5417
#
# Epoch 00014: val_accuracy did not improve from 0.54167
# Epoch 15/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.6634 - accuracy: 0.7130 - val_loss: 0.9747 - val_accuracy: 0.4167
#
# Epoch 00015: val_accuracy did not improve from 0.54167
# Epoch 16/100
# 7/7 [==============================] - 2s 333ms/step - loss: 0.6442 - accuracy: 0.7315 - val_loss: 0.8893 - val_accuracy: 0.4583
#
# Epoch 00016: val_accuracy did not improve from 0.54167
# Epoch 17/100
# 7/7 [==============================] - 2s 325ms/step - loss: 0.6580 - accuracy: 0.7315 - val_loss: 0.7934 - val_accuracy: 0.6667
#
# Epoch 00017: val_accuracy improved from 0.54167 to 0.66667, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 18/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.6106 - accuracy: 0.7407 - val_loss: 0.8474 - val_accuracy: 0.5417
#
# Epoch 00018: val_accuracy did not improve from 0.66667
# Epoch 19/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.5739 - accuracy: 0.7593 - val_loss: 0.9046 - val_accuracy: 0.5417
#
# Epoch 00019: val_accuracy did not improve from 0.66667
# Epoch 20/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.4801 - accuracy: 0.7870 - val_loss: 0.6697 - val_accuracy: 0.6667
#
# Epoch 00020: val_accuracy did not improve from 0.66667
# Epoch 21/100
# 7/7 [==============================] - 3s 393ms/step - loss: 0.5585 - accuracy: 0.7639 - val_loss: 0.7339 - val_accuracy: 0.6667
#
# Epoch 00021: val_accuracy did not improve from 0.66667
# Epoch 22/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.5613 - accuracy: 0.7731 - val_loss: 0.7728 - val_accuracy: 0.6667
#
# Epoch 00022: val_accuracy did not improve from 0.66667
# Epoch 23/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.5036 - accuracy: 0.7778 - val_loss: 0.6336 - val_accuracy: 0.6667
#
# Epoch 00023: val_accuracy did not improve from 0.66667
# Epoch 24/100
# 7/7 [==============================] - 2s 308ms/step - loss: 0.5199 - accuracy: 0.7917 - val_loss: 0.6619 - val_accuracy: 0.6250
#
# Epoch 00024: val_accuracy did not improve from 0.66667
# Epoch 25/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.4423 - accuracy: 0.8102 - val_loss: 0.7242 - val_accuracy: 0.7083
#
# Epoch 00025: val_accuracy improved from 0.66667 to 0.70833, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 26/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.4877 - accuracy: 0.7917 - val_loss: 0.8024 - val_accuracy: 0.5417
#
# Epoch 00026: val_accuracy did not improve from 0.70833
# Epoch 27/100
# 7/7 [==============================] - 2s 323ms/step - loss: 0.5361 - accuracy: 0.7870 - val_loss: 0.6472 - val_accuracy: 0.7500
#
# Epoch 00027: val_accuracy improved from 0.70833 to 0.75000, saving model to C:/Users/user/Desktop/saved_models_4\model_3.h5
# Epoch 28/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.3866 - accuracy: 0.8657 - val_loss: 0.6817 - val_accuracy: 0.6250
#
# Epoch 00028: val_accuracy did not improve from 0.75000
# Epoch 29/100
# ...
#
# Epoch 00021: val_accuracy did not improve from 0.87500
# Epoch 22/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.5184 - accuracy: 0.7917 - val_loss: 0.5968 - val_accuracy: 0.7917
#
# Epoch 00022: val_accuracy did not improve from 0.87500
# Epoch 23/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.6012 - accuracy: 0.7593 - val_loss: 0.3920 - val_accuracy: 0.7917
#
# Epoch 00023: val_accuracy did not improve from 0.87500
# Epoch 24/100
# 7/7 [==============================] - 2s 338ms/step - loss: 0.5353 - accuracy: 0.7731 - val_loss: 0.3242 - val_accuracy: 0.8750
#
# Epoch 00024: val_accuracy did not improve from 0.87500
# Epoch 25/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.6282 - accuracy: 0.7454 - val_loss: 0.3502 - val_accuracy: 0.8333
#
# Epoch 00025: val_accuracy did not improve from 0.87500
# Epoch 26/100
# 7/7 [==============================] - 2s 325ms/step - loss: 0.6338 - accuracy: 0.7315 - val_loss: 0.4266 - val_accuracy: 0.7917
#
# Epoch 00026: val_accuracy did not improve from 0.87500
# Epoch 27/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.6242 - accuracy: 0.7222 - val_loss: 0.3573 - val_accuracy: 0.7917
#
# Epoch 00027: val_accuracy did not improve from 0.87500
# Epoch 28/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.5944 - accuracy: 0.7500 - val_loss: 0.3551 - val_accuracy: 0.8333
#
# Epoch 00028: val_accuracy did not improve from 0.87500
# Epoch 29/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.5015 - accuracy: 0.7917 - val_loss: 0.3975 - val_accuracy: 0.7917
#
# Epoch 00029: val_accuracy did not improve from 0.87500
# Epoch 30/100
# 7/7 [==============================] - 3s 349ms/step - loss: 0.5613 - accuracy: 0.7269 - val_loss: 0.3542 - val_accuracy: 0.8750
#
# Epoch 00030: val_accuracy did not improve from 0.87500
# Epoch 31/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.5447 - accuracy: 0.7639 - val_loss: 0.3365 - val_accuracy: 0.7917
#
# Epoch 00031: val_accuracy did not improve from 0.87500
# Epoch 32/100
# 7/7 [==============================] - 2s 349ms/step - loss: 0.5521 - accuracy: 0.7500 - val_loss: 0.2860 - val_accuracy: 0.9583
#
# Epoch 00032: val_accuracy improved from 0.87500 to 0.95833, saving model to C:/Users/user/Desktop/saved_models_4\model_10.h5
# Epoch 33/100
# 7/7 [==============================] - 2s 334ms/step - loss: 0.5666 - accuracy: 0.7269 - val_loss: 0.2577 - val_accuracy: 0.9167
#
# Epoch 00033: val_accuracy did not improve from 0.95833
# Epoch 34/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.5691 - accuracy: 0.7593 - val_loss: 0.3168 - val_accuracy: 0.8750
#
# Epoch 00034: val_accuracy did not improve from 0.95833
# Epoch 35/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.5623 - accuracy: 0.7407 - val_loss: 0.3245 - val_accuracy: 0.8333
#
# Epoch 00035: val_accuracy did not improve from 0.95833
# Epoch 36/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.5452 - accuracy: 0.7963 - val_loss: 0.2534 - val_accuracy: 0.8750
#
# Epoch 00036: val_accuracy did not improve from 0.95833
# Epoch 37/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.5158 - accuracy: 0.7778 - val_loss: 0.3796 - val_accuracy: 0.8333
#
# Epoch 00037: val_accuracy did not improve from 0.95833
# Epoch 38/100
# 7/7 [==============================] - 2s 313ms/step - loss: 0.5260 - accuracy: 0.7963 - val_loss: 0.3595 - val_accuracy: 0.8333
# Epoch 00038: val_accuracy did not improve from 0.95833
# Epoch 39/100
# 7/7 [==============================] - 2s 311ms/step - loss: 0.4460 - accuracy: 0.8287 - val_loss: 0.3219 - val_accuracy: 0.9167
#
# Epoch 00039: val_accuracy did not improve from 0.95833
# Epoch 40/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.4719 - accuracy: 0.7917 - val_loss: 0.2382 - val_accuracy: 0.9167
#
# Epoch 00040: val_accuracy did not improve from 0.95833
# Epoch 41/100
# 7/7 [==============================] - 2s 346ms/step - loss: 0.5142 - accuracy: 0.7778 - val_loss: 0.3217 - val_accuracy: 0.8750
#
# Epoch 00041: val_accuracy did not improve from 0.95833
# Epoch 42/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.5312 - accuracy: 0.7778 - val_loss: 0.2275 - val_accuracy: 0.9167
#
# Epoch 00042: val_accuracy did not improve from 0.95833
# Epoch 43/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.4747 - accuracy: 0.7917 - val_loss: 0.2315 - val_accuracy: 0.8750
#
# Epoch 00043: val_accuracy did not improve from 0.95833
# Epoch 44/100
# 7/7 [==============================] - 2s 334ms/step - loss: 0.4480 - accuracy: 0.8009 - val_loss: 0.3723 - val_accuracy: 0.8750
#
# Epoch 00044: val_accuracy did not improve from 0.95833
# Epoch 45/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.4319 - accuracy: 0.8519 - val_loss: 0.4027 - val_accuracy: 0.7917
#
# Epoch 00045: val_accuracy did not improve from 0.95833
# Epoch 46/100
# 7/7 [==============================] - 2s 335ms/step - loss: 0.4122 - accuracy: 0.8519 - val_loss: 0.3236 - val_accuracy: 0.8750
#
# Epoch 00046: val_accuracy did not improve from 0.95833
# Epoch 47/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.4291 - accuracy: 0.8009 - val_loss: 0.3382 - val_accuracy: 0.8750
#
# Epoch 00047: val_accuracy did not improve from 0.95833
# Epoch 48/100
# 7/7 [==============================] - 2s 328ms/step - loss: 0.3875 - accuracy: 0.8380 - val_loss: 0.2932 - val_accuracy: 0.9167
#
# Epoch 00048: val_accuracy did not improve from 0.95833
# Epoch 49/100
# 7/7 [==============================] - 2s 325ms/step - loss: 0.4012 - accuracy: 0.8380 - val_loss: 0.3003 - val_accuracy: 0.8750
#
# Epoch 00049: val_accuracy did not improve from 0.95833
# Epoch 50/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.4271 - accuracy: 0.8380 - val_loss: 0.2856 - val_accuracy: 0.8750
#
# Epoch 00050: val_accuracy did not improve from 0.95833
# Epoch 51/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.4233 - accuracy: 0.8148 - val_loss: 0.2274 - val_accuracy: 0.9167
#
# Epoch 00051: val_accuracy did not improve from 0.95833
# Epoch 52/100
# 7/7 [==============================] - 2s 323ms/step - loss: 0.3971 - accuracy: 0.8519 - val_loss: 0.3516 - val_accuracy: 0.8333
#
# Epoch 00052: val_accuracy did not improve from 0.95833
# Epoch 53/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.3920 - accuracy: 0.8750 - val_loss: 0.2723 - val_accuracy: 0.8333
#
# Epoch 00053: val_accuracy did not improve from 0.95833
# Epoch 54/100
# 7/7 [==============================] - 2s 323ms/step - loss: 0.3302 - accuracy: 0.8981 - val_loss: 0.3538 - val_accuracy: 0.8750
#
# Epoch 00054: val_accuracy did not improve from 0.95833
# Epoch 55/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.4639 - accuracy: 0.8148 - val_loss: 0.4023 - val_accuracy: 0.7917
#
# Epoch 00055: val_accuracy did not improve from 0.95833
# Epoch 56/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.3749 - accuracy: 0.8426 - val_loss: 0.2461 - val_accuracy: 0.8750
#
# Epoch 00056: val_accuracy did not improve from 0.95833
# Epoch 57/100
# 7/7 [==============================] - 2s 324ms/step - loss: 0.3833 - accuracy: 0.8472 - val_loss: 0.2159 - val_accuracy: 0.9167
#
# Epoch 00057: val_accuracy did not improve from 0.95833
# Epoch 58/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.4440 - accuracy: 0.8102 - val_loss: 0.4422 - val_accuracy: 0.8333
#
# Epoch 00058: val_accuracy did not improve from 0.95833
# Epoch 59/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.3345 - accuracy: 0.8565 - val_loss: 0.2515 - val_accuracy: 0.8750
#
# Epoch 00059: val_accuracy did not improve from 0.95833
# Epoch 60/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.3912 - accuracy: 0.8611 - val_loss: 0.3579 - val_accuracy: 0.8333
#
# Epoch 00060: val_accuracy did not improve from 0.95833
# Epoch 61/100
# 7/7 [==============================] - 2s 321ms/step - loss: 0.3523 - accuracy: 0.8657 - val_loss: 0.2937 - val_accuracy: 0.8750
#
# Epoch 00061: val_accuracy did not improve from 0.95833
# Epoch 62/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.3910 - accuracy: 0.8611 - val_loss: 0.3362 - val_accuracy: 0.8333
#
# Epoch 00062: val_accuracy did not improve from 0.95833
# Epoch 63/100
# 7/7 [==============================] - 2s 331ms/step - loss: 0.3904 - accuracy: 0.8380 - val_loss: 0.3642 - val_accuracy: 0.8750
#
# Epoch 00063: val_accuracy did not improve from 0.95833
# Epoch 64/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.3820 - accuracy: 0.8611 - val_loss: 0.4318 - val_accuracy: 0.8333
#
# Epoch 00064: val_accuracy did not improve from 0.95833
# Epoch 65/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.3567 - accuracy: 0.8472 - val_loss: 0.3310 - val_accuracy: 0.8333
#
# Epoch 00065: val_accuracy did not improve from 0.95833
# Epoch 66/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.3358 - accuracy: 0.8611 - val_loss: 0.3592 - val_accuracy: 0.7917
#
# Epoch 00066: val_accuracy did not improve from 0.95833
# Epoch 67/100
# 7/7 [==============================] - 2s 314ms/step - loss: 0.3213 - accuracy: 0.8565 - val_loss: 0.3787 - val_accuracy: 0.8333
#
# Epoch 00067: val_accuracy did not improve from 0.95833
# Epoch 68/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.3015 - accuracy: 0.9028 - val_loss: 0.3622 - val_accuracy: 0.7917
#
# Epoch 00068: val_accuracy did not improve from 0.95833
# Epoch 69/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.3570 - accuracy: 0.8426 - val_loss: 0.3764 - val_accuracy: 0.8750
#
# Epoch 00069: val_accuracy did not improve from 0.95833
# Epoch 70/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.3360 - accuracy: 0.8796 - val_loss: 0.2410 - val_accuracy: 0.8750
#
# Epoch 00070: val_accuracy did not improve from 0.95833
# Epoch 71/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.2984 - accuracy: 0.8981 - val_loss: 0.3651 - val_accuracy: 0.9167
#
# Epoch 00071: val_accuracy did not improve from 0.95833
# Epoch 72/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.3675 - accuracy: 0.8611 - val_loss: 0.3197 - val_accuracy: 0.8750
#
# Epoch 00072: val_accuracy did not improve from 0.95833
# Epoch 73/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.2983 - accuracy: 0.8657 - val_loss: 0.3980 - val_accuracy: 0.8333
#
# Epoch 00073: val_accuracy did not improve from 0.95833
# Epoch 74/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.3024 - accuracy: 0.8981 - val_loss: 0.4095 - val_accuracy: 0.8333
#
# Epoch 00074: val_accuracy did not improve from 0.95833
# Epoch 75/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.3526 - accuracy: 0.8565 - val_loss: 0.2474 - val_accuracy: 0.9167
#
# Epoch 00075: val_accuracy did not improve from 0.95833
# Epoch 76/100
# 7/7 [==============================] - 2s 315ms/step - loss: 0.3060 - accuracy: 0.8843 - val_loss: 0.2885 - val_accuracy: 0.8750
#
# Epoch 00076: val_accuracy did not improve from 0.95833
# Epoch 77/100
# 7/7 [==============================] - 2s 316ms/step - loss: 0.3207 - accuracy: 0.8657 - val_loss: 0.1854 - val_accuracy: 0.9167
#
# Epoch 00077: val_accuracy did not improve from 0.95833
# Epoch 78/100
# 7/7 [==============================] - 2s 336ms/step - loss: 0.2748 - accuracy: 0.9167 - val_loss: 0.2693 - val_accuracy: 0.8750
#
# Epoch 00078: val_accuracy did not improve from 0.95833
# Epoch 79/100
# 7/7 [==============================] - 2s 323ms/step - loss: 0.2925 - accuracy: 0.8750 - val_loss: 0.2891 - val_accuracy: 0.8750
#
# Epoch 00079: val_accuracy did not improve from 0.95833
# Epoch 80/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.2943 - accuracy: 0.8981 - val_loss: 0.1852 - val_accuracy: 0.9167
#
# Epoch 00080: val_accuracy did not improve from 0.95833
# Epoch 81/100
# 7/7 [==============================] - 2s 347ms/step - loss: 0.3379 - accuracy: 0.8611 - val_loss: 0.3248 - val_accuracy: 0.8333
#
# Epoch 00081: val_accuracy did not improve from 0.95833
# Epoch 82/100
# 7/7 [==============================] - 2s 341ms/step - loss: 0.3375 - accuracy: 0.8750 - val_loss: 0.2869 - val_accuracy: 0.8750
#
# Epoch 00082: val_accuracy did not improve from 0.95833
# Epoch 83/100
# 7/7 [==============================] - 2s 347ms/step - loss: 0.3161 - accuracy: 0.8981 - val_loss: 0.2114 - val_accuracy: 0.9583
#
# Epoch 00083: val_accuracy did not improve from 0.95833
# Epoch 84/100
# 7/7 [==============================] - 3s 351ms/step - loss: 0.2620 - accuracy: 0.8981 - val_loss: 0.3594 - val_accuracy: 0.8750
#
# Epoch 00084: val_accuracy did not improve from 0.95833
# Epoch 85/100
# 7/7 [==============================] - 2s 347ms/step - loss: 0.3218 - accuracy: 0.8565 - val_loss: 0.3743 - val_accuracy: 0.8750
#
# Epoch 00085: val_accuracy did not improve from 0.95833
# Epoch 86/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.3003 - accuracy: 0.8704 - val_loss: 0.2965 - val_accuracy: 0.8750
#
# Epoch 00086: val_accuracy did not improve from 0.95833
# Epoch 87/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.2733 - accuracy: 0.8889 - val_loss: 0.3501 - val_accuracy: 0.8750
#
# Epoch 00087: val_accuracy did not improve from 0.95833
# Epoch 88/100
# 7/7 [==============================] - 2s 317ms/step - loss: 0.2998 - accuracy: 0.8750 - val_loss: 0.3068 - val_accuracy: 0.9167
#
# Epoch 00088: val_accuracy did not improve from 0.95833
# Epoch 89/100
# 7/7 [==============================] - 2s 318ms/step - loss: 0.2383 - accuracy: 0.9167 - val_loss: 0.2070 - val_accuracy: 0.9167
#
# Epoch 00089: val_accuracy did not improve from 0.95833
# Epoch 90/100
# 7/7 [==============================] - 2s 326ms/step - loss: 0.2474 - accuracy: 0.9028 - val_loss: 0.2303 - val_accuracy: 0.9167
#
# Epoch 00090: val_accuracy did not improve from 0.95833
# Epoch 91/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.2537 - accuracy: 0.9074 - val_loss: 0.2192 - val_accuracy: 0.9167
#
# Epoch 00091: val_accuracy did not improve from 0.95833
# Epoch 92/100
# 7/7 [==============================] - 2s 332ms/step - loss: 0.2547 - accuracy: 0.9306 - val_loss: 0.1953 - val_accuracy: 0.9167
#
# Epoch 00092: val_accuracy did not improve from 0.95833
# Epoch 93/100
# 7/7 [==============================] - 2s 327ms/step - loss: 0.3037 - accuracy: 0.8750 - val_loss: 0.3238 - val_accuracy: 0.8333
#
# Epoch 00093: val_accuracy did not improve from 0.95833
# Epoch 94/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.3115 - accuracy: 0.8843 - val_loss: 0.4073 - val_accuracy: 0.8333
#
# Epoch 00094: val_accuracy did not improve from 0.95833
# Epoch 95/100
# 7/7 [==============================] - 2s 325ms/step - loss: 0.2506 - accuracy: 0.9259 - val_loss: 0.2089 - val_accuracy: 0.9167
#
# Epoch 00095: val_accuracy did not improve from 0.95833
# Epoch 96/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.2404 - accuracy: 0.9074 - val_loss: 0.2861 - val_accuracy: 0.9167
#
# Epoch 00096: val_accuracy did not improve from 0.95833
# Epoch 97/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.2374 - accuracy: 0.9213 - val_loss: 0.2182 - val_accuracy: 0.9167
#
# Epoch 00097: val_accuracy did not improve from 0.95833
# Epoch 98/100
# 7/7 [==============================] - 2s 338ms/step - loss: 0.2339 - accuracy: 0.9167 - val_loss: 0.3009 - val_accuracy: 0.8750
#
# Epoch 00098: val_accuracy did not improve from 0.95833
# Epoch 99/100
# 7/7 [==============================] - 2s 320ms/step - loss: 0.2510 - accuracy: 0.8981 - val_loss: 0.2755 - val_accuracy: 0.8750
#
# Epoch 00099: val_accuracy did not improve from 0.95833
# Epoch 100/100
# 7/7 [==============================] - 2s 312ms/step - loss: 0.2749 - accuracy: 0.9167 - val_loss: 0.2718 - val_accuracy: 0.9167
#
# Epoch 00100: val_accuracy did not improve from 0.95833
# 1/1 [==============================] - 0s 296ms/step - loss: 0.3473 - accuracy: 0.8333
# {'loss': 0.3473339080810547, 'accuracy': 0.8333333134651184}

# %%
print("Validation Accuracy of All Folds:")
print(VALIDATION_ACCURACY)
print("Mean Validation Accuracy: " + str(np.mean(VALIDATION_ACCURACY)))
print("")
print("Validation Loss of All Folds:")
print(VALIDATION_LOSS)
print("Mean Validation Loss: " + str(np.mean(VALIDATION_LOSS)))
# Out:
# Validation Accuracy of All Folds:
# [0.875, 0.8333333134651184, 0.75, 0.7083333134651184, 0.7083333134651184, 0.9166666865348816, 0.7083333134651184, 0.7916666865348816, 0.875, 0.8333333134651184]
# Mean Validation Accuracy: 0.7999999940395355
#
# Validation Loss of All Folds:
# [0.29400864243507385, 0.4309910237789154, 0.5706479549407959, 0.7240538597106934, 0.7023529410362244, 0.37409552931785583, 0.7126215100288391, 0.47306641936302185, 0.2944057285785675, 0.3473339080810547]
# Mean Validation Loss: 0.49235775172710416

# %% [markdown]
# ## Model Prediction

# %% [markdown]
# Recreate the structure of the model used and load the weights

# %%
resnet50 = keras.applications.resnet50

conv_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in conv_model.layers:
    layer.trainable = False

x = keras.layers.Flatten()(conv_model.output)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.BatchNormalization()(x)

x = keras.layers.Dropout(0.5)(x) #to further reduce overfitting

predictions = keras.layers.Dense(3, activation='softmax')(x)
full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

model_dir = "C:/Users/user/Desktop/saved_models_4/model_5.h5"

full_model.load_weights(model_dir)

# %% [markdown]
# load images in the test set and predict what class it is by using the model. There are three values of accuracy. The one with the highest accuracy is the predicted class of the image.

# %%
from keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input

for img_path in X_test['filename']:
    img = image.load_img(img_path, target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    print(x.shape)
    print(img_path)
    print(full_model.predict(x))
    #print(full_model.predict_classes(x))
    #plt.imshow(img)
# Out:
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_14561032_480555.jpg
# [[0.9783675  0.01794994 0.00368259]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_65813878_960629.jpg
# [[0.9077366  0.06092509 0.03133831]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_3320901_987553.jpg
# [[0.00841348 0.03224187 0.9593447 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_90116739_661402.jpg
# [[0.06118993 0.1022035  0.83660656]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_40672127_52189.jpg
# [[0.02490501 0.01435801 0.960737  ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_87310373_255859.jpg
# [[0.48124662 0.336812   0.18194136]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_59278556_603169.jpg
# [[0.05368736 0.03139573 0.91491693]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_5885629_848766.jpg
# [[0.9236627  0.07331542 0.00302186]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_71910019_939104.jpg
# [[0.00472363 0.08598945 0.9092869 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_94525633_953337.jpg
# [[0.9660352  0.01047181 0.02349308]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_92744614_66270.jpg
# [[0.75979364 0.1935032  0.04670318]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_51050353_753541.jpg
# [[0.01970222 0.33960614 0.64069164]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_36857253_76473.jpg
# [[0.5012999  0.42299935 0.07570074]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_42306932_128783.jpg
# [[0.01986303 0.2046911  0.7754458 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_97349710_977103.jpg
# [[0.00155694 0.921648   0.07679504]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_77228917_910060.jpg
# [[0.1577627  0.44645837 0.39577895]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_45027092_814622.jpg
# [[0.3166334  0.3665161  0.31685045]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_10591581_805434.jpg
# [[6.3883612e-04 1.3371304e-03 9.9802411e-01]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_52075739_20206.jpg
# [[0.986967   0.00909715 0.00393586]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_1383524_100570.jpg
# [[0.9627164  0.0178559  0.01942777]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_98716867_906060.jpg
# [[0.02869    0.42195734 0.54935265]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_63368385_44965.jpg
# [[0.8742081  0.08505542 0.0407365 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_36933480_526654.jpg
# [[0.63768053 0.21166284 0.1506566 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_89021638_30333.jpg
# [[0.01391402 0.95728207 0.02880394]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_43780253_141623.jpg
# [[0.00257855 0.82834494 0.16907652]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_86539082_856767.jpg
# [[0.9920556  0.00465617 0.00328814]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_38202332_660007.jpg
# [[0.8691788  0.0529235  0.07789768]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_84865668_841817.jpg
# [[0.159991   0.568667   0.27134198]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_36338138_748432.jpg
# [[0.00570039 0.9746766  0.01962293]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_53304743_912297.jpg
# [[0.02040729 0.7207896  0.25880307]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_39190796_597268.jpg
# [[0.9869898  0.00328821 0.00972203]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_25584911_158735.jpg
# [[0.00545208 0.550348   0.4441999 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_52854179_92860.jpg
# [[0.12717809 0.60224026 0.27058166]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_95303549_243152.jpg
# [[0.9905399  0.00785137 0.00160871]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_18530849_316083.jpg
# [[0.00152912 0.03153687 0.966934  ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_58437301_819560.jpg
# [[0.00399815 0.19003505 0.8059668 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_23460807_662938.jpg
# [[0.00629842 0.7603766  0.23332506]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_58221518_771595.jpg
# [[0.9183939  0.03015696 0.05144908]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_75910767_570517.jpg
# [[0.778502   0.1747794  0.04671858]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_84121561_727338.jpg
# [[0.00555087 0.9886728  0.00577622]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_89264514_657894.jpg
# [[0.00096157 0.08130199 0.9177365 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_20116921_618526.jpg
# [[0.01633109 0.07700335 0.9066656 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_31254041_727562.jpg
# [[0.01865173 0.31401408 0.66733414]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_8857677_434759.jpg
# [[0.0165807  0.04561478 0.9378045 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_90903672_101265.jpg
# [[0.9661264  0.02787642 0.0059972 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_77145530_745010.jpg
# [[0.96308607 0.03182055 0.00509336]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_98734271_490112.jpg
# [[0.09752964 0.56207526 0.34039512]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_7269637_133276.jpg
# [[0.00917947 0.06635885 0.9244617 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_48062669_774929.jpg
# [[0.0080415  0.843316   0.14864253]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_9423504_615383.jpg
# [[0.00976102 0.03191483 0.95832413]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_18187192_670709.jpg
# [[0.02639498 0.1303145  0.8432905 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_20324227_896785.jpg
# [[0.00859381 0.9393133  0.05209284]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_10458701_413477.jpg
# [[0.01889502 0.02996848 0.95113647]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_28736655_330343.jpg
# [[0.9743954  0.01188754 0.01371707]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_40771331_364830.jpg
# [[0.51788336 0.24937731 0.2327393 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_52511152_488670.jpg
# [[0.07510682 0.03525895 0.88963425]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_94620718_237328.jpg
# [[0.27770078 0.01835104 0.70394814]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_71147075_840384.jpg
# [[0.02663769 0.35859397 0.6147683 ]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_16383631_138695.jpg
# [[0.01326496 0.12637264 0.86036235]]
# (1, 224, 224, 3)
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\IMG_70188440_314825.jpg
# [[0.02192986 0.91559815 0.0624719 ]]

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Model Metrics such as precision will then be acquired from the predictions of the whole test set.

# %%
test_set = "C:/Users/user/Desktop/Dataset/ToBeUsed/test_set"

testX = []

for img_path in X_test['filename']:
    img = image.load_img(img_path, target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    x = x.reshape(224,224,3)
    testX.append(x)

testX = np.array(testX)    
    
#print(testX)
    
# predict probabilities for test set, y_test
yhat_probs = full_model.predict(testX, verbose=0)
print(yhat_probs)

# predict crisp classes for test set
yhat_classes = yhat_probs.argmax(axis=-1)
print(yhat_classes)

yh_classes = [[x] for x in yhat_classes]
print(type(yh_classes))
yh_classes = np.array(yh_classes)
print(type(yh_classes))
print(type(yh_classes[0]))
print(yh_classes)
# Out:
# [[9.78367388e-01 1.79499611e-02 3.68260639e-03]
#  [9.07736659e-01 6.09250329e-02 3.13382633e-02]
#  [8.41360353e-03 3.22416909e-02 9.59344685e-01]
#  [6.11894652e-02 1.02201514e-01 8.36609006e-01]
#  [2.49050446e-02 1.43580521e-02 9.60736930e-01]
#  [4.81248885e-01 3.36809844e-01 1.81941241e-01]
#  [5.36883697e-02 3.13963406e-02 9.14915323e-01]
#  [9.23661232e-01 7.33168572e-02 3.02188797e-03]
#  [4.72359313e-03 8.59887749e-02 9.09287691e-01]
#  [9.66035068e-01 1.04718003e-02 2.34932285e-02]
#  [7.59794235e-01 1.93502218e-01 4.67035398e-02]
#  [1.97018422e-02 3.39599043e-01 6.40699089e-01]
#  [5.01301467e-01 4.22997087e-01 7.57014379e-02]
#  [1.98630746e-02 2.04688624e-01 7.75448382e-01]
#  [1.55695039e-03 9.21647906e-01 7.67950937e-02]
#  [1.57764897e-01 4.46453601e-01 3.95781517e-01]
#  [3.16632092e-01 3.66511375e-01 3.16856533e-01]
#  [6.38852594e-04 1.33711949e-03 9.98024106e-01]
#  [9.86967146e-01 9.09703318e-03 3.93587258e-03]
#  [9.62716937e-01 1.78556219e-02 1.94275454e-02]
#  [2.86899786e-02 4.21958864e-01 5.49351096e-01]
#  [8.74208629e-01 8.50543976e-02 4.07369286e-02]
#  [6.37682617e-01 2.11661562e-01 1.50655806e-01]
#  [1.39137832e-02 9.57282245e-01 2.88039427e-02]
#  [2.57850112e-03 8.28348637e-01 1.69072911e-01]
#  [9.92055714e-01 4.65612346e-03 3.28810979e-03]
#  [8.69180441e-01 5.29230461e-02 7.78965577e-02]
#  [1.59989834e-01 5.68664908e-01 2.71345258e-01]
#  [5.70035866e-03 9.74676728e-01 1.96229052e-02]
#  [2.04074271e-02 7.20792234e-01 2.58800387e-01]
#  [9.86989915e-01 3.28813749e-03 9.72200092e-03]
#  [5.45198936e-03 5.50351858e-01 4.44196105e-01]
#  [1.27177402e-01 6.02241576e-01 2.70581007e-01]
#  [9.90539789e-01 7.85144046e-03 1.60872564e-03]
#  [1.52914634e-03 3.15364972e-02 9.66934323e-01]
#  [3.99818970e-03 1.90035656e-01 8.05966198e-01]
#  [6.29842980e-03 7.60374308e-01 2.33327225e-01]
#  [9.18393314e-01 3.01571563e-02 5.14494888e-02]
#  [7.78503954e-01 1.74777597e-01 4.67184633e-02]
#  [5.55083947e-03 9.88673031e-01 5.77613339e-03]
#  [9.61561047e-04 8.13012123e-02 9.17737186e-01]
#  [1.63312033e-02 7.70046934e-02 9.06664133e-01]
#  [1.86519194e-02 3.14015746e-01 6.67332351e-01]
#  [1.65807735e-02 4.56149615e-02 9.37804222e-01]
#  [9.66125846e-01 2.78767925e-02 5.99733554e-03]
#  [9.63086009e-01 3.18206251e-02 5.09332027e-03]
#  [9.75299850e-02 5.62077463e-01 3.40392530e-01]
#  [9.17945243e-03 6.63591549e-02 9.24461424e-01]
#  [8.04141443e-03 8.43315125e-01 1.48643553e-01]
#  [9.76105407e-03 3.19151171e-02 9.58323836e-01]
#  [2.63946820e-02 1.30314007e-01 8.43291283e-01]
#  [8.59380700e-03 9.39313233e-01 5.20929880e-02]
#  [1.88948400e-02 2.99680512e-02 9.51137125e-01]
#  [9.74395156e-01 1.18877757e-02 1.37171084e-02]
#  [5.17884195e-01 2.49373078e-01 2.32742772e-01]
#  [7.51071349e-02 3.52585018e-02 8.89634371e-01]
#  [2.77702123e-01 1.83511861e-02 7.03946650e-01]
#  [2.66372953e-02 3.58591884e-01 6.14770830e-01]
#  [1.32648526e-02 1.26371011e-01 8.60364139e-01]
#  [2.19298434e-02 9.15598512e-01 6.24716543e-02]]
# [0 0 2 2 2 0 2 0 2 0 0 2 0 2 1 1 1 2 0 0 2 0 0 1 1 0 0 1 1 1 0 1 1 0 2 2 1
#  0 0 1 2 2 2 2 0 0 1 2 1 2 2 1 2 0 0 2 2 2 2 1]
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [[0]
#  [0]
#  [2]
#  [2]
#  [2]
#  [0]
#  [2]
#  [0]
#  [2]
#  [0]
#  [0]
#  [2]
#  [0]
#  [2]
#  [1]
#  [1]
#  [1]
#  [2]
#  [0]
#  [0]
#  [2]
#  [0]
#  [0]
#  [1]
#  [1]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [1]
#  [0]
#  [2]
#  [2]
#  [1]
#  [0]
#  [0]
#  [1]
#  [2]
#  [2]
#  [2]
#  [2]
#  [0]
#  [0]
#  [1]
#  [2]
#  [1]
#  [2]
#  [2]
#  [1]
#  [2]
#  [0]
#  [0]
#  [2]
#  [2]
#  [2]
#  [2]
#  [1]]

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yh_classes = yh_classes[:, 0]

# %%
#for x in X_test['filename']:
#    print(x)

# %%
#print(y_test)
#print(y_test.dtypes)

#make the labels to integer to get the model metrics
y_test['label'] = pd.to_numeric(y_test['label'])

#print(y_test)
#print(y_test.dtypes)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15056/3793398402.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test['label'] = pd.to_numeric(y_test['label'])

# %%
yt = y_test.to_numpy()
yt = yt.reshape(len(y_test))
yt = np.array(yt)

#print(yt)


#print(yhat_classes)

#print(yt.shape)
#print(yhat_classes.shape)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes, average="weighted")
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes, average="weighted")
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes, average="weighted")
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.783333
# Precision: 0.783471
# Recall: 0.783333
# F1 score: 0.779227

# %%
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15056/3721053162.py in <module>
#       1 # ROC AUC
# ----> 2 auc = roc_auc_score(y_test, yhat_probs)
#       3 print('ROC AUC: %f' % auc)
#
# NameError: name 'roc_auc_score' is not defined

# %%
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)
# Out:
# [[19  1  0]
#  [ 1 12  7]
#  [ 1  3 16]]

# %%
print(matrix.shape[1])
# Out:
# 3

# %%
df_cm = pd.DataFrame(matrix, range(matrix.shape[0]), range(matrix.shape[1]))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()
