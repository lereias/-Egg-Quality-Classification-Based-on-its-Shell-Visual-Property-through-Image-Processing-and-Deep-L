# %% [markdown]
# ## Imports

# %%
# openCV to concatenate
import cv2

# for image name
import random

# define and move to dataset directory
import os

#for stopping code
import sys

#expanding dataset using data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# duplicate combined image and its augment to other directory
import shutil

#for color correction to undo what ImageDataGenerator does
import numpy as np

import tensorflow.keras as keras

# %%
# the directory where the data is stored
directory = "C:/Users/user/Desktop/Dataset"

# %% [markdown]
# ## Crop Image to Reduce Background

# %% [markdown]
# We shall crop the image in order to reduce the background so that the egg in the image would be more focused on. The cropping procedure will not affect the size diference of the eggs from one another.

# %%
tadirect = directory + "/FourAngleEggs"
#crop width and height
width = 3600
height = 3600

for x in os.listdir(tadirect):
    directory2 = ""
    directory2 = tadirect + "/" + x     #images to be cropped
    
    curdir = os.listdir(directory2)
    
    for y in curdir:
        if x == "Balut-penoy":
            tempim1 = directory2 + "/" + y

            im1 = cv2.imread(tempim1)

            center = (im1.shape[0] / 2, im1.shape[1] / 2)
            #print(center)
            w = center[0] - width/2
            h = center[1] - height/2

            #slicing to perform cropping
            print("cropping " + y + " in dimensions (" + str(width) + "," + str(height) + ")")
            crop_img = im1[int(h):int(h+width), int(w):int(w+height)]

            #save and replace the image
            cv2.imwrite(tempim1, crop_img)
            print("crop finish " + y)
            
        else:
            for z in os.listdir(directory2 + "/" + y):
                tempim1 = directory2 + "/" + y + "/" + z

                im1 = cv2.imread(tempim1)

                center = (im1.shape[0] / 2, im1.shape[1] / 2)
                #print(center)
                w = center[0] - width/2
                h = center[1] - height/2

                #slicing to perform cropping
                print("cropping " + z + " in dimensions (" + str(width) + "," + str(height) + ")")
                crop_img = im1[int(h):int(h+width), int(w):int(w+height)]

                #save and replace the image
                cv2.imwrite(tempim1, crop_img)
                print("crop finish " + z)

print("\nAll finished")

# %% [markdown]
# ## Concatenate Four Angles of Egg

# %% [markdown]
# Four images of an egg are taken (the front, back, top, bottom). We will combine all of them to represent the entire egg.

# %%
tadirect = directory + "/FourAngleEggs"
combfour = directory + "/CombinedFourAngleEggs"

if not os.path.exists(combfour):
    os.makedirs(combfour)

#check if there is the right amount of images (1 for each angle of egg)
for w in os.listdir(tadirect):
    directory2 = ""
    directory2 = tadirect + "/" + w
    
    if w == "Balut-penoy":
        curdir = os.listdir(directory2)

        #number of files in directory
        filecnt = len([name for name in curdir])

        if filecnt%4 == 1:
            print("ERROR (" + w + "): Incorrect number of images.")
            sys.exit()
            
    else:
        for v in os.listdir(directory2):
            directory3 = directory2 + "/" + v
            
            curdir = os.listdir(directory3)
            
            #number of files in directory
            filecnt = len([name for name in curdir])

            if filecnt%4 == 1:
                print("ERROR (" + w + "): Incorrect number of images.")
                sys.exit()

for x in os.listdir(tadirect):
    directory2 = ""
    directory2 = tadirect + "/" + x                             #where the two images of two angles of egg is stored
    directory3 = directory  + "/CombinedFourAngleEggs/" + x     #where to put the combined image of the angles
    
    if x == "Balut-penoy":
        curdir = os.listdir(directory2)
        #number of files in directory
        filecnt = len([name for name in curdir])
        
        i = 1
        for y in range(filecnt):

            if y%4 == 0:
                tempim1 = directory2 + "/" + curdir[y]
                im1 = cv2.imread(tempim1)
                tempim2 = directory2 + "/" + curdir[y+1]
                im2 = cv2.imread(tempim2)
                tempim3 = directory2 + "/" + curdir[y+2]
                im3 = cv2.imread(tempim3)
                tempim4 = directory2 + "/" + curdir[y+3]
                im4 = cv2.imread(tempim4)

                #resize for ResNet50
                width = 224
                height = 224

                dim = (width,height)

                im_v = cv2.vconcat([cv2.resize(im1, dim), cv2.resize(im2, dim)])
                im_v2 = cv2.vconcat([cv2.resize(im3, dim), cv2.resize(im4, dim)])
                im_v3 = cv2.hconcat([im_v, im_v2])
                # show the output image
                #cv2.imshow("image",im_v)
                #cv2.waitkey(0)

                #save image
                #create folder to store concatenated images if not existing
                newpath = directory3 + "2"
                if not os.path.exists(newpath):
                    os.makedirs(newpath)

                #combine_img = newpath + "/IMG_" + str(random.randint(0,99999999)) + "_" + str(random.randint(0,999999)) + ".jpg"
                combine_img = newpath + "/" + x + " " + str(i) + ".jpg"

                i += 1

                cv2.imwrite(combine_img,cv2.resize(im_v3, dim))

                print(curdir[y] + " , " + curdir[y+1] + " , " + curdir[y+2] + " , " + curdir[y+3] + " combined.")
                 
    else:
        for y in os.listdir(directory2):
            directory4 = ""
            directory4 = directory2 + "/" + y
            
            curdir = os.listdir(directory4)
            #number of files in directory
            filecnt = len([name for name in curdir])
            
            i = 1
            for z in range(filecnt):
                if z%4 == 0:
                    tempim1 = directory4 + "/" + curdir[z]
                    im1 = cv2.imread(tempim1)
                    tempim2 = directory4 + "/" + curdir[z+1]
                    im2 = cv2.imread(tempim2)
                    tempim3 = directory4 + "/" + curdir[z+2]
                    im3 = cv2.imread(tempim3)
                    tempim4 = directory4 + "/" + curdir[z+3]
                    im4 = cv2.imread(tempim4)

                    #resize for ResNet50
                    width = 224
                    height = 224

                    dim = (width,height)

                    im_v = cv2.vconcat([cv2.resize(im1, dim), cv2.resize(im2, dim)])
                    im_v2 = cv2.vconcat([cv2.resize(im3, dim), cv2.resize(im4, dim)])
                    im_v3 = cv2.hconcat([im_v, im_v2])
                    # show the output image
                    #cv2.imshow("image",im_v)
                    #cv2.waitkey(0)

                    #save image
                    #create folder to store concatenated images if not existing
                    newpath = directory3 + "2"
                    if not os.path.exists(newpath):
                        os.makedirs(newpath)

                    #combine_img = newpath + "/IMG_" + str(random.randint(0,99999999)) + "_" + str(random.randint(0,999999)) + ".jpg"
                    combine_img = newpath + "/" + x + "_" + y + " " + str(i) + ".jpg"

                    i += 1

                    cv2.imwrite(combine_img,cv2.resize(im_v3, dim))

                    print(curdir[z] + " , " + curdir[z+1] + " , " + curdir[z+2] + " , " + curdir[z+3] + " combined.")
        
print("All finished")

# %% [markdown]
# ## Expand dataset using Data Augmentation

# %% [markdown]
# Due to the lack of data in the dataset, we will produce additional images using data augmentation. The generation of images saved is not the exact amount due to the random name generation of it. There is a chance of overreading images. Here is the link: https://github.com/keras-team/keras/issues/8249

# %%
resnet50 = keras.applications.resnet50

imgdatagen = ImageDataGenerator(
        #preprocessing_function = resnet50.preprocess_input,
        width_shift_range = 10,
        height_shift_range = 5,
        fill_mode="nearest",
        )

# %%
tadirect = directory + "/CombinedFourAngleEggs"
augtadirect = directory + "/AugCombinedFourAngleEggs"

if not os.path.exists(augtadirect):
    os.makedirs(augtadirect)

for ta in os.listdir(tadirect):
    tadirect2 = tadirect + "/" + ta
    print("\n\n" + str(len(os.listdir(tadirect2))) + "\n\n")
    augtadirect2 = augtadirect + "/" + ta[:-1] + "3"
    #print(augtadirect2)
    
    if ta == "Balut-penoy2":
        datanumero = 4
    elif ta == "Salted egg2":
        datanumero = 1
    else:
        datanumero = 2 
    
    if not os.path.exists(augtadirect2):
        os.makedirs(augtadirect2)
    
    for f in os.listdir(tadirect2):
        print(f)
        tadirect3 = tadirect2 + "/" + f
        #print(tadirect3)
        
        img = load_img(tadirect3)  
        x = img_to_array(img) 
        # Reshape the input image 
        x = x.reshape((1, ) + x.shape)  
        i = 1

        # generate augmented images 
        for batch in imgdatagen.flow(x, batch_size = 50, 
                          save_to_dir = augtadirect2,  
                          save_prefix ='aug', save_format ='jpeg'):
            i += 1
            if i > datanumero: 
                break
# Out:
# 50
#
#
# Balut-penoy 1.jpg
# Balut-penoy 10.jpg
# Balut-penoy 11.jpg
# Balut-penoy 12.jpg
# Balut-penoy 13.jpg
# Balut-penoy 14.jpg
# Balut-penoy 15.jpg
# Balut-penoy 16.jpg
# Balut-penoy 17.jpg
# Balut-penoy 18.jpg
# Balut-penoy 19.jpg
# Balut-penoy 2.jpg
# Balut-penoy 20.jpg
# Balut-penoy 21.jpg
# Balut-penoy 22.jpg
# Balut-penoy 23.jpg
# Balut-penoy 24.jpg
# Balut-penoy 25.jpg
# Balut-penoy 26.jpg
# Balut-penoy 27.jpg
# Balut-penoy 28.jpg
# Balut-penoy 29.jpg
# Balut-penoy 3.jpg
# Balut-penoy 30.jpg
# Balut-penoy 31.jpg
# Balut-penoy 32.jpg
# Balut-penoy 33.jpg
# Balut-penoy 34.jpg
# Balut-penoy 35.jpg
# Balut-penoy 36.jpg
# Balut-penoy 37.jpg
# Balut-penoy 38.jpg
# Balut-penoy 39.jpg
# Balut-penoy 4.jpg
# Balut-penoy 40.jpg
# Balut-penoy 41.jpg
# Balut-penoy 42.jpg
# Balut-penoy 43.jpg
# Balut-penoy 44.jpg
# Balut-penoy 45.jpg
# Balut-penoy 46.jpg
# Balut-penoy 47.jpg
# Balut-penoy 48.jpg
# Balut-penoy 49.jpg
# Balut-penoy 5.jpg
# Balut-penoy 50.jpg
# Balut-penoy 6.jpg
# Balut-penoy 7.jpg
# Balut-penoy 8.jpg
# Balut-penoy 9.jpg
#
#
# 149
#
#
# Salted egg_dirty 1.jpg
# Salted egg_dirty 10.jpg
# Salted egg_dirty 11.jpg
# Salted egg_dirty 12.jpg
# Salted egg_dirty 13.jpg
# Salted egg_dirty 14.jpg
# Salted egg_dirty 15.jpg
# Salted egg_dirty 16.jpg
# Salted egg_dirty 17.jpg
# Salted egg_dirty 18.jpg
# Salted egg_dirty 19.jpg
# Salted egg_dirty 2.jpg
# Salted egg_dirty 20.jpg
# Salted egg_dirty 21.jpg
# Salted egg_dirty 22.jpg
# Salted egg_dirty 23.jpg
# Salted egg_dirty 24.jpg
# Salted egg_dirty 25.jpg
# Salted egg_dirty 26.jpg
# Salted egg_dirty 27.jpg
# Salted egg_dirty 28.jpg
# Salted egg_dirty 29.jpg
# Salted egg_dirty 3.jpg
# Salted egg_dirty 30.jpg
# Salted egg_dirty 31.jpg
# Salted egg_dirty 32.jpg
# Salted egg_dirty 33.jpg
# Salted egg_dirty 4.jpg
# Salted egg_dirty 5.jpg
# Salted egg_dirty 6.jpg
# Salted egg_dirty 7.jpg
# Salted egg_dirty 8.jpg
# Salted egg_dirty 9.jpg
# Salted egg_hairline cracks 1.jpg
# Salted egg_hairline cracks 10.jpg
# Salted egg_hairline cracks 11.jpg
# Salted egg_hairline cracks 12.jpg
# Salted egg_hairline cracks 13.jpg
# Salted egg_hairline cracks 14.jpg
# Salted egg_hairline cracks 15.jpg
# Salted egg_hairline cracks 16.jpg
# Salted egg_hairline cracks 17.jpg
# Salted egg_hairline cracks 18.jpg
# Salted egg_hairline cracks 19.jpg
# Salted egg_hairline cracks 2.jpg
# Salted egg_hairline cracks 20.jpg
# Salted egg_hairline cracks 21.jpg
# Salted egg_hairline cracks 22.jpg
# Salted egg_hairline cracks 23.jpg
# Salted egg_hairline cracks 24.jpg
# Salted egg_hairline cracks 25.jpg
# Salted egg_hairline cracks 26.jpg
# Salted egg_hairline cracks 27.jpg
# Salted egg_hairline cracks 28.jpg
# Salted egg_hairline cracks 29.jpg
# Salted egg_hairline cracks 3.jpg
# Salted egg_hairline cracks 30.jpg
# Salted egg_hairline cracks 31.jpg
# Salted egg_hairline cracks 32.jpg
# Salted egg_hairline cracks 33.jpg
# Salted egg_hairline cracks 34.jpg
# Salted egg_hairline cracks 35.jpg
# Salted egg_hairline cracks 36.jpg
# Salted egg_hairline cracks 37.jpg
# Salted egg_hairline cracks 38.jpg
# Salted egg_hairline cracks 39.jpg
# Salted egg_hairline cracks 4.jpg
# Salted egg_hairline cracks 40.jpg
# Salted egg_hairline cracks 41.jpg
# Salted egg_hairline cracks 42.jpg
# Salted egg_hairline cracks 43.jpg
# Salted egg_hairline cracks 44.jpg
# Salted egg_hairline cracks 45.jpg
# Salted egg_hairline cracks 46.jpg
# Salted egg_hairline cracks 47.jpg
# Salted egg_hairline cracks 48.jpg
# Salted egg_hairline cracks 49.jpg
# Salted egg_hairline cracks 5.jpg
# Salted egg_hairline cracks 50.jpg
# Salted egg_hairline cracks 51.jpg
# Salted egg_hairline cracks 52.jpg
# Salted egg_hairline cracks 53.jpg
# Salted egg_hairline cracks 54.jpg
# Salted egg_hairline cracks 55.jpg
# Salted egg_hairline cracks 56.jpg
# Salted egg_hairline cracks 57.jpg
# Salted egg_hairline cracks 58.jpg
# Salted egg_hairline cracks 59.jpg
# Salted egg_hairline cracks 6.jpg
# Salted egg_hairline cracks 60.jpg
# Salted egg_hairline cracks 61.jpg
# Salted egg_hairline cracks 62.jpg
# Salted egg_hairline cracks 63.jpg
# Salted egg_hairline cracks 64.jpg
# Salted egg_hairline cracks 65.jpg
# Salted egg_hairline cracks 66.jpg
# Salted egg_hairline cracks 7.jpg
# Salted egg_hairline cracks 8.jpg
# Salted egg_hairline cracks 9.jpg
# Salted egg_small medium 1.jpg
# Salted egg_small medium 10.jpg
# Salted egg_small medium 11.jpg
# Salted egg_small medium 12.jpg
# Salted egg_small medium 13.jpg
# Salted egg_small medium 14.jpg
# Salted egg_small medium 15.jpg
# Salted egg_small medium 16.jpg
# Salted egg_small medium 17.jpg
# Salted egg_small medium 18.jpg
# Salted egg_small medium 19.jpg
# Salted egg_small medium 2.jpg
# Salted egg_small medium 20.jpg
# Salted egg_small medium 21.jpg
# Salted egg_small medium 22.jpg
# Salted egg_small medium 23.jpg
# Salted egg_small medium 24.jpg
# Salted egg_small medium 25.jpg
# Salted egg_small medium 26.jpg
# Salted egg_small medium 27.jpg
# Salted egg_small medium 28.jpg
# Salted egg_small medium 29.jpg
# Salted egg_small medium 3.jpg
# Salted egg_small medium 30.jpg
# Salted egg_small medium 31.jpg
# Salted egg_small medium 32.jpg
# Salted egg_small medium 33.jpg
# Salted egg_small medium 34.jpg
# Salted egg_small medium 35.jpg
# Salted egg_small medium 36.jpg
# Salted egg_small medium 37.jpg
# Salted egg_small medium 38.jpg
# Salted egg_small medium 39.jpg
# Salted egg_small medium 4.jpg
# Salted egg_small medium 40.jpg
# Salted egg_small medium 41.jpg
# Salted egg_small medium 42.jpg
# Salted egg_small medium 43.jpg
# Salted egg_small medium 44.jpg
# Salted egg_small medium 45.jpg
# Salted egg_small medium 46.jpg
# Salted egg_small medium 47.jpg
# Salted egg_small medium 48.jpg
# Salted egg_small medium 49.jpg
# Salted egg_small medium 5.jpg
# Salted egg_small medium 50.jpg
# Salted egg_small medium 6.jpg
# Salted egg_small medium 7.jpg
# Salted egg_small medium 8.jpg
# Salted egg_small medium 9.jpg
#
#
# 100
#
#
# Table egg_broken crack 1.jpg
# Table egg_broken crack 10.jpg
# Table egg_broken crack 11.jpg
# Table egg_broken crack 12.jpg
# Table egg_broken crack 13.jpg
# Table egg_broken crack 14.jpg
# Table egg_broken crack 15.jpg
# Table egg_broken crack 16.jpg
# Table egg_broken crack 17.jpg
# Table egg_broken crack 18.jpg
# Table egg_broken crack 19.jpg
# Table egg_broken crack 2.jpg
# Table egg_broken crack 20.jpg
# Table egg_broken crack 21.jpg
# Table egg_broken crack 22.jpg
# Table egg_broken crack 23.jpg
# Table egg_broken crack 24.jpg
# Table egg_broken crack 25.jpg
# Table egg_broken crack 26.jpg
# Table egg_broken crack 27.jpg
# Table egg_broken crack 28.jpg
# Table egg_broken crack 29.jpg
# Table egg_broken crack 3.jpg
# Table egg_broken crack 30.jpg
# Table egg_broken crack 31.jpg
# Table egg_broken crack 32.jpg
# Table egg_broken crack 33.jpg
# Table egg_broken crack 34.jpg
# Table egg_broken crack 35.jpg
# Table egg_broken crack 36.jpg
# Table egg_broken crack 37.jpg
# Table egg_broken crack 38.jpg
# Table egg_broken crack 39.jpg
# Table egg_broken crack 4.jpg
# Table egg_broken crack 40.jpg
# Table egg_broken crack 41.jpg
# Table egg_broken crack 42.jpg
# Table egg_broken crack 43.jpg
# Table egg_broken crack 44.jpg
# Table egg_broken crack 45.jpg
# Table egg_broken crack 46.jpg
# Table egg_broken crack 47.jpg
# Table egg_broken crack 48.jpg
# Table egg_broken crack 49.jpg
# Table egg_broken crack 5.jpg
# Table egg_broken crack 50.jpg
# Table egg_broken crack 6.jpg
# Table egg_broken crack 7.jpg
# Table egg_broken crack 8.jpg
# Table egg_broken crack 9.jpg
# Table egg_peewee 1.jpg
# Table egg_peewee 10.jpg
# Table egg_peewee 11.jpg
# Table egg_peewee 12.jpg
# Table egg_peewee 13.jpg
# Table egg_peewee 14.jpg
# Table egg_peewee 15.jpg
# Table egg_peewee 16.jpg
# Table egg_peewee 17.jpg
# Table egg_peewee 18.jpg
# Table egg_peewee 19.jpg
# Table egg_peewee 2.jpg
# Table egg_peewee 20.jpg
# Table egg_peewee 21.jpg
# Table egg_peewee 22.jpg
# Table egg_peewee 23.jpg
# Table egg_peewee 24.jpg
# Table egg_peewee 25.jpg
# Table egg_peewee 26.jpg
# Table egg_peewee 27.jpg
# Table egg_peewee 28.jpg
# Table egg_peewee 29.jpg
# Table egg_peewee 3.jpg
# Table egg_peewee 30.jpg
# Table egg_peewee 31.jpg
# Table egg_peewee 32.jpg
# Table egg_peewee 33.jpg
# Table egg_peewee 34.jpg
# Table egg_peewee 35.jpg
# Table egg_peewee 36.jpg
# Table egg_peewee 37.jpg
# Table egg_peewee 38.jpg
# Table egg_peewee 39.jpg
# Table egg_peewee 4.jpg
# Table egg_peewee 40.jpg
# Table egg_peewee 41.jpg
# Table egg_peewee 42.jpg
# Table egg_peewee 43.jpg
# Table egg_peewee 44.jpg
# Table egg_peewee 45.jpg
# Table egg_peewee 46.jpg
# Table egg_peewee 47.jpg
# Table egg_peewee 48.jpg
# Table egg_peewee 49.jpg
# Table egg_peewee 5.jpg
# Table egg_peewee 50.jpg
# Table egg_peewee 6.jpg
# Table egg_peewee 7.jpg
# Table egg_peewee 8.jpg
# Table egg_peewee 9.jpg

# %%
tadirect = directory + "/CombinedFourAngleEggs"
augtadirect = directory + "/AugCombinedFourAngleEggs"
totaldsdirect = directory + "/TotalCombined"

if not os.path.exists(augtadirect):
    print("Directory does not exist. Run the code above.")
    sys.exit()
    
if not os.path.exists(totaldsdirect):
    os.makedirs(totaldsdirect)
    
for x in os.listdir(tadirect):
    tadirect2 = tadirect + "/" + x
    totaldsdirect2 = totaldsdirect + "/" + x[:-1] + "4"
    
    if not os.path.exists(totaldsdirect2):
        os.makedirs(totaldsdirect2)
    
    for y in os.listdir(tadirect2):
        tadirect3 = tadirect2 + "/" + y
        shutil.copy2(tadirect3, totaldsdirect2)
        
for x in os.listdir(augtadirect):
    augtadirect2 = augtadirect + "/" + x
    totaldsdirect2 = totaldsdirect + "/" + x[:-1] + "4"
    
    if not os.path.exists(totaldsdirect2):
        os.makedirs(totaldsdirect2)
    
    for y in os.listdir(augtadirect2):
        augtadirect3 = augtadirect2 + "/" + y
        shutil.copy2(augtadirect3, totaldsdirect2)

# %% [markdown]
# Manually remove excess data augmented images if needed. Rename the augmented images names to its class in order to avoid overwriting.

# %% [markdown]
# ## Rename the augment images

# %%
tadirect = directory + "/CombinedFourAngleEggs"
totaldsdirect = directory + "/TotalCombined"

numfiles = []

#check 
for x in os.listdir(tadirect):
    directory2 = tadirect + "/" + x
    curdir = os.listdir(directory2)
    #number of files in directory
    filecnt = len([name for name in curdir])
    numfiles.append(filecnt + 1)

for x in os.listdir(totaldsdirect):
    directory2 = totaldsdirect + "/" + x
    curdir = os.listdir(directory2)
    #number of files in directory
    filecnt = len([name for name in curdir])
    
    for y in os.listdir(directory2):
        #print(y)
        directory3 = directory2 + "/" + y
        
        if "aug" in y:
            if x == "Balut-penoy4":
                neymu = x[:-1] + " " + str(numfiles[0]) + ".jpg"
                reneymu = directory2 + "/" + neymu
                numfiles[0] += 1
            elif x == "Salted egg4":
                neymu = x[:-1] + " " + str(numfiles[1]) + ".jpg"
                reneymu = directory2 + "/" + neymu
                numfiles[1] += 1
            else:
                neymu = x[:-1] + " " + str(numfiles[2]) + ".jpg"
                reneymu = directory2 + "/" + neymu
                numfiles[2] += 1
                
            os.rename(directory3 , reneymu)
            print(y + " renamed to " + neymu)
# Out:
# aug_0_1089.jpeg renamed to Balut-penoy 51.jpg
# aug_0_1119.jpeg renamed to Balut-penoy 52.jpg
# aug_0_1158.jpeg renamed to Balut-penoy 53.jpg
# aug_0_126.jpeg renamed to Balut-penoy 54.jpg
# aug_0_1286.jpeg renamed to Balut-penoy 55.jpg
# aug_0_1469.jpeg renamed to Balut-penoy 56.jpg
# aug_0_1646.jpeg renamed to Balut-penoy 57.jpg
# aug_0_1664.jpeg renamed to Balut-penoy 58.jpg
# aug_0_1726.jpeg renamed to Balut-penoy 59.jpg
# aug_0_1795.jpeg renamed to Balut-penoy 60.jpg
# aug_0_1816.jpeg renamed to Balut-penoy 61.jpg
# aug_0_1827.jpeg renamed to Balut-penoy 62.jpg
# aug_0_1846.jpeg renamed to Balut-penoy 63.jpg
# aug_0_2008.jpeg renamed to Balut-penoy 64.jpg
# aug_0_2081.jpeg renamed to Balut-penoy 65.jpg
# aug_0_2147.jpeg renamed to Balut-penoy 66.jpg
# aug_0_2168.jpeg renamed to Balut-penoy 67.jpg
# aug_0_2223.jpeg renamed to Balut-penoy 68.jpg
# aug_0_2234.jpeg renamed to Balut-penoy 69.jpg
# aug_0_2250.jpeg renamed to Balut-penoy 70.jpg
# aug_0_2266.jpeg renamed to Balut-penoy 71.jpg
# aug_0_2299.jpeg renamed to Balut-penoy 72.jpg
# aug_0_2412.jpeg renamed to Balut-penoy 73.jpg
# aug_0_2431.jpeg renamed to Balut-penoy 74.jpg
# aug_0_2521.jpeg renamed to Balut-penoy 75.jpg
# aug_0_2572.jpeg renamed to Balut-penoy 76.jpg
# aug_0_2677.jpeg renamed to Balut-penoy 77.jpg
# aug_0_2713.jpeg renamed to Balut-penoy 78.jpg
# aug_0_2734.jpeg renamed to Balut-penoy 79.jpg
# aug_0_2742.jpeg renamed to Balut-penoy 80.jpg
# aug_0_2852.jpeg renamed to Balut-penoy 81.jpg
# aug_0_2909.jpeg renamed to Balut-penoy 82.jpg
# aug_0_3086.jpeg renamed to Balut-penoy 83.jpg
# aug_0_3093.jpeg renamed to Balut-penoy 84.jpg
# aug_0_3179.jpeg renamed to Balut-penoy 85.jpg
# aug_0_3345.jpeg renamed to Balut-penoy 86.jpg
# aug_0_3419.jpeg renamed to Balut-penoy 87.jpg
# aug_0_3440.jpeg renamed to Balut-penoy 88.jpg
# aug_0_3539.jpeg renamed to Balut-penoy 89.jpg
# aug_0_3636.jpeg renamed to Balut-penoy 90.jpg
# aug_0_3672.jpeg renamed to Balut-penoy 91.jpg
# aug_0_3759.jpeg renamed to Balut-penoy 92.jpg
# aug_0_3806.jpeg renamed to Balut-penoy 93.jpg
# aug_0_3807.jpeg renamed to Balut-penoy 94.jpg
# aug_0_3826.jpeg renamed to Balut-penoy 95.jpg
# aug_0_3945.jpeg renamed to Balut-penoy 96.jpg
# aug_0_4061.jpeg renamed to Balut-penoy 97.jpg
# aug_0_4166.jpeg renamed to Balut-penoy 98.jpg
# aug_0_420.jpeg renamed to Balut-penoy 99.jpg
# aug_0_4290.jpeg renamed to Balut-penoy 100.jpg
# aug_0_431.jpeg renamed to Balut-penoy 101.jpg
# aug_0_4331.jpeg renamed to Balut-penoy 102.jpg
# aug_0_4354.jpeg renamed to Balut-penoy 103.jpg
# aug_0_4365.jpeg renamed to Balut-penoy 104.jpg
# aug_0_4690.jpeg renamed to Balut-penoy 105.jpg
# aug_0_486.jpeg renamed to Balut-penoy 106.jpg
# aug_0_4903.jpeg renamed to Balut-penoy 107.jpg
# aug_0_4932.jpeg renamed to Balut-penoy 108.jpg
# aug_0_5128.jpeg renamed to Balut-penoy 109.jpg
# aug_0_5229.jpeg renamed to Balut-penoy 110.jpg
# aug_0_5410.jpeg renamed to Balut-penoy 111.jpg
# aug_0_5528.jpeg renamed to Balut-penoy 112.jpg
# aug_0_5625.jpeg renamed to Balut-penoy 113.jpg
# aug_0_5735.jpeg renamed to Balut-penoy 114.jpg
# aug_0_5754.jpeg renamed to Balut-penoy 115.jpg
# aug_0_5812.jpeg renamed to Balut-penoy 116.jpg
# aug_0_5882.jpeg renamed to Balut-penoy 117.jpg
# aug_0_5888.jpeg renamed to Balut-penoy 118.jpg
# aug_0_592.jpeg renamed to Balut-penoy 119.jpg
# aug_0_5921.jpeg renamed to Balut-penoy 120.jpg
# aug_0_5990.jpeg renamed to Balut-penoy 121.jpg
# aug_0_6000.jpeg renamed to Balut-penoy 122.jpg
# aug_0_6066.jpeg renamed to Balut-penoy 123.jpg
# aug_0_6168.jpeg renamed to Balut-penoy 124.jpg
# aug_0_6227.jpeg renamed to Balut-penoy 125.jpg
# aug_0_6279.jpeg renamed to Balut-penoy 126.jpg
# aug_0_640.jpeg renamed to Balut-penoy 127.jpg
# aug_0_6516.jpeg renamed to Balut-penoy 128.jpg
# aug_0_6639.jpeg renamed to Balut-penoy 129.jpg
# aug_0_6683.jpeg renamed to Balut-penoy 130.jpg
# aug_0_6748.jpeg renamed to Balut-penoy 131.jpg
# aug_0_6773.jpeg renamed to Balut-penoy 132.jpg
# aug_0_6815.jpeg renamed to Balut-penoy 133.jpg
# aug_0_6935.jpeg renamed to Balut-penoy 134.jpg
# aug_0_6986.jpeg renamed to Balut-penoy 135.jpg
# aug_0_6998.jpeg renamed to Balut-penoy 136.jpg
# aug_0_7008.jpeg renamed to Balut-penoy 137.jpg
# aug_0_7037.jpeg renamed to Balut-penoy 138.jpg
# aug_0_7096.jpeg renamed to Balut-penoy 139.jpg
# aug_0_7122.jpeg renamed to Balut-penoy 140.jpg
# aug_0_7128.jpeg renamed to Balut-penoy 141.jpg
# aug_0_7153.jpeg renamed to Balut-penoy 142.jpg
# aug_0_7171.jpeg renamed to Balut-penoy 143.jpg
# aug_0_7182.jpeg renamed to Balut-penoy 144.jpg
# aug_0_7210.jpeg renamed to Balut-penoy 145.jpg
# aug_0_7256.jpeg renamed to Balut-penoy 146.jpg
# aug_0_7302.jpeg renamed to Balut-penoy 147.jpg
# aug_0_7328.jpeg renamed to Balut-penoy 148.jpg
# aug_0_7349.jpeg renamed to Balut-penoy 149.jpg
# aug_0_7365.jpeg renamed to Balut-penoy 150.jpg
# aug_0_750.jpeg renamed to Balut-penoy 151.jpg
# aug_0_7543.jpeg renamed to Balut-penoy 152.jpg
# aug_0_7640.jpeg renamed to Balut-penoy 153.jpg
# aug_0_7665.jpeg renamed to Balut-penoy 154.jpg
# aug_0_771.jpeg renamed to Balut-penoy 155.jpg
# aug_0_7768.jpeg renamed to Balut-penoy 156.jpg
# aug_0_7797.jpeg renamed to Balut-penoy 157.jpg
# aug_0_7899.jpeg renamed to Balut-penoy 158.jpg
# aug_0_7918.jpeg renamed to Balut-penoy 159.jpg
# aug_0_7994.jpeg renamed to Balut-penoy 160.jpg
# aug_0_8020.jpeg renamed to Balut-penoy 161.jpg
# aug_0_8037.jpeg renamed to Balut-penoy 162.jpg
# aug_0_808.jpeg renamed to Balut-penoy 163.jpg
# aug_0_8227.jpeg renamed to Balut-penoy 164.jpg
# aug_0_8283.jpeg renamed to Balut-penoy 165.jpg
# aug_0_8369.jpeg renamed to Balut-penoy 166.jpg
# aug_0_8448.jpeg renamed to Balut-penoy 167.jpg
# aug_0_8543.jpeg renamed to Balut-penoy 168.jpg
# aug_0_855.jpeg renamed to Balut-penoy 169.jpg
# aug_0_8602.jpeg renamed to Balut-penoy 170.jpg
# aug_0_8645.jpeg renamed to Balut-penoy 171.jpg
# aug_0_866.jpeg renamed to Balut-penoy 172.jpg
# aug_0_8663.jpeg renamed to Balut-penoy 173.jpg
# aug_0_8675.jpeg renamed to Balut-penoy 174.jpg
# aug_0_8730.jpeg renamed to Balut-penoy 175.jpg
# aug_0_8834.jpeg renamed to Balut-penoy 176.jpg
# aug_0_8897.jpeg renamed to Balut-penoy 177.jpg
# aug_0_8942.jpeg renamed to Balut-penoy 178.jpg
# aug_0_896.jpeg renamed to Balut-penoy 179.jpg
# aug_0_9005.jpeg renamed to Balut-penoy 180.jpg
# aug_0_9056.jpeg renamed to Balut-penoy 181.jpg
# aug_0_9154.jpeg renamed to Balut-penoy 182.jpg
# aug_0_9209.jpeg renamed to Balut-penoy 183.jpg
# aug_0_9216.jpeg renamed to Balut-penoy 184.jpg
# aug_0_9248.jpeg renamed to Balut-penoy 185.jpg
# aug_0_9333.jpeg renamed to Balut-penoy 186.jpg
# aug_0_939.jpeg renamed to Balut-penoy 187.jpg
# aug_0_9530.jpeg renamed to Balut-penoy 188.jpg
# aug_0_9535.jpeg renamed to Balut-penoy 189.jpg
# aug_0_9549.jpeg renamed to Balut-penoy 190.jpg
# aug_0_9587.jpeg renamed to Balut-penoy 191.jpg
# aug_0_9651.jpeg renamed to Balut-penoy 192.jpg
# aug_0_968.jpeg renamed to Balut-penoy 193.jpg
# aug_0_9713.jpeg renamed to Balut-penoy 194.jpg
# aug_0_9737.jpeg renamed to Balut-penoy 195.jpg
# aug_0_9746.jpeg renamed to Balut-penoy 196.jpg
# aug_0_9757.jpeg renamed to Balut-penoy 197.jpg
# aug_0_9806.jpeg renamed to Balut-penoy 198.jpg
# aug_0_9888.jpeg renamed to Balut-penoy 199.jpg
# aug_0_9978.jpeg renamed to Balut-penoy 200.jpg
# aug_0_6640.jpeg renamed to Salted egg 150.jpg
# aug_0_6802.jpeg renamed to Salted egg 151.jpg
# aug_0_7015.jpeg renamed to Salted egg 152.jpg
# aug_0_7023.jpeg renamed to Salted egg 153.jpg
# aug_0_7056.jpeg renamed to Salted egg 154.jpg
# aug_0_7098.jpeg renamed to Salted egg 155.jpg
# aug_0_7131.jpeg renamed to Salted egg 156.jpg
# aug_0_7172.jpeg renamed to Salted egg 157.jpg
# aug_0_7228.jpeg renamed to Salted egg 158.jpg
# aug_0_7329.jpeg renamed to Salted egg 159.jpg
# aug_0_7330.jpeg renamed to Salted egg 160.jpg
# aug_0_7335.jpeg renamed to Salted egg 161.jpg
# aug_0_7475.jpeg renamed to Salted egg 162.jpg
# aug_0_7570.jpeg renamed to Salted egg 163.jpg
# aug_0_7722.jpeg renamed to Salted egg 164.jpg
# aug_0_7757.jpeg renamed to Salted egg 165.jpg
# aug_0_7814.jpeg renamed to Salted egg 166.jpg
# aug_0_7996.jpeg renamed to Salted egg 167.jpg
# aug_0_8029.jpeg renamed to Salted egg 168.jpg
# aug_0_8076.jpeg renamed to Salted egg 169.jpg
# aug_0_8139.jpeg renamed to Salted egg 170.jpg
# aug_0_8186.jpeg renamed to Salted egg 171.jpg
# aug_0_8203.jpeg renamed to Salted egg 172.jpg
# aug_0_8220.jpeg renamed to Salted egg 173.jpg
# aug_0_8283.jpeg renamed to Salted egg 174.jpg
# aug_0_8296.jpeg renamed to Salted egg 175.jpg
# aug_0_8328.jpeg renamed to Salted egg 176.jpg
# aug_0_8329.jpeg renamed to Salted egg 177.jpg
# aug_0_8488.jpeg renamed to Salted egg 178.jpg
# aug_0_8581.jpeg renamed to Salted egg 179.jpg
# aug_0_8695.jpeg renamed to Salted egg 180.jpg
# aug_0_8721.jpeg renamed to Salted egg 181.jpg
# aug_0_8749.jpeg renamed to Salted egg 182.jpg
# aug_0_8836.jpeg renamed to Salted egg 183.jpg
# aug_0_8849.jpeg renamed to Salted egg 184.jpg
# aug_0_8862.jpeg renamed to Salted egg 185.jpg
# aug_0_8978.jpeg renamed to Salted egg 186.jpg
# aug_0_9015.jpeg renamed to Salted egg 187.jpg
# aug_0_9062.jpeg renamed to Salted egg 188.jpg
# aug_0_9065.jpeg renamed to Salted egg 189.jpg
# aug_0_9075.jpeg renamed to Salted egg 190.jpg
# aug_0_9235.jpeg renamed to Salted egg 191.jpg
# aug_0_9278.jpeg renamed to Salted egg 192.jpg
# aug_0_9620.jpeg renamed to Salted egg 193.jpg
# aug_0_9700.jpeg renamed to Salted egg 194.jpg
# aug_0_9725.jpeg renamed to Salted egg 195.jpg
# aug_0_9761.jpeg renamed to Salted egg 196.jpg
# aug_0_9766.jpeg renamed to Salted egg 197.jpg
# aug_0_9860.jpeg renamed to Salted egg 198.jpg
# aug_0_9911.jpeg renamed to Salted egg 199.jpg
# aug_0_9960.jpeg renamed to Salted egg 200.jpg
# aug_0_4767.jpeg renamed to Table egg 101.jpg
# aug_0_4824.jpeg renamed to Table egg 102.jpg
# aug_0_4913.jpeg renamed to Table egg 103.jpg
# aug_0_4935.jpeg renamed to Table egg 104.jpg
# aug_0_4976.jpeg renamed to Table egg 105.jpg
# aug_0_5055.jpeg renamed to Table egg 106.jpg
# aug_0_5063.jpeg renamed to Table egg 107.jpg
# aug_0_5101.jpeg renamed to Table egg 108.jpg
# aug_0_5147.jpeg renamed to Table egg 109.jpg
# aug_0_5184.jpeg renamed to Table egg 110.jpg
# aug_0_5258.jpeg renamed to Table egg 111.jpg
# aug_0_5314.jpeg renamed to Table egg 112.jpg
# aug_0_5353.jpeg renamed to Table egg 113.jpg
# aug_0_5400.jpeg renamed to Table egg 114.jpg
# aug_0_5459.jpeg renamed to Table egg 115.jpg
# aug_0_5477.jpeg renamed to Table egg 116.jpg
# aug_0_5488.jpeg renamed to Table egg 117.jpg
# aug_0_5540.jpeg renamed to Table egg 118.jpg
# aug_0_5569.jpeg renamed to Table egg 119.jpg
# aug_0_5805.jpeg renamed to Table egg 120.jpg
# aug_0_5894.jpeg renamed to Table egg 121.jpg
# aug_0_5912.jpeg renamed to Table egg 122.jpg
# aug_0_5924.jpeg renamed to Table egg 123.jpg
# aug_0_5933.jpeg renamed to Table egg 124.jpg
# aug_0_6000.jpeg renamed to Table egg 125.jpg
# aug_0_6101.jpeg renamed to Table egg 126.jpg
# aug_0_6145.jpeg renamed to Table egg 127.jpg
# aug_0_6202.jpeg renamed to Table egg 128.jpg
# aug_0_6279.jpeg renamed to Table egg 129.jpg
# aug_0_6489.jpeg renamed to Table egg 130.jpg
# aug_0_6514.jpeg renamed to Table egg 131.jpg
# aug_0_6533.jpeg renamed to Table egg 132.jpg
# aug_0_6544.jpeg renamed to Table egg 133.jpg
# aug_0_6545.jpeg renamed to Table egg 134.jpg
# aug_0_6613.jpeg renamed to Table egg 135.jpg
# aug_0_6644.jpeg renamed to Table egg 136.jpg
# aug_0_6683.jpeg renamed to Table egg 137.jpg
# aug_0_6729.jpeg renamed to Table egg 138.jpg
# aug_0_6765.jpeg renamed to Table egg 139.jpg
# aug_0_6777.jpeg renamed to Table egg 140.jpg
# aug_0_6938.jpeg renamed to Table egg 141.jpg
# aug_0_7030.jpeg renamed to Table egg 142.jpg
# aug_0_7073.jpeg renamed to Table egg 143.jpg
# aug_0_7078.jpeg renamed to Table egg 144.jpg
# aug_0_7192.jpeg renamed to Table egg 145.jpg
# aug_0_7195.jpeg renamed to Table egg 146.jpg
# aug_0_7274.jpeg renamed to Table egg 147.jpg
# aug_0_7342.jpeg renamed to Table egg 148.jpg
# aug_0_7372.jpeg renamed to Table egg 149.jpg
# aug_0_7435.jpeg renamed to Table egg 150.jpg
# aug_0_7450.jpeg renamed to Table egg 151.jpg
# aug_0_7485.jpeg renamed to Table egg 152.jpg
# aug_0_7497.jpeg renamed to Table egg 153.jpg
# aug_0_7520.jpeg renamed to Table egg 154.jpg
# aug_0_7652.jpeg renamed to Table egg 155.jpg
# aug_0_7669.jpeg renamed to Table egg 156.jpg
# aug_0_7699.jpeg renamed to Table egg 157.jpg
# aug_0_7762.jpeg renamed to Table egg 158.jpg
# aug_0_7800.jpeg renamed to Table egg 159.jpg
# aug_0_7830.jpeg renamed to Table egg 160.jpg
# aug_0_7834.jpeg renamed to Table egg 161.jpg
# aug_0_7948.jpeg renamed to Table egg 162.jpg
# aug_0_8148.jpeg renamed to Table egg 163.jpg
# aug_0_8376.jpeg renamed to Table egg 164.jpg
# aug_0_8393.jpeg renamed to Table egg 165.jpg
# aug_0_8423.jpeg renamed to Table egg 166.jpg
# aug_0_8535.jpeg renamed to Table egg 167.jpg
# aug_0_8583.jpeg renamed to Table egg 168.jpg
# aug_0_8606.jpeg renamed to Table egg 169.jpg
# aug_0_8680.jpeg renamed to Table egg 170.jpg
# aug_0_8829.jpeg renamed to Table egg 171.jpg
# aug_0_8888.jpeg renamed to Table egg 172.jpg
# aug_0_8889.jpeg renamed to Table egg 173.jpg
# aug_0_8975.jpeg renamed to Table egg 174.jpg
# aug_0_9019.jpeg renamed to Table egg 175.jpg
# aug_0_9048.jpeg renamed to Table egg 176.jpg
# aug_0_9158.jpeg renamed to Table egg 177.jpg
# aug_0_9164.jpeg renamed to Table egg 178.jpg
# aug_0_9172.jpeg renamed to Table egg 179.jpg
# aug_0_9187.jpeg renamed to Table egg 180.jpg
# aug_0_9211.jpeg renamed to Table egg 181.jpg
# aug_0_9227.jpeg renamed to Table egg 182.jpg
# aug_0_9261.jpeg renamed to Table egg 183.jpg
# aug_0_9285.jpeg renamed to Table egg 184.jpg
# aug_0_9381.jpeg renamed to Table egg 185.jpg
# aug_0_9408.jpeg renamed to Table egg 186.jpg
# aug_0_9441.jpeg renamed to Table egg 187.jpg
# aug_0_9486.jpeg renamed to Table egg 188.jpg
# aug_0_9489.jpeg renamed to Table egg 189.jpg
# aug_0_9502.jpeg renamed to Table egg 190.jpg
# aug_0_9565.jpeg renamed to Table egg 191.jpg
# aug_0_9623.jpeg renamed to Table egg 192.jpg
# aug_0_9647.jpeg renamed to Table egg 193.jpg
# aug_0_9675.jpeg renamed to Table egg 194.jpg
# aug_0_9747.jpeg renamed to Table egg 195.jpg
# aug_0_9766.jpeg renamed to Table egg 196.jpg
# aug_0_9838.jpeg renamed to Table egg 197.jpg
# aug_0_9877.jpeg renamed to Table egg 198.jpg
# aug_0_9950.jpeg renamed to Table egg 199.jpg
# aug_0_9958.jpeg renamed to Table egg 200.jpg
