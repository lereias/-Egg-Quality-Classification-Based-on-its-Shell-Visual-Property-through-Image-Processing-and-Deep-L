# %% [markdown]
# # Duck Egg Quality Classification Based on its Shell Visual Property through Image Processing and Deep Learning

# %% [markdown]
# Group CGM: <br>
#
# Caguioa, JV Bryan <br>
# Guinto, Ryhle Nodnyhlson <br>
# Mesias, Lee Reuben

# %% [markdown]
# # References

# %% [markdown]
# https://thedatafrog.com/en/articles/image-recognition-transfer-learning/ <br>
# https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538 <br>
# https://www.datacamp.com/community/tutorials/convolutional-neural-networks-python <br>
# https://keras.io/examples/vision/grad_cam/

# %% [markdown]
# ## Imports

# %%
import os                                              # define and move to dataset and model directory
import shutil                                          # duplicate images and delete directories
import sys                                             # exit out code     
import cv2                                             

import tensorflow.keras as keras
import numpy as np
import tensorflow as tf                                 #for callbacks
import seaborn as sn
import pandas as pd 
# %matplotlib inline
import matplotlib.pyplot as plt                         #histograph/confusion matrix

from sklearn.model_selection import StratifiedKFold     #k-fold cross validation
from sklearn.model_selection import train_test_split    #split the dataset to train-test

from tensorflow.keras.preprocessing.image import ImageDataGenerator      # data augmentation
from tensorflow.keras.preprocessing import image as im                   #load image
from tensorflow.keras.applications.resnet50 import preprocess_input      #preprocess image                                                               

#measure performance metrics
#---------------------------------------------------------------------------------------------------------------------
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc       
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.preprocessing import label_binarize

from scipy import interp                            #interpolation needed for plotting all classes into one roc plot
from itertools import cycle                         #for the color of lines on that multiclass plot
#---------------------------------------------------------------------------------------------------------------------

#Grad-CAM
from IPython.display import Image, display
import matplotlib.cm as cm

import warnings
warnings.filterwarnings("ignore")

# %%
# the directory where the data is stored
directory = "C:/Users/user/Desktop/Dataset"
#directory where set of models per training are stored
gen_dir = "C:/Users/user/Desktop/Model"

if not os.path.exists(directory):
    os.makedirs(directory)
if not os.path.exists(gen_dir):
    os.makedirs(gen_dir)

# %% [markdown]
# ## Put Dataset in a Dataframe

# %% [markdown]
# The directory of the images are put in a dataframe in order to prepare for splitting the dataset into train and test set.

# %%
totaldsdirect = directory + "/TotalCombined"

image = []

if not os.path.exists(totaldsdirect):
    print("Directory does not exist. Please run the code on data cleaning notebook.")
    sys.exit()

#label the images
for x in os.listdir(totaldsdirect):
    totaldsdirect2 = totaldsdirect + "/" + x
    for y in os.listdir(totaldsdirect2):
        if x == "Balut-penoy2":
            lbl = "0"
        elif x == "Salted egg2":
            lbl = "1"
        else:
            lbl = "2"
                 
        #append to image array
        image.append([totaldsdirect2 + "/" + y,lbl])

# %%
df = pd.DataFrame(image,columns=['filename','label'])
df
# Out:
#                                               filename label
# 0    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 1    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 2    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 3    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 4    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# ..                                                 ...   ...
# 595  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 596  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 597  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 598  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 599  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
#
# [600 rows x 2 columns]

# %% [markdown]
# Classes: <br>
# 0 - Balut/Penoy <br>
# 1 - Salted <br>
# 2 - Table

# %% [markdown]
# ## Split Data to train and test set

# %% [markdown]
# We will need to split the dataset to train and test set (90:10). Only the train set will be used for Hyperparameter tuning with Stratified K-fold Cross Validation. Test set will be used for model prediction and model evaluation. Stratify is used in order to split the data in equal numbers under each class specified.

# %%
# Split the data to train and test
X = df[['filename']]
y = df[['label']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=420)

# %% [markdown]
# Save the images in the split sets to train and test set folders.

# %%
#folder to store the train and test set folders
fortraintest = directory + "/ToBeUsed"
if not os.path.exists(fortraintest):
    os.makedirs(fortraintest)

#train set folder
tr = fortraintest + "/train_set"
if not os.path.exists(tr):
    os.makedirs(tr)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr)
    os.makedirs(tr)
    
#test set folder
te = fortraintest + "/test_set"
if not os.path.exists(te):
    os.makedirs(te)
else:
    #remove previous folder and create new one
    shutil.rmtree(te)
    os.makedirs(te)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    trcpy = shutil.copy2(row['filename'], tr)
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_test.iterrows():
    tecpy = shutil.copy2(row['filename'], te)
    X_test.loc[X_test['filename']==row['filename'],'filename']=tecpy #change to directory where image is copied

# %% [markdown]
# ### Train Set

# %%
df2 = pd.concat([X_train,y_train],axis=1)
df2
# Out:
#                                               filename label
# 11   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 581  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 377  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 487  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 216  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# ..                                                 ...   ...
# 273  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 486  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 86   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 200  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 538  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
#
# [540 rows x 2 columns]

# %% [markdown]
# To check whether or not there are equal amounts of images per class in the train set, we have done what is shown below.

# %%
counto = [0,0,0]

counto_count = 0

df2_lbl = sorted(df2['label'].unique(), reverse=False) 

for x in df2_lbl:
    for y in df2['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1

# %%
print(counto)
# Out:
# [180, 180, 180]

# %% [markdown]
# ### Test Set

# %%
df3 = pd.concat([X_test,y_test],axis=1)
df3
# Out:
#                                               filename label
# 177  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 535  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 563  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 498  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 502  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 257  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 559  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 134  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 298  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 10   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 154  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 126  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 348  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 275  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 142  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 152  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 63   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 356  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 422  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 427  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 115  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 361  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 326  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 478  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 506  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 35   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 278  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 415  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 205  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 174  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 47   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 537  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 578  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 262  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 31   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 151  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 304  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 393  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 72   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 85   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 327  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 238  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 132  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 243  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 403  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 277  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 544  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 37   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 533  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 518  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 185  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 213  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 220  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 198  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 350  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 414  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 569  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 421  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 517  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 245  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1

# %% [markdown]
# Same with the train set, we checked whether or not there is an equal distribution of images in the test set.

# %%
counto = [0,0,0]

counto_count = 0

df3_lbl = sorted(df3['label'].unique(), reverse=False) 

for x in df3_lbl:
    for y in df3['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1

# %%
print(counto)
# Out:
# [20, 20, 20]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Create Plot History

# %% [markdown]
# Plot history will display the training and validation accuracy and loss in every epoch per fold.

# %%
def plot_history(history, yrange):
    #Plot loss and accuracy as a function of the epoch,
    #for the training and validation datasets.
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams["axes.edgecolor"] = 'black'
    plt.rcParams["axes.linewidth"]  = 1.25
    
    # Plot training and validation accuracy per epoch
    plt.plot(epochs, acc)
    plt.plot(epochs, val_acc)
    plt.title('Training and validation accuracy')
    plt.legend(['train_accuracy','val_accuracy'])
    plt.ylim(yrange)
    
    # Plot training and validation loss per epoch
    plt.figure()

    plt.plot(epochs, loss)
    plt.plot(epochs, val_loss)
    plt.title('Training and validation loss')
    plt.legend(['train_loss','val_loss'])
    
    plt.show()

# %% [markdown]
# ### Save Models

# %% [markdown]
# Stratified K-fold Cross Validation will be used in getting the best hyperparameters that will be utilized to train the final model. The set of model weights produced per fold will be saved in an automatic generated folder. Every training will generate another folder to save the new set.

# %%
def savemodel():
    save_cur = ""  #check if there is any saved_models folder(s)

    svnum = 0
    svnum2 = 0

    for x in os.listdir(gen_dir):
        if "saved_models" in x:
            save_cur = x
            if not save_cur == "":
                for word in save_cur.split("_"):
                    if word.isdigit():
                        svnum2 = int(word)
                        if svnum < svnum2:
                            svnum = svnum2


    #save_dir is where the created models using the current set of hyperparameters are added        
    if save_cur == "":
        save_dir = gen_dir + "/saved_models_1"
        os.makedirs(save_dir)
    else:
        save_dir = gen_dir + "/saved_models_" + str(svnum + 1)
        os.makedirs(save_dir)
        
    return save_dir

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# We will apply data augmentation to increase the dataset. We will use data augmentation per epoch in order to generate unique images in order to increase the dataset.

# %%
resnet50 = keras.applications.resnet50

imgdatagen = ImageDataGenerator(
        preprocessing_function = resnet50.preprocess_input,
        horizontal_flip = True,
        vertical_flip = True,
        width_shift_range = 10,
        height_shift_range = 10,
        rotation_range = 5,
        brightness_range = [0.8,1.3],
        fill_mode = "nearest"
    )

# %% [markdown]
# ## Model Creation

# %% [markdown]
# The model will be based on ResNet50 Architecture. The classifier block will be changed to suit to our dataset.

# %%
def create_model():
    conv_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

    for layer in conv_model.layers:
        layer.trainable = False

    x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
    x = keras.layers.Dense(512, activation='relu')(x)
    x = keras.layers.Dense(256, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.2)(x)
    predictions = keras.layers.Dense(3, activation='softmax')(x)

    full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

    return full_model

# %%
full_model = create_model()
full_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            771         dropout[0][0]
# ==================================================================================================
# Total params: 24,769,923
# Trainable params: 1,181,699
# Non-trainable params: 23,588,224
# __________________________________________________________________________________________________

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# We will check the combination of hyperparameters that yielded the highest validation accuracy and lowest validation loss. A set of values on chosen hyperparameters is given. The best combination will be used to train the final model.

# %% [markdown]
# ### Model Hyperparameters

# %%
batch_size_arr = [8]                                #batch size
num_epochs_arr = [90]                               #number of epochs
lr_arr = [0.0001]                                   #learning rate Adamax

# %% [markdown]
# ### Initialize Variables

# %%
VALIDATION_ACCURACY = []                          #holds all validation_accuracy in current combination
VALIDATION_LOSS = []                              #holds all validation_loss in current combination

TRAIN_ACCURACY = []                               #holds all train_accuracy in current combination
TRAIN_LOSS = []                                   #holds all train_loss in current combination

TEST_ACCURACY = []                                #holds all test_accuracy in current combination
TEST_LOSS = []                                    #holds all test_loss in current combination

param_arr = []                                    #holds the hyperparameter values per combination

val_acc_arr = []                                  #holds the set of validation accuracy per combination
val_loss_arr = []                                 #holds the set of validation loss per combination
val_acc_means = []                                #holds the means of all set of validation accuracy per combination
val_loss_means = []                               #holds the means of all set of validation loss per combination

train_acc_arr = []                                #holds the set of train accuracy per combination
train_loss_arr = []                               #holds the set of train loss per combination
train_acc_means = []                              #holds the means of all set of train accuracy per combination
train_loss_means = []                             #holds the means of all set of train loss per combination

test_acc_arr = []                                 #holds the set of test accuracy per combination
test_loss_arr = []                                #holds the set of test loss per combination
test_acc_means = []                               #holds the means of all set of test accuracy per combination
test_loss_means = []                              #holds the means of all set of test loss per combination

# %% [markdown]
# ### Train, Validation, Test data settings

# %%
train_dir = directory + "/ToBeUsed/train_set"     #where the train set images are stored

#strat kfold parameters
Y = df2[['label']]
skf = StratifiedKFold(n_splits = 5, random_state = 69, shuffle = True)

#to get the test set images convert the image to numpy array and store to testX
testX = []

for img_path in X_test['filename']:
    img = im.load_img(img_path, target_size=(224,224))
    x = im.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    x = x.reshape(224,224,3)
    testX.append(x)

testX = np.array(testX)

yt = pd.to_numeric(y_test['label'])                #make the labels to integer to get the model metrics

# %% [markdown]
# Train the model per combination of hyperparameters.

# %%
for x in range(len(batch_size_arr)):
    
    #for batch size values
    if len(param_arr) == 0:
        param_arr.append([])
    
    for y in range(len(num_epochs_arr)):

        #for epoch values
        if len(param_arr) == 1:
            param_arr.append([])
        
        for z in range(len(lr_arr)):
            
            #for learning rate values
            if len(param_arr) == 2:
                param_arr.append([])
               
            print('')
            print("batch size: ", batch_size_arr[x])
            print("epochs: ", num_epochs_arr[y])
            print("learning rate: ", lr_arr[z])
            print('')
            
            #append the values per combo
            param_arr[0].append(batch_size_arr[x])
            param_arr[1].append(num_epochs_arr[y])
            param_arr[2].append(lr_arr[z])
            
            VALIDATION_ACCURACY = []
            VALIDATION_LOSS = []
            
            TRAIN_ACCURACY = []
            TRAIN_LOSS = []
            
            TEST_ACCURACY = []
            TEST_LOSS = []
            
            #change save_dir value per combination
            save_dir = savemodel()
            fold_var = 1
            
            for train_index, val_index in skf.split(np.zeros(len(df2)),Y):
                
                #continuously split the dataset to train set and validation set in n folds
                training_data = df2.iloc[train_index]
                validation_data = df2.iloc[val_index]
                
                print('')
                print("Fold number " + str(fold_var))
                
                #apply data augmentation to both train set and validation set
                train_data_generator = imgdatagen.flow_from_dataframe(training_data, directory = train_dir,
                                       x_col = "filename", y_col = "label",
                                       class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                valid_data_generator  = imgdatagen.flow_from_dataframe(validation_data, directory = train_dir,
                                        x_col = "filename", y_col = "label",
                                        class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                
                #use the created model
                full_model = create_model()
                
                #compile the model
                full_model.compile(loss='categorical_crossentropy',
                              optimizer=keras.optimizers.Adamax(learning_rate=lr_arr[z]),
                              metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

                #create callbacks
                checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "model_" + str(fold_var) + ".h5"), 
                                        monitor='val_accuracy', verbose=1, 
                                        save_best_only=True, mode='max')
                callbacks_list = [checkpoint]
                #this saves the best model


                #fit the model
                history = full_model.fit(train_data_generator,
                                         epochs=num_epochs_arr[y],
                                         callbacks=callbacks_list,
                                         validation_data=valid_data_generator,
                                         verbose=1)

                #plot the history
                plot_history(history, yrange=(0.2,1))

                #load the best model instance to evaluate the performance of the model
                full_model.load_weights(save_dir+"/model_"+str(fold_var)+".h5")

                results = full_model.evaluate(valid_data_generator)
                results = dict(zip(full_model.metrics_names,results))
                
                #store Validation accuracy/loss
                VALIDATION_ACCURACY.append(results['accuracy'])
                VALIDATION_LOSS.append(results['loss'])
                
                #store Train accuracy/loss
                TRAIN_ACCURACY.append(np.mean(history.history['accuracy']))
                TRAIN_LOSS.append(np.mean(history.history['loss']))
                
                #predict test set to get the test accuracy/loss
                yhat_probs = full_model.predict(testX, verbose=0) 
                yhat_classes = yhat_probs.argmax(axis=-1)
                
                #test accuracy and loss score
                accuracy = accuracy_score(yt, yhat_classes)
                loss = log_loss(yt, yhat_probs)
                
                #store Test accuracy and loss
                TEST_ACCURACY.append(accuracy)
                TEST_LOSS.append(loss)
                
                tf.keras.backend.clear_session()

                fold_var += 1
            
            #store the all accuracy and loss in all folds per combination
            val_acc_arr.append(VALIDATION_ACCURACY)
            val_loss_arr.append(VALIDATION_LOSS)
            
            train_acc_arr.append(TRAIN_ACCURACY)                            
            train_loss_arr.append(TRAIN_LOSS)
            
            test_acc_arr.append(TEST_ACCURACY)
            test_loss_arr.append(TEST_LOSS)
# Out:
# batch size:  8
# epochs:  90
# learning rate:  0.0001
#
#
# Fold number 1
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/90
# 54/54 [==============================] - 20s 278ms/step - loss: 1.0623 - accuracy: 0.5185 - val_loss: 1.0883 - val_accuracy: 0.4722
#
# Epoch 00001: val_accuracy improved from -inf to 0.47222, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 2/90
# 54/54 [==============================] - 8s 154ms/step - loss: 0.8789 - accuracy: 0.6042 - val_loss: 0.9280 - val_accuracy: 0.5556
#
# Epoch 00002: val_accuracy improved from 0.47222 to 0.55556, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 3/90
# 54/54 [==============================] - 10s 188ms/step - loss: 0.7638 - accuracy: 0.6620 - val_loss: 0.8121 - val_accuracy: 0.7130
#
# Epoch 00003: val_accuracy improved from 0.55556 to 0.71296, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 4/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.7579 - accuracy: 0.6713 - val_loss: 0.7722 - val_accuracy: 0.7037
#
# Epoch 00004: val_accuracy did not improve from 0.71296
# Epoch 5/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.6972 - accuracy: 0.6968 - val_loss: 0.7735 - val_accuracy: 0.6574
#
# Epoch 00005: val_accuracy did not improve from 0.71296
# Epoch 6/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.6554 - accuracy: 0.7384 - val_loss: 0.6913 - val_accuracy: 0.7037
#
# Epoch 00006: val_accuracy did not improve from 0.71296
# Epoch 7/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.6153 - accuracy: 0.7454 - val_loss: 0.5908 - val_accuracy: 0.7963
#
# Epoch 00007: val_accuracy improved from 0.71296 to 0.79630, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 8/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.6012 - accuracy: 0.7338 - val_loss: 0.6529 - val_accuracy: 0.7315
#
# Epoch 00008: val_accuracy did not improve from 0.79630
# Epoch 9/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.6173 - accuracy: 0.7269 - val_loss: 0.5752 - val_accuracy: 0.7870
#
# Epoch 00009: val_accuracy did not improve from 0.79630
# Epoch 10/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.5685 - accuracy: 0.7801 - val_loss: 0.6671 - val_accuracy: 0.7130
#
# Epoch 00010: val_accuracy did not improve from 0.79630
# Epoch 11/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.6098 - accuracy: 0.7500 - val_loss: 0.6061 - val_accuracy: 0.7778
#
# Epoch 00011: val_accuracy did not improve from 0.79630
# Epoch 12/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.5837 - accuracy: 0.7731 - val_loss: 0.5143 - val_accuracy: 0.7593
#
# Epoch 00012: val_accuracy did not improve from 0.79630
# Epoch 13/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.6026 - accuracy: 0.7731 - val_loss: 0.5995 - val_accuracy: 0.7685
#
# Epoch 00013: val_accuracy did not improve from 0.79630
# Epoch 14/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.5327 - accuracy: 0.8032 - val_loss: 0.6667 - val_accuracy: 0.7222
#
# Epoch 00014: val_accuracy did not improve from 0.79630
# Epoch 15/90
# 54/54 [==============================] - 8s 137ms/step - loss: 0.5655 - accuracy: 0.7963 - val_loss: 0.5587 - val_accuracy: 0.7593
#
# Epoch 00015: val_accuracy did not improve from 0.79630
# Epoch 16/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.5724 - accuracy: 0.7593 - val_loss: 0.6239 - val_accuracy: 0.7685
#
# Epoch 00016: val_accuracy did not improve from 0.79630
# Epoch 17/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.5703 - accuracy: 0.7569 - val_loss: 0.6239 - val_accuracy: 0.7315
#
# Epoch 00017: val_accuracy did not improve from 0.79630
# Epoch 18/90
# 54/54 [==============================] - 8s 144ms/step - loss: 0.5233 - accuracy: 0.7986 - val_loss: 0.5329 - val_accuracy: 0.7685
#
# Epoch 00018: val_accuracy did not improve from 0.79630
# Epoch 19/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.5219 - accuracy: 0.7801 - val_loss: 0.5615 - val_accuracy: 0.7407
#
# Epoch 00019: val_accuracy did not improve from 0.79630
# Epoch 20/90
# 54/54 [==============================] - 8s 136ms/step - loss: 0.5121 - accuracy: 0.7870 - val_loss: 0.5256 - val_accuracy: 0.7685
#
# Epoch 00020: val_accuracy did not improve from 0.79630
# Epoch 21/90
# 54/54 [==============================] - 8s 137ms/step - loss: 0.4773 - accuracy: 0.8079 - val_loss: 0.6205 - val_accuracy: 0.7500
#
# Epoch 00021: val_accuracy did not improve from 0.79630
# Epoch 22/90
# 54/54 [==============================] - 8s 136ms/step - loss: 0.4465 - accuracy: 0.8287 - val_loss: 0.6143 - val_accuracy: 0.7407
#
# Epoch 00022: val_accuracy did not improve from 0.79630
# Epoch 23/90
# 54/54 [==============================] - 8s 137ms/step - loss: 0.5145 - accuracy: 0.7986 - val_loss: 0.5444 - val_accuracy: 0.7685
#
# Epoch 00023: val_accuracy did not improve from 0.79630
# Epoch 24/90
# 54/54 [==============================] - 9s 155ms/step - loss: 0.4837 - accuracy: 0.8148 - val_loss: 0.5085 - val_accuracy: 0.7870
#
# Epoch 00024: val_accuracy did not improve from 0.79630
# Epoch 25/90
# 54/54 [==============================] - 8s 145ms/step - loss: 0.5063 - accuracy: 0.8148 - val_loss: 0.4877 - val_accuracy: 0.8056
#
# Epoch 00025: val_accuracy improved from 0.79630 to 0.80556, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 26/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4458 - accuracy: 0.8426 - val_loss: 0.5750 - val_accuracy: 0.7500
#
# Epoch 00026: val_accuracy did not improve from 0.80556
# Epoch 27/90
# 54/54 [==============================] - 8s 148ms/step - loss: 0.4759 - accuracy: 0.8171 - val_loss: 0.5076 - val_accuracy: 0.7778
#
# Epoch 00027: val_accuracy did not improve from 0.80556
# Epoch 28/90
# 54/54 [==============================] - 8s 150ms/step - loss: 0.4933 - accuracy: 0.8056 - val_loss: 0.5757 - val_accuracy: 0.7870
#
# Epoch 00028: val_accuracy did not improve from 0.80556
# Epoch 29/90
# 54/54 [==============================] - 8s 146ms/step - loss: 0.5194 - accuracy: 0.7986 - val_loss: 0.5009 - val_accuracy: 0.7685
#
# Epoch 00029: val_accuracy did not improve from 0.80556
# Epoch 30/90
# 54/54 [==============================] - 9s 155ms/step - loss: 0.5134 - accuracy: 0.7917 - val_loss: 0.6343 - val_accuracy: 0.7315
#
# Epoch 00030: val_accuracy did not improve from 0.80556
# Epoch 31/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.4397 - accuracy: 0.8264 - val_loss: 0.5602 - val_accuracy: 0.7870
#
# Epoch 00031: val_accuracy did not improve from 0.80556
# Epoch 32/90
# 54/54 [==============================] - 8s 141ms/step - loss: 0.4101 - accuracy: 0.8449 - val_loss: 0.5084 - val_accuracy: 0.7870
#
# Epoch 00032: val_accuracy did not improve from 0.80556
# Epoch 33/90
# 54/54 [==============================] - 8s 147ms/step - loss: 0.4749 - accuracy: 0.8032 - val_loss: 0.5946 - val_accuracy: 0.7500
#
# Epoch 00033: val_accuracy did not improve from 0.80556
# Epoch 34/90
# 54/54 [==============================] - 8s 136ms/step - loss: 0.4027 - accuracy: 0.8426 - val_loss: 0.5405 - val_accuracy: 0.8056
#
# Epoch 00034: val_accuracy did not improve from 0.80556
# Epoch 35/90
# 54/54 [==============================] - 8s 137ms/step - loss: 0.4341 - accuracy: 0.8287 - val_loss: 0.5519 - val_accuracy: 0.8056
#
# Epoch 00035: val_accuracy did not improve from 0.80556
# Epoch 36/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.4797 - accuracy: 0.8264 - val_loss: 0.5621 - val_accuracy: 0.8056
#
# Epoch 00036: val_accuracy did not improve from 0.80556
# Epoch 37/90
# 54/54 [==============================] - 8s 144ms/step - loss: 0.4609 - accuracy: 0.8310 - val_loss: 0.6215 - val_accuracy: 0.7593
#
# Epoch 00037: val_accuracy did not improve from 0.80556
# Epoch 38/90
# 54/54 [==============================] - 8s 148ms/step - loss: 0.4376 - accuracy: 0.8264 - val_loss: 0.4846 - val_accuracy: 0.7963
#
# Epoch 00038: val_accuracy did not improve from 0.80556
# Epoch 39/90
# 54/54 [==============================] - 9s 162ms/step - loss: 0.4449 - accuracy: 0.8218 - val_loss: 0.5228 - val_accuracy: 0.7778
#
# Epoch 00039: val_accuracy did not improve from 0.80556
# Epoch 40/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4863 - accuracy: 0.8264 - val_loss: 0.5213 - val_accuracy: 0.8056
#
# Epoch 00040: val_accuracy did not improve from 0.80556
# Epoch 41/90
# 54/54 [==============================] - 8s 153ms/step - loss: 0.3810 - accuracy: 0.8426 - val_loss: 0.5718 - val_accuracy: 0.7685
#
# Epoch 00041: val_accuracy did not improve from 0.80556
# Epoch 42/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.4295 - accuracy: 0.8310 - val_loss: 0.6488 - val_accuracy: 0.7500
#
# Epoch 00042: val_accuracy did not improve from 0.80556
# Epoch 43/90
# 54/54 [==============================] - 9s 158ms/step - loss: 0.4273 - accuracy: 0.8218 - val_loss: 0.5478 - val_accuracy: 0.7778
#
# Epoch 00043: val_accuracy did not improve from 0.80556
# Epoch 44/90
# 54/54 [==============================] - 9s 170ms/step - loss: 0.4017 - accuracy: 0.8472 - val_loss: 0.3873 - val_accuracy: 0.8704
#
# Epoch 00044: val_accuracy improved from 0.80556 to 0.87037, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 45/90
# 54/54 [==============================] - 8s 141ms/step - loss: 0.3920 - accuracy: 0.8495 - val_loss: 0.5231 - val_accuracy: 0.7778
#
# Epoch 00045: val_accuracy did not improve from 0.87037
# Epoch 46/90
# 54/54 [==============================] - 8s 143ms/step - loss: 0.3953 - accuracy: 0.8565 - val_loss: 0.5667 - val_accuracy: 0.7407
#
# Epoch 00046: val_accuracy did not improve from 0.87037
# Epoch 47/90
# 54/54 [==============================] - 8s 135ms/step - loss: 0.4038 - accuracy: 0.8472 - val_loss: 0.4753 - val_accuracy: 0.8148
#
# Epoch 00047: val_accuracy did not improve from 0.87037
# Epoch 48/90
# 54/54 [==============================] - 8s 149ms/step - loss: 0.3802 - accuracy: 0.8565 - val_loss: 0.5917 - val_accuracy: 0.7685
#
# Epoch 00048: val_accuracy did not improve from 0.87037
# Epoch 49/90
# 54/54 [==============================] - 8s 141ms/step - loss: 0.3863 - accuracy: 0.8449 - val_loss: 0.5760 - val_accuracy: 0.7963
#
# Epoch 00049: val_accuracy did not improve from 0.87037
# Epoch 50/90
# 54/54 [==============================] - 8s 141ms/step - loss: 0.4175 - accuracy: 0.8356 - val_loss: 0.5044 - val_accuracy: 0.8056
#
# Epoch 00050: val_accuracy did not improve from 0.87037
# Epoch 51/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4289 - accuracy: 0.8403 - val_loss: 0.5264 - val_accuracy: 0.7870
#
# Epoch 00051: val_accuracy did not improve from 0.87037
# Epoch 52/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.4188 - accuracy: 0.8287 - val_loss: 0.5451 - val_accuracy: 0.8333
#
# Epoch 00052: val_accuracy did not improve from 0.87037
# Epoch 53/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.3532 - accuracy: 0.8657 - val_loss: 0.4668 - val_accuracy: 0.8426
#
# Epoch 00053: val_accuracy did not improve from 0.87037
# Epoch 54/90
# 54/54 [==============================] - 9s 158ms/step - loss: 0.3443 - accuracy: 0.8796 - val_loss: 0.5256 - val_accuracy: 0.7963
#
# Epoch 00054: val_accuracy did not improve from 0.87037
# Epoch 55/90
# 54/54 [==============================] - 9s 166ms/step - loss: 0.3987 - accuracy: 0.8542 - val_loss: 0.5699 - val_accuracy: 0.8148
#
# Epoch 00055: val_accuracy did not improve from 0.87037
# Epoch 56/90
# 54/54 [==============================] - 9s 163ms/step - loss: 0.3074 - accuracy: 0.8889 - val_loss: 0.5308 - val_accuracy: 0.7963
#
# Epoch 00056: val_accuracy did not improve from 0.87037
# Epoch 57/90
# 54/54 [==============================] - 9s 157ms/step - loss: 0.3420 - accuracy: 0.8704 - val_loss: 0.5126 - val_accuracy: 0.8056
#
# Epoch 00057: val_accuracy did not improve from 0.87037
# Epoch 58/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.4034 - accuracy: 0.8426 - val_loss: 0.5153 - val_accuracy: 0.7778
#
# Epoch 00058: val_accuracy did not improve from 0.87037
# Epoch 59/90
# 54/54 [==============================] - 9s 155ms/step - loss: 0.3808 - accuracy: 0.8472 - val_loss: 0.4612 - val_accuracy: 0.8333
#
# Epoch 00059: val_accuracy did not improve from 0.87037
# Epoch 60/90
# 54/54 [==============================] - 9s 152ms/step - loss: 0.3578 - accuracy: 0.8426 - val_loss: 0.5305 - val_accuracy: 0.8241
#
# Epoch 00060: val_accuracy did not improve from 0.87037
# Epoch 61/90
# 54/54 [==============================] - 9s 154ms/step - loss: 0.3879 - accuracy: 0.8495 - val_loss: 0.4916 - val_accuracy: 0.8148
#
# Epoch 00061: val_accuracy did not improve from 0.87037
# Epoch 62/90
# 54/54 [==============================] - 9s 154ms/step - loss: 0.3693 - accuracy: 0.8426 - val_loss: 0.4592 - val_accuracy: 0.8333
#
# Epoch 00062: val_accuracy did not improve from 0.87037
# Epoch 63/90
# 54/54 [==============================] - 9s 154ms/step - loss: 0.3575 - accuracy: 0.8727 - val_loss: 0.4998 - val_accuracy: 0.8333
#
# Epoch 00063: val_accuracy did not improve from 0.87037
# Epoch 64/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.3813 - accuracy: 0.8588 - val_loss: 0.4365 - val_accuracy: 0.8333
#
# Epoch 00064: val_accuracy did not improve from 0.87037
# Epoch 65/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.3885 - accuracy: 0.8403 - val_loss: 0.6295 - val_accuracy: 0.7778
#
# Epoch 00065: val_accuracy did not improve from 0.87037
# Epoch 66/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.3445 - accuracy: 0.8634 - val_loss: 0.4686 - val_accuracy: 0.7778
#
# Epoch 00066: val_accuracy did not improve from 0.87037
# Epoch 67/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.3442 - accuracy: 0.8565 - val_loss: 0.4784 - val_accuracy: 0.8426
#
# Epoch 00067: val_accuracy did not improve from 0.87037
# Epoch 68/90
# 54/54 [==============================] - 9s 157ms/step - loss: 0.3826 - accuracy: 0.8542 - val_loss: 0.5415 - val_accuracy: 0.7593
#
# Epoch 00068: val_accuracy did not improve from 0.87037
# Epoch 69/90
# 54/54 [==============================] - 9s 161ms/step - loss: 0.3396 - accuracy: 0.8681 - val_loss: 0.4618 - val_accuracy: 0.8148
#
# Epoch 00069: val_accuracy did not improve from 0.87037
# Epoch 70/90
# 54/54 [==============================] - 9s 159ms/step - loss: 0.3702 - accuracy: 0.8542 - val_loss: 0.4982 - val_accuracy: 0.8333
#
# Epoch 00070: val_accuracy did not improve from 0.87037
# Epoch 71/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.3641 - accuracy: 0.8704 - val_loss: 0.4283 - val_accuracy: 0.8519
#
# Epoch 00071: val_accuracy did not improve from 0.87037
# Epoch 72/90
# 54/54 [==============================] - 9s 166ms/step - loss: 0.3613 - accuracy: 0.8495 - val_loss: 0.4388 - val_accuracy: 0.8426
#
# Epoch 00072: val_accuracy did not improve from 0.87037
# Epoch 73/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.3434 - accuracy: 0.8519 - val_loss: 0.3904 - val_accuracy: 0.8426
#
# Epoch 00073: val_accuracy did not improve from 0.87037
# Epoch 74/90
# 54/54 [==============================] - 8s 146ms/step - loss: 0.3560 - accuracy: 0.8472 - val_loss: 0.5621 - val_accuracy: 0.7685
#
# Epoch 00074: val_accuracy did not improve from 0.87037
# Epoch 75/90
# 54/54 [==============================] - 8s 144ms/step - loss: 0.3496 - accuracy: 0.8634 - val_loss: 0.5006 - val_accuracy: 0.7963
#
# Epoch 00075: val_accuracy did not improve from 0.87037
# Epoch 76/90
# 54/54 [==============================] - 9s 157ms/step - loss: 0.3259 - accuracy: 0.8773 - val_loss: 0.4748 - val_accuracy: 0.8148
#
# Epoch 00076: val_accuracy did not improve from 0.87037
# Epoch 77/90
# 54/54 [==============================] - 8s 147ms/step - loss: 0.3344 - accuracy: 0.8866 - val_loss: 0.5022 - val_accuracy: 0.8333
#
# Epoch 00077: val_accuracy did not improve from 0.87037
# Epoch 78/90
# 54/54 [==============================] - 9s 159ms/step - loss: 0.2822 - accuracy: 0.9028 - val_loss: 0.4123 - val_accuracy: 0.8519
#
# Epoch 00078: val_accuracy did not improve from 0.87037
# Epoch 79/90
# 54/54 [==============================] - 9s 163ms/step - loss: 0.3019 - accuracy: 0.8912 - val_loss: 0.5251 - val_accuracy: 0.8148
#
# Epoch 00079: val_accuracy did not improve from 0.87037
# Epoch 80/90
# 54/54 [==============================] - 9s 158ms/step - loss: 0.3166 - accuracy: 0.8819 - val_loss: 0.4594 - val_accuracy: 0.8704
#
# Epoch 00080: val_accuracy did not improve from 0.87037
# Epoch 81/90
# 54/54 [==============================] - 9s 162ms/step - loss: 0.2746 - accuracy: 0.9051 - val_loss: 0.4284 - val_accuracy: 0.8519
#
# Epoch 00081: val_accuracy did not improve from 0.87037
# Epoch 82/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.3019 - accuracy: 0.8889 - val_loss: 0.4540 - val_accuracy: 0.8519
#
# Epoch 00082: val_accuracy did not improve from 0.87037
# Epoch 83/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.3190 - accuracy: 0.8819 - val_loss: 0.5191 - val_accuracy: 0.7963
#
# Epoch 00083: val_accuracy did not improve from 0.87037
# Epoch 84/90
# 54/54 [==============================] - 9s 162ms/step - loss: 0.3024 - accuracy: 0.8773 - val_loss: 0.5367 - val_accuracy: 0.8241
#
# Epoch 00084: val_accuracy did not improve from 0.87037
# Epoch 85/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.2891 - accuracy: 0.8981 - val_loss: 0.4531 - val_accuracy: 0.8611
#
# Epoch 00085: val_accuracy did not improve from 0.87037
# Epoch 86/90
# 54/54 [==============================] - 9s 164ms/step - loss: 0.2740 - accuracy: 0.8912 - val_loss: 0.5175 - val_accuracy: 0.8241
#
# Epoch 00086: val_accuracy did not improve from 0.87037
# Epoch 87/90
# 54/54 [==============================] - 8s 150ms/step - loss: 0.3566 - accuracy: 0.8657 - val_loss: 0.5500 - val_accuracy: 0.8056
#
# Epoch 00087: val_accuracy did not improve from 0.87037
# Epoch 88/90
# 54/54 [==============================] - 7s 135ms/step - loss: 0.2893 - accuracy: 0.8866 - val_loss: 0.5002 - val_accuracy: 0.8241
#
# Epoch 00088: val_accuracy did not improve from 0.87037
# Epoch 89/90
# 54/54 [==============================] - 8s 136ms/step - loss: 0.3463 - accuracy: 0.8704 - val_loss: 0.5975 - val_accuracy: 0.7778
#
# Epoch 00089: val_accuracy did not improve from 0.87037
# Epoch 90/90
# 54/54 [==============================] - 8s 146ms/step - loss: 0.3385 - accuracy: 0.8750 - val_loss: 0.4411 - val_accuracy: 0.8519
#
# Epoch 00090: val_accuracy did not improve from 0.87037
# 14/14 [==============================] - 2s 101ms/step - loss: 0.4158 - accuracy: 0.8704
#
# Fold number 2
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/90
# 54/54 [==============================] - 12s 157ms/step - loss: 1.1227 - accuracy: 0.4699 - val_loss: 0.9324 - val_accuracy: 0.5185
#
# Epoch 00001: val_accuracy improved from -inf to 0.51852, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 2/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.8742 - accuracy: 0.5833 - val_loss: 0.8166 - val_accuracy: 0.6944
#
# Epoch 00002: val_accuracy improved from 0.51852 to 0.69444, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 3/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.8278 - accuracy: 0.6343 - val_loss: 0.7828 - val_accuracy: 0.6944
#
# Epoch 00003: val_accuracy did not improve from 0.69444
# Epoch 4/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.7513 - accuracy: 0.6759 - val_loss: 0.7173 - val_accuracy: 0.7315
#
# Epoch 00004: val_accuracy improved from 0.69444 to 0.73148, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 5/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.7409 - accuracy: 0.6736 - val_loss: 0.6696 - val_accuracy: 0.7778
#
# Epoch 00005: val_accuracy improved from 0.73148 to 0.77778, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 6/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.7420 - accuracy: 0.7106 - val_loss: 0.6307 - val_accuracy: 0.7500
#
# Epoch 00006: val_accuracy did not improve from 0.77778
# Epoch 7/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.6987 - accuracy: 0.7176 - val_loss: 0.6224 - val_accuracy: 0.7870
#
# Epoch 00007: val_accuracy improved from 0.77778 to 0.78704, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 8/90
# 54/54 [==============================] - 8s 147ms/step - loss: 0.7123 - accuracy: 0.7014 - val_loss: 0.6132 - val_accuracy: 0.7593
#
# Epoch 00008: val_accuracy did not improve from 0.78704
# Epoch 9/90
# 54/54 [==============================] - 9s 155ms/step - loss: 0.6905 - accuracy: 0.7130 - val_loss: 0.6143 - val_accuracy: 0.7870
#
# Epoch 00009: val_accuracy did not improve from 0.78704
# Epoch 10/90
# 54/54 [==============================] - 8s 147ms/step - loss: 0.6481 - accuracy: 0.7431 - val_loss: 0.5999 - val_accuracy: 0.7963
#
# Epoch 00010: val_accuracy improved from 0.78704 to 0.79630, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 11/90
# 54/54 [==============================] - 8s 150ms/step - loss: 0.6404 - accuracy: 0.7384 - val_loss: 0.6254 - val_accuracy: 0.7130
#
# Epoch 00011: val_accuracy did not improve from 0.79630
# Epoch 12/90
# 54/54 [==============================] - 9s 154ms/step - loss: 0.5815 - accuracy: 0.7870 - val_loss: 0.5318 - val_accuracy: 0.7778
#
# Epoch 00012: val_accuracy did not improve from 0.79630
# Epoch 13/90
# 54/54 [==============================] - 8s 144ms/step - loss: 0.6039 - accuracy: 0.7384 - val_loss: 0.5472 - val_accuracy: 0.8148
#
# Epoch 00013: val_accuracy improved from 0.79630 to 0.81481, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 14/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.6135 - accuracy: 0.7662 - val_loss: 0.6534 - val_accuracy: 0.7778
#
# Epoch 00014: val_accuracy did not improve from 0.81481
# Epoch 15/90
# 54/54 [==============================] - 8s 150ms/step - loss: 0.5944 - accuracy: 0.7778 - val_loss: 0.6092 - val_accuracy: 0.7870
#
# Epoch 00015: val_accuracy did not improve from 0.81481
# Epoch 16/90
# 54/54 [==============================] - 9s 159ms/step - loss: 0.5938 - accuracy: 0.7569 - val_loss: 0.5528 - val_accuracy: 0.7870
#
# Epoch 00016: val_accuracy did not improve from 0.81481
# Epoch 17/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.5671 - accuracy: 0.7685 - val_loss: 0.4201 - val_accuracy: 0.8333
#
# Epoch 00017: val_accuracy improved from 0.81481 to 0.83333, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 18/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.5838 - accuracy: 0.7662 - val_loss: 0.4307 - val_accuracy: 0.8333
#
# Epoch 00018: val_accuracy did not improve from 0.83333
# Epoch 19/90
# 54/54 [==============================] - 9s 167ms/step - loss: 0.5722 - accuracy: 0.7731 - val_loss: 0.4023 - val_accuracy: 0.8426
#
# Epoch 00019: val_accuracy improved from 0.83333 to 0.84259, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 20/90
# 54/54 [==============================] - 9s 161ms/step - loss: 0.5338 - accuracy: 0.7755 - val_loss: 0.4446 - val_accuracy: 0.8148
#
# Epoch 00020: val_accuracy did not improve from 0.84259
# Epoch 21/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.5170 - accuracy: 0.8009 - val_loss: 0.4841 - val_accuracy: 0.8056
#
# Epoch 00021: val_accuracy did not improve from 0.84259
# Epoch 22/90
# 54/54 [==============================] - 9s 157ms/step - loss: 0.5393 - accuracy: 0.7940 - val_loss: 0.4429 - val_accuracy: 0.8333
#
# Epoch 00022: val_accuracy did not improve from 0.84259
# Epoch 23/90
# 54/54 [==============================] - 8s 150ms/step - loss: 0.5208 - accuracy: 0.8148 - val_loss: 0.4550 - val_accuracy: 0.8426
#
# Epoch 00023: val_accuracy did not improve from 0.84259
# Epoch 24/90
# 54/54 [==============================] - 8s 152ms/step - loss: 0.5281 - accuracy: 0.7801 - val_loss: 0.5666 - val_accuracy: 0.7593
#
# Epoch 00024: val_accuracy did not improve from 0.84259
# Epoch 25/90
# 54/54 [==============================] - 9s 158ms/step - loss: 0.5963 - accuracy: 0.7639 - val_loss: 0.4692 - val_accuracy: 0.7963
#
# Epoch 00025: val_accuracy did not improve from 0.84259
# Epoch 26/90
# 54/54 [==============================] - 8s 149ms/step - loss: 0.5325 - accuracy: 0.7986 - val_loss: 0.4239 - val_accuracy: 0.8426
#
# Epoch 00026: val_accuracy did not improve from 0.84259
# Epoch 27/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.5233 - accuracy: 0.7731 - val_loss: 0.3647 - val_accuracy: 0.8426
#
# Epoch 00027: val_accuracy did not improve from 0.84259
# Epoch 28/90
# 54/54 [==============================] - 9s 167ms/step - loss: 0.4803 - accuracy: 0.8194 - val_loss: 0.3982 - val_accuracy: 0.8519
#
# Epoch 00028: val_accuracy improved from 0.84259 to 0.85185, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 29/90
# 54/54 [==============================] - 9s 154ms/step - loss: 0.4852 - accuracy: 0.7963 - val_loss: 0.3786 - val_accuracy: 0.8333
#
# Epoch 00029: val_accuracy did not improve from 0.85185
# Epoch 30/90
# 54/54 [==============================] - 8s 150ms/step - loss: 0.4765 - accuracy: 0.7870 - val_loss: 0.4263 - val_accuracy: 0.8611
#
# Epoch 00030: val_accuracy improved from 0.85185 to 0.86111, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 31/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.5198 - accuracy: 0.7894 - val_loss: 0.4295 - val_accuracy: 0.8426
#
# Epoch 00031: val_accuracy did not improve from 0.86111
# Epoch 32/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4648 - accuracy: 0.8356 - val_loss: 0.4306 - val_accuracy: 0.8519
#
# Epoch 00032: val_accuracy did not improve from 0.86111
# Epoch 33/90
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4621 - accuracy: 0.7986 - val_loss: 0.4788 - val_accuracy: 0.7963
#
# Epoch 00033: val_accuracy did not improve from 0.86111
# Epoch 34/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4670 - accuracy: 0.8264 - val_loss: 0.4307 - val_accuracy: 0.8333
#
# Epoch 00034: val_accuracy did not improve from 0.86111
# Epoch 35/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.4809 - accuracy: 0.7847 - val_loss: 0.4300 - val_accuracy: 0.8704
#
# Epoch 00035: val_accuracy improved from 0.86111 to 0.87037, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 36/90
# 54/54 [==============================] - 8s 144ms/step - loss: 0.4192 - accuracy: 0.8171 - val_loss: 0.3607 - val_accuracy: 0.8704
# Epoch 00036: val_accuracy did not improve from 0.87037
# Epoch 37/90
# 54/54 [==============================] - 9s 157ms/step - loss: 0.4520 - accuracy: 0.8125 - val_loss: 0.3999 - val_accuracy: 0.8148
#
# Epoch 00037: val_accuracy did not improve from 0.87037
# Epoch 38/90
# 54/54 [==============================] - 8s 138ms/step - loss: 0.4812 - accuracy: 0.8148 - val_loss: 0.3692 - val_accuracy: 0.8519
#
# Epoch 00038: val_accuracy did not improve from 0.87037
# Epoch 39/90
# 54/54 [==============================] - 8s 145ms/step - loss: 0.5046 - accuracy: 0.8032 - val_loss: 0.4267 - val_accuracy: 0.8333
#
# Epoch 00039: val_accuracy did not improve from 0.87037
# Epoch 40/90
# 54/54 [==============================] - 8s 146ms/step - loss: 0.4532 - accuracy: 0.8310 - val_loss: 0.3726 - val_accuracy: 0.8519
#
# Epoch 00040: val_accuracy did not improve from 0.87037
# Epoch 41/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.4546 - accuracy: 0.8287 - val_loss: 0.3413 - val_accuracy: 0.8796
#
# Epoch 00041: val_accuracy improved from 0.87037 to 0.87963, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 42/90
# 54/54 [==============================] - 10s 175ms/step - loss: 0.4434 - accuracy: 0.8056 - val_loss: 0.3980 - val_accuracy: 0.8519
#
# Epoch 00042: val_accuracy did not improve from 0.87963
# Epoch 43/90
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4122 - accuracy: 0.8356 - val_loss: 0.4372 - val_accuracy: 0.8704
#
# Epoch 00043: val_accuracy did not improve from 0.87963
# Epoch 44/90
# 54/54 [==============================] - 10s 179ms/step - loss: 0.4180 - accuracy: 0.8449 - val_loss: 0.3797 - val_accuracy: 0.8704
#
# Epoch 00044: val_accuracy did not improve from 0.87963
# Epoch 45/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4667 - accuracy: 0.8194 - val_loss: 0.3644 - val_accuracy: 0.8333
#
# Epoch 00045: val_accuracy did not improve from 0.87963
# Epoch 46/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.4682 - accuracy: 0.8218 - val_loss: 0.3567 - val_accuracy: 0.8889
#
# Epoch 00046: val_accuracy improved from 0.87963 to 0.88889, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 47/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3942 - accuracy: 0.8356 - val_loss: 0.3502 - val_accuracy: 0.8796
#
# Epoch 00047: val_accuracy did not improve from 0.88889
# Epoch 48/90
# 54/54 [==============================] - 9s 174ms/step - loss: 0.4413 - accuracy: 0.8148 - val_loss: 0.3903 - val_accuracy: 0.8611
#
# Epoch 00048: val_accuracy did not improve from 0.88889
# Epoch 49/90
# 54/54 [==============================] - 13s 233ms/step - loss: 0.4237 - accuracy: 0.8310 - val_loss: 0.3565 - val_accuracy: 0.8611
#
# Epoch 00049: val_accuracy did not improve from 0.88889
# Epoch 50/90
# 54/54 [==============================] - 12s 220ms/step - loss: 0.4336 - accuracy: 0.8333 - val_loss: 0.5000 - val_accuracy: 0.8241
#
# Epoch 00050: val_accuracy did not improve from 0.88889
# Epoch 51/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4207 - accuracy: 0.8264 - val_loss: 0.3748 - val_accuracy: 0.8796
#
# Epoch 00051: val_accuracy did not improve from 0.88889
# Epoch 52/90
# 54/54 [==============================] - 10s 187ms/step - loss: 0.4124 - accuracy: 0.8287 - val_loss: 0.3182 - val_accuracy: 0.9074
#
# Epoch 00052: val_accuracy improved from 0.88889 to 0.90741, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 53/90
# 54/54 [==============================] - 9s 170ms/step - loss: 0.4192 - accuracy: 0.8403 - val_loss: 0.3779 - val_accuracy: 0.8333
#
# Epoch 00053: val_accuracy did not improve from 0.90741
# Epoch 54/90
# 54/54 [==============================] - 11s 211ms/step - loss: 0.4547 - accuracy: 0.8056 - val_loss: 0.3244 - val_accuracy: 0.8889
#
# Epoch 00054: val_accuracy did not improve from 0.90741
# Epoch 55/90
# 54/54 [==============================] - 15s 271ms/step - loss: 0.4557 - accuracy: 0.8356 - val_loss: 0.3566 - val_accuracy: 0.8796
#
# Epoch 00055: val_accuracy did not improve from 0.90741
# Epoch 56/90
# 54/54 [==============================] - 11s 211ms/step - loss: 0.3971 - accuracy: 0.8611 - val_loss: 0.3508 - val_accuracy: 0.8796
#
# Epoch 00056: val_accuracy did not improve from 0.90741
# Epoch 57/90
# 54/54 [==============================] - 11s 199ms/step - loss: 0.3976 - accuracy: 0.8356 - val_loss: 0.3542 - val_accuracy: 0.8889
#
# Epoch 00057: val_accuracy did not improve from 0.90741
# Epoch 58/90
# 54/54 [==============================] - 11s 196ms/step - loss: 0.4537 - accuracy: 0.8380 - val_loss: 0.4260 - val_accuracy: 0.8519
#
# Epoch 00058: val_accuracy did not improve from 0.90741
# Epoch 59/90
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3902 - accuracy: 0.8588 - val_loss: 0.3615 - val_accuracy: 0.8796
#
# Epoch 00059: val_accuracy did not improve from 0.90741
# Epoch 60/90
# 54/54 [==============================] - 12s 220ms/step - loss: 0.3920 - accuracy: 0.8565 - val_loss: 0.3539 - val_accuracy: 0.8426
#
# Epoch 00060: val_accuracy did not improve from 0.90741
# Epoch 61/90
# 54/54 [==============================] - 11s 204ms/step - loss: 0.4194 - accuracy: 0.8403 - val_loss: 0.3786 - val_accuracy: 0.8889
#
# Epoch 00061: val_accuracy did not improve from 0.90741
# Epoch 62/90
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4463 - accuracy: 0.8125 - val_loss: 0.3361 - val_accuracy: 0.8704
#
# Epoch 00062: val_accuracy did not improve from 0.90741
# Epoch 63/90
# 54/54 [==============================] - 10s 176ms/step - loss: 0.4428 - accuracy: 0.8333 - val_loss: 0.3666 - val_accuracy: 0.8241
#
# Epoch 00063: val_accuracy did not improve from 0.90741
# Epoch 64/90
# 54/54 [==============================] - 9s 171ms/step - loss: 0.4182 - accuracy: 0.8333 - val_loss: 0.3468 - val_accuracy: 0.8611
#
# Epoch 00064: val_accuracy did not improve from 0.90741
# Epoch 65/90
# 54/54 [==============================] - 9s 161ms/step - loss: 0.4114 - accuracy: 0.8380 - val_loss: 0.4963 - val_accuracy: 0.8241
#
# Epoch 00065: val_accuracy did not improve from 0.90741
# Epoch 66/90
# 54/54 [==============================] - 9s 167ms/step - loss: 0.3816 - accuracy: 0.8611 - val_loss: 0.3704 - val_accuracy: 0.8611
#
# Epoch 00066: val_accuracy did not improve from 0.90741
# Epoch 67/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3236 - accuracy: 0.8866 - val_loss: 0.3174 - val_accuracy: 0.8519
#
# Epoch 00067: val_accuracy did not improve from 0.90741
# Epoch 68/90
# 54/54 [==============================] - 11s 196ms/step - loss: 0.3988 - accuracy: 0.8588 - val_loss: 0.3228 - val_accuracy: 0.8704
#
# Epoch 00068: val_accuracy did not improve from 0.90741
# Epoch 69/90
# 54/54 [==============================] - 11s 203ms/step - loss: 0.3748 - accuracy: 0.8588 - val_loss: 0.3039 - val_accuracy: 0.8981
#
# Epoch 00069: val_accuracy did not improve from 0.90741
# Epoch 70/90
# 54/54 [==============================] - 9s 167ms/step - loss: 0.4377 - accuracy: 0.8356 - val_loss: 0.2867 - val_accuracy: 0.8981
#
# Epoch 00070: val_accuracy did not improve from 0.90741
# Epoch 71/90
# 54/54 [==============================] - 11s 195ms/step - loss: 0.4019 - accuracy: 0.8611 - val_loss: 0.3388 - val_accuracy: 0.8889
#
# Epoch 00071: val_accuracy did not improve from 0.90741
# Epoch 72/90
# 54/54 [==============================] - 9s 171ms/step - loss: 0.3661 - accuracy: 0.8542 - val_loss: 0.3248 - val_accuracy: 0.8611
#
# Epoch 00072: val_accuracy did not improve from 0.90741
# Epoch 73/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.3550 - accuracy: 0.8588 - val_loss: 0.2606 - val_accuracy: 0.9074
#
# Epoch 00073: val_accuracy did not improve from 0.90741
# Epoch 74/90
# 54/54 [==============================] - 9s 163ms/step - loss: 0.3935 - accuracy: 0.8519 - val_loss: 0.4095 - val_accuracy: 0.8241
#
# Epoch 00074: val_accuracy did not improve from 0.90741
# Epoch 75/90
# 54/54 [==============================] - 10s 179ms/step - loss: 0.3917 - accuracy: 0.8495 - val_loss: 0.4793 - val_accuracy: 0.8056
#
# Epoch 00075: val_accuracy did not improve from 0.90741
# Epoch 76/90
# 54/54 [==============================] - 8s 144ms/step - loss: 0.3960 - accuracy: 0.8542 - val_loss: 0.2909 - val_accuracy: 0.8981
# Epoch 00076: val_accuracy did not improve from 0.90741
# Epoch 77/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3482 - accuracy: 0.8773 - val_loss: 0.3079 - val_accuracy: 0.8981
#
# Epoch 00077: val_accuracy did not improve from 0.90741
# Epoch 78/90
# 54/54 [==============================] - 11s 191ms/step - loss: 0.3795 - accuracy: 0.8588 - val_loss: 0.3282 - val_accuracy: 0.8704
#
# Epoch 00078: val_accuracy did not improve from 0.90741
# Epoch 79/90
# 54/54 [==============================] - 10s 171ms/step - loss: 0.3938 - accuracy: 0.8519 - val_loss: 0.2712 - val_accuracy: 0.9167
#
# Epoch 00079: val_accuracy improved from 0.90741 to 0.91667, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 80/90
# 54/54 [==============================] - 10s 187ms/step - loss: 0.3660 - accuracy: 0.8565 - val_loss: 0.3726 - val_accuracy: 0.8426
#
# Epoch 00080: val_accuracy did not improve from 0.91667
# Epoch 81/90
# 54/54 [==============================] - 12s 220ms/step - loss: 0.3753 - accuracy: 0.8727 - val_loss: 0.2395 - val_accuracy: 0.9259
#
# Epoch 00081: val_accuracy improved from 0.91667 to 0.92593, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 82/90
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3739 - accuracy: 0.8704 - val_loss: 0.2710 - val_accuracy: 0.8796
#
# Epoch 00082: val_accuracy did not improve from 0.92593
# Epoch 83/90
# 54/54 [==============================] - 9s 153ms/step - loss: 0.3547 - accuracy: 0.8519 - val_loss: 0.3168 - val_accuracy: 0.8796
#
# Epoch 00083: val_accuracy did not improve from 0.92593
# Epoch 84/90
# 54/54 [==============================] - 8s 149ms/step - loss: 0.3240 - accuracy: 0.8611 - val_loss: 0.3548 - val_accuracy: 0.8519
#
# Epoch 00084: val_accuracy did not improve from 0.92593
# Epoch 85/90
# 54/54 [==============================] - 8s 154ms/step - loss: 0.3609 - accuracy: 0.8657 - val_loss: 0.3316 - val_accuracy: 0.8611
#
# Epoch 00085: val_accuracy did not improve from 0.92593
# Epoch 86/90
# 54/54 [==============================] - 10s 176ms/step - loss: 0.3615 - accuracy: 0.8588 - val_loss: 0.3642 - val_accuracy: 0.8519
#
# Epoch 00086: val_accuracy did not improve from 0.92593
# Epoch 87/90
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3483 - accuracy: 0.8750 - val_loss: 0.2843 - val_accuracy: 0.8981
#
# Epoch 00087: val_accuracy did not improve from 0.92593
# Epoch 88/90
# 54/54 [==============================] - 12s 218ms/step - loss: 0.3527 - accuracy: 0.8611 - val_loss: 0.3470 - val_accuracy: 0.8704
#
# Epoch 00088: val_accuracy did not improve from 0.92593
# Epoch 89/90
# 54/54 [==============================] - 9s 170ms/step - loss: 0.3119 - accuracy: 0.8750 - val_loss: 0.3329 - val_accuracy: 0.8426
#
# Epoch 00089: val_accuracy did not improve from 0.92593
# Epoch 90/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3550 - accuracy: 0.8704 - val_loss: 0.3719 - val_accuracy: 0.8611
#
# Epoch 00090: val_accuracy did not improve from 0.92593
# 14/14 [==============================] - 2s 125ms/step - loss: 0.2876 - accuracy: 0.8796
#
# Fold number 3
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/90
# 54/54 [==============================] - 13s 178ms/step - loss: 1.1065 - accuracy: 0.5023 - val_loss: 1.2387 - val_accuracy: 0.4537
#
# Epoch 00001: val_accuracy improved from -inf to 0.45370, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 2/90
# 54/54 [==============================] - 9s 161ms/step - loss: 0.9288 - accuracy: 0.5995 - val_loss: 0.9952 - val_accuracy: 0.5185
#
# Epoch 00002: val_accuracy improved from 0.45370 to 0.51852, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 3/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.8058 - accuracy: 0.6551 - val_loss: 0.8418 - val_accuracy: 0.6481
#
# Epoch 00003: val_accuracy improved from 0.51852 to 0.64815, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 4/90
# 54/54 [==============================] - 10s 174ms/step - loss: 0.7570 - accuracy: 0.6412 - val_loss: 0.7343 - val_accuracy: 0.7130
#
# Epoch 00004: val_accuracy improved from 0.64815 to 0.71296, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 5/90
# 54/54 [==============================] - 8s 145ms/step - loss: 0.6793 - accuracy: 0.7431 - val_loss: 0.7250 - val_accuracy: 0.7037
#
# Epoch 00005: val_accuracy did not improve from 0.71296
# Epoch 6/90
# 54/54 [==============================] - 10s 176ms/step - loss: 0.7082 - accuracy: 0.7037 - val_loss: 0.5927 - val_accuracy: 0.7778
#
# Epoch 00006: val_accuracy improved from 0.71296 to 0.77778, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 7/90
# 54/54 [==============================] - 10s 175ms/step - loss: 0.6804 - accuracy: 0.6944 - val_loss: 0.5883 - val_accuracy: 0.7963
#
# Epoch 00007: val_accuracy improved from 0.77778 to 0.79630, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 8/90
# 54/54 [==============================] - 9s 161ms/step - loss: 0.6446 - accuracy: 0.7245 - val_loss: 0.5766 - val_accuracy: 0.7315
#
# Epoch 00008: val_accuracy did not improve from 0.79630
# Epoch 9/90
# 54/54 [==============================] - 10s 179ms/step - loss: 0.6110 - accuracy: 0.7384 - val_loss: 0.5500 - val_accuracy: 0.8056
#
# Epoch 00009: val_accuracy improved from 0.79630 to 0.80556, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 10/90
# 54/54 [==============================] - 10s 187ms/step - loss: 0.6185 - accuracy: 0.7593 - val_loss: 0.5786 - val_accuracy: 0.7778
#
# Epoch 00010: val_accuracy did not improve from 0.80556
# Epoch 11/90
# 54/54 [==============================] - 12s 211ms/step - loss: 0.6329 - accuracy: 0.7500 - val_loss: 0.5060 - val_accuracy: 0.8148
#
# Epoch 00011: val_accuracy improved from 0.80556 to 0.81481, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 12/90
# 54/54 [==============================] - 11s 194ms/step - loss: 0.6446 - accuracy: 0.7245 - val_loss: 0.5497 - val_accuracy: 0.7778
#
# Epoch 00012: val_accuracy did not improve from 0.81481
# Epoch 13/90
# 54/54 [==============================] - 11s 203ms/step - loss: 0.6244 - accuracy: 0.7361 - val_loss: 0.4917 - val_accuracy: 0.8241
#
# Epoch 00013: val_accuracy improved from 0.81481 to 0.82407, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 14/90
# 54/54 [==============================] - 11s 195ms/step - loss: 0.6417 - accuracy: 0.7477 - val_loss: 0.5094 - val_accuracy: 0.8148
#
# Epoch 00014: val_accuracy did not improve from 0.82407
# Epoch 15/90
# 54/54 [==============================] - 11s 204ms/step - loss: 0.5623 - accuracy: 0.7801 - val_loss: 0.5199 - val_accuracy: 0.7593
#
# Epoch 00015: val_accuracy did not improve from 0.82407
# Epoch 16/90
# 54/54 [==============================] - 10s 185ms/step - loss: 0.5776 - accuracy: 0.7801 - val_loss: 0.4566 - val_accuracy: 0.8148
#
# Epoch 00016: val_accuracy did not improve from 0.82407
# Epoch 17/90
# 54/54 [==============================] - 10s 189ms/step - loss: 0.6243 - accuracy: 0.7292 - val_loss: 0.4471 - val_accuracy: 0.8426
#
# Epoch 00017: val_accuracy improved from 0.82407 to 0.84259, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 18/90
# 54/54 [==============================] - 10s 178ms/step - loss: 0.6321 - accuracy: 0.7431 - val_loss: 0.4866 - val_accuracy: 0.7778
#
# Epoch 00018: val_accuracy did not improve from 0.84259
# Epoch 19/90
# 54/54 [==============================] - 10s 177ms/step - loss: 0.5633 - accuracy: 0.7731 - val_loss: 0.4201 - val_accuracy: 0.8611
#
# Epoch 00019: val_accuracy improved from 0.84259 to 0.86111, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 20/90
# 54/54 [==============================] - 12s 220ms/step - loss: 0.5556 - accuracy: 0.7662 - val_loss: 0.5381 - val_accuracy: 0.7593
#
# Epoch 00020: val_accuracy did not improve from 0.86111
# Epoch 21/90
# 54/54 [==============================] - 11s 194ms/step - loss: 0.5715 - accuracy: 0.7685 - val_loss: 0.4417 - val_accuracy: 0.8333
#
# Epoch 00021: val_accuracy did not improve from 0.86111
# Epoch 22/90
# 54/54 [==============================] - 11s 197ms/step - loss: 0.5386 - accuracy: 0.7685 - val_loss: 0.4024 - val_accuracy: 0.8519
#
# Epoch 00022: val_accuracy did not improve from 0.86111
# Epoch 23/90
# 54/54 [==============================] - 11s 209ms/step - loss: 0.5621 - accuracy: 0.7847 - val_loss: 0.4555 - val_accuracy: 0.8333
#
# Epoch 00023: val_accuracy did not improve from 0.86111
# Epoch 24/90
# 54/54 [==============================] - 11s 198ms/step - loss: 0.5362 - accuracy: 0.7824 - val_loss: 0.5259 - val_accuracy: 0.7870
#
# Epoch 00024: val_accuracy did not improve from 0.86111
# Epoch 25/90
# 54/54 [==============================] - 12s 215ms/step - loss: 0.5420 - accuracy: 0.7731 - val_loss: 0.4109 - val_accuracy: 0.8148
#
# Epoch 00025: val_accuracy did not improve from 0.86111
# Epoch 26/90
# 54/54 [==============================] - 12s 217ms/step - loss: 0.4509 - accuracy: 0.8056 - val_loss: 0.3760 - val_accuracy: 0.8981
#
# Epoch 00026: val_accuracy improved from 0.86111 to 0.89815, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 27/90
# 54/54 [==============================] - 12s 221ms/step - loss: 0.5450 - accuracy: 0.7894 - val_loss: 0.3824 - val_accuracy: 0.8611
#
# Epoch 00027: val_accuracy did not improve from 0.89815
# Epoch 28/90
# 54/54 [==============================] - 10s 184ms/step - loss: 0.5133 - accuracy: 0.8009 - val_loss: 0.3978 - val_accuracy: 0.8426
#
# Epoch 00028: val_accuracy did not improve from 0.89815
# Epoch 29/90
# 54/54 [==============================] - 9s 161ms/step - loss: 0.5166 - accuracy: 0.7986 - val_loss: 0.5398 - val_accuracy: 0.7963
#
# Epoch 00029: val_accuracy did not improve from 0.89815
# Epoch 30/90
# 54/54 [==============================] - 10s 179ms/step - loss: 0.5119 - accuracy: 0.7917 - val_loss: 0.4261 - val_accuracy: 0.8519
#
# Epoch 00030: val_accuracy did not improve from 0.89815
# Epoch 31/90
# 54/54 [==============================] - 12s 229ms/step - loss: 0.4995 - accuracy: 0.7847 - val_loss: 0.3548 - val_accuracy: 0.8704
#
# Epoch 00031: val_accuracy did not improve from 0.89815
# Epoch 32/90
# 54/54 [==============================] - 10s 178ms/step - loss: 0.4734 - accuracy: 0.8102 - val_loss: 0.4308 - val_accuracy: 0.8796
#
# Epoch 00032: val_accuracy did not improve from 0.89815
# Epoch 33/90
# 54/54 [==============================] - 10s 179ms/step - loss: 0.4669 - accuracy: 0.8009 - val_loss: 0.4077 - val_accuracy: 0.8704
#
# Epoch 00033: val_accuracy did not improve from 0.89815
# Epoch 34/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.4763 - accuracy: 0.8056 - val_loss: 0.3838 - val_accuracy: 0.8519
#
# Epoch 00034: val_accuracy did not improve from 0.89815
# Epoch 35/90
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4987 - accuracy: 0.7708 - val_loss: 0.4455 - val_accuracy: 0.8148
#
# Epoch 00035: val_accuracy did not improve from 0.89815
# Epoch 36/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4783 - accuracy: 0.8218 - val_loss: 0.3589 - val_accuracy: 0.8704
#
# Epoch 00036: val_accuracy did not improve from 0.89815
# Epoch 37/90
# 54/54 [==============================] - 9s 169ms/step - loss: 0.5145 - accuracy: 0.7917 - val_loss: 0.3948 - val_accuracy: 0.8704
#
# Epoch 00037: val_accuracy did not improve from 0.89815
# Epoch 38/90
# 54/54 [==============================] - 10s 186ms/step - loss: 0.5158 - accuracy: 0.7824 - val_loss: 0.3469 - val_accuracy: 0.8611
#
# Epoch 00038: val_accuracy did not improve from 0.89815
# Epoch 39/90
# 54/54 [==============================] - 9s 158ms/step - loss: 0.4748 - accuracy: 0.7986 - val_loss: 0.3820 - val_accuracy: 0.8611
#
# Epoch 00039: val_accuracy did not improve from 0.89815
# Epoch 40/90
# 54/54 [==============================] - 11s 196ms/step - loss: 0.4746 - accuracy: 0.8102 - val_loss: 0.4426 - val_accuracy: 0.8426
#
# Epoch 00040: val_accuracy did not improve from 0.89815
# Epoch 41/90
# 54/54 [==============================] - 10s 189ms/step - loss: 0.4524 - accuracy: 0.8032 - val_loss: 0.3514 - val_accuracy: 0.8611
#
# Epoch 00041: val_accuracy did not improve from 0.89815
# Epoch 42/90
# 54/54 [==============================] - 12s 212ms/step - loss: 0.4486 - accuracy: 0.8218 - val_loss: 0.3076 - val_accuracy: 0.8981
#
# Epoch 00042: val_accuracy did not improve from 0.89815
# Epoch 43/90
# 54/54 [==============================] - 10s 178ms/step - loss: 0.4801 - accuracy: 0.8102 - val_loss: 0.4235 - val_accuracy: 0.8148
#
# Epoch 00043: val_accuracy did not improve from 0.89815
# Epoch 44/90
# 54/54 [==============================] - 11s 196ms/step - loss: 0.4674 - accuracy: 0.8241 - val_loss: 0.4521 - val_accuracy: 0.8241
#
# Epoch 00044: val_accuracy did not improve from 0.89815
# Epoch 45/90
# ...
#
# Epoch 00016: val_accuracy did not improve from 0.84259
# Epoch 17/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.6356 - accuracy: 0.7407 - val_loss: 0.6432 - val_accuracy: 0.7870
#
# Epoch 00017: val_accuracy did not improve from 0.84259
# Epoch 18/90
# 54/54 [==============================] - 12s 223ms/step - loss: 0.5902 - accuracy: 0.7454 - val_loss: 0.5358 - val_accuracy: 0.8333
#
# Epoch 00018: val_accuracy did not improve from 0.84259
# Epoch 19/90
# 54/54 [==============================] - 11s 210ms/step - loss: 0.6379 - accuracy: 0.7407 - val_loss: 0.4727 - val_accuracy: 0.8241
#
# Epoch 00019: val_accuracy did not improve from 0.84259
# Epoch 20/90
# 54/54 [==============================] - 11s 195ms/step - loss: 0.5579 - accuracy: 0.7546 - val_loss: 0.4682 - val_accuracy: 0.8056
#
# Epoch 00020: val_accuracy did not improve from 0.84259
# Epoch 21/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.6035 - accuracy: 0.7801 - val_loss: 0.4721 - val_accuracy: 0.8333
#
# Epoch 00021: val_accuracy did not improve from 0.84259
# Epoch 22/90
# 54/54 [==============================] - 9s 171ms/step - loss: 0.5653 - accuracy: 0.7778 - val_loss: 0.4865 - val_accuracy: 0.8333
#
# Epoch 00022: val_accuracy did not improve from 0.84259
# Epoch 23/90
# 54/54 [==============================] - 10s 191ms/step - loss: 0.5287 - accuracy: 0.8056 - val_loss: 0.5301 - val_accuracy: 0.7870
#
# Epoch 00023: val_accuracy did not improve from 0.84259
# Epoch 24/90
# 54/54 [==============================] - 11s 209ms/step - loss: 0.5833 - accuracy: 0.7616 - val_loss: 0.5120 - val_accuracy: 0.8333
#
# Epoch 00024: val_accuracy did not improve from 0.84259
# Epoch 25/90
# 54/54 [==============================] - 12s 216ms/step - loss: 0.5306 - accuracy: 0.7847 - val_loss: 0.4918 - val_accuracy: 0.8333
#
# Epoch 00025: val_accuracy did not improve from 0.84259
# Epoch 26/90
# 54/54 [==============================] - 9s 165ms/step - loss: 0.5921 - accuracy: 0.7546 - val_loss: 0.5212 - val_accuracy: 0.8333
#
# Epoch 00026: val_accuracy did not improve from 0.84259
# Epoch 27/90
# 54/54 [==============================] - 8s 148ms/step - loss: 0.5330 - accuracy: 0.7824 - val_loss: 0.5587 - val_accuracy: 0.8148
#
# Epoch 00027: val_accuracy did not improve from 0.84259
# Epoch 28/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.6005 - accuracy: 0.7546 - val_loss: 0.4291 - val_accuracy: 0.8519
#
# Epoch 00028: val_accuracy improved from 0.84259 to 0.85185, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 29/90
# 54/54 [==============================] - 9s 162ms/step - loss: 0.5753 - accuracy: 0.7731 - val_loss: 0.3789 - val_accuracy: 0.8426
#
# Epoch 00029: val_accuracy did not improve from 0.85185
# Epoch 30/90
# 54/54 [==============================] - 10s 189ms/step - loss: 0.5135 - accuracy: 0.7940 - val_loss: 0.5304 - val_accuracy: 0.7778
#
# Epoch 00030: val_accuracy did not improve from 0.85185
# Epoch 31/90
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4825 - accuracy: 0.8171 - val_loss: 0.3882 - val_accuracy: 0.8611
#
# Epoch 00031: val_accuracy improved from 0.85185 to 0.86111, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 32/90
# 54/54 [==============================] - 11s 198ms/step - loss: 0.4330 - accuracy: 0.8426 - val_loss: 0.3791 - val_accuracy: 0.8519
#
# Epoch 00032: val_accuracy did not improve from 0.86111
# Epoch 33/90
# 54/54 [==============================] - 11s 200ms/step - loss: 0.5076 - accuracy: 0.8194 - val_loss: 0.4586 - val_accuracy: 0.8241
#
# Epoch 00033: val_accuracy did not improve from 0.86111
# Epoch 34/90
# 54/54 [==============================] - 11s 203ms/step - loss: 0.4274 - accuracy: 0.8148 - val_loss: 0.4501 - val_accuracy: 0.8333
#
# Epoch 00034: val_accuracy did not improve from 0.86111
# Epoch 35/90
# 54/54 [==============================] - 12s 217ms/step - loss: 0.4660 - accuracy: 0.8079 - val_loss: 0.5605 - val_accuracy: 0.7963
#
# Epoch 00035: val_accuracy did not improve from 0.86111
# Epoch 36/90
# 54/54 [==============================] - 11s 196ms/step - loss: 0.4289 - accuracy: 0.8403 - val_loss: 0.4210 - val_accuracy: 0.8241
#
# Epoch 00036: val_accuracy did not improve from 0.86111
# Epoch 37/90
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4965 - accuracy: 0.8009 - val_loss: 0.5306 - val_accuracy: 0.8241
#
# Epoch 00037: val_accuracy did not improve from 0.86111
# Epoch 38/90
# 54/54 [==============================] - 9s 157ms/step - loss: 0.5169 - accuracy: 0.7963 - val_loss: 0.4060 - val_accuracy: 0.8704
#
# Epoch 00038: val_accuracy improved from 0.86111 to 0.87037, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 39/90
# 54/54 [==============================] - 9s 159ms/step - loss: 0.5634 - accuracy: 0.7616 - val_loss: 0.4892 - val_accuracy: 0.8519
#
# Epoch 00039: val_accuracy did not improve from 0.87037
# Epoch 40/90
# 54/54 [==============================] - 9s 163ms/step - loss: 0.4867 - accuracy: 0.8264 - val_loss: 0.4833 - val_accuracy: 0.8241
#
# Epoch 00040: val_accuracy did not improve from 0.87037
# Epoch 41/90
# 54/54 [==============================] - 11s 203ms/step - loss: 0.4248 - accuracy: 0.8241 - val_loss: 0.5276 - val_accuracy: 0.8241
#
# Epoch 00041: val_accuracy did not improve from 0.87037
# Epoch 42/90
# 54/54 [==============================] - 10s 184ms/step - loss: 0.4674 - accuracy: 0.8218 - val_loss: 0.4749 - val_accuracy: 0.8426
#
# Epoch 00042: val_accuracy did not improve from 0.87037
# Epoch 43/90
# 54/54 [==============================] - 12s 222ms/step - loss: 0.4852 - accuracy: 0.8102 - val_loss: 0.4952 - val_accuracy: 0.8519
#
# Epoch 00043: val_accuracy did not improve from 0.87037
# Epoch 44/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.5021 - accuracy: 0.7917 - val_loss: 0.3985 - val_accuracy: 0.8704
#
# Epoch 00044: val_accuracy did not improve from 0.87037
# Epoch 45/90
# 54/54 [==============================] - 12s 216ms/step - loss: 0.4801 - accuracy: 0.7986 - val_loss: 0.4302 - val_accuracy: 0.8333
#
# Epoch 00045: val_accuracy did not improve from 0.87037
# Epoch 46/90
# 54/54 [==============================] - 13s 229ms/step - loss: 0.4094 - accuracy: 0.8426 - val_loss: 0.4385 - val_accuracy: 0.8056
#
# Epoch 00046: val_accuracy did not improve from 0.87037
# Epoch 47/90
# 54/54 [==============================] - 11s 200ms/step - loss: 0.4535 - accuracy: 0.8171 - val_loss: 0.4895 - val_accuracy: 0.8519
#
# Epoch 00047: val_accuracy did not improve from 0.87037
# Epoch 48/90
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4308 - accuracy: 0.8356 - val_loss: 0.4119 - val_accuracy: 0.8519
#
# Epoch 00048: val_accuracy did not improve from 0.87037
# Epoch 49/90
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4650 - accuracy: 0.7778 - val_loss: 0.5874 - val_accuracy: 0.8148
#
# Epoch 00049: val_accuracy did not improve from 0.87037
# Epoch 50/90
# 54/54 [==============================] - 8s 151ms/step - loss: 0.4027 - accuracy: 0.8449 - val_loss: 0.4939 - val_accuracy: 0.8426
#
# Epoch 00050: val_accuracy did not improve from 0.87037
# Epoch 51/90
# 54/54 [==============================] - 9s 158ms/step - loss: 0.4311 - accuracy: 0.8218 - val_loss: 0.4494 - val_accuracy: 0.8426
#
# Epoch 00051: val_accuracy did not improve from 0.87037
# Epoch 52/90
# 54/54 [==============================] - 10s 174ms/step - loss: 0.4525 - accuracy: 0.8194 - val_loss: 0.3474 - val_accuracy: 0.8981
#
# Epoch 00052: val_accuracy improved from 0.87037 to 0.89815, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 53/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3901 - accuracy: 0.8495 - val_loss: 0.3996 - val_accuracy: 0.8519
#
# Epoch 00053: val_accuracy did not improve from 0.89815
# Epoch 54/90
# 54/54 [==============================] - 10s 179ms/step - loss: 0.4237 - accuracy: 0.8241 - val_loss: 0.4222 - val_accuracy: 0.8519
#
# Epoch 00054: val_accuracy did not improve from 0.89815
# Epoch 55/90
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3589 - accuracy: 0.8843 - val_loss: 0.4159 - val_accuracy: 0.8704
#
# Epoch 00055: val_accuracy did not improve from 0.89815
# Epoch 56/90
# 54/54 [==============================] - 11s 193ms/step - loss: 0.4796 - accuracy: 0.8079 - val_loss: 0.4193 - val_accuracy: 0.8611
#
# Epoch 00056: val_accuracy did not improve from 0.89815
# Epoch 57/90
# 54/54 [==============================] - 11s 190ms/step - loss: 0.3737 - accuracy: 0.8611 - val_loss: 0.3924 - val_accuracy: 0.8796
#
# Epoch 00057: val_accuracy did not improve from 0.89815
# Epoch 58/90
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3988 - accuracy: 0.8588 - val_loss: 0.3573 - val_accuracy: 0.8796
#
# Epoch 00058: val_accuracy did not improve from 0.89815
# Epoch 59/90
# 54/54 [==============================] - 11s 204ms/step - loss: 0.3623 - accuracy: 0.8657 - val_loss: 0.3750 - val_accuracy: 0.8704
#
# Epoch 00059: val_accuracy did not improve from 0.89815
# Epoch 60/90
# 54/54 [==============================] - 12s 219ms/step - loss: 0.4140 - accuracy: 0.8403 - val_loss: 0.4656 - val_accuracy: 0.8333
#
# Epoch 00060: val_accuracy did not improve from 0.89815
# Epoch 61/90
# 54/54 [==============================] - 9s 163ms/step - loss: 0.3872 - accuracy: 0.8449 - val_loss: 0.3800 - val_accuracy: 0.8426
#
# Epoch 00061: val_accuracy did not improve from 0.89815
# Epoch 62/90
# 54/54 [==============================] - 9s 167ms/step - loss: 0.3747 - accuracy: 0.8380 - val_loss: 0.4225 - val_accuracy: 0.8611
#
# Epoch 00062: val_accuracy did not improve from 0.89815
# Epoch 63/90
# 54/54 [==============================] - 9s 163ms/step - loss: 0.3822 - accuracy: 0.8519 - val_loss: 0.4149 - val_accuracy: 0.8519
#
# Epoch 00063: val_accuracy did not improve from 0.89815
# Epoch 64/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3973 - accuracy: 0.8403 - val_loss: 0.5348 - val_accuracy: 0.8426
#
# Epoch 00064: val_accuracy did not improve from 0.89815
# Epoch 65/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3915 - accuracy: 0.8472 - val_loss: 0.3782 - val_accuracy: 0.8704
#
# Epoch 00065: val_accuracy did not improve from 0.89815
# Epoch 66/90
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4404 - accuracy: 0.8102 - val_loss: 0.4737 - val_accuracy: 0.8426
#
# Epoch 00066: val_accuracy did not improve from 0.89815
# Epoch 67/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.4077 - accuracy: 0.8356 - val_loss: 0.4831 - val_accuracy: 0.8704
#
# Epoch 00067: val_accuracy did not improve from 0.89815
# Epoch 68/90
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4090 - accuracy: 0.8565 - val_loss: 0.3446 - val_accuracy: 0.8796
#
# Epoch 00068: val_accuracy did not improve from 0.89815
# Epoch 69/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3940 - accuracy: 0.8426 - val_loss: 0.4074 - val_accuracy: 0.8426
#
# Epoch 00069: val_accuracy did not improve from 0.89815
# Epoch 70/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3979 - accuracy: 0.8356 - val_loss: 0.4004 - val_accuracy: 0.8796
#
# Epoch 00070: val_accuracy did not improve from 0.89815
# Epoch 71/90
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3758 - accuracy: 0.8634 - val_loss: 0.3530 - val_accuracy: 0.8796
#
# Epoch 00071: val_accuracy did not improve from 0.89815
# Epoch 72/90
# 54/54 [==============================] - 11s 199ms/step - loss: 0.4249 - accuracy: 0.8426 - val_loss: 0.4647 - val_accuracy: 0.8611
#
# Epoch 00072: val_accuracy did not improve from 0.89815
# Epoch 73/90
# 54/54 [==============================] - 9s 166ms/step - loss: 0.3561 - accuracy: 0.8565 - val_loss: 0.3872 - val_accuracy: 0.8704
#
# Epoch 00073: val_accuracy did not improve from 0.89815
# Epoch 74/90
# 54/54 [==============================] - 9s 173ms/step - loss: 0.3834 - accuracy: 0.8356 - val_loss: 0.3683 - val_accuracy: 0.8611
#
# Epoch 00074: val_accuracy did not improve from 0.89815
# Epoch 75/90
# 54/54 [==============================] - 9s 166ms/step - loss: 0.3987 - accuracy: 0.8472 - val_loss: 0.3607 - val_accuracy: 0.8704
#
# Epoch 00075: val_accuracy did not improve from 0.89815
# Epoch 76/90
# 54/54 [==============================] - 9s 167ms/step - loss: 0.3925 - accuracy: 0.8588 - val_loss: 0.5539 - val_accuracy: 0.7870
#
# Epoch 00076: val_accuracy did not improve from 0.89815
# Epoch 77/90
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4081 - accuracy: 0.8380 - val_loss: 0.3844 - val_accuracy: 0.8889
#
# Epoch 00077: val_accuracy did not improve from 0.89815
# Epoch 78/90
# 54/54 [==============================] - 9s 173ms/step - loss: 0.3947 - accuracy: 0.8310 - val_loss: 0.3479 - val_accuracy: 0.8611
#
# Epoch 00078: val_accuracy did not improve from 0.89815
# Epoch 79/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4137 - accuracy: 0.8148 - val_loss: 0.5035 - val_accuracy: 0.8519
#
# Epoch 00079: val_accuracy did not improve from 0.89815
# Epoch 80/90
# 54/54 [==============================] - 11s 206ms/step - loss: 0.4139 - accuracy: 0.8356 - val_loss: 0.3518 - val_accuracy: 0.8704
#
# Epoch 00080: val_accuracy did not improve from 0.89815
# Epoch 81/90
# 54/54 [==============================] - 11s 203ms/step - loss: 0.3669 - accuracy: 0.8796 - val_loss: 0.3699 - val_accuracy: 0.8796
#
# Epoch 00081: val_accuracy did not improve from 0.89815
# Epoch 82/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3604 - accuracy: 0.8657 - val_loss: 0.4638 - val_accuracy: 0.8611
#
# Epoch 00082: val_accuracy did not improve from 0.89815
# Epoch 83/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3791 - accuracy: 0.8495 - val_loss: 0.4156 - val_accuracy: 0.8519
#
# Epoch 00083: val_accuracy did not improve from 0.89815
# Epoch 84/90
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3879 - accuracy: 0.8287 - val_loss: 0.3552 - val_accuracy: 0.8796
#
# Epoch 00084: val_accuracy did not improve from 0.89815
# Epoch 85/90
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3801 - accuracy: 0.8403 - val_loss: 0.3944 - val_accuracy: 0.8333
#
# Epoch 00085: val_accuracy did not improve from 0.89815
# Epoch 86/90
# 54/54 [==============================] - 9s 174ms/step - loss: 0.3714 - accuracy: 0.8773 - val_loss: 0.3214 - val_accuracy: 0.8889
#
# Epoch 00086: val_accuracy did not improve from 0.89815
# Epoch 87/90
# 54/54 [==============================] - 8s 152ms/step - loss: 0.3873 - accuracy: 0.8611 - val_loss: 0.4847 - val_accuracy: 0.8426
#
# Epoch 00087: val_accuracy did not improve from 0.89815
# Epoch 88/90
# 54/54 [==============================] - 8s 143ms/step - loss: 0.3511 - accuracy: 0.8681 - val_loss: 0.3139 - val_accuracy: 0.8889
#
# Epoch 00088: val_accuracy did not improve from 0.89815
# Epoch 89/90
# 54/54 [==============================] - 9s 160ms/step - loss: 0.4330 - accuracy: 0.8472 - val_loss: 0.4847 - val_accuracy: 0.8426
#
# Epoch 00089: val_accuracy did not improve from 0.89815
# Epoch 90/90
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3344 - accuracy: 0.8773 - val_loss: 0.2916 - val_accuracy: 0.8981
#
# Epoch 00090: val_accuracy did not improve from 0.89815
# 14/14 [==============================] - 2s 132ms/step - loss: 0.3659 - accuracy: 0.8611
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000219F53E6D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#stopper

# %% [markdown]
# ### Display Values Per Combination of Hyperparameters

# %% [markdown]
# We will put the combination of hyperparameters and the resulting means of accuracy and loss together in a dataframe in order to display it nicely.

# %%
#append means of accuracy and loss per combo
for x in range(len(val_acc_arr)):
    val_acc_means.append(np.mean(val_acc_arr[x]))                                
    val_loss_means.append(np.mean(val_loss_arr[x]))
    
    train_acc_means.append(np.mean(train_acc_arr[x]))                              
    train_loss_means.append(np.mean(train_loss_arr[x]))                             

    test_acc_means.append(np.mean(test_acc_arr[x]))                               
    test_loss_means.append(np.mean(test_loss_arr[x])) 
    
df_hyperparam = pd.DataFrame(list(zip(param_arr[0],param_arr[1],param_arr[2],
                                      train_acc_means, train_loss_means,
                                      val_acc_means,val_loss_means,
                                      test_acc_means, test_loss_means))
                             ,columns=['batch size','number of epoch', 'learning rate', 
                                       'train accuracy', 'train loss',
                                       'val accuracy', 'val loss',
                                       'test accuracy', 'test loss'])

df_hyperparam = df_hyperparam.sort_values(ascending=False,by = 'val accuracy')

#df_hyperparam.to_excel("hyperparam_result.xlsx")

df_hyperparam
# Out:
#    batch size  number of epoch  learning rate  train accuracy  train loss  \
# 0           8               90         0.0001        0.810556    0.475358
#
#    val accuracy  val loss  test accuracy  test loss
# 0      0.868519  0.363054       0.806667   0.582975

# %%
#stopper

# %% [markdown]
# ### Each fold results of best combination

# %% [markdown]
# Below are the validation accuracy and validation loss per fold and their average of the best combination.

# %%
#get the index of the best combination
comb_no = df_hyperparam.loc[[df_hyperparam['val accuracy'].idxmax()]].index.tolist()[0]
fold_num = [*range(1,6)]

fold_eval = pd.DataFrame(list(zip(fold_num,train_acc_arr[comb_no],train_loss_arr[comb_no],
                                  val_acc_arr[comb_no],val_loss_arr[comb_no],
                                  test_acc_arr[comb_no],test_loss_arr[comb_no]))
                         ,columns=['fold','Training Accuracy','Training Loss',
                                   'Validation Accuracy','Validation Loss',
                                   'Test Accuracy','Test Loss'])

fold_eval.set_index('fold', inplace=True)
fold_eval.loc['mean'] = fold_eval.mean()

#fold_eval.to_excel('fold_eval.xlsx')
fold_eval
# Out:
#       Training Accuracy  Training Loss  Validation Accuracy  Validation Loss  \
# fold
# 1              0.824100       0.444459             0.870370         0.415758
# 2              0.807382       0.483455             0.879630         0.287606
# 3              0.802726       0.490125             0.916667         0.248951
# 4              0.815561       0.464467             0.814815         0.497049
# 5              0.803009       0.494283             0.861111         0.365907
# mean           0.810556       0.475358             0.868519         0.363054
#
#       Test Accuracy  Test Loss
# fold
# 1          0.850000   0.562847
# 2          0.816667   0.595072
# 3          0.783333   0.636968
# 4          0.816667   0.518724
# 5          0.766667   0.601265
# mean       0.806667   0.582975

# %%
#stopper

# %% [markdown]
# ## Final Model

# %% [markdown]
# We will use the best combination of hypaparameters to train our final model. We will evaluate the model using the train set.

# %% [markdown]
# ### Get best combination of hyperparameters

# %%
df_bestohypaparamu = df_hyperparam.loc[[df_hyperparam['val accuracy'].idxmax()]]

bestohypaparamu = [df_bestohypaparamu['batch size'].values[0],
                   df_bestohypaparamu['number of epoch'].values[0],
                   df_bestohypaparamu['learning rate'].values[0]]

# %% [markdown]
# ### Train and Predict the model

# %% [markdown]
# The same as to what was done in the hyperparameter tuning, we will split the train set to train and validation set with the same random state of 69 in order to have a similar resulting accuracy and loss.

# %%
# Split train set to train set and valid set
X = df2[['filename']]
y = df2[['label']]
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=69)

# %% [markdown]
# We will save the images from the new train set and validation set to separate folders.

# %%
#folder to store the train and test set folders
fortraintest2 = directory + "/ToBeUsedFinalModel"
if not os.path.exists(fortraintest2):
    os.makedirs(fortraintest2)

#train set folder
tr2 = fortraintest2 + "/train_set"
if not os.path.exists(tr2):
    os.makedirs(tr2)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr2)
    os.makedirs(tr2)
    
#test set folder
va = fortraintest2 + "/val_set"
if not os.path.exists(va):
    os.makedirs(va)
else:
    #remove previous folder and create new one
    shutil.rmtree(va)
    os.makedirs(va)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    try:
        trcpy = shutil.copy2(row['filename'], tr2)
    except shutil.SameFileError:
        pass
    
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_val.iterrows():
    try:
        vacpy = shutil.copy2(row['filename'], va)
    except shutil.SameFileError:
        pass
    
    X_val.loc[X_val['filename']==row['filename'],'filename']=vacpy #change to directory where image is copied

# %% [markdown]
# ### Train Set Final Model

# %%
df4 = pd.concat([X_train,y_train],axis=1)
df4

# %%
counto = [0,0,0]

counto_count = 0

df4_lbl = sorted(df4['label'].unique(), reverse=False) 

for x in df4_lbl:
    for y in df4['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1
    
print(counto)

# %% [markdown]
# ### Validation Set Final Model

# %%
df5 = pd.concat([X_val,y_val],axis=1)
df5

# %%
counto = [0,0,0]

counto_count = 0

df5_lbl = sorted(df5['label'].unique(), reverse=False) 

for x in df5_lbl:
    for y in df5['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1
    
print(counto)

# %% [markdown]
# Finally we train the model. Prediction is also done using the test set.

# %%
VAL_ACCURACY = None
VAL_LOSS = None

train_dir = tr2
valid_dir = va
save_dir = gen_dir + "/saved_finalmodel_1"

if os.path.exists(save_dir):
    shutil.rmtree(save_dir)
    
os.makedirs(save_dir)

trainu = df4
validu = df5

train_data_generator = imgdatagen.flow_from_dataframe(trainu, directory = train_dir,
                                       x_col = "filename", y_col = "label",
                                       class_mode = "categorical", target_size = (224,224), batch_size = bestohypaparamu[0],
                                            shuffle = True)
valid_data_generator  = imgdatagen.flow_from_dataframe(validu, directory = valid_dir,
                        x_col = "filename", y_col = "label",
                        class_mode = "categorical", target_size = (224,224), batch_size = bestohypaparamu[0],
                            shuffle = True)

#print(len(train_data_generator))

full_model = create_model()
# Compile the model
full_model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adamax(learning_rate=bestohypaparamu[2]),
              metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

# Create callbacks
checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "finalmodel_1.h5"), 
                        monitor='val_accuracy', verbose=1, 
                        save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# This saves the best model


# Fit the model
history = full_model.fit(train_data_generator,
                         epochs=bestohypaparamu[1],
                         callbacks=callbacks_list,
                         validation_data=valid_data_generator,
                         verbose=1)

# Plot the history
plot_history(history, yrange=(0.2,1))

# Load the best model instance to evaluate the performance of the model
full_model.load_weights(save_dir+"/"+ "finalmodel_1.h5")

results = full_model.evaluate(valid_data_generator)

#print(results)

results = dict(zip(full_model.metrics_names,results))

# Store Validation accuracy/loss
VAL_ACCURACY = results['accuracy']
VAL_LOSS = results['loss']

tf.keras.backend.clear_session()

# %% [markdown]
# Display the validation accuracy and loss.

# %%
print("Val acc:  " + str(VAL_ACCURACY))
print("Val loss: " + str(VAL_LOSS))

# %% [markdown]
# Predict using test set.

# %%
save_dir = gen_dir + "/saved_finalmodel_1"
full_model = create_model()
full_model.load_weights(save_dir+"/"+ "finalmodel_1.h5")

# Needed later for measuring performance metrics
# Predict test set to get the test accuracy/loss
yhat_probs2 = full_model.predict(testX, verbose=0) 
yhat_classes2 = yhat_probs2.argmax(axis=-1)

# %% [markdown]
# ## Measure Performance Metrics

# %% [markdown]
# After we have trained the final model with the entire train set and done prediction using the test set, we can now measure the performance metrics for model evaluation.

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Accuracy, Precision, Recall

# %%
def metriksu(yhat_classes2):
    
    # accuracy: (tp + tn) / (p + n)
    matrix = confusion_matrix(yt, yhat_classes2)
    accuracy2 = matrix.diagonal()/matrix.sum(axis=1)
    print('Accuracy per class: ' + str(accuracy2))
    # precision tp / (tp + fp)
    precision = precision_score(yt, yhat_classes2, average="weighted")
    print('Precision: %f' % precision)
    precision2 = precision_score(yt, yhat_classes2, average=None)
    print('Precision per class: ' + str(precision2))
    # recall: tp / (tp + fn)
    recall = recall_score(yt, yhat_classes2, average="weighted")
    print('Recall: %f' % recall)
    recall2 = recall_score(yt, yhat_classes2, average=None)
    print('Recall per class: ' + str(recall2))
    
    return accuracy2, precision2, recall2

# %% [markdown]
# ### ROC AUC

# %%
def roshi_aushi(yhat_probs2):
    
    # Binarize the true label
    ytbin = label_binarize(yt, classes=[0, 1, 2])
    n_classes = ytbin.shape[1]

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
      
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(ytbin[:, i], yhat_probs2[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i]) 

    # Compute micro-average ROC curve and ROC area
    fpr["macro"], tpr["macro"], _ = roc_curve(ytbin.ravel(), yhat_probs2.ravel())
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams["axes.edgecolor"] = 'black'
    plt.rcParams["axes.linewidth"]  = 1.25
    
    #balut-penoy
    plt.figure()
    lw = 2
    plt.plot(fpr[0], tpr[0], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[0])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Balut-Penoy')
    plt.legend(loc="lower right")
    plt.show()

    #salted egg
    plt.figure()
    lw = 2
    plt.plot(fpr[1], tpr[1], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[1])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Salted Egg')
    plt.legend(loc="lower right")
    plt.show()

    #table egg
    plt.figure()
    lw = 2
    plt.plot(fpr[2], tpr[2], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Table Egg')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
def confuuusion_meytriksu(yhat_classes2):

    #confusion matrix
    matrix = confusion_matrix(yt, yhat_classes2)
    
    df_cm = pd.DataFrame(matrix, range(matrix.shape[0]), range(matrix.shape[1]))
    df_cm = df_cm.rename(columns={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'}, 
                         index={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'})
    
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title('Confusion Matrix of Final Model Evaluation')

# %% [markdown]
# Call all the functions.

# %%
accuracy2, precision2, recall2 = metriksu(yhat_classes2)

# %%
roshi_aushi(yhat_probs2)

# %%
confuuusion_meytriksu(yhat_classes2)

# %% [markdown]
# ### Metrics per Class

# %%
accuracy2 = list(accuracy2)
precision2 = list(precision2)
recall2 = list(recall2)

accuracy2.append(0)
precision2.append(0)
recall2.append(0)

classes = 3

for x in range(classes):
    accuracy2[-1] += accuracy2[x]
    precision2[-1] += precision2[x]
    recall2[-1] += recall2[x]

accuracy2[-1] = accuracy2[-1]/classes
precision2[-1] = precision2[-1]/classes
recall2[-1] = recall2[-1]/classes

# %%
label = ['Balut/Penoy','Salted','Table','Ave']

df_eval_per_class = pd.DataFrame(data = list(zip(label,accuracy2,precision2,recall2)), 
                       columns=["Class","Accuracy","Precision","Recall"])

#set fold_ave as the index
df_eval_per_class.set_index("Class",inplace=True)

df_eval_per_class

# %% [markdown]
# ## Validating Misclassified Images

# %% [markdown]
# We will display the correct and incorrect predictions. We will first get the images from the directories stored under the filename column.

# %%
testX2 = []

for img_path in X_test['filename']:
    img = cv2.imread(img_path)
    testX2.append(img)

testX2 = np.array(testX2)

# %% [markdown]
# We will be applying Grad-CAM in order to check where is the focus of the model. It presents a heatmap. The hotter the color on a region is, the more it is focused on.

# %% [markdown]
# ### Grad-CAM algorithm

# %%
last_conv_layer_name = "conv5_block3_add"

preprocess_input = keras.applications.resnet50.preprocess_input

def get_img_array(img_path, size):
    # `img` is a PIL image of size 224x224
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (224, 224, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 224, 224, 3)
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %% [markdown]
# ### superimposed visualization

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.5):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    
    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))

# %% [markdown]
# ### Prediction

# %%
def guraducamu(img_dir):
    img_size = (224,224)

    # Prepare image
    img_array = get_img_array(img_dir, img_size)

    conv_model = keras.applications.resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

    for layer in conv_model.layers:
        layer.trainable = False

    x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
    x = keras.layers.Dense(512, activation='relu')(x)
    x = keras.layers.Dense(256, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.2)(x)
    predictions = keras.layers.Dense(3, activation='softmax',name = "prediction")(x)

    model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

    model.load_weights(save_dir+"/"+ "finalmodel_1.h5")

    # Remove last layer's softmax
    model.layers[-1].activation = None

    # Generate class activation heatmap
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
 
    print("Original Image")
    display(Image(img_dir))

    print("Heatmap Prediction")
    plt.matshow(heatmap)
    plt.grid(False)
    plt.axis('off')
    plt.show()

    print("Grad-CAM")
    save_and_display_gradcam(img_dir, heatmap)

# %% [markdown]
# ### Correct predictions

# %%
correct = np.where(yhat_classes2==yt)[0]

print("Found %d correct labels" % len(correct))

for x in correct:
    print("Predict {0}, Class {1}".format(str(yhat_classes2[x]),str(yt.values[x])))
    img_dir = X_test.iloc[x]['filename']
    print(img_dir)
    guraducamu(img_dir)
    
plt.figure(figsize=(20,60))
for i, correct in enumerate(correct[:6]):
    plt.subplot(3,2,i+1)
    RGB_img = cv2.cvtColor(testX2[correct], cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img) #, interpolation='none') #, cmap='gray')
    plt.title("Predict {0}, Class {1}".format(str(yhat_classes2[correct]),str(yt.values[correct])))
    plt.grid(False)
    plt.axis('off')

plt.show()

# %% [markdown]
# ### Incorrect predictions

# %%
incorrect = np.where(yhat_classes2!=yt)[0]

print ("Found %d incorrect labels" % len(incorrect))

for x in incorrect:
    print("Predict {0}, Class {1}".format(str(yhat_classes2[x]),str(yt.values[x])))
    img_dir = X_test.iloc[x]['filename']
    print(img_dir)
    guraducamu(img_dir)

plt.figure(figsize=(20,60))
for i, incorrect in enumerate(incorrect[:6]):
    plt.subplot(3,2,i+1)
    RGB_img = cv2.cvtColor(testX2[incorrect], cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img) #, interpolation='none') #, cmap='gray')
    plt.title("Predicted {0}, Class {1}".format(str(yhat_classes2[incorrect]), str(yt.values[incorrect])))
    plt.grid(False)
    plt.axis('off')

plt.show()
