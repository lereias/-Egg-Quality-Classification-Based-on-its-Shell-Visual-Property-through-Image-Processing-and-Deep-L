# %% [markdown]
# # Duck Egg Quality Classification Based on its Shell Visual Property through Image Processing and Deep Learning

# %% [markdown]
# Group CGM: <br>
#
# Caguioa, JV Bryan <br>
# Guinto, Ryhle Nodnyhlson <br>
# Mesias, Lee Reuben

# %% [markdown]
# # References

# %% [markdown]
# https://thedatafrog.com/en/articles/image-recognition-transfer-learning/ <br>
# https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538 <br>
# https://www.datacamp.com/community/tutorials/convolutional-neural-networks-python <br>
# https://keras.io/examples/vision/grad_cam/

# %% [markdown]
# ## Imports

# %%
import os                                              # define and move to dataset and model directory
import shutil                                          # duplicate images and delete directories
import sys                                             # exit out code     
import cv2                                             

import tensorflow.keras as keras
import numpy as np
import tensorflow as tf                                 #for callbacks
import seaborn as sn
import pandas as pd 
# %matplotlib inline
import matplotlib.pyplot as plt                         #histograph/confusion matrix

from sklearn.model_selection import StratifiedKFold     #k-fold cross validation
from sklearn.model_selection import train_test_split    #split the dataset to train-test

from tensorflow.keras.preprocessing.image import ImageDataGenerator      # data augmentation
from tensorflow.keras.preprocessing import image as im                   #load image
from tensorflow.keras.applications.resnet50 import preprocess_input      #preprocess image                                                               

#measure performance metrics
#---------------------------------------------------------------------------------------------------------------------
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc       
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.preprocessing import label_binarize

from scipy import interp                            #interpolation needed for plotting all classes into one roc plot
from itertools import cycle                         #for the color of lines on that multiclass plot
#---------------------------------------------------------------------------------------------------------------------

#Grad-CAM
from IPython.display import Image, display
import matplotlib.cm as cm

import warnings
warnings.filterwarnings("ignore")

# %%
# the directory where the data is stored
directory = "C:/Users/user/Desktop/Dataset"
#directory where set of models per training are stored
gen_dir = "C:/Users/user/Desktop/Model"

if not os.path.exists(directory):
    os.makedirs(directory)
if not os.path.exists(gen_dir):
    os.makedirs(gen_dir)

# %% [markdown]
# ## Put Dataset in a Dataframe

# %% [markdown]
# The directory of the images are put in a dataframe in order to prepare for splitting the dataset into train and test set.

# %%
totaldsdirect = directory + "/CombinedFourAngleEggs"

image = []

if not os.path.exists(totaldsdirect):
    print("Directory does not exist. Please run the code on data cleaning notebook.")
    sys.exit()

#label the images
for x in os.listdir(totaldsdirect):
    totaldsdirect2 = totaldsdirect + "/" + x
    for y in os.listdir(totaldsdirect2):
        if x == "Balut-penoy5":
            lbl = "0"
        elif x == "Salted egg5":
            lbl = "1"
        else:
            lbl = "2"
                 
        #append to image array
        image.append([totaldsdirect2 + "/" + y,lbl])

# %%
df = pd.DataFrame(image,columns=['filename','label'])
df
# Out:
#                                               filename label
# 0    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 1    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 2    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 3    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# 4    C:/Users/user/Desktop/Dataset/CombinedFourAngl...     0
# ..                                                 ...   ...
# 595  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 596  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 597  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 598  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
# 599  C:/Users/user/Desktop/Dataset/CombinedFourAngl...     2
#
# [600 rows x 2 columns]

# %% [markdown]
# Classes: <br>
# 0 - Balut/Penoy <br>
# 1 - Salted <br>
# 2 - Table

# %% [markdown]
# ## Split Data to train and test set

# %% [markdown]
# We will need to split the dataset to train and test set (90:10). The train set will be used for Hyperparameter tuning with Stratified K-fold Cross Validation to find the best hyperparameters and use that as the hyperparameters to train the final model using the train set. Test set will be used for model prediction and model evaluation. Stratify is used in order to split the data in equal numbers under each class specified.

# %%
# Split the data to train and test
X = df[['filename']]
y = df[['label']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=420)

# %% [markdown]
# Save the images in the split sets to train and test set folders.

# %%
#folder to store the train and test set folders
fortraintest = directory + "/ToBeUsed"
if not os.path.exists(fortraintest):
    os.makedirs(fortraintest)

#train set folder
tr = fortraintest + "/train_set"
if not os.path.exists(tr):
    os.makedirs(tr)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr)
    os.makedirs(tr)
    
#test set folder
te = fortraintest + "/test_set"
if not os.path.exists(te):
    os.makedirs(te)
else:
    #remove previous folder and create new one
    shutil.rmtree(te)
    os.makedirs(te)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    trcpy = shutil.copy2(row['filename'], tr)
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_test.iterrows():
    tecpy = shutil.copy2(row['filename'], te)
    X_test.loc[X_test['filename']==row['filename'],'filename']=tecpy #change to directory where image is copied

# %% [markdown]
# ### Train Set

# %%
df2 = pd.concat([X_train,y_train],axis=1)
df2
# Out:
#                                               filename label
# 11   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 581  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 377  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 487  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 216  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# ..                                                 ...   ...
# 273  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 486  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 86   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 200  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 538  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
#
# [540 rows x 2 columns]

# %% [markdown]
# To check whether or not there are equal amounts of images per class in the train set, we have done what is shown below.

# %%
counto = [0,0,0]

counto_count = 0

df2_lbl = sorted(df2['label'].unique(), reverse=False) 

for x in df2_lbl:
    for y in df2['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1

# %%
print(counto)
# Out:
# [180, 180, 180]

# %% [markdown]
# ### Test Set

# %%
df3 = pd.concat([X_test,y_test],axis=1)
df3
# Out:
#                                               filename label
# 177  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 535  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 563  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 498  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 502  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 257  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 559  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 134  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 298  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 10   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 154  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 126  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 348  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 275  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 142  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 152  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 63   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 356  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 422  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 427  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 115  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 361  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 326  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 478  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 506  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 35   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 278  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 415  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 205  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 174  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 47   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 537  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 578  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 262  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 31   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 151  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 304  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 393  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 72   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 85   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 327  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 238  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 132  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 243  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 403  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 277  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 544  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 37   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 533  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 518  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 185  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 213  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 220  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 198  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 350  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 414  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 569  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 421  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 517  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 245  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1

# %% [markdown]
# Same with the train set, we checked whether or not there is an equal distribution of images in the test set.

# %%
counto = [0,0,0]

counto_count = 0

df3_lbl = sorted(df3['label'].unique(), reverse=False) 

for x in df3_lbl:
    for y in df3['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1

# %%
print(counto)
# Out:
# [20, 20, 20]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Create Plot History

# %% [markdown]
# Plot history will display the training and validation accuracy and loss in every epoch per fold.

# %%
def plot_history(history, yrange):
    #Plot loss and accuracy as a function of the epoch,
    #for the training and validation datasets.
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams["axes.edgecolor"] = 'black'
    plt.rcParams["axes.linewidth"]  = 1.25
    
    # Plot training and validation accuracy per epoch
    plt.plot(epochs, acc)
    plt.plot(epochs, val_acc)
    plt.title('Training and validation accuracy')
    plt.legend(['train_accuracy','val_accuracy'])
    plt.ylim(yrange)
    
    # Plot training and validation loss per epoch
    plt.figure()

    plt.plot(epochs, loss)
    plt.plot(epochs, val_loss)
    plt.title('Training and validation loss')
    plt.legend(['train_loss','val_loss'])
    
    plt.show()

# %% [markdown]
# ### Save Models

# %% [markdown]
# Stratified K-fold Cross Validation will be used in getting the best hyperparameters that will be utilized to train the final model. The set of model weights produced per fold will be saved in an automatic generated folder. Every training will generate another folder to save the new set.

# %%
def savemodel():
    save_cur = ""  #check if there is any saved_models folder(s)

    svnum = 0
    svnum2 = 0

    for x in os.listdir(gen_dir):
        if "saved_models" in x:
            save_cur = x
            if not save_cur == "":
                if save_cur.split("_")[-1].isdigit():
                    svnum2 = int(save_cur.split("_")[-1])
                    if svnum < svnum2:
                        svnum = svnum2

    #save_dir is where the created models using the current set of hyperparameters are added        
    if save_cur == "":
        save_dir = gen_dir + "/saved_models_1"
        os.makedirs(save_dir)
    else:
        save_dir = gen_dir + "/saved_models_" + str(svnum + 1)
        os.makedirs(save_dir)
        
    return save_dir

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# We will apply data augmentation to increase the dataset. We will use data augmentation per epoch in order to generate unique images in order to increase the dataset.

# %%
resnet50 = keras.applications.resnet50

imgdatagen = ImageDataGenerator(
        preprocessing_function = resnet50.preprocess_input,
        horizontal_flip = True,
        vertical_flip = True,
        width_shift_range = 10,
        height_shift_range = 10,
        rotation_range = 5,
        brightness_range = [0.8,1.3],
        fill_mode = "nearest"
    )

# %% [markdown]
# ## Model Creation

# %% [markdown]
# The model will be based on ResNet50 Architecture. The classifier block will be changed to suit to our dataset.

# %%
def create_model():
    conv_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

    for layer in conv_model.layers:
        layer.trainable = False

    x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
    x = keras.layers.Dense(512, activation='relu')(x)
    x = keras.layers.Dense(256, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.2)(x)
    predictions = keras.layers.Dense(3, activation='softmax')(x)

    full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

    return full_model

# %%
full_model = create_model()
full_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            771         dropout[0][0]
# ==================================================================================================
# Total params: 24,769,923
# Trainable params: 1,181,699
# Non-trainable params: 23,588,224
# __________________________________________________________________________________________________

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# We will check the combination of hyperparameters that yielded the lowest validation loss. A set of values on chosen hyperparameters is given. The best combination will be used to train the final model.

# %% [markdown]
# ### Model Hyperparameters

# %%
batch_size_arr = [8]                                 #batch size
num_epochs_arr = [100]                              #number of epochs
lr_arr = [0.0001]                                  #learning rate Adamax

# %% [markdown]
# ### Initialize Variables

# %%
VALIDATION_ACCURACY = []                          #holds all validation_accuracy in current combination
VALIDATION_LOSS = []                              #holds all validation_loss in current combination

TRAIN_ACCURACY = []                               #holds all train_accuracy in current combination
TRAIN_LOSS = []                                   #holds all train_loss in current combination

param_arr = []                                    #holds the hyperparameter values per combination

val_acc_arr = []                                  #holds the set of validation accuracy per combination
val_loss_arr = []                                 #holds the set of validation loss per combination
val_acc_means = []                                #holds the means of all set of validation accuracy per combination
val_loss_means = []                               #holds the means of all set of validation loss per combination

train_acc_arr = []                                #holds the set of train accuracy per combination
train_loss_arr = []                               #holds the set of train loss per combination
train_acc_means = []                              #holds the means of all set of train accuracy per combination
train_loss_means = []                             #holds the means of all set of train loss per combination

# %% [markdown]
# ### Train, Validation, Test data settings

# %%
train_dir = directory + "/ToBeUsed/train_set"     #where the train set images are stored

#strat kfold parameters
Y = df2[['label']]
skf = StratifiedKFold(n_splits = 5, random_state = 69, shuffle = True)

# %% [markdown]
# Train the model per combination of hyperparameters.

# %%
for x in range(len(batch_size_arr)):
    
    #for batch size values
    if len(param_arr) == 0:
        param_arr.append([])
    
    for y in range(len(num_epochs_arr)):

        #for epoch values
        if len(param_arr) == 1:
            param_arr.append([])
        
        for z in range(len(lr_arr)):
            
            #for learning rate values
            if len(param_arr) == 2:
                param_arr.append([])
               
            print('')
            print("batch size: ", batch_size_arr[x])
            print("epochs: ", num_epochs_arr[y])
            print("learning rate: ", lr_arr[z])
            print('')
            
            #append the values per combo
            param_arr[0].append(batch_size_arr[x])
            param_arr[1].append(num_epochs_arr[y])
            param_arr[2].append(lr_arr[z])
            
            VALIDATION_ACCURACY = []
            VALIDATION_LOSS = []
            
            TRAIN_ACCURACY = []
            TRAIN_LOSS = []
            
            #change save_dir value per combination
            save_dir = savemodel()
            fold_var = 1
            
            for train_index, val_index in skf.split(np.zeros(len(df2)),Y):
                
                #continuously split the dataset to train set and validation set in n folds
                training_data = df2.iloc[train_index]
                validation_data = df2.iloc[val_index]
                
                print('')
                print("Fold number " + str(fold_var))
                
                #apply data augmentation to both train set and validation set
                train_data_generator = imgdatagen.flow_from_dataframe(training_data, directory = train_dir,
                                       x_col = "filename", y_col = "label",
                                       class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                valid_data_generator  = imgdatagen.flow_from_dataframe(validation_data, directory = train_dir,
                                        x_col = "filename", y_col = "label",
                                        class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                
                #use the created model
                full_model = create_model()
                
                #compile the model
                full_model.compile(loss='categorical_crossentropy',
                              optimizer=keras.optimizers.Adamax(learning_rate=lr_arr[z]),
                              metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

                #create callbacks
                checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "model_" + str(fold_var) + ".h5"), 
                                        monitor='val_loss', verbose=1, 
                                        save_best_only=True, mode='min')
                callbacks_list = [checkpoint]
                #this saves the best model


                #fit the model
                history = full_model.fit(train_data_generator,
                                         epochs=num_epochs_arr[y],
                                         callbacks=callbacks_list,
                                         validation_data=valid_data_generator,
                                         verbose=1)

                #plot the history
                plot_history(history, yrange=(0.2,1))

                #load the best model instance to evaluate the performance of the model
                full_model.load_weights(save_dir+"/model_"+str(fold_var)+".h5")

                results = full_model.evaluate(valid_data_generator)
                results = dict(zip(full_model.metrics_names,results))
                
                #store Validation accuracy/loss
                VALIDATION_ACCURACY.append(results['accuracy'])
                VALIDATION_LOSS.append(results['loss'])
                
                #store Train accuracy/loss
                TRAIN_ACCURACY.append(np.mean(history.history['accuracy']))
                TRAIN_LOSS.append(np.mean(history.history['loss']))
                
                tf.keras.backend.clear_session()

                fold_var += 1
            
            #store the all accuracy and loss in all folds per combination
            val_acc_arr.append(VALIDATION_ACCURACY)
            val_loss_arr.append(VALIDATION_LOSS)
            
            train_acc_arr.append(TRAIN_ACCURACY)                            
            train_loss_arr.append(TRAIN_LOSS)
# Out:
# batch size:  8
# epochs:  100
# learning rate:  0.0001
#
#
# Fold number 1
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 54/54 [==============================] - 21s 261ms/step - loss: 1.0767 - accuracy: 0.4838 - val_loss: 1.0170 - val_accuracy: 0.5370
#
# Epoch 00001: val_loss improved from inf to 1.01702, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 2/100
# 54/54 [==============================] - 8s 154ms/step - loss: 0.9140 - accuracy: 0.5810 - val_loss: 0.9612 - val_accuracy: 0.5463
#
# Epoch 00002: val_loss improved from 1.01702 to 0.96118, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 3/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.8644 - accuracy: 0.6250 - val_loss: 0.8294 - val_accuracy: 0.6852
#
# Epoch 00003: val_loss improved from 0.96118 to 0.82937, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 4/100
# 54/54 [==============================] - 8s 151ms/step - loss: 0.7342 - accuracy: 0.6852 - val_loss: 0.8324 - val_accuracy: 0.6481
#
# Epoch 00004: val_loss did not improve from 0.82937
# Epoch 5/100
# 54/54 [==============================] - 8s 149ms/step - loss: 0.6700 - accuracy: 0.7269 - val_loss: 0.7343 - val_accuracy: 0.6667
#
# Epoch 00005: val_loss improved from 0.82937 to 0.73432, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 6/100
# 54/54 [==============================] - 8s 145ms/step - loss: 0.6756 - accuracy: 0.6991 - val_loss: 0.7122 - val_accuracy: 0.7222
#
# Epoch 00006: val_loss improved from 0.73432 to 0.71215, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 7/100
# 54/54 [==============================] - 8s 151ms/step - loss: 0.6386 - accuracy: 0.7338 - val_loss: 0.6735 - val_accuracy: 0.6944
#
# Epoch 00007: val_loss improved from 0.71215 to 0.67345, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 8/100
# 54/54 [==============================] - 8s 149ms/step - loss: 0.6316 - accuracy: 0.7454 - val_loss: 0.6353 - val_accuracy: 0.7222
#
# Epoch 00008: val_loss improved from 0.67345 to 0.63534, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 9/100
# 54/54 [==============================] - 8s 150ms/step - loss: 0.5565 - accuracy: 0.7963 - val_loss: 0.6351 - val_accuracy: 0.6852
#
# Epoch 00009: val_loss improved from 0.63534 to 0.63507, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 10/100
# 54/54 [==============================] - 9s 155ms/step - loss: 0.5614 - accuracy: 0.7616 - val_loss: 0.5944 - val_accuracy: 0.7315
#
# Epoch 00010: val_loss improved from 0.63507 to 0.59436, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 11/100
# 54/54 [==============================] - 9s 160ms/step - loss: 0.5867 - accuracy: 0.7685 - val_loss: 0.6183 - val_accuracy: 0.6759
#
# Epoch 00011: val_loss did not improve from 0.59436
# Epoch 12/100
# 54/54 [==============================] - 9s 171ms/step - loss: 0.5009 - accuracy: 0.7894 - val_loss: 0.5447 - val_accuracy: 0.7315
#
# Epoch 00012: val_loss improved from 0.59436 to 0.54473, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 13/100
# 54/54 [==============================] - 9s 156ms/step - loss: 0.5517 - accuracy: 0.7593 - val_loss: 0.5483 - val_accuracy: 0.8056
#
# Epoch 00013: val_loss did not improve from 0.54473
# Epoch 14/100
# 54/54 [==============================] - 11s 200ms/step - loss: 0.5417 - accuracy: 0.7662 - val_loss: 0.6715 - val_accuracy: 0.6944
#
# Epoch 00014: val_loss did not improve from 0.54473
# Epoch 15/100
# 54/54 [==============================] - 8s 152ms/step - loss: 0.5239 - accuracy: 0.7963 - val_loss: 0.5572 - val_accuracy: 0.7685
#
# Epoch 00015: val_loss did not improve from 0.54473
# Epoch 16/100
# 54/54 [==============================] - 8s 152ms/step - loss: 0.5102 - accuracy: 0.7940 - val_loss: 0.5946 - val_accuracy: 0.7407
#
# Epoch 00016: val_loss did not improve from 0.54473
# Epoch 17/100
# 54/54 [==============================] - 9s 171ms/step - loss: 0.5006 - accuracy: 0.8125 - val_loss: 0.5454 - val_accuracy: 0.7685
#
# Epoch 00017: val_loss did not improve from 0.54473
# Epoch 18/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4567 - accuracy: 0.8218 - val_loss: 0.5116 - val_accuracy: 0.7778
#
# Epoch 00018: val_loss improved from 0.54473 to 0.51164, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 19/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.5110 - accuracy: 0.7755 - val_loss: 0.6343 - val_accuracy: 0.7037
#
# Epoch 00019: val_loss did not improve from 0.51164
# Epoch 20/100
# 54/54 [==============================] - 10s 190ms/step - loss: 0.4844 - accuracy: 0.8403 - val_loss: 0.5297 - val_accuracy: 0.7778
#
# Epoch 00020: val_loss did not improve from 0.51164
# Epoch 21/100
# 54/54 [==============================] - 11s 196ms/step - loss: 0.4279 - accuracy: 0.8426 - val_loss: 0.5375 - val_accuracy: 0.7593
#
# Epoch 00021: val_loss did not improve from 0.51164
# Epoch 22/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.4264 - accuracy: 0.8380 - val_loss: 0.4788 - val_accuracy: 0.8056
#
# Epoch 00022: val_loss improved from 0.51164 to 0.47877, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 23/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.4325 - accuracy: 0.8310 - val_loss: 0.5561 - val_accuracy: 0.7778
#
# Epoch 00023: val_loss did not improve from 0.47877
# Epoch 24/100
# 54/54 [==============================] - 11s 201ms/step - loss: 0.4241 - accuracy: 0.8565 - val_loss: 0.6216 - val_accuracy: 0.7500
#
# Epoch 00024: val_loss did not improve from 0.47877
# Epoch 25/100
# 54/54 [==============================] - 13s 242ms/step - loss: 0.4586 - accuracy: 0.8356 - val_loss: 0.5639 - val_accuracy: 0.7778
#
# Epoch 00025: val_loss did not improve from 0.47877
# Epoch 26/100
# 54/54 [==============================] - 17s 308ms/step - loss: 0.4990 - accuracy: 0.8032 - val_loss: 0.6144 - val_accuracy: 0.7500
#
# Epoch 00026: val_loss did not improve from 0.47877
# Epoch 27/100
# 54/54 [==============================] - 13s 242ms/step - loss: 0.4381 - accuracy: 0.8125 - val_loss: 0.6095 - val_accuracy: 0.7222
#
# Epoch 00027: val_loss did not improve from 0.47877
# Epoch 28/100
# 54/54 [==============================] - 10s 190ms/step - loss: 0.4127 - accuracy: 0.8519 - val_loss: 0.5117 - val_accuracy: 0.7963
#
# Epoch 00028: val_loss did not improve from 0.47877
# Epoch 29/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3770 - accuracy: 0.8542 - val_loss: 0.5127 - val_accuracy: 0.8056
#
# Epoch 00029: val_loss did not improve from 0.47877
# Epoch 30/100
# 54/54 [==============================] - 12s 226ms/step - loss: 0.4392 - accuracy: 0.8356 - val_loss: 0.5235 - val_accuracy: 0.7870
#
# Epoch 00030: val_loss did not improve from 0.47877
# Epoch 31/100
# 54/54 [==============================] - 11s 197ms/step - loss: 0.3989 - accuracy: 0.8565 - val_loss: 0.4919 - val_accuracy: 0.7963
#
# Epoch 00031: val_loss did not improve from 0.47877
# Epoch 32/100
# 54/54 [==============================] - 11s 209ms/step - loss: 0.4222 - accuracy: 0.8241 - val_loss: 0.4597 - val_accuracy: 0.7963
#
# Epoch 00032: val_loss improved from 0.47877 to 0.45969, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 33/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3700 - accuracy: 0.8542 - val_loss: 0.4815 - val_accuracy: 0.7500
#
# Epoch 00033: val_loss did not improve from 0.45969
# Epoch 34/100
# 54/54 [==============================] - 11s 206ms/step - loss: 0.4140 - accuracy: 0.8333 - val_loss: 0.5081 - val_accuracy: 0.7500
#
# Epoch 00034: val_loss did not improve from 0.45969
# Epoch 35/100
# 54/54 [==============================] - 11s 206ms/step - loss: 0.4163 - accuracy: 0.8380 - val_loss: 0.4729 - val_accuracy: 0.7870
#
# Epoch 00035: val_loss did not improve from 0.45969
# Epoch 36/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.3739 - accuracy: 0.8542 - val_loss: 0.4601 - val_accuracy: 0.8426
#
# Epoch 00036: val_loss did not improve from 0.45969
# Epoch 37/100
# 54/54 [==============================] - 12s 219ms/step - loss: 0.3757 - accuracy: 0.8588 - val_loss: 0.6031 - val_accuracy: 0.7593
#
# Epoch 00037: val_loss did not improve from 0.45969
# Epoch 38/100
# 54/54 [==============================] - 12s 219ms/step - loss: 0.3715 - accuracy: 0.8565 - val_loss: 0.3906 - val_accuracy: 0.8241
#
# Epoch 00038: val_loss improved from 0.45969 to 0.39058, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 39/100
# 54/54 [==============================] - 9s 162ms/step - loss: 0.3888 - accuracy: 0.8634 - val_loss: 0.4659 - val_accuracy: 0.7963
#
# Epoch 00039: val_loss did not improve from 0.39058
# Epoch 40/100
# 54/54 [==============================] - 9s 169ms/step - loss: 0.3970 - accuracy: 0.8588 - val_loss: 0.4495 - val_accuracy: 0.8056
#
# Epoch 00040: val_loss did not improve from 0.39058
# Epoch 41/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3477 - accuracy: 0.8542 - val_loss: 0.5053 - val_accuracy: 0.8333
#
# Epoch 00041: val_loss did not improve from 0.39058
# Epoch 42/100
# 54/54 [==============================] - 11s 194ms/step - loss: 0.3862 - accuracy: 0.8472 - val_loss: 0.4980 - val_accuracy: 0.7963
#
# Epoch 00042: val_loss did not improve from 0.39058
# Epoch 43/100
# 54/54 [==============================] - 11s 197ms/step - loss: 0.3982 - accuracy: 0.8380 - val_loss: 0.3847 - val_accuracy: 0.8519
#
# Epoch 00043: val_loss improved from 0.39058 to 0.38473, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 44/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3778 - accuracy: 0.8565 - val_loss: 0.5084 - val_accuracy: 0.7778
#
# Epoch 00044: val_loss did not improve from 0.38473
# Epoch 45/100
# 54/54 [==============================] - 10s 171ms/step - loss: 0.3385 - accuracy: 0.8819 - val_loss: 0.3954 - val_accuracy: 0.8519
#
# Epoch 00045: val_loss did not improve from 0.38473
# Epoch 46/100
# 54/54 [==============================] - 11s 200ms/step - loss: 0.3942 - accuracy: 0.8565 - val_loss: 0.4647 - val_accuracy: 0.7963
#
# Epoch 00046: val_loss did not improve from 0.38473
# Epoch 47/100
# 54/54 [==============================] - 12s 217ms/step - loss: 0.3092 - accuracy: 0.8935 - val_loss: 0.3661 - val_accuracy: 0.8241
#
# Epoch 00047: val_loss improved from 0.38473 to 0.36612, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 48/100
# 54/54 [==============================] - 8s 151ms/step - loss: 0.3046 - accuracy: 0.8773 - val_loss: 0.3853 - val_accuracy: 0.8426
#
# Epoch 00048: val_loss did not improve from 0.36612
# Epoch 49/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3260 - accuracy: 0.8819 - val_loss: 0.4673 - val_accuracy: 0.7685
#
# Epoch 00049: val_loss did not improve from 0.36612
# Epoch 50/100
# 54/54 [==============================] - 12s 227ms/step - loss: 0.3286 - accuracy: 0.8750 - val_loss: 0.3471 - val_accuracy: 0.8426
#
# Epoch 00050: val_loss improved from 0.36612 to 0.34707, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 51/100
# 54/54 [==============================] - 9s 162ms/step - loss: 0.2967 - accuracy: 0.8981 - val_loss: 0.4797 - val_accuracy: 0.8241
#
# Epoch 00051: val_loss did not improve from 0.34707
# Epoch 52/100
# 54/54 [==============================] - 9s 174ms/step - loss: 0.3133 - accuracy: 0.8935 - val_loss: 0.3810 - val_accuracy: 0.8333
#
# Epoch 00052: val_loss did not improve from 0.34707
# Epoch 53/100
# 54/54 [==============================] - 13s 236ms/step - loss: 0.3222 - accuracy: 0.8796 - val_loss: 0.4042 - val_accuracy: 0.8241
#
# Epoch 00053: val_loss did not improve from 0.34707
# Epoch 54/100
# 54/54 [==============================] - 12s 202ms/step - loss: 0.3048 - accuracy: 0.8866 - val_loss: 0.3133 - val_accuracy: 0.8796
#
# Epoch 00054: val_loss improved from 0.34707 to 0.31328, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 55/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3054 - accuracy: 0.8981 - val_loss: 0.3630 - val_accuracy: 0.8611
#
# Epoch 00055: val_loss did not improve from 0.31328
# Epoch 56/100
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3403 - accuracy: 0.8565 - val_loss: 0.3522 - val_accuracy: 0.8704
#
# Epoch 00056: val_loss did not improve from 0.31328
# Epoch 57/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.3107 - accuracy: 0.8796 - val_loss: 0.4810 - val_accuracy: 0.7963
#
# Epoch 00057: val_loss did not improve from 0.31328
# Epoch 58/100
# 54/54 [==============================] - 12s 210ms/step - loss: 0.3090 - accuracy: 0.8773 - val_loss: 0.3698 - val_accuracy: 0.8426
#
# Epoch 00058: val_loss did not improve from 0.31328
# Epoch 59/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3270 - accuracy: 0.8773 - val_loss: 0.4031 - val_accuracy: 0.8241
#
# Epoch 00059: val_loss did not improve from 0.31328
# Epoch 60/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.2850 - accuracy: 0.9005 - val_loss: 0.3516 - val_accuracy: 0.8704
#
# Epoch 00060: val_loss did not improve from 0.31328
# Epoch 61/100
# 54/54 [==============================] - 11s 197ms/step - loss: 0.3277 - accuracy: 0.8819 - val_loss: 0.3653 - val_accuracy: 0.8426
#
# Epoch 00061: val_loss did not improve from 0.31328
# Epoch 62/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.2900 - accuracy: 0.8819 - val_loss: 0.4510 - val_accuracy: 0.8333
#
# Epoch 00062: val_loss did not improve from 0.31328
# Epoch 63/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3236 - accuracy: 0.8657 - val_loss: 0.3801 - val_accuracy: 0.8426
#
# Epoch 00063: val_loss did not improve from 0.31328
# Epoch 64/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.2623 - accuracy: 0.9167 - val_loss: 0.3067 - val_accuracy: 0.8796
#
# Epoch 00064: val_loss improved from 0.31328 to 0.30668, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 65/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3172 - accuracy: 0.8819 - val_loss: 0.4813 - val_accuracy: 0.8241
#
# Epoch 00065: val_loss did not improve from 0.30668
# Epoch 66/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2693 - accuracy: 0.9005 - val_loss: 0.4498 - val_accuracy: 0.8148
#
# Epoch 00066: val_loss did not improve from 0.30668
# Epoch 67/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.3093 - accuracy: 0.8843 - val_loss: 0.4280 - val_accuracy: 0.8426
#
# Epoch 00067: val_loss did not improve from 0.30668
# Epoch 68/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.2810 - accuracy: 0.9051 - val_loss: 0.4280 - val_accuracy: 0.8148
#
# Epoch 00068: val_loss did not improve from 0.30668
# Epoch 69/100
# 54/54 [==============================] - 10s 193ms/step - loss: 0.3078 - accuracy: 0.8773 - val_loss: 0.2888 - val_accuracy: 0.8889
#
# Epoch 00069: val_loss improved from 0.30668 to 0.28884, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 70/100
# 54/54 [==============================] - 9s 164ms/step - loss: 0.3162 - accuracy: 0.8611 - val_loss: 0.5053 - val_accuracy: 0.7593
#
# Epoch 00070: val_loss did not improve from 0.28884
# Epoch 71/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.3135 - accuracy: 0.8889 - val_loss: 0.3867 - val_accuracy: 0.8333
#
# Epoch 00071: val_loss did not improve from 0.28884
# Epoch 72/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.2866 - accuracy: 0.9144 - val_loss: 0.4336 - val_accuracy: 0.8148
#
# Epoch 00072: val_loss did not improve from 0.28884
# Epoch 73/100
# 54/54 [==============================] - 9s 154ms/step - loss: 0.3145 - accuracy: 0.8958 - val_loss: 0.4036 - val_accuracy: 0.8519
#
# Epoch 00073: val_loss did not improve from 0.28884
# Epoch 74/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.2704 - accuracy: 0.9190 - val_loss: 0.3864 - val_accuracy: 0.8426
#
# Epoch 00074: val_loss did not improve from 0.28884
# Epoch 75/100
# 54/54 [==============================] - 10s 189ms/step - loss: 0.3071 - accuracy: 0.8704 - val_loss: 0.4400 - val_accuracy: 0.8148
#
# Epoch 00075: val_loss did not improve from 0.28884
# Epoch 76/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.2770 - accuracy: 0.9051 - val_loss: 0.3466 - val_accuracy: 0.8889
#
# Epoch 00076: val_loss did not improve from 0.28884
# Epoch 77/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.2794 - accuracy: 0.9005 - val_loss: 0.3525 - val_accuracy: 0.8426
#
# Epoch 00077: val_loss did not improve from 0.28884
# Epoch 78/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.2563 - accuracy: 0.9144 - val_loss: 0.4265 - val_accuracy: 0.8241
#
# Epoch 00078: val_loss did not improve from 0.28884
# Epoch 79/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.2320 - accuracy: 0.9213 - val_loss: 0.3570 - val_accuracy: 0.8704
#
# Epoch 00079: val_loss did not improve from 0.28884
# Epoch 80/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.3068 - accuracy: 0.8912 - val_loss: 0.4092 - val_accuracy: 0.8148
#
# Epoch 00080: val_loss did not improve from 0.28884
# Epoch 81/100
# 54/54 [==============================] - 11s 192ms/step - loss: 0.2652 - accuracy: 0.9051 - val_loss: 0.3318 - val_accuracy: 0.8889
#
# Epoch 00081: val_loss did not improve from 0.28884
# Epoch 82/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2885 - accuracy: 0.8819 - val_loss: 0.3718 - val_accuracy: 0.8426
#
# Epoch 00082: val_loss did not improve from 0.28884
# Epoch 83/100
# 54/54 [==============================] - 8s 152ms/step - loss: 0.2861 - accuracy: 0.8981 - val_loss: 0.3470 - val_accuracy: 0.8611
#
# Epoch 00083: val_loss did not improve from 0.28884
# Epoch 84/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.2702 - accuracy: 0.9074 - val_loss: 0.3652 - val_accuracy: 0.8889
#
# Epoch 00084: val_loss did not improve from 0.28884
# Epoch 85/100
# 54/54 [==============================] - 10s 189ms/step - loss: 0.2098 - accuracy: 0.9375 - val_loss: 0.3567 - val_accuracy: 0.8611
#
# Epoch 00085: val_loss did not improve from 0.28884
# Epoch 86/100
# 54/54 [==============================] - 11s 196ms/step - loss: 0.2890 - accuracy: 0.9005 - val_loss: 0.3499 - val_accuracy: 0.8426
#
# Epoch 00086: val_loss did not improve from 0.28884
# Epoch 87/100
# 54/54 [==============================] - 16s 278ms/step - loss: 0.2369 - accuracy: 0.9213 - val_loss: 0.3161 - val_accuracy: 0.8889
#
# Epoch 00087: val_loss did not improve from 0.28884
# Epoch 88/100
# 54/54 [==============================] - 11s 201ms/step - loss: 0.2198 - accuracy: 0.9236 - val_loss: 0.4909 - val_accuracy: 0.7963
#
# Epoch 00088: val_loss did not improve from 0.28884
# Epoch 89/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.2856 - accuracy: 0.8773 - val_loss: 0.3411 - val_accuracy: 0.8889
#
# Epoch 00089: val_loss did not improve from 0.28884
# Epoch 90/100
# 54/54 [==============================] - 11s 201ms/step - loss: 0.2130 - accuracy: 0.9213 - val_loss: 0.3286 - val_accuracy: 0.8889
#
# Epoch 00090: val_loss did not improve from 0.28884
# Epoch 91/100
# 54/54 [==============================] - 13s 246ms/step - loss: 0.2553 - accuracy: 0.9190 - val_loss: 0.3158 - val_accuracy: 0.8796
#
# Epoch 00091: val_loss did not improve from 0.28884
# Epoch 92/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.2367 - accuracy: 0.9190 - val_loss: 0.3571 - val_accuracy: 0.8889
#
# Epoch 00092: val_loss did not improve from 0.28884
# Epoch 93/100
# 54/54 [==============================] - 9s 170ms/step - loss: 0.2922 - accuracy: 0.8889 - val_loss: 0.3488 - val_accuracy: 0.8704
#
# Epoch 00093: val_loss did not improve from 0.28884
# Epoch 94/100
# 54/54 [==============================] - 11s 210ms/step - loss: 0.2488 - accuracy: 0.8981 - val_loss: 0.4441 - val_accuracy: 0.7963
#
# Epoch 00094: val_loss did not improve from 0.28884
# Epoch 95/100
# 54/54 [==============================] - 10s 189ms/step - loss: 0.2660 - accuracy: 0.9005 - val_loss: 0.3423 - val_accuracy: 0.8611
#
# Epoch 00095: val_loss did not improve from 0.28884
# Epoch 96/100
# 54/54 [==============================] - 9s 170ms/step - loss: 0.2384 - accuracy: 0.9097 - val_loss: 0.3257 - val_accuracy: 0.8333
#
# Epoch 00096: val_loss did not improve from 0.28884
# Epoch 97/100
# 54/54 [==============================] - 11s 206ms/step - loss: 0.2739 - accuracy: 0.9051 - val_loss: 0.3066 - val_accuracy: 0.9074
#
# Epoch 00097: val_loss did not improve from 0.28884
# Epoch 98/100
# 54/54 [==============================] - 15s 266ms/step - loss: 0.1951 - accuracy: 0.9282 - val_loss: 0.3326 - val_accuracy: 0.8519
#
# Epoch 00098: val_loss did not improve from 0.28884
# Epoch 99/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.2105 - accuracy: 0.9282 - val_loss: 0.2859 - val_accuracy: 0.8981
#
# Epoch 00099: val_loss improved from 0.28884 to 0.28593, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 100/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.2537 - accuracy: 0.8981 - val_loss: 0.3987 - val_accuracy: 0.8704
#
# Epoch 00100: val_loss did not improve from 0.28593
# 14/14 [==============================] - 2s 112ms/step - loss: 0.2798 - accuracy: 0.9259
#
# Fold number 2
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 54/54 [==============================] - 15s 223ms/step - loss: 1.1756 - accuracy: 0.4606 - val_loss: 0.9765 - val_accuracy: 0.5926
#
# Epoch 00001: val_loss improved from inf to 0.97650, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 2/100
# 54/54 [==============================] - 9s 155ms/step - loss: 0.8779 - accuracy: 0.6227 - val_loss: 0.9211 - val_accuracy: 0.5833
#
# Epoch 00002: val_loss improved from 0.97650 to 0.92107, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 3/100
# 54/54 [==============================] - 8s 153ms/step - loss: 0.7664 - accuracy: 0.6782 - val_loss: 0.8365 - val_accuracy: 0.6389
#
# Epoch 00003: val_loss improved from 0.92107 to 0.83652, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 4/100
# 54/54 [==============================] - 9s 157ms/step - loss: 0.7511 - accuracy: 0.6829 - val_loss: 0.8215 - val_accuracy: 0.6481
#
# Epoch 00004: val_loss improved from 0.83652 to 0.82148, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 5/100
# 54/54 [==============================] - 9s 165ms/step - loss: 0.7174 - accuracy: 0.6898 - val_loss: 0.6592 - val_accuracy: 0.7222
#
# Epoch 00005: val_loss improved from 0.82148 to 0.65923, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 6/100
# 54/54 [==============================] - 10s 173ms/step - loss: 0.6876 - accuracy: 0.6782 - val_loss: 0.6917 - val_accuracy: 0.7222
#
# Epoch 00006: val_loss did not improve from 0.65923
# Epoch 7/100
# 54/54 [==============================] - 10s 175ms/step - loss: 0.6633 - accuracy: 0.7269 - val_loss: 0.6230 - val_accuracy: 0.7685
#
# Epoch 00007: val_loss improved from 0.65923 to 0.62296, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 8/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.5994 - accuracy: 0.7685 - val_loss: 0.5796 - val_accuracy: 0.7963
#
# Epoch 00008: val_loss improved from 0.62296 to 0.57961, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 9/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.6342 - accuracy: 0.7500 - val_loss: 0.5937 - val_accuracy: 0.7593
#
# Epoch 00009: val_loss did not improve from 0.57961
# Epoch 10/100
# 54/54 [==============================] - 13s 246ms/step - loss: 0.6570 - accuracy: 0.7060 - val_loss: 0.6587 - val_accuracy: 0.7130
#
# Epoch 00010: val_loss did not improve from 0.57961
# Epoch 11/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.6046 - accuracy: 0.7685 - val_loss: 0.5752 - val_accuracy: 0.7870
#
# Epoch 00011: val_loss improved from 0.57961 to 0.57515, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 12/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.6016 - accuracy: 0.7500 - val_loss: 0.5958 - val_accuracy: 0.7315
#
# Epoch 00012: val_loss did not improve from 0.57515
# Epoch 13/100
# 54/54 [==============================] - 10s 185ms/step - loss: 0.6051 - accuracy: 0.7662 - val_loss: 0.5751 - val_accuracy: 0.7500
#
# Epoch 00013: val_loss improved from 0.57515 to 0.57507, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 14/100
# 54/54 [==============================] - 9s 152ms/step - loss: 0.5326 - accuracy: 0.7546 - val_loss: 0.5333 - val_accuracy: 0.7778
#
# Epoch 00014: val_loss improved from 0.57507 to 0.53333, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 15/100
# 54/54 [==============================] - 8s 149ms/step - loss: 0.5244 - accuracy: 0.7801 - val_loss: 0.5483 - val_accuracy: 0.7593
#
# Epoch 00015: val_loss did not improve from 0.53333
# Epoch 16/100
# 54/54 [==============================] - 9s 162ms/step - loss: 0.5129 - accuracy: 0.7870 - val_loss: 0.5717 - val_accuracy: 0.7685
#
# Epoch 00016: val_loss did not improve from 0.53333
# Epoch 17/100
# 54/54 [==============================] - 9s 164ms/step - loss: 0.5240 - accuracy: 0.8009 - val_loss: 0.5161 - val_accuracy: 0.8056
#
# Epoch 00017: val_loss improved from 0.53333 to 0.51611, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 18/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.5094 - accuracy: 0.7917 - val_loss: 0.5094 - val_accuracy: 0.7870
#
# Epoch 00018: val_loss improved from 0.51611 to 0.50944, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 19/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.5826 - accuracy: 0.7616 - val_loss: 0.5373 - val_accuracy: 0.7593
#
# Epoch 00019: val_loss did not improve from 0.50944
# Epoch 20/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4904 - accuracy: 0.8148 - val_loss: 0.4874 - val_accuracy: 0.8056
#
# Epoch 00020: val_loss improved from 0.50944 to 0.48740, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 21/100
# 54/54 [==============================] - 18s 336ms/step - loss: 0.4872 - accuracy: 0.7894 - val_loss: 0.5596 - val_accuracy: 0.7315
#
# Epoch 00021: val_loss did not improve from 0.48740
# Epoch 22/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.4817 - accuracy: 0.8079 - val_loss: 0.4544 - val_accuracy: 0.8519
#
# Epoch 00022: val_loss improved from 0.48740 to 0.45437, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 23/100
# 54/54 [==============================] - 10s 189ms/step - loss: 0.5358 - accuracy: 0.7662 - val_loss: 0.5065 - val_accuracy: 0.8056
#
# Epoch 00023: val_loss did not improve from 0.45437
# Epoch 24/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.5343 - accuracy: 0.7824 - val_loss: 0.4791 - val_accuracy: 0.7778
#
# Epoch 00024: val_loss did not improve from 0.45437
# Epoch 25/100
# 54/54 [==============================] - 9s 170ms/step - loss: 0.4735 - accuracy: 0.8032 - val_loss: 0.4654 - val_accuracy: 0.8333
#
# Epoch 00025: val_loss did not improve from 0.45437
# Epoch 26/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4851 - accuracy: 0.8241 - val_loss: 0.3890 - val_accuracy: 0.8611
#
# Epoch 00026: val_loss improved from 0.45437 to 0.38903, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 27/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.4292 - accuracy: 0.8519 - val_loss: 0.5209 - val_accuracy: 0.7963
#
# Epoch 00027: val_loss did not improve from 0.38903
# Epoch 28/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4611 - accuracy: 0.8171 - val_loss: 0.3704 - val_accuracy: 0.8426
#
# Epoch 00028: val_loss improved from 0.38903 to 0.37040, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 29/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.3983 - accuracy: 0.8519 - val_loss: 0.4069 - val_accuracy: 0.8333
#
# Epoch 00029: val_loss did not improve from 0.37040
# Epoch 30/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.4581 - accuracy: 0.8056 - val_loss: 0.4252 - val_accuracy: 0.8148
#
# Epoch 00030: val_loss did not improve from 0.37040
# Epoch 31/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.5035 - accuracy: 0.8032 - val_loss: 0.3916 - val_accuracy: 0.8426
#
# Epoch 00031: val_loss did not improve from 0.37040
# Epoch 32/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4711 - accuracy: 0.8079 - val_loss: 0.5010 - val_accuracy: 0.8056
#
# Epoch 00032: val_loss did not improve from 0.37040
# Epoch 33/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4352 - accuracy: 0.8426 - val_loss: 0.4811 - val_accuracy: 0.8426
#
# Epoch 00033: val_loss did not improve from 0.37040
# Epoch 34/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4425 - accuracy: 0.8194 - val_loss: 0.4875 - val_accuracy: 0.7963
#
# Epoch 00034: val_loss did not improve from 0.37040
# Epoch 35/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3879 - accuracy: 0.8565 - val_loss: 0.3485 - val_accuracy: 0.8796
#
# Epoch 00035: val_loss improved from 0.37040 to 0.34850, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 36/100
# 54/54 [==============================] - 9s 165ms/step - loss: 0.3942 - accuracy: 0.8519 - val_loss: 0.3261 - val_accuracy: 0.8796
#
# Epoch 00036: val_loss improved from 0.34850 to 0.32610, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 37/100
# 54/54 [==============================] - 12s 218ms/step - loss: 0.4037 - accuracy: 0.8403 - val_loss: 0.4151 - val_accuracy: 0.8148
#
# Epoch 00037: val_loss did not improve from 0.32610
# Epoch 38/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.4081 - accuracy: 0.8403 - val_loss: 0.3948 - val_accuracy: 0.8519
#
# Epoch 00038: val_loss did not improve from 0.32610
# Epoch 39/100
# 54/54 [==============================] - 9s 157ms/step - loss: 0.3582 - accuracy: 0.8704 - val_loss: 0.3832 - val_accuracy: 0.8333
#
# Epoch 00039: val_loss did not improve from 0.32610
# Epoch 40/100
# 54/54 [==============================] - 9s 165ms/step - loss: 0.3980 - accuracy: 0.8449 - val_loss: 0.3960 - val_accuracy: 0.8704
#
# Epoch 00040: val_loss did not improve from 0.32610
# Epoch 41/100
# 54/54 [==============================] - 10s 174ms/step - loss: 0.3716 - accuracy: 0.8519 - val_loss: 0.3836 - val_accuracy: 0.8333
#
# Epoch 00041: val_loss did not improve from 0.32610
# Epoch 42/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3776 - accuracy: 0.8449 - val_loss: 0.3511 - val_accuracy: 0.8519
#
# Epoch 00042: val_loss did not improve from 0.32610
# Epoch 43/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.4220 - accuracy: 0.8264 - val_loss: 0.3573 - val_accuracy: 0.8796
#
# Epoch 00043: val_loss did not improve from 0.32610
# Epoch 44/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3902 - accuracy: 0.8519 - val_loss: 0.3442 - val_accuracy: 0.8704
#
# Epoch 00044: val_loss did not improve from 0.32610
# Epoch 45/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3422 - accuracy: 0.8611 - val_loss: 0.3725 - val_accuracy: 0.8704
#
# Epoch 00045: val_loss did not improve from 0.32610
# Epoch 46/100
# 54/54 [==============================] - 11s 210ms/step - loss: 0.3439 - accuracy: 0.8704 - val_loss: 0.3633 - val_accuracy: 0.8704
#
# Epoch 00046: val_loss did not improve from 0.32610
# Epoch 47/100
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3753 - accuracy: 0.8519 - val_loss: 0.4924 - val_accuracy: 0.8056
#
# Epoch 00047: val_loss did not improve from 0.32610
# Epoch 48/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.3633 - accuracy: 0.8542 - val_loss: 0.3419 - val_accuracy: 0.8611
#
# Epoch 00048: val_loss did not improve from 0.32610
# Epoch 49/100
# 54/54 [==============================] - 13s 247ms/step - loss: 0.3541 - accuracy: 0.8565 - val_loss: 0.4131 - val_accuracy: 0.8704
#
# Epoch 00049: val_loss did not improve from 0.32610
# Epoch 50/100
# 54/54 [==============================] - 11s 194ms/step - loss: 0.4085 - accuracy: 0.8449 - val_loss: 0.3303 - val_accuracy: 0.8611
#
# Epoch 00050: val_loss did not improve from 0.32610
# Epoch 51/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.4157 - accuracy: 0.8287 - val_loss: 0.2873 - val_accuracy: 0.8981
#
# Epoch 00051: val_loss improved from 0.32610 to 0.28733, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 52/100
# 54/54 [==============================] - 11s 203ms/step - loss: 0.3435 - accuracy: 0.8727 - val_loss: 0.2839 - val_accuracy: 0.9167
#
# Epoch 00052: val_loss improved from 0.28733 to 0.28391, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 53/100
# 54/54 [==============================] - 12s 220ms/step - loss: 0.3516 - accuracy: 0.8704 - val_loss: 0.3327 - val_accuracy: 0.8519
#
# Epoch 00053: val_loss did not improve from 0.28391
# Epoch 54/100
# 54/54 [==============================] - 13s 234ms/step - loss: 0.3182 - accuracy: 0.8796 - val_loss: 0.4213 - val_accuracy: 0.8241
#
# Epoch 00054: val_loss did not improve from 0.28391
# Epoch 55/100
# 54/54 [==============================] - 11s 206ms/step - loss: 0.3689 - accuracy: 0.8565 - val_loss: 0.3109 - val_accuracy: 0.8519
#
# Epoch 00055: val_loss did not improve from 0.28391
# Epoch 56/100
# 54/54 [==============================] - 11s 206ms/step - loss: 0.3759 - accuracy: 0.8542 - val_loss: 0.3655 - val_accuracy: 0.8426
#
# Epoch 00056: val_loss did not improve from 0.28391
# Epoch 57/100
# 54/54 [==============================] - 11s 208ms/step - loss: 0.3622 - accuracy: 0.8727 - val_loss: 0.2572 - val_accuracy: 0.9259
#
# Epoch 00057: val_loss improved from 0.28391 to 0.25718, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 58/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.2865 - accuracy: 0.8912 - val_loss: 0.3302 - val_accuracy: 0.8519
#
# Epoch 00058: val_loss did not improve from 0.25718
# Epoch 59/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.3651 - accuracy: 0.8380 - val_loss: 0.2952 - val_accuracy: 0.8704
#
# Epoch 00059: val_loss did not improve from 0.25718
# Epoch 60/100
# 54/54 [==============================] - 11s 208ms/step - loss: 0.3191 - accuracy: 0.8819 - val_loss: 0.2787 - val_accuracy: 0.8981
#
# Epoch 00060: val_loss did not improve from 0.25718
# Epoch 61/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3235 - accuracy: 0.8819 - val_loss: 0.3150 - val_accuracy: 0.8704
#
# Epoch 00061: val_loss did not improve from 0.25718
# Epoch 62/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3131 - accuracy: 0.8657 - val_loss: 0.2903 - val_accuracy: 0.8981
#
# Epoch 00062: val_loss did not improve from 0.25718
# Epoch 63/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3439 - accuracy: 0.8727 - val_loss: 0.4249 - val_accuracy: 0.8519
#
# Epoch 00063: val_loss did not improve from 0.25718
# Epoch 64/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3549 - accuracy: 0.8704 - val_loss: 0.3160 - val_accuracy: 0.8796
#
# Epoch 00064: val_loss did not improve from 0.25718
# Epoch 65/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3388 - accuracy: 0.8750 - val_loss: 0.3217 - val_accuracy: 0.8796
#
# Epoch 00065: val_loss did not improve from 0.25718
# Epoch 66/100
# 54/54 [==============================] - 11s 196ms/step - loss: 0.3177 - accuracy: 0.8819 - val_loss: 0.2841 - val_accuracy: 0.8796
#
# Epoch 00066: val_loss did not improve from 0.25718
# Epoch 67/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.2885 - accuracy: 0.8958 - val_loss: 0.2614 - val_accuracy: 0.8889
#
# Epoch 00067: val_loss did not improve from 0.25718
# Epoch 68/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3494 - accuracy: 0.8681 - val_loss: 0.2788 - val_accuracy: 0.9074
#
# Epoch 00068: val_loss did not improve from 0.25718
# Epoch 69/100
# 54/54 [==============================] - 12s 226ms/step - loss: 0.3300 - accuracy: 0.8565 - val_loss: 0.2711 - val_accuracy: 0.9167
#
# Epoch 00069: val_loss did not improve from 0.25718
# Epoch 70/100
# 54/54 [==============================] - 15s 279ms/step - loss: 0.3324 - accuracy: 0.8727 - val_loss: 0.2264 - val_accuracy: 0.9444
#
# Epoch 00070: val_loss improved from 0.25718 to 0.22644, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 71/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.3321 - accuracy: 0.8773 - val_loss: 0.4898 - val_accuracy: 0.8148
#
# Epoch 00071: val_loss did not improve from 0.22644
# Epoch 72/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.2569 - accuracy: 0.8981 - val_loss: 0.3008 - val_accuracy: 0.9259
#
# Epoch 00072: val_loss did not improve from 0.22644
# Epoch 73/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.2914 - accuracy: 0.8773 - val_loss: 0.2574 - val_accuracy: 0.9352
#
# Epoch 00073: val_loss did not improve from 0.22644
# Epoch 74/100
# 54/54 [==============================] - 11s 196ms/step - loss: 0.2874 - accuracy: 0.8819 - val_loss: 0.3047 - val_accuracy: 0.8704
#
# Epoch 00074: val_loss did not improve from 0.22644
# Epoch 75/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.3124 - accuracy: 0.8912 - val_loss: 0.2992 - val_accuracy: 0.9074
#
# Epoch 00075: val_loss did not improve from 0.22644
# Epoch 76/100
# 54/54 [==============================] - 11s 210ms/step - loss: 0.3114 - accuracy: 0.8773 - val_loss: 0.4005 - val_accuracy: 0.8426
#
# Epoch 00076: val_loss did not improve from 0.22644
# Epoch 77/100
# 54/54 [==============================] - 14s 247ms/step - loss: 0.3180 - accuracy: 0.8773 - val_loss: 0.5156 - val_accuracy: 0.7963
#
# Epoch 00077: val_loss did not improve from 0.22644
# Epoch 78/100
# 54/54 [==============================] - 14s 255ms/step - loss: 0.3128 - accuracy: 0.8681 - val_loss: 0.3044 - val_accuracy: 0.8519
#
# Epoch 00078: val_loss did not improve from 0.22644
# Epoch 79/100
# 54/54 [==============================] - 14s 254ms/step - loss: 0.2982 - accuracy: 0.8889 - val_loss: 0.2564 - val_accuracy: 0.8796
#
# Epoch 00079: val_loss did not improve from 0.22644
# Epoch 80/100
# 54/54 [==============================] - 21s 382ms/step - loss: 0.2245 - accuracy: 0.9259 - val_loss: 0.2450 - val_accuracy: 0.9167
#
# Epoch 00080: val_loss did not improve from 0.22644
# Epoch 81/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.2598 - accuracy: 0.9097 - val_loss: 0.2743 - val_accuracy: 0.8981
#
# Epoch 00081: val_loss did not improve from 0.22644
# Epoch 82/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2657 - accuracy: 0.8981 - val_loss: 0.3073 - val_accuracy: 0.8796
#
# Epoch 00082: val_loss did not improve from 0.22644
# Epoch 83/100
# 54/54 [==============================] - 12s 213ms/step - loss: 0.2612 - accuracy: 0.8935 - val_loss: 0.3632 - val_accuracy: 0.8704
#
# Epoch 00083: val_loss did not improve from 0.22644
# Epoch 84/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.2710 - accuracy: 0.9074 - val_loss: 0.3482 - val_accuracy: 0.8519
#
# Epoch 00084: val_loss did not improve from 0.22644
# Epoch 85/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.2797 - accuracy: 0.9005 - val_loss: 0.2868 - val_accuracy: 0.8889
#
# Epoch 00085: val_loss did not improve from 0.22644
# Epoch 86/100
# 54/54 [==============================] - 12s 215ms/step - loss: 0.2624 - accuracy: 0.9005 - val_loss: 0.3619 - val_accuracy: 0.8796
#
# Epoch 00086: val_loss did not improve from 0.22644
# Epoch 87/100
# 54/54 [==============================] - 11s 208ms/step - loss: 0.2903 - accuracy: 0.8866 - val_loss: 0.2789 - val_accuracy: 0.8796
#
# Epoch 00087: val_loss did not improve from 0.22644
# Epoch 88/100
# 54/54 [==============================] - 12s 226ms/step - loss: 0.2652 - accuracy: 0.9005 - val_loss: 0.2565 - val_accuracy: 0.8796
#
# Epoch 00088: val_loss did not improve from 0.22644
# Epoch 89/100
# 54/54 [==============================] - 13s 247ms/step - loss: 0.2652 - accuracy: 0.9028 - val_loss: 0.3082 - val_accuracy: 0.8519
#
# Epoch 00089: val_loss did not improve from 0.22644
# Epoch 90/100
# 54/54 [==============================] - 19s 344ms/step - loss: 0.3015 - accuracy: 0.8634 - val_loss: 0.2678 - val_accuracy: 0.9259
#
# Epoch 00090: val_loss did not improve from 0.22644
# Epoch 91/100
# 54/54 [==============================] - 22s 402ms/step - loss: 0.2635 - accuracy: 0.8958 - val_loss: 0.1989 - val_accuracy: 0.9444
#
# Epoch 00091: val_loss improved from 0.22644 to 0.19886, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 92/100
# 54/54 [==============================] - 13s 235ms/step - loss: 0.2484 - accuracy: 0.9190 - val_loss: 0.2806 - val_accuracy: 0.8981
#
# Epoch 00092: val_loss did not improve from 0.19886
# Epoch 93/100
# 54/54 [==============================] - 20s 369ms/step - loss: 0.2506 - accuracy: 0.9028 - val_loss: 0.3147 - val_accuracy: 0.8704
#
# Epoch 00093: val_loss did not improve from 0.19886
# Epoch 94/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2731 - accuracy: 0.8958 - val_loss: 0.4373 - val_accuracy: 0.8519
#
# Epoch 00094: val_loss did not improve from 0.19886
# Epoch 95/100
# 54/54 [==============================] - 16s 300ms/step - loss: 0.2297 - accuracy: 0.9144 - val_loss: 0.2881 - val_accuracy: 0.9074
#
# Epoch 00095: val_loss did not improve from 0.19886
# Epoch 96/100
# 54/54 [==============================] - 13s 230ms/step - loss: 0.2823 - accuracy: 0.8912 - val_loss: 0.2908 - val_accuracy: 0.8796
#
# Epoch 00096: val_loss did not improve from 0.19886
# Epoch 97/100
# 54/54 [==============================] - 16s 291ms/step - loss: 0.2802 - accuracy: 0.8796 - val_loss: 0.2580 - val_accuracy: 0.8981
#
# Epoch 00097: val_loss did not improve from 0.19886
# Epoch 98/100
# 54/54 [==============================] - 15s 269ms/step - loss: 0.2790 - accuracy: 0.8935 - val_loss: 0.2237 - val_accuracy: 0.8889
#
# Epoch 00098: val_loss did not improve from 0.19886
# Epoch 99/100
# 54/54 [==============================] - 14s 246ms/step - loss: 0.2412 - accuracy: 0.9097 - val_loss: 0.2502 - val_accuracy: 0.8981
#
# Epoch 00099: val_loss did not improve from 0.19886
# Epoch 100/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.2461 - accuracy: 0.9167 - val_loss: 0.3777 - val_accuracy: 0.8704
#
# Epoch 00100: val_loss did not improve from 0.19886
# 14/14 [==============================] - 2s 126ms/step - loss: 0.2507 - accuracy: 0.8981
#
# Fold number 3
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 54/54 [==============================] - 17s 241ms/step - loss: 1.0418 - accuracy: 0.4931 - val_loss: 0.9458 - val_accuracy: 0.5556
#
# Epoch 00001: val_loss improved from inf to 0.94575, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 2/100
# 54/54 [==============================] - 10s 189ms/step - loss: 0.7980 - accuracy: 0.6620 - val_loss: 0.8622 - val_accuracy: 0.6204
#
# Epoch 00002: val_loss improved from 0.94575 to 0.86221, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 3/100
# 54/54 [==============================] - 14s 259ms/step - loss: 0.7511 - accuracy: 0.6620 - val_loss: 0.7591 - val_accuracy: 0.7315
#
# Epoch 00003: val_loss improved from 0.86221 to 0.75911, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 4/100
# 54/54 [==============================] - 18s 330ms/step - loss: 0.6460 - accuracy: 0.7315 - val_loss: 0.7466 - val_accuracy: 0.6667
#
# Epoch 00004: val_loss improved from 0.75911 to 0.74664, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 5/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.7310 - accuracy: 0.6852 - val_loss: 0.6081 - val_accuracy: 0.7685
#
# Epoch 00005: val_loss improved from 0.74664 to 0.60808, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 6/100
# 54/54 [==============================] - 14s 247ms/step - loss: 0.7251 - accuracy: 0.6921 - val_loss: 0.5898 - val_accuracy: 0.7407
#
# Epoch 00006: val_loss improved from 0.60808 to 0.58980, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 7/100
# 54/54 [==============================] - 14s 256ms/step - loss: 0.6157 - accuracy: 0.7245 - val_loss: 0.5203 - val_accuracy: 0.7963
#
# Epoch 00007: val_loss improved from 0.58980 to 0.52032, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 8/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.6077 - accuracy: 0.7315 - val_loss: 0.5363 - val_accuracy: 0.7963
#
# Epoch 00008: val_loss did not improve from 0.52032
# Epoch 9/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.5855 - accuracy: 0.7662 - val_loss: 0.4545 - val_accuracy: 0.8241
#
# Epoch 00009: val_loss improved from 0.52032 to 0.45446, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 10/100
# 54/54 [==============================] - 12s 220ms/step - loss: 0.5783 - accuracy: 0.7500 - val_loss: 0.4913 - val_accuracy: 0.8148
#
# Epoch 00010: val_loss did not improve from 0.45446
# Epoch 11/100
# 54/54 [==============================] - 12s 215ms/step - loss: 0.5815 - accuracy: 0.7222 - val_loss: 0.4376 - val_accuracy: 0.8056
#
# Epoch 00011: val_loss improved from 0.45446 to 0.43760, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 12/100
# 54/54 [==============================] - 13s 242ms/step - loss: 0.6226 - accuracy: 0.7384 - val_loss: 0.4452 - val_accuracy: 0.8333
#
# Epoch 00012: val_loss did not improve from 0.43760
# Epoch 13/100
# 54/54 [==============================] - 13s 231ms/step - loss: 0.5550 - accuracy: 0.7593 - val_loss: 0.4271 - val_accuracy: 0.8148
#
# Epoch 00013: val_loss improved from 0.43760 to 0.42711, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 14/100
# 54/54 [==============================] - 9s 163ms/step - loss: 0.5451 - accuracy: 0.7731 - val_loss: 0.4297 - val_accuracy: 0.8148
#
# Epoch 00014: val_loss did not improve from 0.42711
# Epoch 15/100
# 54/54 [==============================] - 10s 175ms/step - loss: 0.5784 - accuracy: 0.7523 - val_loss: 0.3577 - val_accuracy: 0.8981
#
# Epoch 00015: val_loss improved from 0.42711 to 0.35766, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 16/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.5152 - accuracy: 0.8148 - val_loss: 0.3792 - val_accuracy: 0.8704
#
# Epoch 00016: val_loss did not improve from 0.35766
# Epoch 17/100
# 54/54 [==============================] - 12s 229ms/step - loss: 0.5538 - accuracy: 0.7639 - val_loss: 0.3896 - val_accuracy: 0.8519
#
# Epoch 00017: val_loss did not improve from 0.35766
# Epoch 18/100
# 54/54 [==============================] - 15s 272ms/step - loss: 0.5437 - accuracy: 0.7639 - val_loss: 0.4650 - val_accuracy: 0.8241
#
# Epoch 00018: val_loss did not improve from 0.35766
# Epoch 19/100
# 54/54 [==============================] - 11s 209ms/step - loss: 0.5219 - accuracy: 0.7963 - val_loss: 0.3880 - val_accuracy: 0.8704
#
# Epoch 00019: val_loss did not improve from 0.35766
# Epoch 20/100
# 54/54 [==============================] - 11s 200ms/step - loss: 0.5517 - accuracy: 0.7870 - val_loss: 0.3668 - val_accuracy: 0.8426
#
# ...
# Epoch 24/100
# 54/54 [==============================] - 10s 190ms/step - loss: 0.4199 - accuracy: 0.8333 - val_loss: 0.4171 - val_accuracy: 0.8611- loss: 0.4186 - accuracy:
#
# Epoch 00024: val_loss did not improve from 0.40344
# Epoch 25/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.4816 - accuracy: 0.8102 - val_loss: 0.4448 - val_accuracy: 0.8611
#
# Epoch 00025: val_loss did not improve from 0.40344
# Epoch 26/100
# 54/54 [==============================] - 11s 191ms/step - loss: 0.4868 - accuracy: 0.8079 - val_loss: 0.4002 - val_accuracy: 0.8333
#
# Epoch 00026: val_loss improved from 0.40344 to 0.40024, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 27/100
# 54/54 [==============================] - 11s 203ms/step - loss: 0.4567 - accuracy: 0.7986 - val_loss: 0.3846 - val_accuracy: 0.8889
#
# Epoch 00027: val_loss improved from 0.40024 to 0.38460, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 28/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.4557 - accuracy: 0.8079 - val_loss: 0.3541 - val_accuracy: 0.8889
#
# Epoch 00028: val_loss improved from 0.38460 to 0.35405, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 29/100
# 54/54 [==============================] - 9s 164ms/step - loss: 0.4301 - accuracy: 0.8495 - val_loss: 0.3617 - val_accuracy: 0.8796
#
# Epoch 00029: val_loss did not improve from 0.35405
# Epoch 30/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4506 - accuracy: 0.8218 - val_loss: 0.4022 - val_accuracy: 0.8611
#
# Epoch 00030: val_loss did not improve from 0.35405
# Epoch 31/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.4152 - accuracy: 0.8403 - val_loss: 0.3268 - val_accuracy: 0.9167
#
# Epoch 00031: val_loss improved from 0.35405 to 0.32680, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 32/100
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4291 - accuracy: 0.8380 - val_loss: 0.4548 - val_accuracy: 0.8426
#
# Epoch 00032: val_loss did not improve from 0.32680
# Epoch 33/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.4288 - accuracy: 0.8241 - val_loss: 0.4002 - val_accuracy: 0.8519
#
# Epoch 00033: val_loss did not improve from 0.32680
# Epoch 34/100
# 54/54 [==============================] - 13s 242ms/step - loss: 0.4215 - accuracy: 0.8356 - val_loss: 0.3581 - val_accuracy: 0.8611
#
# Epoch 00034: val_loss did not improve from 0.32680
# Epoch 35/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3663 - accuracy: 0.8542 - val_loss: 0.5028 - val_accuracy: 0.7963
#
# Epoch 00035: val_loss did not improve from 0.32680
# Epoch 36/100
# 54/54 [==============================] - 12s 219ms/step - loss: 0.3732 - accuracy: 0.8356 - val_loss: 0.4732 - val_accuracy: 0.8333
#
# Epoch 00036: val_loss did not improve from 0.32680
# Epoch 37/100
# 54/54 [==============================] - 11s 200ms/step - loss: 0.4380 - accuracy: 0.8287 - val_loss: 0.3422 - val_accuracy: 0.8704
#
# Epoch 00037: val_loss did not improve from 0.32680
# Epoch 38/100
# 54/54 [==============================] - 13s 230ms/step - loss: 0.4411 - accuracy: 0.8333 - val_loss: 0.3365 - val_accuracy: 0.8981
#
# Epoch 00038: val_loss did not improve from 0.32680
# Epoch 39/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4107 - accuracy: 0.8403 - val_loss: 0.3257 - val_accuracy: 0.9074
#
# Epoch 00039: val_loss improved from 0.32680 to 0.32568, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 40/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4384 - accuracy: 0.8171 - val_loss: 0.3539 - val_accuracy: 0.8704
#
# Epoch 00040: val_loss did not improve from 0.32568
# Epoch 41/100
# 54/54 [==============================] - 12s 209ms/step - loss: 0.3417 - accuracy: 0.8519 - val_loss: 0.2527 - val_accuracy: 0.9444
#
# Epoch 00041: val_loss improved from 0.32568 to 0.25265, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 42/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.3982 - accuracy: 0.8380 - val_loss: 0.3176 - val_accuracy: 0.8704
#
# Epoch 00042: val_loss did not improve from 0.25265
# Epoch 43/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3851 - accuracy: 0.8611 - val_loss: 0.4142 - val_accuracy: 0.8519
#
# Epoch 00043: val_loss did not improve from 0.25265
# Epoch 44/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.4562 - accuracy: 0.8148 - val_loss: 0.3221 - val_accuracy: 0.8796
#
# Epoch 00044: val_loss did not improve from 0.25265
# Epoch 45/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.3617 - accuracy: 0.8588 - val_loss: 0.3064 - val_accuracy: 0.9259
#
# Epoch 00045: val_loss did not improve from 0.25265
# Epoch 46/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.3934 - accuracy: 0.8542 - val_loss: 0.3422 - val_accuracy: 0.8981
#
# Epoch 00046: val_loss did not improve from 0.25265
# Epoch 47/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.3804 - accuracy: 0.8565 - val_loss: 0.3768 - val_accuracy: 0.8889
#
# Epoch 00047: val_loss did not improve from 0.25265
# Epoch 48/100
# 54/54 [==============================] - 12s 211ms/step - loss: 0.3873 - accuracy: 0.8495 - val_loss: 0.2819 - val_accuracy: 0.9074
#
# Epoch 00048: val_loss did not improve from 0.25265
# Epoch 49/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.3441 - accuracy: 0.8727 - val_loss: 0.3694 - val_accuracy: 0.8519
#
# Epoch 00049: val_loss did not improve from 0.25265
# Epoch 50/100
# 54/54 [==============================] - 12s 220ms/step - loss: 0.3544 - accuracy: 0.8495 - val_loss: 0.3378 - val_accuracy: 0.8704
#
# Epoch 00050: val_loss did not improve from 0.25265
# Epoch 51/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3650 - accuracy: 0.8611 - val_loss: 0.2899 - val_accuracy: 0.9074
#
# Epoch 00051: val_loss did not improve from 0.25265
# Epoch 52/100
# 54/54 [==============================] - 10s 190ms/step - loss: 0.3508 - accuracy: 0.8657 - val_loss: 0.3446 - val_accuracy: 0.8981
#
# Epoch 00052: val_loss did not improve from 0.25265
# Epoch 53/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.3963 - accuracy: 0.8495 - val_loss: 0.3178 - val_accuracy: 0.8981
#
# Epoch 00053: val_loss did not improve from 0.25265
# Epoch 54/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.3142 - accuracy: 0.8796 - val_loss: 0.2641 - val_accuracy: 0.9259
#
# Epoch 00054: val_loss did not improve from 0.25265
# Epoch 55/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3568 - accuracy: 0.8704 - val_loss: 0.2763 - val_accuracy: 0.9259
#
# Epoch 00055: val_loss did not improve from 0.25265
# Epoch 56/100
# 54/54 [==============================] - 11s 209ms/step - loss: 0.3164 - accuracy: 0.8773 - val_loss: 0.2390 - val_accuracy: 0.9259
#
# Epoch 00056: val_loss improved from 0.25265 to 0.23903, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 57/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3215 - accuracy: 0.8796 - val_loss: 0.2826 - val_accuracy: 0.9444
#
# Epoch 00057: val_loss did not improve from 0.23903
# Epoch 58/100
# 54/54 [==============================] - 13s 239ms/step - loss: 0.3447 - accuracy: 0.8611 - val_loss: 0.3154 - val_accuracy: 0.8889
#
# Epoch 00058: val_loss did not improve from 0.23903
# Epoch 59/100
# 54/54 [==============================] - 11s 191ms/step - loss: 0.3436 - accuracy: 0.8588 - val_loss: 0.3430 - val_accuracy: 0.8796
#
# Epoch 00059: val_loss did not improve from 0.23903
# Epoch 60/100
# 54/54 [==============================] - 9s 167ms/step - loss: 0.3412 - accuracy: 0.8611 - val_loss: 0.2836 - val_accuracy: 0.9352
#
# Epoch 00060: val_loss did not improve from 0.23903
# Epoch 61/100
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3108 - accuracy: 0.8796 - val_loss: 0.2471 - val_accuracy: 0.9444
#
# Epoch 00061: val_loss did not improve from 0.23903
# Epoch 62/100
# 54/54 [==============================] - 12s 214ms/step - loss: 0.2878 - accuracy: 0.8958 - val_loss: 0.3256 - val_accuracy: 0.8519
#
# Epoch 00062: val_loss did not improve from 0.23903
# Epoch 63/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.3300 - accuracy: 0.8588 - val_loss: 0.2921 - val_accuracy: 0.8889
#
# Epoch 00063: val_loss did not improve from 0.23903
# Epoch 64/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.3498 - accuracy: 0.8495 - val_loss: 0.2890 - val_accuracy: 0.9074
#
# Epoch 00064: val_loss did not improve from 0.23903
# Epoch 65/100
# 54/54 [==============================] - 11s 189ms/step - loss: 0.3301 - accuracy: 0.8681 - val_loss: 0.3001 - val_accuracy: 0.8704
#
# Epoch 00065: val_loss did not improve from 0.23903
# Epoch 66/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3158 - accuracy: 0.8773 - val_loss: 0.2365 - val_accuracy: 0.9167
#
# Epoch 00066: val_loss improved from 0.23903 to 0.23650, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 67/100
# 54/54 [==============================] - 13s 234ms/step - loss: 0.2814 - accuracy: 0.9005 - val_loss: 0.2640 - val_accuracy: 0.9074
#
# Epoch 00067: val_loss did not improve from 0.23650
# Epoch 68/100
# 54/54 [==============================] - 11s 210ms/step - loss: 0.2890 - accuracy: 0.9028 - val_loss: 0.2640 - val_accuracy: 0.9074
#
# Epoch 00068: val_loss did not improve from 0.23650
# Epoch 69/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.2905 - accuracy: 0.8912 - val_loss: 0.2745 - val_accuracy: 0.8796
#
# Epoch 00069: val_loss did not improve from 0.23650
# Epoch 70/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3109 - accuracy: 0.8773 - val_loss: 0.1778 - val_accuracy: 0.9630
#
# Epoch 00070: val_loss improved from 0.23650 to 0.17782, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 71/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.2776 - accuracy: 0.8866 - val_loss: 0.2160 - val_accuracy: 0.9352
#
# Epoch 00071: val_loss did not improve from 0.17782
# Epoch 72/100
# 54/54 [==============================] - 11s 190ms/step - loss: 0.3100 - accuracy: 0.8796 - val_loss: 0.5514 - val_accuracy: 0.8056
#
# Epoch 00072: val_loss did not improve from 0.17782
# Epoch 73/100
# 54/54 [==============================] - 15s 266ms/step - loss: 0.3747 - accuracy: 0.8519 - val_loss: 0.3089 - val_accuracy: 0.9259
#
# Epoch 00073: val_loss did not improve from 0.17782
# Epoch 74/100
# 54/54 [==============================] - 14s 263ms/step - loss: 0.3254 - accuracy: 0.8866 - val_loss: 0.2856 - val_accuracy: 0.9259
#
# Epoch 00074: val_loss did not improve from 0.17782
# Epoch 75/100
# 54/54 [==============================] - 12s 221ms/step - loss: 0.2994 - accuracy: 0.8866 - val_loss: 0.3088 - val_accuracy: 0.9074
#
# Epoch 00075: val_loss did not improve from 0.17782
# Epoch 76/100
# 54/54 [==============================] - 11s 192ms/step - loss: 0.3253 - accuracy: 0.8704 - val_loss: 0.2472 - val_accuracy: 0.9074
#
# Epoch 00076: val_loss did not improve from 0.17782
# Epoch 77/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.2957 - accuracy: 0.8866 - val_loss: 0.1913 - val_accuracy: 0.9722
#
# Epoch 00077: val_loss did not improve from 0.17782
# Epoch 78/100
# 54/54 [==============================] - 12s 213ms/step - loss: 0.2724 - accuracy: 0.9051 - val_loss: 0.2511 - val_accuracy: 0.9074
#
# Epoch 00078: val_loss did not improve from 0.17782
# Epoch 79/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.2741 - accuracy: 0.8912 - val_loss: 0.3032 - val_accuracy: 0.8981
#
# Epoch 00079: val_loss did not improve from 0.17782
# Epoch 80/100
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3053 - accuracy: 0.8935 - val_loss: 0.2346 - val_accuracy: 0.9259
#
# Epoch 00080: val_loss did not improve from 0.17782
# Epoch 81/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3155 - accuracy: 0.8819 - val_loss: 0.2495 - val_accuracy: 0.9537
#
# Epoch 00081: val_loss did not improve from 0.17782
# Epoch 82/100
# 54/54 [==============================] - 12s 220ms/step - loss: 0.2855 - accuracy: 0.9005 - val_loss: 0.2872 - val_accuracy: 0.9444
#
# Epoch 00082: val_loss did not improve from 0.17782
# Epoch 83/100
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3175 - accuracy: 0.8727 - val_loss: 0.3100 - val_accuracy: 0.8889
#
# Epoch 00083: val_loss did not improve from 0.17782
# Epoch 84/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.3015 - accuracy: 0.8796 - val_loss: 0.3008 - val_accuracy: 0.8796
#
# Epoch 00084: val_loss did not improve from 0.17782
# Epoch 85/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.2595 - accuracy: 0.8912 - val_loss: 0.3390 - val_accuracy: 0.8889
#
# Epoch 00085: val_loss did not improve from 0.17782
# Epoch 86/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.2903 - accuracy: 0.8912 - val_loss: 0.2453 - val_accuracy: 0.9167
#
# Epoch 00086: val_loss did not improve from 0.17782
# Epoch 87/100
# 54/54 [==============================] - 10s 190ms/step - loss: 0.3113 - accuracy: 0.8750 - val_loss: 0.2474 - val_accuracy: 0.9444
#
# Epoch 00087: val_loss did not improve from 0.17782
# Epoch 88/100
# 54/54 [==============================] - 10s 190ms/step - loss: 0.2861 - accuracy: 0.8866 - val_loss: 0.3199 - val_accuracy: 0.8704
#
# Epoch 00088: val_loss did not improve from 0.17782
# Epoch 89/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.2614 - accuracy: 0.9005 - val_loss: 0.2477 - val_accuracy: 0.9444
#
# Epoch 00089: val_loss did not improve from 0.17782
# Epoch 90/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.2893 - accuracy: 0.8796 - val_loss: 0.3013 - val_accuracy: 0.9074
#
# Epoch 00090: val_loss did not improve from 0.17782
# Epoch 91/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.2655 - accuracy: 0.8889 - val_loss: 0.2039 - val_accuracy: 0.9537
#
# Epoch 00091: val_loss did not improve from 0.17782
# Epoch 92/100
# 54/54 [==============================] - 12s 222ms/step - loss: 0.2478 - accuracy: 0.9051 - val_loss: 0.2692 - val_accuracy: 0.9167
#
# Epoch 00092: val_loss did not improve from 0.17782
# Epoch 93/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.2494 - accuracy: 0.9097 - val_loss: 0.3155 - val_accuracy: 0.8704
#
# Epoch 00093: val_loss did not improve from 0.17782
# Epoch 94/100
# 54/54 [==============================] - 12s 224ms/step - loss: 0.2278 - accuracy: 0.9144 - val_loss: 0.2807 - val_accuracy: 0.9167
#
# Epoch 00094: val_loss did not improve from 0.17782
# Epoch 95/100
# 54/54 [==============================] - 12s 211ms/step - loss: 0.2967 - accuracy: 0.8796 - val_loss: 0.2473 - val_accuracy: 0.8796
#
# Epoch 00095: val_loss did not improve from 0.17782
# Epoch 96/100
# 54/54 [==============================] - 17s 298ms/step - loss: 0.3037 - accuracy: 0.8819 - val_loss: 0.2420 - val_accuracy: 0.9444
#
# Epoch 00096: val_loss did not improve from 0.17782
# Epoch 97/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.2263 - accuracy: 0.9074 - val_loss: 0.3045 - val_accuracy: 0.8981
#
# Epoch 00097: val_loss did not improve from 0.17782
# Epoch 98/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.3200 - accuracy: 0.8819 - val_loss: 0.3179 - val_accuracy: 0.8889
#
# Epoch 00098: val_loss did not improve from 0.17782
# Epoch 99/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.3109 - accuracy: 0.8843 - val_loss: 0.2530 - val_accuracy: 0.9259
#
# Epoch 00099: val_loss did not improve from 0.17782
# Epoch 100/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3044 - accuracy: 0.8819 - val_loss: 0.2986 - val_accuracy: 0.8889
#
# Epoch 00100: val_loss did not improve from 0.17782
# 14/14 [==============================] - 2s 128ms/step - loss: 0.2626 - accuracy: 0.9259

# %%
#stopper

# %% [markdown]
# ### Display Values Per Combination of Hyperparameters

# %% [markdown]
# We will put the combination of hyperparameters and the resulting means of accuracy and loss together in a dataframe in order to display it nicely.

# %%
#append means of accuracy and loss per combo
for x in range(len(val_acc_arr)):
    val_acc_means.append(np.mean(val_acc_arr[x]))                                
    val_loss_means.append(np.mean(val_loss_arr[x]))
    
    train_acc_means.append(np.mean(train_acc_arr[x]))                              
    train_loss_means.append(np.mean(train_loss_arr[x]))                             
    
df_hyperparam = pd.DataFrame(list(zip(param_arr[0],param_arr[1],param_arr[2],
                                      train_acc_means, train_loss_means,
                                      val_acc_means,val_loss_means))
                             ,columns=['batch size','number of epoch', 'learning rate', 
                                       'train accuracy', 'train loss',
                                       'val accuracy', 'val loss'])

df_hyperparam = df_hyperparam.sort_values(ascending=True,by = 'val loss')

#df_hyperparam.to_excel("hyperparam_result.xlsx")

df_hyperparam
# Out:
#    batch size  number of epoch  learning rate  train accuracy  train loss  \
# 0           8              100         0.0001        0.841894    0.400142
#
#    val accuracy  val loss
# 0      0.922222  0.246519

# %%
#stopper

# %% [markdown]
# ### Each fold results of best combination

# %% [markdown]
# Below are the validation accuracy and validation loss per fold and their average of the best combination.

# %%
#get the index of the best combination
comb_no = df_hyperparam.loc[[df_hyperparam['val loss'].idxmin()]].index.tolist()[0]
fold_num = [*range(1,6)]

fold_eval = pd.DataFrame(list(zip(fold_num,train_acc_arr[comb_no],train_loss_arr[comb_no],
                                  val_acc_arr[comb_no],val_loss_arr[comb_no]))
                         ,columns=['fold','Training Accuracy','Training Loss',
                                   'Validation Accuracy','Validation Loss'])

fold_eval.set_index('fold', inplace=True)
fold_eval.loc['mean'] = fold_eval.mean()

#fold_eval.to_excel('fold_eval.xlsx')
fold_eval
# Out:
#       Training Accuracy  Training Loss  Validation Accuracy  Validation Loss
# fold
# 1              0.851759       0.382625             0.925926         0.279817
# 2              0.837616       0.407732             0.898148         0.250739
# 3              0.839213       0.405772             0.944444         0.223656
# 4              0.844120       0.396424             0.916667         0.215808
# 5              0.836759       0.408154             0.925926         0.262575
# mean           0.841894       0.400142             0.922222         0.246519

# %%
#stopper

# %% [markdown]
# ## Final Model

# %% [markdown]
# We will use the best combination of hypaparameters to train our final model. We will evaluate the model using the train set.

# %% [markdown]
# ### Get best combination of hyperparameters

# %%
df_bestohypaparamu = df_hyperparam.loc[[df_hyperparam['val loss'].idxmin()]]

bestohypaparamu = [df_bestohypaparamu['batch size'].values[0],
                   df_bestohypaparamu['number of epoch'].values[0],
                   df_bestohypaparamu['learning rate'].values[0]]

# %% [markdown]
# ### Split Train Set to Train Set and Validation Set

# %% [markdown]
# The same as to what was done in the hyperparameter tuning, we will split the train set to train and validation set with the same random state of 69 in order to have a similar resulting accuracy and loss.

# %%
# Split train set to train set and valid set
X = df2[['filename']]
y = df2[['label']]
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=69)

# %% [markdown]
# We will save the images from the new train set and validation set to separate folders.

# %%
#folder to store the train and test set folders
fortraintest2 = directory + "/ToBeUsedFinalModel"
if not os.path.exists(fortraintest2):
    os.makedirs(fortraintest2)

#train set folder
tr2 = fortraintest2 + "/train_set"
if not os.path.exists(tr2):
    os.makedirs(tr2)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr2)
    os.makedirs(tr2)
    
#test set folder
va = fortraintest2 + "/val_set"
if not os.path.exists(va):
    os.makedirs(va)
else:
    #remove previous folder and create new one
    shutil.rmtree(va)
    os.makedirs(va)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    try:
        trcpy = shutil.copy2(row['filename'], tr2)
    except shutil.SameFileError:
        pass
    
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_val.iterrows():
    try:
        vacpy = shutil.copy2(row['filename'], va)
    except shutil.SameFileError:
        pass
    
    X_val.loc[X_val['filename']==row['filename'],'filename']=vacpy #change to directory where image is copied

# %% [markdown]
# ### Train Set Final Model

# %%
df4 = pd.concat([X_train,y_train],axis=1)
df4
# Out:
#                                               filename label
# 547  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
# 382  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 218  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 549  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
# 468  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
# ..                                                 ...   ...
# 322  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 269  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 127  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     0
# 442  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
# 470  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
#
# [432 rows x 2 columns]

# %%
counto = [0,0,0]

counto_count = 0

df4_lbl = sorted(df4['label'].unique(), reverse=False) 

for x in df4_lbl:
    for y in df4['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1
    
print(counto)
# Out:
# [144, 144, 144]

# %% [markdown]
# ### Validation Set Final Model

# %%
df5 = pd.concat([X_val,y_val],axis=1)
df5
# Out:
#                                               filename label
# 420  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
# 27   C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     0
# 240  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 306  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 354  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# ..                                                 ...   ...
# 34   C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     0
# 199  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     0
# 336  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     1
# 67   C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     0
# 416  C:/Users/user/Desktop/Dataset/ToBeUsedFinalMod...     2
#
# [108 rows x 2 columns]

# %%
counto = [0,0,0]

counto_count = 0

df5_lbl = sorted(df5['label'].unique(), reverse=False) 

for x in df5_lbl:
    for y in df5['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1
    
print(counto)
# Out:
# [36, 36, 36]

# %% [markdown]
# ### Train the Final Model

# %% [markdown]
# We will now train the final model.

# %%
VAL_ACCURACY = None
VAL_LOSS = None

train_dir = tr2
valid_dir = va
save_dir = gen_dir + "/saved_finalmodel_1"

if os.path.exists(save_dir):
    shutil.rmtree(save_dir)
    
os.makedirs(save_dir)

trainu = df4
validu = df5

train_data_generator = imgdatagen.flow_from_dataframe(trainu, directory = train_dir,
                                       x_col = "filename", y_col = "label",
                                       class_mode = "categorical", target_size = (224,224), batch_size = bestohypaparamu[0],
                                            shuffle = True)
valid_data_generator  = imgdatagen.flow_from_dataframe(validu, directory = valid_dir,
                        x_col = "filename", y_col = "label",
                        class_mode = "categorical", target_size = (224,224), batch_size = bestohypaparamu[0],
                            shuffle = True)

#print(len(train_data_generator))

full_model = create_model()
# Compile the model
full_model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adamax(learning_rate=bestohypaparamu[2]),
              metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

# Create callbacks
checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "finalmodel_1.h5"), 
                        monitor='val_loss', verbose=1, 
                        save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# This saves the best model


# Fit the model
history = full_model.fit(train_data_generator,
                         epochs=bestohypaparamu[1],
                         callbacks=callbacks_list,
                         validation_data=valid_data_generator,
                         verbose=1)

# Plot the history
plot_history(history, yrange=(0.2,1))

# Load the best model instance to evaluate the performance of the model
full_model.load_weights(save_dir+"/"+ "finalmodel_1.h5")

results = full_model.evaluate(valid_data_generator)

#print(results)

results = dict(zip(full_model.metrics_names,results))

# Store Validation accuracy/loss
VAL_ACCURACY = results['accuracy']
VAL_LOSS = results['loss']

tf.keras.backend.clear_session()
# Out:
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 54/54 [==============================] - 15s 222ms/step - loss: 1.0972 - accuracy: 0.5023 - val_loss: 1.0037 - val_accuracy: 0.4907
#
# Epoch 00001: val_loss improved from inf to 1.00373, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 2/100
# 54/54 [==============================] - 9s 167ms/step - loss: 0.9293 - accuracy: 0.5741 - val_loss: 0.8907 - val_accuracy: 0.6481
#
# Epoch 00002: val_loss improved from 1.00373 to 0.89071, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 3/100
# 54/54 [==============================] - 10s 186ms/step - loss: 0.7774 - accuracy: 0.6852 - val_loss: 0.8387 - val_accuracy: 0.6574
#
# Epoch 00003: val_loss improved from 0.89071 to 0.83865, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 4/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.7204 - accuracy: 0.7014 - val_loss: 0.8184 - val_accuracy: 0.6296
#
# Epoch 00004: val_loss improved from 0.83865 to 0.81839, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 5/100
# 54/54 [==============================] - 9s 164ms/step - loss: 0.7165 - accuracy: 0.7060 - val_loss: 0.7478 - val_accuracy: 0.6944
#
# Epoch 00005: val_loss improved from 0.81839 to 0.74780, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 6/100
# 54/54 [==============================] - 10s 185ms/step - loss: 0.6356 - accuracy: 0.7199 - val_loss: 0.6919 - val_accuracy: 0.7222
#
# Epoch 00006: val_loss improved from 0.74780 to 0.69192, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 7/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.6316 - accuracy: 0.7500 - val_loss: 0.6615 - val_accuracy: 0.7407
#
# Epoch 00007: val_loss improved from 0.69192 to 0.66153, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 8/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.6102 - accuracy: 0.7431 - val_loss: 0.6896 - val_accuracy: 0.7593
#
# Epoch 00008: val_loss did not improve from 0.66153
# Epoch 9/100
# 54/54 [==============================] - 9s 167ms/step - loss: 0.5955 - accuracy: 0.7569 - val_loss: 0.6391 - val_accuracy: 0.7315
#
# Epoch 00009: val_loss improved from 0.66153 to 0.63908, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 10/100
# 54/54 [==============================] - 9s 170ms/step - loss: 0.6083 - accuracy: 0.7384 - val_loss: 0.7000 - val_accuracy: 0.7037
#
# Epoch 00010: val_loss did not improve from 0.63908
# Epoch 11/100
# 54/54 [==============================] - 10s 185ms/step - loss: 0.5788 - accuracy: 0.7569 - val_loss: 0.6010 - val_accuracy: 0.7593
#
# Epoch 00011: val_loss improved from 0.63908 to 0.60102, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 12/100
# 54/54 [==============================] - 11s 192ms/step - loss: 0.6004 - accuracy: 0.7407 - val_loss: 0.5891 - val_accuracy: 0.7870
#
# Epoch 00012: val_loss improved from 0.60102 to 0.58906, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 13/100
# 54/54 [==============================] - 12s 210ms/step - loss: 0.5140 - accuracy: 0.7870 - val_loss: 0.6249 - val_accuracy: 0.7407
#
# Epoch 00013: val_loss did not improve from 0.58906
# Epoch 14/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.5457 - accuracy: 0.8079 - val_loss: 0.5378 - val_accuracy: 0.8056
#
# Epoch 00014: val_loss improved from 0.58906 to 0.53780, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 15/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4991 - accuracy: 0.7894 - val_loss: 0.5639 - val_accuracy: 0.7963
#
# Epoch 00015: val_loss did not improve from 0.53780
# Epoch 16/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.5385 - accuracy: 0.7847 - val_loss: 0.5422 - val_accuracy: 0.7685
#
# Epoch 00016: val_loss did not improve from 0.53780
# Epoch 17/100
# 54/54 [==============================] - 9s 159ms/step - loss: 0.5146 - accuracy: 0.7847 - val_loss: 0.5735 - val_accuracy: 0.7778
#
# Epoch 00017: val_loss did not improve from 0.53780
# Epoch 18/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.5464 - accuracy: 0.7824 - val_loss: 0.5438 - val_accuracy: 0.7963
#
# Epoch 00018: val_loss did not improve from 0.53780
# Epoch 19/100
# 54/54 [==============================] - 14s 248ms/step - loss: 0.5076 - accuracy: 0.7940 - val_loss: 0.6178 - val_accuracy: 0.7685
#
# Epoch 00019: val_loss did not improve from 0.53780
# Epoch 20/100
# 54/54 [==============================] - 9s 172ms/step - loss: 0.4575 - accuracy: 0.8148 - val_loss: 0.5607 - val_accuracy: 0.7685
#
# Epoch 00020: val_loss did not improve from 0.53780
# Epoch 21/100
# 54/54 [==============================] - 11s 203ms/step - loss: 0.5334 - accuracy: 0.8032 - val_loss: 0.6129 - val_accuracy: 0.7500
#
# Epoch 00021: val_loss did not improve from 0.53780
# Epoch 22/100
# 54/54 [==============================] - 13s 245ms/step - loss: 0.4292 - accuracy: 0.8218 - val_loss: 0.4970 - val_accuracy: 0.7870
#
# Epoch 00022: val_loss improved from 0.53780 to 0.49697, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 23/100
# 54/54 [==============================] - 15s 278ms/step - loss: 0.4717 - accuracy: 0.8009 - val_loss: 0.4859 - val_accuracy: 0.7963
#
# Epoch 00023: val_loss improved from 0.49697 to 0.48587, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 24/100
# 54/54 [==============================] - 12s 223ms/step - loss: 0.4950 - accuracy: 0.8125 - val_loss: 0.5274 - val_accuracy: 0.7870
#
# Epoch 00024: val_loss did not improve from 0.48587
# Epoch 25/100
# 54/54 [==============================] - 11s 208ms/step - loss: 0.4909 - accuracy: 0.7940 - val_loss: 0.4931 - val_accuracy: 0.7778
#
# Epoch 00025: val_loss did not improve from 0.48587
# Epoch 26/100
# 54/54 [==============================] - 13s 237ms/step - loss: 0.4440 - accuracy: 0.8218 - val_loss: 0.4227 - val_accuracy: 0.8148
#
# Epoch 00026: val_loss improved from 0.48587 to 0.42271, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 27/100
# 54/54 [==============================] - 12s 217ms/step - loss: 0.4459 - accuracy: 0.8102 - val_loss: 0.4483 - val_accuracy: 0.8148
#
# Epoch 00027: val_loss did not improve from 0.42271
# Epoch 28/100
# 54/54 [==============================] - 9s 161ms/step - loss: 0.4288 - accuracy: 0.8472 - val_loss: 0.5218 - val_accuracy: 0.7963
#
# Epoch 00028: val_loss did not improve from 0.42271
# Epoch 29/100
# 54/54 [==============================] - 13s 242ms/step - loss: 0.4361 - accuracy: 0.8519 - val_loss: 0.4928 - val_accuracy: 0.8148
#
# Epoch 00029: val_loss did not improve from 0.42271
# Epoch 30/100
# 54/54 [==============================] - 13s 237ms/step - loss: 0.4327 - accuracy: 0.8264 - val_loss: 0.4827 - val_accuracy: 0.7870
#
# Epoch 00030: val_loss did not improve from 0.42271
# Epoch 31/100
# 54/54 [==============================] - 15s 276ms/step - loss: 0.4595 - accuracy: 0.8287 - val_loss: 0.3658 - val_accuracy: 0.8889
#
# Epoch 00031: val_loss improved from 0.42271 to 0.36579, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 32/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.4436 - accuracy: 0.8102 - val_loss: 0.4837 - val_accuracy: 0.8519
#
# Epoch 00032: val_loss did not improve from 0.36579
# Epoch 33/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.4089 - accuracy: 0.8472 - val_loss: 0.4829 - val_accuracy: 0.7870
#
# Epoch 00033: val_loss did not improve from 0.36579
# Epoch 34/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4018 - accuracy: 0.8264 - val_loss: 0.4224 - val_accuracy: 0.8519
#
# Epoch 00034: val_loss did not improve from 0.36579
# Epoch 35/100
# 54/54 [==============================] - 10s 192ms/step - loss: 0.4548 - accuracy: 0.8125 - val_loss: 0.3393 - val_accuracy: 0.8426
# Epoch 00035: val_loss improved from 0.36579 to 0.33933, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 36/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.3819 - accuracy: 0.8472 - val_loss: 0.4951 - val_accuracy: 0.8241
#
# Epoch 00036: val_loss did not improve from 0.33933
# Epoch 37/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.4105 - accuracy: 0.8287 - val_loss: 0.7036 - val_accuracy: 0.7222
#
# Epoch 00037: val_loss did not improve from 0.33933
# Epoch 38/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.4083 - accuracy: 0.8403 - val_loss: 0.5883 - val_accuracy: 0.7963
#
# Epoch 00038: val_loss did not improve from 0.33933
# Epoch 39/100
# 54/54 [==============================] - 9s 162ms/step - loss: 0.4353 - accuracy: 0.8264 - val_loss: 0.3619 - val_accuracy: 0.8519
#
# Epoch 00039: val_loss did not improve from 0.33933
# Epoch 40/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3684 - accuracy: 0.8704 - val_loss: 0.3723 - val_accuracy: 0.8519
#
# Epoch 00040: val_loss did not improve from 0.33933
# Epoch 41/100
# 54/54 [==============================] - 11s 212ms/step - loss: 0.3708 - accuracy: 0.8403 - val_loss: 0.4176 - val_accuracy: 0.8426
#
# Epoch 00041: val_loss did not improve from 0.33933
# Epoch 42/100
# 54/54 [==============================] - 12s 215ms/step - loss: 0.3509 - accuracy: 0.8889 - val_loss: 0.4437 - val_accuracy: 0.8333
#
# Epoch 00042: val_loss did not improve from 0.33933
# Epoch 43/100
# 54/54 [==============================] - 11s 202ms/step - loss: 0.3815 - accuracy: 0.8565 - val_loss: 0.3683 - val_accuracy: 0.8611
#
# Epoch 00043: val_loss did not improve from 0.33933
# Epoch 44/100
# 54/54 [==============================] - 11s 204ms/step - loss: 0.3170 - accuracy: 0.8889 - val_loss: 0.4713 - val_accuracy: 0.8426
#
# Epoch 00044: val_loss did not improve from 0.33933
# Epoch 45/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.3473 - accuracy: 0.8681 - val_loss: 0.4032 - val_accuracy: 0.8333
#
# Epoch 00045: val_loss did not improve from 0.33933
# Epoch 46/100
# 54/54 [==============================] - 12s 212ms/step - loss: 0.2925 - accuracy: 0.9005 - val_loss: 0.4497 - val_accuracy: 0.8611
#
# Epoch 00046: val_loss did not improve from 0.33933
# Epoch 47/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.3425 - accuracy: 0.8889 - val_loss: 0.4771 - val_accuracy: 0.8426
#
# Epoch 00047: val_loss did not improve from 0.33933
# Epoch 48/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.3097 - accuracy: 0.8819 - val_loss: 0.3597 - val_accuracy: 0.8889
#
# Epoch 00048: val_loss did not improve from 0.33933
# Epoch 49/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.3731 - accuracy: 0.8449 - val_loss: 0.4637 - val_accuracy: 0.7963
#
# Epoch 00049: val_loss did not improve from 0.33933
# Epoch 50/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3662 - accuracy: 0.8657 - val_loss: 0.4707 - val_accuracy: 0.7963
#
# Epoch 00050: val_loss did not improve from 0.33933
# Epoch 51/100
# 54/54 [==============================] - 9s 168ms/step - loss: 0.3189 - accuracy: 0.8773 - val_loss: 0.5002 - val_accuracy: 0.8426
#
# Epoch 00051: val_loss did not improve from 0.33933
# Epoch 52/100
# 54/54 [==============================] - 12s 209ms/step - loss: 0.3776 - accuracy: 0.8426 - val_loss: 0.4069 - val_accuracy: 0.8704
#
# Epoch 00052: val_loss did not improve from 0.33933
# Epoch 53/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.3382 - accuracy: 0.8657 - val_loss: 0.5171 - val_accuracy: 0.8333
#
# Epoch 00053: val_loss did not improve from 0.33933
# Epoch 54/100
# 54/54 [==============================] - 11s 210ms/step - loss: 0.3352 - accuracy: 0.8495 - val_loss: 0.3408 - val_accuracy: 0.8519
#
# Epoch 00054: val_loss did not improve from 0.33933
# Epoch 55/100
# 54/54 [==============================] - 12s 213ms/step - loss: 0.3382 - accuracy: 0.8727 - val_loss: 0.3685 - val_accuracy: 0.8796
#
# Epoch 00055: val_loss did not improve from 0.33933
# Epoch 56/100
# 54/54 [==============================] - 11s 209ms/step - loss: 0.3469 - accuracy: 0.8773 - val_loss: 0.3580 - val_accuracy: 0.8796
#
# Epoch 00056: val_loss did not improve from 0.33933
# Epoch 57/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.2816 - accuracy: 0.8958 - val_loss: 0.3423 - val_accuracy: 0.8611
#
# Epoch 00057: val_loss did not improve from 0.33933
# Epoch 58/100
# 54/54 [==============================] - 12s 215ms/step - loss: 0.3390 - accuracy: 0.8681 - val_loss: 0.3457 - val_accuracy: 0.8704
#
# Epoch 00058: val_loss did not improve from 0.33933
# Epoch 59/100
# 54/54 [==============================] - 10s 174ms/step - loss: 0.3414 - accuracy: 0.8565 - val_loss: 0.3051 - val_accuracy: 0.9074
#
# Epoch 00059: val_loss improved from 0.33933 to 0.30508, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 60/100
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3646 - accuracy: 0.8519 - val_loss: 0.3467 - val_accuracy: 0.8704
#
# Epoch 00060: val_loss did not improve from 0.30508
# Epoch 61/100
# 54/54 [==============================] - 11s 194ms/step - loss: 0.3640 - accuracy: 0.8542 - val_loss: 0.3390 - val_accuracy: 0.9167
#
# Epoch 00061: val_loss did not improve from 0.30508
# Epoch 62/100
# 54/54 [==============================] - 10s 175ms/step - loss: 0.3598 - accuracy: 0.8495 - val_loss: 0.3763 - val_accuracy: 0.8796
#
# Epoch 00062: val_loss did not improve from 0.30508
# Epoch 63/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.3350 - accuracy: 0.8519 - val_loss: 0.3329 - val_accuracy: 0.8889
#
# Epoch 00063: val_loss did not improve from 0.30508
# Epoch 64/100
# 54/54 [==============================] - 13s 233ms/step - loss: 0.3231 - accuracy: 0.8866 - val_loss: 0.4480 - val_accuracy: 0.8704
#
# Epoch 00064: val_loss did not improve from 0.30508
# Epoch 65/100
# 54/54 [==============================] - 16s 284ms/step - loss: 0.3131 - accuracy: 0.8704 - val_loss: 0.3353 - val_accuracy: 0.8704
#
# Epoch 00065: val_loss did not improve from 0.30508
# Epoch 66/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.3458 - accuracy: 0.8611 - val_loss: 0.4181 - val_accuracy: 0.8426
#
# Epoch 00066: val_loss did not improve from 0.30508
# Epoch 67/100
# 54/54 [==============================] - 11s 195ms/step - loss: 0.3003 - accuracy: 0.8843 - val_loss: 0.4293 - val_accuracy: 0.8056
#
# Epoch 00067: val_loss did not improve from 0.30508
# Epoch 68/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2818 - accuracy: 0.8912 - val_loss: 0.4355 - val_accuracy: 0.8611
#
# Epoch 00068: val_loss did not improve from 0.30508
# Epoch 69/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.2908 - accuracy: 0.8866 - val_loss: 0.4305 - val_accuracy: 0.8796
#
# Epoch 00069: val_loss did not improve from 0.30508
# Epoch 70/100
# 54/54 [==============================] - 9s 158ms/step - loss: 0.2829 - accuracy: 0.8866 - val_loss: 0.3091 - val_accuracy: 0.8981
#
# Epoch 00070: val_loss did not improve from 0.30508
# Epoch 71/100
# 54/54 [==============================] - 10s 187ms/step - loss: 0.2853 - accuracy: 0.8935 - val_loss: 0.3144 - val_accuracy: 0.8796
#
# Epoch 00071: val_loss did not improve from 0.30508
# Epoch 72/100
# 54/54 [==============================] - 9s 157ms/step - loss: 0.3208 - accuracy: 0.8704 - val_loss: 0.3679 - val_accuracy: 0.8796
#
# Epoch 00072: val_loss did not improve from 0.30508
# Epoch 73/100
# 54/54 [==============================] - 9s 166ms/step - loss: 0.2560 - accuracy: 0.9144 - val_loss: 0.3655 - val_accuracy: 0.8519
#
# Epoch 00073: val_loss did not improve from 0.30508
# Epoch 74/100
# 54/54 [==============================] - 9s 169ms/step - loss: 0.3025 - accuracy: 0.8843 - val_loss: 0.3530 - val_accuracy: 0.9074
#
# Epoch 00074: val_loss did not improve from 0.30508
# Epoch 75/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3215 - accuracy: 0.8773 - val_loss: 0.3688 - val_accuracy: 0.8426
#
# Epoch 00075: val_loss did not improve from 0.30508
# Epoch 76/100
# 54/54 [==============================] - 10s 191ms/step - loss: 0.2753 - accuracy: 0.8866 - val_loss: 0.3229 - val_accuracy: 0.9167
# Epoch 00076: val_loss did not improve from 0.30508
# Epoch 77/100
# 54/54 [==============================] - 15s 280ms/step - loss: 0.3284 - accuracy: 0.8704 - val_loss: 0.3359 - val_accuracy: 0.8889
#
# Epoch 00077: val_loss did not improve from 0.30508
# Epoch 78/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.2838 - accuracy: 0.8773 - val_loss: 0.3376 - val_accuracy: 0.8889
#
# Epoch 00078: val_loss did not improve from 0.30508
# Epoch 79/100
# 54/54 [==============================] - 12s 215ms/step - loss: 0.2723 - accuracy: 0.8889 - val_loss: 0.4654 - val_accuracy: 0.8426
#
# Epoch 00079: val_loss did not improve from 0.30508
# Epoch 80/100
# 54/54 [==============================] - 12s 225ms/step - loss: 0.2841 - accuracy: 0.8843 - val_loss: 0.3652 - val_accuracy: 0.8796
#
# Epoch 00080: val_loss did not improve from 0.30508
# Epoch 81/100
# 54/54 [==============================] - 12s 218ms/step - loss: 0.3490 - accuracy: 0.8565 - val_loss: 0.3959 - val_accuracy: 0.8611
#
# Epoch 00081: val_loss did not improve from 0.30508
# Epoch 82/100
# 54/54 [==============================] - 11s 193ms/step - loss: 0.2492 - accuracy: 0.9097 - val_loss: 0.4503 - val_accuracy: 0.8426
#
# Epoch 00082: val_loss did not improve from 0.30508
# Epoch 83/100
# 54/54 [==============================] - 10s 188ms/step - loss: 0.2872 - accuracy: 0.8912 - val_loss: 0.3401 - val_accuracy: 0.8704
#
# Epoch 00083: val_loss did not improve from 0.30508
# Epoch 84/100
# 54/54 [==============================] - 10s 186ms/step - loss: 0.2260 - accuracy: 0.9051 - val_loss: 0.3070 - val_accuracy: 0.9167
#
# Epoch 00084: val_loss did not improve from 0.30508
# Epoch 85/100
# 54/54 [==============================] - 11s 207ms/step - loss: 0.3139 - accuracy: 0.8981 - val_loss: 0.3395 - val_accuracy: 0.8981
#
# Epoch 00085: val_loss did not improve from 0.30508
# Epoch 86/100
# 54/54 [==============================] - 12s 218ms/step - loss: 0.2655 - accuracy: 0.9167 - val_loss: 0.2748 - val_accuracy: 0.9074
#
# Epoch 00086: val_loss improved from 0.30508 to 0.27481, saving model to C:/Users/user/Desktop/Model/saved_finalmodel_1\finalmodel_1.h5
# Epoch 87/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.2722 - accuracy: 0.8866 - val_loss: 0.4297 - val_accuracy: 0.8796
#
# Epoch 00087: val_loss did not improve from 0.27481
# Epoch 88/100
# 54/54 [==============================] - 21s 383ms/step - loss: 0.2664 - accuracy: 0.9236 - val_loss: 0.3010 - val_accuracy: 0.8981
#
# Epoch 00088: val_loss did not improve from 0.27481
# Epoch 89/100
# 54/54 [==============================] - 11s 199ms/step - loss: 0.3020 - accuracy: 0.8843 - val_loss: 0.3112 - val_accuracy: 0.8796
#
# Epoch 00089: val_loss did not improve from 0.27481
# Epoch 90/100
# 54/54 [==============================] - 12s 213ms/step - loss: 0.2640 - accuracy: 0.9051 - val_loss: 0.3075 - val_accuracy: 0.9167
#
# Epoch 00090: val_loss did not improve from 0.27481
# Epoch 91/100
# 54/54 [==============================] - 11s 205ms/step - loss: 0.2319 - accuracy: 0.9190 - val_loss: 0.3055 - val_accuracy: 0.8704
#
# Epoch 00091: val_loss did not improve from 0.27481
# Epoch 92/100
# 54/54 [==============================] - 13s 228ms/step - loss: 0.2371 - accuracy: 0.8981 - val_loss: 0.3848 - val_accuracy: 0.8519
#
# Epoch 00092: val_loss did not improve from 0.27481
# Epoch 93/100
# 54/54 [==============================] - 17s 264ms/step - loss: 0.2402 - accuracy: 0.9120 - val_loss: 0.4999 - val_accuracy: 0.8519
#
# Epoch 00093: val_loss did not improve from 0.27481
# Epoch 94/100
# 54/54 [==============================] - 16s 294ms/step - loss: 0.2818 - accuracy: 0.8912 - val_loss: 0.3096 - val_accuracy: 0.8981
#
# Epoch 00094: val_loss did not improve from 0.27481
# Epoch 95/100
# 54/54 [==============================] - 14s 264ms/step - loss: 0.2479 - accuracy: 0.9120 - val_loss: 0.2901 - val_accuracy: 0.9074
#
# Epoch 00095: val_loss did not improve from 0.27481
# Epoch 96/100
# 54/54 [==============================] - 18s 336ms/step - loss: 0.2910 - accuracy: 0.8912 - val_loss: 0.3908 - val_accuracy: 0.8519
#
# Epoch 00096: val_loss did not improve from 0.27481
# Epoch 97/100
# 54/54 [==============================] - 38s 674ms/step - loss: 0.2507 - accuracy: 0.9097 - val_loss: 0.3879 - val_accuracy: 0.8796
#
# Epoch 00097: val_loss did not improve from 0.27481
# Epoch 98/100
# 54/54 [==============================] - 14s 258ms/step - loss: 0.2205 - accuracy: 0.9213 - val_loss: 0.4292 - val_accuracy: 0.8426
#
# Epoch 00098: val_loss did not improve from 0.27481
# Epoch 99/100
# 54/54 [==============================] - 16s 299ms/step - loss: 0.2339 - accuracy: 0.9120 - val_loss: 0.3135 - val_accuracy: 0.8889
#
# Epoch 00099: val_loss did not improve from 0.27481
# Epoch 100/100
# 54/54 [==============================] - 13s 248ms/step - loss: 0.2588 - accuracy: 0.8912 - val_loss: 0.3098 - val_accuracy: 0.8796
#
# Epoch 00100: val_loss did not improve from 0.27481
# 14/14 [==============================] - 2s 161ms/step - loss: 0.2984 - accuracy: 0.9259

# %% [markdown]
# Display the validation accuracy and loss.

# %%
print("Val acc:  " + str(VAL_ACCURACY))
print("Val loss: " + str(VAL_LOSS))
# Out:
# Val acc:  0.9259259104728699
# Val loss: 0.2983819544315338

# %% [markdown]
# ### Predict Using Test Set

# %% [markdown]
# Test set is used in order to do model prediction.

# %%
#to get the test set images convert the image to numpy array and store to testX
testX = []

for img_path in X_test['filename']:
    img = im.load_img(img_path, target_size=(224,224))
    x = im.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    x = x.reshape(224,224,3)
    testX.append(x)

testX = np.array(testX)

# %%
save_dir = gen_dir + "/saved_finalmodel_1"
full_model = create_model()
full_model.load_weights(save_dir+"/"+ "finalmodel_1.h5")

# Needed later for measuring performance metrics
# Predict test set to get the test accuracy/loss
yhat_probs2 = full_model.predict(testX, verbose=0) 
yhat_classes2 = yhat_probs2.argmax(axis=-1)

# %% [markdown]
# ## Measure Performance Metrics

# %% [markdown]
# After we have trained the final model with the entire train set and done prediction using the test set, we can now measure the performance metrics for model evaluation.

# %%
yt = pd.to_numeric(y_test['label'])                #make the labels to integer to get the model metrics

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Accuracy, Precision, Recall

# %%
def metriksu(yhat_classes2):
    
    # accuracy: (tp + tn) / (p + n)
    matrix = confusion_matrix(yt, yhat_classes2)
    accuracy2 = matrix.diagonal()/matrix.sum(axis=1)
    print('Accuracy per class: ' + str(accuracy2))
    # precision tp / (tp + fp)
    precision = precision_score(yt, yhat_classes2, average="weighted")
    print('Precision: %f' % precision)
    precision2 = precision_score(yt, yhat_classes2, average=None)
    print('Precision per class: ' + str(precision2))
    # recall: tp / (tp + fn)
    recall = recall_score(yt, yhat_classes2, average="weighted")
    print('Recall: %f' % recall)
    recall2 = recall_score(yt, yhat_classes2, average=None)
    print('Recall per class: ' + str(recall2))
    
    return accuracy2, precision2, recall2

# %% [markdown]
# ### ROC AUC

# %%
def roshi_aushi(yhat_probs2):
    
    # Binarize the true label
    ytbin = label_binarize(yt, classes=[0, 1, 2])
    n_classes = ytbin.shape[1]

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
      
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(ytbin[:, i], yhat_probs2[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i]) 

    # Compute micro-average ROC curve and ROC area
    fpr["macro"], tpr["macro"], _ = roc_curve(ytbin.ravel(), yhat_probs2.ravel())
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams["axes.edgecolor"] = 'black'
    plt.rcParams["axes.linewidth"]  = 1.25
    
    #balut-penoy
    plt.figure()
    lw = 2
    plt.plot(fpr[0], tpr[0], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[0])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Balut-Penoy')
    plt.legend(loc="lower right")
    plt.show()

    #salted egg
    plt.figure()
    lw = 2
    plt.plot(fpr[1], tpr[1], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[1])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Salted Egg')
    plt.legend(loc="lower right")
    plt.show()

    #table egg
    plt.figure()
    lw = 2
    plt.plot(fpr[2], tpr[2], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Table Egg')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
def confuuusion_meytriksu(yhat_classes2):

    #confusion matrix
    matrix = confusion_matrix(yt, yhat_classes2)
    
    df_cm = pd.DataFrame(matrix, range(matrix.shape[0]), range(matrix.shape[1]))
    df_cm = df_cm.rename(columns={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'}, 
                         index={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'})
    
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title('Confusion Matrix of Final Model Evaluation')

# %% [markdown]
# Call all the functions.

# %%
accuracy2, precision2, recall2 = metriksu(yhat_classes2)
# Out:
# Accuracy per class: [1.  1.  0.7]
# Precision: 0.923077
# Precision per class: [1.         0.76923077 1.        ]
# Recall: 0.900000
# Recall per class: [1.  1.  0.7]

# %%
roshi_aushi(yhat_probs2)

# %%
confuuusion_meytriksu(yhat_classes2)

# %% [markdown]
# ### Metrics per Class

# %%
accuracy2 = list(accuracy2)
precision2 = list(precision2)
recall2 = list(recall2)

accuracy2.append(0)
precision2.append(0)
recall2.append(0)

classes = 3

for x in range(classes):
    accuracy2[-1] += accuracy2[x]
    precision2[-1] += precision2[x]
    recall2[-1] += recall2[x]

accuracy2[-1] = accuracy2[-1]/classes
precision2[-1] = precision2[-1]/classes
recall2[-1] = recall2[-1]/classes

# %%
label = ['Balut/Penoy','Salted','Table','Ave']

df_eval_per_class = pd.DataFrame(data = list(zip(label,accuracy2,precision2,recall2)), 
                       columns=["Class","Accuracy","Precision","Recall"])

#set fold_ave as the index
df_eval_per_class.set_index("Class",inplace=True)

df_eval_per_class
# Out:
#              Accuracy  Precision  Recall
# Class
# Balut/Penoy       1.0   1.000000     1.0
# Salted            1.0   0.769231     1.0
# Table             0.7   1.000000     0.7
# Ave               0.9   0.923077     0.9

# %% [markdown]
# ## Validating Misclassified Images

# %% [markdown]
# We will display the correct and incorrect predictions. We will first get the images from the directories stored under the filename column.

# %%
testX2 = []

for img_path in X_test['filename']:
    img = cv2.imread(img_path)
    testX2.append(img)

testX2 = np.array(testX2)

# %% [markdown]
# We will be applying Grad-CAM in order to check where is the focus of the model. It presents a heatmap. The hotter the color on a region is, the more it is focused on.

# %% [markdown]
# ### Grad-CAM algorithm

# %%
last_conv_layer_name = "conv5_block3_add"

preprocess_input = keras.applications.resnet50.preprocess_input

def get_img_array(img_path, size):
    # `img` is a PIL image of size 224x224
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (224, 224, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 224, 224, 3)
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %% [markdown]
# ### superimposed visualization

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.5):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    
    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))

# %% [markdown]
# ### Prediction

# %%
def guraducamu(img_dir):
    img_size = (224,224)

    # Prepare image
    img_array = get_img_array(img_dir, img_size)

    conv_model = keras.applications.resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

    for layer in conv_model.layers:
        layer.trainable = False

    x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
    x = keras.layers.Dense(512, activation='relu')(x)
    x = keras.layers.Dense(256, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.2)(x)
    predictions = keras.layers.Dense(3, activation='softmax',name = "prediction")(x)

    model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

    model.load_weights(save_dir+"/"+ "finalmodel_1.h5")

    # Remove last layer's softmax
    model.layers[-1].activation = None

    # Generate class activation heatmap
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
 
    print("Original Image")
    display(Image(img_dir))

    print("Heatmap Prediction")
    plt.matshow(heatmap)
    plt.grid(False)
    plt.axis('off')
    plt.show()

    print("Grad-CAM")
    save_and_display_gradcam(img_dir, heatmap)

# %% [markdown]
# ### Correct predictions

# %%
correct = np.where(yhat_classes2==yt)[0]

print("Found %d correct labels" % len(correct))

for x in correct:
    print("Predict {0}, Class {1}".format(str(yhat_classes2[x]),str(yt.values[x])))
    img_dir = X_test.iloc[x]['filename']
    print(img_dir)
    guraducamu(img_dir)
    
plt.figure(figsize=(20,60))
for i, correct in enumerate(correct[:6]):
    plt.subplot(3,2,i+1)
    RGB_img = cv2.cvtColor(testX2[correct], cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img) #, interpolation='none') #, cmap='gray')
    plt.title("Predict {0}, Class {1}".format(str(yhat_classes2[correct]),str(yt.values[correct])))
    plt.grid(False)
    plt.axis('off')

plt.show()
# Out:
# Found 54 correct labels
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 79.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 40.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 66.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 61.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 62.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 4.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 39.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 108.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 58.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 32.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.small medium 23.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 18.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 47.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 56.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 156.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.small medium 30.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 29.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 33.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 22.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.small medium 35.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 64.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 8.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 14.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 130.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 20.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 14.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 76.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 141.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 42.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 8.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 66.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 127.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 55.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 44.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.small medium 64.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 164.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 176.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 65.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 44.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 38.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 49.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 11.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.hairline cracks 2.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 132.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 39.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 25.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 86.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 21.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 28.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 0, Class 0
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Balut-penoy 98.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.small medium 25.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 71.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 2, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 28.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 1
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Salted egg.dirty 50.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM

# %% [markdown]
# ### Incorrect predictions

# %%
incorrect = np.where(yhat_classes2!=yt)[0]

print ("Found %d incorrect labels" % len(incorrect))

for x in incorrect:
    print("Predict {0}, Class {1}".format(str(yhat_classes2[x]),str(yt.values[x])))
    img_dir = X_test.iloc[x]['filename']
    print(img_dir)
    guraducamu(img_dir)

plt.figure(figsize=(20,60))
for i, incorrect in enumerate(incorrect[:6]):
    plt.subplot(3,2,i+1)
    RGB_img = cv2.cvtColor(testX2[incorrect], cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img) #, interpolation='none') #, cmap='gray')
    plt.title("Predicted {0}, Class {1}".format(str(yhat_classes2[incorrect]), str(yt.values[incorrect])))
    plt.grid(False)
    plt.axis('off')

plt.show()
# Out:
# Found 6 incorrect labels
# Predict 1, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 98.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 100.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 22.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 49.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.broken crack 21.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
# Predict 1, Class 2
# C:/Users/user/Desktop/Dataset/ToBeUsed/test_set\Table egg.peewee 24.jpg
# Original Image
# Heatmap Prediction
# Grad-CAM
