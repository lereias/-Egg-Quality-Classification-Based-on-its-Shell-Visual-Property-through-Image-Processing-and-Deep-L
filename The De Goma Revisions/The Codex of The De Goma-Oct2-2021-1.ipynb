# %% [markdown]
# # Duck Egg Quality Classification Based on its Shell Visual Property through Image Processing and Deep Learning

# %% [markdown]
# Group CGM: <br>
#
# Caguioa, JV Bryan <br>
# Guinto, Ryhle Nodnyhlson <br>
# Mesias, Lee Reuben

# %% [markdown]
# # References

# %% [markdown]
# https://thedatafrog.com/en/articles/image-recognition-transfer-learning/ <br>
# https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538 <br>
# https://www.datacamp.com/community/tutorials/convolutional-neural-networks-python

# %% [markdown]
# ## Imports

# %%
# the directory where the data is stored
directory = "C:/Users/user/Desktop/Dataset"
#directory where set of models per training are stored
gen_dir = "C:/Users/user/Desktop/Model"

import os                                              # define and move to dataset and model directory
import random                                          # for image name
import shutil                                          # dupli
import sys
import cv2     

import tensorflow.keras as keras
import numpy as np
import tensorflow as tf                                 #for callbacks
import seaborn as sn
import pandas as pd 
# %matplotlib inline
import matplotlib.pyplot as plt                         #histograph/confusion matrix

from sklearn.model_selection import StratifiedKFold     #k-fold cross validation
from sklearn.model_selection import train_test_split    #split the dataset to train-test

from tensorflow.keras.preprocessing.image import ImageDataGenerator      # data augmentation
from tensorflow.keras.preprocessing import image as im                   #load image
from tensorflow.keras.applications.resnet50 import preprocess_input      #preprocess image                                                               

from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc       
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.preprocessing import label_binarize

from scipy import interp                            #interpolation needed for plotting all classes into one roc plot
from itertools import cycle                         #for the color of lines on that multiclass plot

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Put Dataset in a Dataframe

# %% [markdown]
# The directory of the images are put in a dataframe in order to prepare for splitting the dataset into train and test set.

# %%
totaldsdirect = directory + "/CombinedTwoAngleEggs"

image = []

if not os.path.exists(totaldsdirect):
    print("Directory does not exist. Please run the code on data cleaning notebook.")
    sys.exit()

for x in os.listdir(totaldsdirect):
    totaldsdirect2 = totaldsdirect + "/" + x
    for y in os.listdir(totaldsdirect2):
        if x == "Balut-penoy2":
            lbl = "0"
        elif x == "Salted egg2":
            lbl = "1"
        else:
            lbl = "2"
                 
        #append to image array
        image.append([totaldsdirect2 + "/" + y,lbl])

# %%
df = pd.DataFrame(image,columns=['filename','label'])
df
# Out:
#                                               filename label
# 0    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 1    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 2    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 3    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# 4    C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     0
# ..                                                 ...   ...
# 595  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 596  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 597  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 598  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
# 599  C:/Users/user/Desktop/Dataset/CombinedTwoAngle...     2
#
# [600 rows x 2 columns]

# %% [markdown]
# Classes: <br>
# 0 - Balut/Penoy <br>
# 1 - Salted <br>
# 2 - Table

# %% [markdown]
# ## Split Data to train and test set

# %% [markdown]
# We will need to split the dataset to train and test set. Only the train set will be used for transfer learning with K-fold validation. Test set will be used for model prediction and use that for model evaluation. Stratify is used in order to split the data in equal numbers under the classes specified.

# %%
# Split the data to train and test
X = df[['filename']]
y = df[['label']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=420)

# %% [markdown]
# Save the split sets to train and test set folders.

# %%
#folder to store the train and test set folders
fortraintest = directory + "/ToBeUsed"
if not os.path.exists(fortraintest):
    os.makedirs(fortraintest)

#train set folder
tr = fortraintest + "/train_set"
if not os.path.exists(tr):
    os.makedirs(tr)
else:
    #remove previous folder and create new one
    shutil.rmtree(tr)
    os.makedirs(tr)
    
#test set folder
te = fortraintest + "/test_set"
if not os.path.exists(te):
    os.makedirs(te)
else:
    #remove previous folder and create new one
    shutil.rmtree(te)
    os.makedirs(te)

#copying the images to the train set folder
for index, row in X_train.iterrows():
    trcpy = shutil.copy2(row['filename'], tr)
    X_train.loc[X_train['filename']==row['filename'],'filename']=trcpy #change to directory where image is copied
    
#copying the images to the test set folder
for index, row in X_test.iterrows():
    tecpy = shutil.copy2(row['filename'], te)
    X_test.loc[X_test['filename']==row['filename'],'filename']=tecpy #change to directory where image is copiedb

# %%
df2 = pd.concat([X_train,y_train],axis=1)
df2
# Out:
#                                               filename label
# 11   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 581  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 377  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 487  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 216  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# ..                                                 ...   ...
# 273  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 486  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
# 86   C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     0
# 200  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     1
# 538  C:/Users/user/Desktop/Dataset/ToBeUsed/train_s...     2
#
# [540 rows x 2 columns]

# %% [markdown]
# To check whether or not there are equal amounts of images per class in the train set, we have done what is shown below.

# %%
counto = [0,0,0]

counto_count = 0

for x in df2['label'].unique():
    for y in df2['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1

# %%
print(counto)
# Out:
# [180, 180, 180]

# %%
df3 = pd.concat([X_test,y_test],axis=1)
df3
# Out:
#                                               filename label
# 177  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 535  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 563  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 498  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 502  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 257  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 559  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 134  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 298  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 10   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 154  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 126  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 348  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 275  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 142  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 152  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 63   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 356  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 422  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 427  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 115  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 361  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 326  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 478  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 506  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 35   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 278  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 415  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 205  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 174  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 47   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 537  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 578  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 262  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 31   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 151  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 304  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 393  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 72   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 85   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 327  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 238  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 132  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 243  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 403  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 277  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 544  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 37   C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 533  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 518  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 185  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 213  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 220  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 198  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     0
# 350  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1
# 414  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 569  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 421  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 517  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     2
# 245  C:/Users/user/Desktop/Dataset/ToBeUsed/test_se...     1

# %% [markdown]
# Same with the train set, we checked whether or not there is an equal distribution of images

# %%
counto = [0,0,0]

counto_count = 0

for x in df3['label'].unique():
    for y in df3['label']:
        if x == y:
            if counto_count == 0:
                counto[0] += 1
            elif counto_count == 1:
                counto[1] += 1
            else:
                counto[2] += 1
                
    counto_count += 1

# %%
print(counto)
# Out:
# [20, 20, 20]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Create Plot History

# %% [markdown]
# Plot history will display the training and validation accuracy, and training and validation loss in every epoch in a fold.

# %%
def plot_history(history, yrange):
    #Plot loss and accuracy as a function of the epoch,
    #for the training and validation datasets.
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    # Plot training and validation accuracy per epoch
    plt.plot(epochs, acc)
    plt.plot(epochs, val_acc)
    plt.title('Training and validation accuracy')
    plt.legend(['train_accuracy','val_accuracy'])
    plt.ylim(yrange)
    
    # Plot training and validation loss per epoch
    plt.figure()

    plt.plot(epochs, loss)
    plt.plot(epochs, val_loss)
    plt.title('Training and validation loss')
    plt.legend(['train_loss','val_loss'])
    
    plt.show()

# %% [markdown]
# ### Save Models

# %% [markdown]
# K-fold cross validation will be used in training the model.The set of models produced per fold will be saved in an automatic generated folder. Every training will generated another folder to save the new set of models.

# %%
def savemodel():
    save_cur = ""  #check if there is any saved_models folders

    svnum = 0
    svnum2 = 0

    for x in os.listdir(gen_dir):
        if "saved_models" in x:
            save_cur = x
            if not save_cur == "":
                for word in save_cur.split("_"):
                    if word.isdigit():
                        svnum2 = int(word)
                        if svnum < svnum2:
                            svnum = svnum2


    #save_dir is where the created models using the current set of parameters are added        
    if save_cur == "":
        save_dir = gen_dir + "/saved_models_1"
        os.makedirs(save_dir)
    else:
        save_dir = gen_dir + "/saved_models_" + str(svnum + 1)
        os.makedirs(save_dir)
        
    return save_dir

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# We will apply data augmentation to the dataset to increase the accuracy of the models. For the training and validation set, we will use data augmentation per epoch in order to generate unique images in order to increase the dataset. For the test set, we will apply the same preprocessing used for the training and validation set so that it will match with the generated images.

# %% [markdown]
# ### For training set and validation set

# %%
resnet50 = keras.applications.resnet50

imgdatagen = ImageDataGenerator(
        preprocessing_function = resnet50.preprocess_input,
        horizontal_flip = True,
        vertical_flip = True,
        width_shift_range = 10,
        height_shift_range = 10,
        rotation_range = 5,
        brightness_range = [0.8,1.3],
        fill_mode = "nearest"
    )

# %% [markdown]
# ### For test set

# %%
resnet50 = keras.applications.resnet50

imgdatagen2 = ImageDataGenerator(
        preprocessing_function = resnet50.preprocess_input,
    )

# %% [markdown]
# ## Model Creation

# %% [markdown]
# The model will be based on ResNet50 Architecture. The classifier block will be changed to suit to our dataset.

# %%
def create_model():
    conv_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

    for layer in conv_model.layers:
        layer.trainable = False

    x = keras.layers.GlobalAveragePooling2D()(conv_model.output)
    x = keras.layers.Dense(512, activation='relu')(x)
    x = keras.layers.Dense(256, activation='relu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.2)(x)
    predictions = keras.layers.Dense(3, activation='softmax')(x)

    full_model = keras.models.Model(inputs=conv_model.input, outputs=predictions)

    return full_model

# %%
full_model = create_model()
full_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            771         dropout[0][0]
# ==================================================================================================
# Total params: 24,769,923
# Trainable params: 1,181,699
# Non-trainable params: 23,588,224
# __________________________________________________________________________________________________

# %% [markdown]
# ## Hyper-Parameter Tuning

# %% [markdown]
# We will check the parameters that yielded the best results. A set of values on chosen parameters is given. The one that will yield the best results will be used for prediction.

# %% [markdown]
# ### Model Parameters

# %%
batch_size_arr = [8]                              #batch size
num_epochs_arr = [110]                                #number of epochs
lr_arr = [0.0001]                                   #learning rate Adamax

# %% [markdown]
# ### Initialize Variables

# %%
VALIDATION_ACCURACY = []                          #holds all validation_accuracy
VALIDATION_LOSS = []                              #holds all validation_loss

TRAIN_ACCURACY = []                               #holds all train_accuracy
TRAIN_LOSS = []                                   #holds all train_loss

TEST_ACCURACY = []                                #holds all test_accuracy
TEST_LOSS = []                                    #holds all test_loss

param_arr = []                                    #holds the parameter values per combination

val_acc_arr = []                                  #holds the set of validation accuracy per combination
val_loss_arr = []                                 #holds the set of validation loss per combination
val_acc_means = []                                #holds the means of all set of validation accuracy per combination
val_loss_means = []                               #holds the means of all set of validation loss per combination

train_acc_arr = []                                #holds the set of train accuracy per combination
train_loss_arr = []                               #holds the set of train loss per combination
train_acc_means = []                              #holds the means of all set of train accuracy per combination
train_loss_means = []                             #holds the means of all set of train loss per combination

test_acc_arr = []                                 #holds the set of test accuracy per combination
test_loss_arr = []                                #holds the set of test loss per combination
test_acc_means = []                               #holds the means of all set of test accuracy per combination
test_loss_means = []                              #holds the means of all set of test loss per combination

# %% [markdown]
# ### Train, Validation, Test data settings

# %%
train_dir = directory + "/ToBeUsed/train_set"     #where the train set images are stored
test_dir = directory + "/ToBeUsed/test_set"

#kfold parameters
Y = df2[['label']]
skf = StratifiedKFold(n_splits = 5, random_state = 69, shuffle = True)

yt = pd.to_numeric(y_test['label'])                #make the labels to integer to get the model metrics

# %% [markdown]
# Train the model per combination of parameters.

# %%
for x in range(len(batch_size_arr)):
    
    #for batch size values
    if len(param_arr) == 0:
        param_arr.append([])
    
    for y in range(len(num_epochs_arr)):

        #for epoch values
        if len(param_arr) == 1:
            param_arr.append([])
        
        for z in range(len(lr_arr)):
            
            #for learning rate values
            if len(param_arr) == 2:
                param_arr.append([])
                
            print('')
            print("batch size: ", batch_size_arr[x])
            print("epochs: ", num_epochs_arr[y])
            print("learning rate: ", lr_arr[z])
            print('')
            
            #append the values per combo
            param_arr[0].append(batch_size_arr[x])
            param_arr[1].append(num_epochs_arr[y])
            param_arr[2].append(lr_arr[z])
            
            VALIDATION_ACCURACY = []
            VALIDATION_LOSS = []
            
            TRAIN_ACCURACY = []
            TRAIN_LOSS = []
            
            TEST_ACCURACY = []
            TEST_LOSS = []
            
            #change save_dir value per combination
            save_dir = savemodel()
            fold_var = 1
            
            for train_index, val_index in skf.split(np.zeros(len(df2)),Y):

                training_data = df2.iloc[train_index]
                validation_data = df2.iloc[val_index]
                
                print('')
                print("Fold number " + str(fold_var))
                
                train_data_generator = imgdatagen.flow_from_dataframe(training_data, directory = train_dir,
                                       x_col = "filename", y_col = "label",
                                       class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                valid_data_generator  = imgdatagen.flow_from_dataframe(validation_data, directory = train_dir,
                                        x_col = "filename", y_col = "label",
                                        class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                
                test_data = df3
                
                test_data_preprocessed = imgdatagen2.flow_from_dataframe(test_data, directory = test_dir,
                                         x_col = "filename", y_col = "label",
                                         class_mode = "categorical", target_size = (224,224), batch_size = batch_size_arr[x],
                                            shuffle = True)
                
                full_model = create_model()
                # Compile the model
                full_model.compile(loss='categorical_crossentropy',
                              optimizer=keras.optimizers.Adamax(learning_rate=lr_arr[z]),
                              metrics=['accuracy']) #categorical_crossentropy cause it is more than 2 classes

                # Create callbacks
                checkpoint = tf.keras.callbacks.ModelCheckpoint((save_dir+"/"+ "model_" + str(fold_var) + ".h5"), 
                                        monitor='val_accuracy', verbose=1, 
                                        save_best_only=True, mode='max')
                callbacks_list = [checkpoint]
                # This saves the best model


                # Fit the model
                history = full_model.fit(train_data_generator,
                                         epochs=num_epochs_arr[y],
                                         callbacks=callbacks_list,
                                         validation_data=valid_data_generator,
                                         verbose=1)

                # Plot the history
                plot_history(history, yrange=(0.2,1))

                # Load the best model instance to evaluate the performance of the model
                full_model.load_weights(save_dir+"/model_"+str(fold_var)+".h5")

                results = full_model.evaluate(valid_data_generator)
                results = dict(zip(full_model.metrics_names,results))
                
                results2 = full_model.predict(valid_data_generator)
                
                # Store Validation accuracy/loss
                VALIDATION_ACCURACY.append(results['accuracy'])
                VALIDATION_LOSS.append(results['loss'])
                
                # Store Train accuracy/loss
                TRAIN_ACCURACY.append(np.mean(history.history['accuracy']))
                TRAIN_LOSS.append(np.mean(history.history['loss']))
                
                # Predict test set to get the test accuracy/loss
                yhat_probs = full_model.predict(test_data_preprocessed, verbose=0)
                yhat_classes = yhat_probs.argmax(axis=-1)
                
                # Test accuracy and loss score
                accuracy = accuracy_score(yt, yhat_classes)
                loss = log_loss(yt, yhat_probs)
                
                # Store Test accuracy and loss
                TEST_ACCURACY.append(accuracy)
                TEST_LOSS.append(loss)
                
                tf.keras.backend.clear_session()

                fold_var += 1
                
            val_acc_arr.append(VALIDATION_ACCURACY)
            val_loss_arr.append(VALIDATION_LOSS)
            
            train_acc_arr.append(TRAIN_ACCURACY)                            
            train_loss_arr.append(TRAIN_LOSS)
            
            test_acc_arr.append(TEST_ACCURACY)
            test_loss_arr.append(TEST_LOSS)
# Out:
# batch size:  8
# epochs:  110
# learning rate:  0.0001
#
#
# Fold number 1
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Found 60 validated image filenames belonging to 3 classes.
# Epoch 1/110
# 54/54 [==============================] - 17s 218ms/step - loss: 1.0397 - accuracy: 0.5370 - val_loss: 0.9406 - val_accuracy: 0.5741
#
# Epoch 00001: val_accuracy improved from -inf to 0.57407, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 2/110
# 54/54 [==============================] - 8s 148ms/step - loss: 0.7960 - accuracy: 0.6551 - val_loss: 0.8549 - val_accuracy: 0.5926
#
# Epoch 00002: val_accuracy improved from 0.57407 to 0.59259, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 3/110
# 54/54 [==============================] - 9s 157ms/step - loss: 0.7406 - accuracy: 0.6944 - val_loss: 0.8082 - val_accuracy: 0.6111
#
# Epoch 00003: val_accuracy improved from 0.59259 to 0.61111, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 4/110
# 54/54 [==============================] - 8s 153ms/step - loss: 0.7420 - accuracy: 0.6898 - val_loss: 0.7237 - val_accuracy: 0.6852
#
# Epoch 00004: val_accuracy improved from 0.61111 to 0.68519, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 5/110
# 54/54 [==============================] - 8s 152ms/step - loss: 0.6558 - accuracy: 0.7014 - val_loss: 0.6900 - val_accuracy: 0.6574
#
# Epoch 00005: val_accuracy did not improve from 0.68519
# Epoch 6/110
# 54/54 [==============================] - 9s 162ms/step - loss: 0.6536 - accuracy: 0.7269 - val_loss: 0.6687 - val_accuracy: 0.6852
#
# Epoch 00006: val_accuracy did not improve from 0.68519
# Epoch 7/110
# 54/54 [==============================] - 9s 161ms/step - loss: 0.7038 - accuracy: 0.6991 - val_loss: 0.6390 - val_accuracy: 0.7222
#
# Epoch 00007: val_accuracy improved from 0.68519 to 0.72222, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 8/110
# 54/54 [==============================] - 9s 164ms/step - loss: 0.6606 - accuracy: 0.7060 - val_loss: 0.7851 - val_accuracy: 0.6759
#
# Epoch 00008: val_accuracy did not improve from 0.72222
# Epoch 9/110
# 54/54 [==============================] - 9s 160ms/step - loss: 0.6538 - accuracy: 0.7407 - val_loss: 0.6334 - val_accuracy: 0.7407
#
# Epoch 00009: val_accuracy improved from 0.72222 to 0.74074, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 10/110
# 54/54 [==============================] - 8s 146ms/step - loss: 0.6287 - accuracy: 0.7315 - val_loss: 0.5818 - val_accuracy: 0.7870
#
# Epoch 00010: val_accuracy improved from 0.74074 to 0.78704, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 11/110
# 54/54 [==============================] - 8s 149ms/step - loss: 0.6182 - accuracy: 0.7384 - val_loss: 0.5315 - val_accuracy: 0.7870
#
# Epoch 00011: val_accuracy did not improve from 0.78704
# Epoch 12/110
# 54/54 [==============================] - 9s 158ms/step - loss: 0.6031 - accuracy: 0.7130 - val_loss: 0.5548 - val_accuracy: 0.7315
#
# Epoch 00012: val_accuracy did not improve from 0.78704
# Epoch 13/110
# 54/54 [==============================] - 8s 147ms/step - loss: 0.5628 - accuracy: 0.7593 - val_loss: 0.5956 - val_accuracy: 0.7130
#
# Epoch 00013: val_accuracy did not improve from 0.78704
# Epoch 14/110
# 54/54 [==============================] - 9s 165ms/step - loss: 0.5962 - accuracy: 0.7407 - val_loss: 0.5623 - val_accuracy: 0.7778
#
# Epoch 00014: val_accuracy did not improve from 0.78704
# Epoch 15/110
# 54/54 [==============================] - 9s 159ms/step - loss: 0.6006 - accuracy: 0.7523 - val_loss: 0.5738 - val_accuracy: 0.7500
#
# Epoch 00015: val_accuracy did not improve from 0.78704
# Epoch 16/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.6060 - accuracy: 0.7500 - val_loss: 0.5590 - val_accuracy: 0.7407
#
# Epoch 00016: val_accuracy did not improve from 0.78704
# Epoch 17/110
# 54/54 [==============================] - 11s 197ms/step - loss: 0.5649 - accuracy: 0.7708 - val_loss: 0.6990 - val_accuracy: 0.7593
#
# Epoch 00017: val_accuracy did not improve from 0.78704
# Epoch 18/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.5883 - accuracy: 0.7569 - val_loss: 0.4617 - val_accuracy: 0.8426
#
# Epoch 00018: val_accuracy improved from 0.78704 to 0.84259, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 19/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.5336 - accuracy: 0.7731 - val_loss: 0.5236 - val_accuracy: 0.7500
#
# Epoch 00019: val_accuracy did not improve from 0.84259
# Epoch 20/110
# 54/54 [==============================] - 9s 169ms/step - loss: 0.5156 - accuracy: 0.8102 - val_loss: 0.4874 - val_accuracy: 0.8148
#
# Epoch 00020: val_accuracy did not improve from 0.84259
# Epoch 21/110
# 54/54 [==============================] - 8s 151ms/step - loss: 0.5928 - accuracy: 0.7708 - val_loss: 0.5433 - val_accuracy: 0.7685
#
# Epoch 00021: val_accuracy did not improve from 0.84259
# Epoch 22/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.5044 - accuracy: 0.7870 - val_loss: 0.5068 - val_accuracy: 0.7870
#
# Epoch 00022: val_accuracy did not improve from 0.84259
# Epoch 23/110
# 54/54 [==============================] - 11s 195ms/step - loss: 0.5395 - accuracy: 0.7662 - val_loss: 0.5613 - val_accuracy: 0.7315
#
# Epoch 00023: val_accuracy did not improve from 0.84259
# Epoch 24/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.5531 - accuracy: 0.7731 - val_loss: 0.4560 - val_accuracy: 0.8426
#
# Epoch 00024: val_accuracy did not improve from 0.84259
# Epoch 25/110
# 54/54 [==============================] - 10s 189ms/step - loss: 0.5224 - accuracy: 0.7685 - val_loss: 0.5854 - val_accuracy: 0.7685
#
# Epoch 00025: val_accuracy did not improve from 0.84259
# Epoch 26/110
# 54/54 [==============================] - 11s 198ms/step - loss: 0.5432 - accuracy: 0.7940 - val_loss: 0.5884 - val_accuracy: 0.7685
#
# Epoch 00026: val_accuracy did not improve from 0.84259
# Epoch 27/110
# 54/54 [==============================] - 9s 166ms/step - loss: 0.4889 - accuracy: 0.8056 - val_loss: 0.5473 - val_accuracy: 0.7778
#
# Epoch 00027: val_accuracy did not improve from 0.84259
# Epoch 28/110
# 54/54 [==============================] - 8s 143ms/step - loss: 0.5236 - accuracy: 0.7986 - val_loss: 0.5105 - val_accuracy: 0.8056
#
# Epoch 00028: val_accuracy did not improve from 0.84259
# Epoch 29/110
# 54/54 [==============================] - 9s 162ms/step - loss: 0.4905 - accuracy: 0.8102 - val_loss: 0.4608 - val_accuracy: 0.8056
#
# Epoch 00029: val_accuracy did not improve from 0.84259
# Epoch 30/110
# 54/54 [==============================] - 12s 216ms/step - loss: 0.5103 - accuracy: 0.7824 - val_loss: 0.5601 - val_accuracy: 0.7778
#
# Epoch 00030: val_accuracy did not improve from 0.84259
# Epoch 31/110
# 54/54 [==============================] - 9s 172ms/step - loss: 0.5432 - accuracy: 0.7824 - val_loss: 0.5211 - val_accuracy: 0.7870
#
# Epoch 00031: val_accuracy did not improve from 0.84259
# Epoch 32/110
# 54/54 [==============================] - 9s 160ms/step - loss: 0.4880 - accuracy: 0.7940 - val_loss: 0.4402 - val_accuracy: 0.8426
#
# Epoch 00032: val_accuracy did not improve from 0.84259
# Epoch 33/110
# 54/54 [==============================] - 9s 162ms/step - loss: 0.4976 - accuracy: 0.7824 - val_loss: 0.4460 - val_accuracy: 0.8333
#
# Epoch 00033: val_accuracy did not improve from 0.84259
# Epoch 34/110
# 54/54 [==============================] - 9s 170ms/step - loss: 0.4872 - accuracy: 0.7986 - val_loss: 0.4651 - val_accuracy: 0.8056
#
# Epoch 00034: val_accuracy did not improve from 0.84259
# Epoch 35/110
# 54/54 [==============================] - 9s 170ms/step - loss: 0.5078 - accuracy: 0.7755 - val_loss: 0.4692 - val_accuracy: 0.7870
#
# Epoch 00035: val_accuracy did not improve from 0.84259
# Epoch 36/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.5111 - accuracy: 0.8009 - val_loss: 0.5353 - val_accuracy: 0.7963
#
# Epoch 00036: val_accuracy did not improve from 0.84259
# Epoch 37/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.5078 - accuracy: 0.7917 - val_loss: 0.4924 - val_accuracy: 0.8519
#
# Epoch 00037: val_accuracy improved from 0.84259 to 0.85185, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 38/110
# 54/54 [==============================] - 11s 203ms/step - loss: 0.4790 - accuracy: 0.7963 - val_loss: 0.4828 - val_accuracy: 0.8056
#
# Epoch 00038: val_accuracy did not improve from 0.85185
# Epoch 39/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4905 - accuracy: 0.7963 - val_loss: 0.4855 - val_accuracy: 0.8148
#
# Epoch 00039: val_accuracy did not improve from 0.85185
# Epoch 40/110
# 54/54 [==============================] - 9s 159ms/step - loss: 0.4630 - accuracy: 0.7963 - val_loss: 0.4542 - val_accuracy: 0.7963
#
# Epoch 00040: val_accuracy did not improve from 0.85185
# Epoch 41/110
# 54/54 [==============================] - 9s 161ms/step - loss: 0.4574 - accuracy: 0.8241 - val_loss: 0.4259 - val_accuracy: 0.8333
#
# Epoch 00041: val_accuracy did not improve from 0.85185
# Epoch 42/110
# 54/54 [==============================] - 8s 156ms/step - loss: 0.4478 - accuracy: 0.8171 - val_loss: 0.4763 - val_accuracy: 0.8241
#
# Epoch 00042: val_accuracy did not improve from 0.85185
# Epoch 43/110
# 54/54 [==============================] - 9s 172ms/step - loss: 0.4679 - accuracy: 0.8218 - val_loss: 0.4341 - val_accuracy: 0.8148
#
# Epoch 00043: val_accuracy did not improve from 0.85185
# Epoch 44/110
# 54/54 [==============================] - 8s 150ms/step - loss: 0.4669 - accuracy: 0.8171 - val_loss: 0.4682 - val_accuracy: 0.8056
#
# Epoch 00044: val_accuracy did not improve from 0.85185
# Epoch 45/110
# 54/54 [==============================] - 8s 152ms/step - loss: 0.5091 - accuracy: 0.7778 - val_loss: 0.4619 - val_accuracy: 0.8241
#
# Epoch 00045: val_accuracy did not improve from 0.85185
# Epoch 46/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.4834 - accuracy: 0.7986 - val_loss: 0.4642 - val_accuracy: 0.7963
#
# Epoch 00046: val_accuracy did not improve from 0.85185
# Epoch 47/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4501 - accuracy: 0.8079 - val_loss: 0.3776 - val_accuracy: 0.8519
#
# Epoch 00047: val_accuracy did not improve from 0.85185
# Epoch 48/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4689 - accuracy: 0.8032 - val_loss: 0.3687 - val_accuracy: 0.8426
#
# Epoch 00048: val_accuracy did not improve from 0.85185
# Epoch 49/110
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4187 - accuracy: 0.8009 - val_loss: 0.3643 - val_accuracy: 0.8704
#
# Epoch 00049: val_accuracy improved from 0.85185 to 0.87037, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 50/110
# 54/54 [==============================] - 9s 159ms/step - loss: 0.4230 - accuracy: 0.8148 - val_loss: 0.4103 - val_accuracy: 0.8426
#
# Epoch 00050: val_accuracy did not improve from 0.87037
# Epoch 51/110
# 54/54 [==============================] - 8s 152ms/step - loss: 0.4037 - accuracy: 0.8472 - val_loss: 0.3683 - val_accuracy: 0.8704
#
# Epoch 00051: val_accuracy did not improve from 0.87037
# Epoch 52/110
# 54/54 [==============================] - 10s 188ms/step - loss: 0.4774 - accuracy: 0.7917 - val_loss: 0.4775 - val_accuracy: 0.8056
#
# Epoch 00052: val_accuracy did not improve from 0.87037
# Epoch 53/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4858 - accuracy: 0.8056 - val_loss: 0.4120 - val_accuracy: 0.8519
#
# Epoch 00053: val_accuracy did not improve from 0.87037
# Epoch 54/110
# 54/54 [==============================] - 9s 175ms/step - loss: 0.4151 - accuracy: 0.8241 - val_loss: 0.4477 - val_accuracy: 0.8333
#
# Epoch 00054: val_accuracy did not improve from 0.87037
# Epoch 55/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4294 - accuracy: 0.8241 - val_loss: 0.4371 - val_accuracy: 0.8241
#
# Epoch 00055: val_accuracy did not improve from 0.87037
# Epoch 56/110
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4428 - accuracy: 0.8287 - val_loss: 0.5336 - val_accuracy: 0.7778
#
# Epoch 00056: val_accuracy did not improve from 0.87037
# Epoch 57/110
# 54/54 [==============================] - 9s 172ms/step - loss: 0.4224 - accuracy: 0.8287 - val_loss: 0.4445 - val_accuracy: 0.8148
#
# Epoch 00057: val_accuracy did not improve from 0.87037
# Epoch 58/110
# 54/54 [==============================] - 9s 163ms/step - loss: 0.3601 - accuracy: 0.8611 - val_loss: 0.4837 - val_accuracy: 0.8148
#
# Epoch 00058: val_accuracy did not improve from 0.87037
# Epoch 59/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4637 - accuracy: 0.8148 - val_loss: 0.3765 - val_accuracy: 0.8519
#
# Epoch 00059: val_accuracy did not improve from 0.87037
# Epoch 60/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.4098 - accuracy: 0.8565 - val_loss: 0.3845 - val_accuracy: 0.8611
#
# Epoch 00060: val_accuracy did not improve from 0.87037
# Epoch 61/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4902 - accuracy: 0.7917 - val_loss: 0.4767 - val_accuracy: 0.8241
#
# Epoch 00061: val_accuracy did not improve from 0.87037
# Epoch 62/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.4415 - accuracy: 0.8125 - val_loss: 0.5075 - val_accuracy: 0.7685
#
# Epoch 00062: val_accuracy did not improve from 0.87037
# Epoch 63/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.4178 - accuracy: 0.8241 - val_loss: 0.4913 - val_accuracy: 0.8241
#
# Epoch 00063: val_accuracy did not improve from 0.87037
# Epoch 64/110
# 54/54 [==============================] - 9s 163ms/step - loss: 0.4356 - accuracy: 0.8125 - val_loss: 0.3755 - val_accuracy: 0.8611
#
# Epoch 00064: val_accuracy did not improve from 0.87037
# Epoch 65/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.3983 - accuracy: 0.8472 - val_loss: 0.4326 - val_accuracy: 0.8519
#
# Epoch 00065: val_accuracy did not improve from 0.87037
# Epoch 66/110
# 54/54 [==============================] - 9s 166ms/step - loss: 0.4221 - accuracy: 0.8264 - val_loss: 0.4764 - val_accuracy: 0.7963
#
# Epoch 00066: val_accuracy did not improve from 0.87037
# Epoch 67/110
# 54/54 [==============================] - 8s 141ms/step - loss: 0.4382 - accuracy: 0.8287 - val_loss: 0.5124 - val_accuracy: 0.8148
#
# Epoch 00067: val_accuracy did not improve from 0.87037
# Epoch 68/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.4764 - accuracy: 0.7963 - val_loss: 0.3811 - val_accuracy: 0.8241
#
# Epoch 00068: val_accuracy did not improve from 0.87037
# Epoch 69/110
# 54/54 [==============================] - 8s 155ms/step - loss: 0.4095 - accuracy: 0.8264 - val_loss: 0.5157 - val_accuracy: 0.7870
#
# Epoch 00069: val_accuracy did not improve from 0.87037
# Epoch 70/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3958 - accuracy: 0.8519 - val_loss: 0.3544 - val_accuracy: 0.8426
#
# Epoch 00070: val_accuracy did not improve from 0.87037
# Epoch 71/110
# 54/54 [==============================] - 11s 196ms/step - loss: 0.3719 - accuracy: 0.8380 - val_loss: 0.5368 - val_accuracy: 0.7963
#
# Epoch 00071: val_accuracy did not improve from 0.87037
# Epoch 72/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.4579 - accuracy: 0.8241 - val_loss: 0.4022 - val_accuracy: 0.8148
#
# Epoch 00072: val_accuracy did not improve from 0.87037
# Epoch 73/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3977 - accuracy: 0.8426 - val_loss: 0.4702 - val_accuracy: 0.8056
#
# Epoch 00073: val_accuracy did not improve from 0.87037
# Epoch 74/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.4535 - accuracy: 0.8241 - val_loss: 0.3771 - val_accuracy: 0.8241
#
# Epoch 00074: val_accuracy did not improve from 0.87037
# Epoch 75/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4083 - accuracy: 0.8287 - val_loss: 0.4349 - val_accuracy: 0.8426
#
# Epoch 00075: val_accuracy did not improve from 0.87037
# Epoch 76/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4062 - accuracy: 0.8310 - val_loss: 0.4183 - val_accuracy: 0.8704
#
# Epoch 00076: val_accuracy did not improve from 0.87037
# Epoch 77/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3664 - accuracy: 0.8542 - val_loss: 0.3979 - val_accuracy: 0.8333
#
# Epoch 00077: val_accuracy did not improve from 0.87037
# Epoch 78/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.3848 - accuracy: 0.8426 - val_loss: 0.4509 - val_accuracy: 0.8148
# Epoch 00078: val_accuracy did not improve from 0.87037
# Epoch 79/110
# 54/54 [==============================] - 9s 175ms/step - loss: 0.4020 - accuracy: 0.8241 - val_loss: 0.3813 - val_accuracy: 0.8426
#
# Epoch 00079: val_accuracy did not improve from 0.87037
# Epoch 80/110
# 54/54 [==============================] - 9s 164ms/step - loss: 0.3630 - accuracy: 0.8750 - val_loss: 0.4593 - val_accuracy: 0.8056
#
# Epoch 00080: val_accuracy did not improve from 0.87037
# Epoch 81/110
# 54/54 [==============================] - 9s 169ms/step - loss: 0.4096 - accuracy: 0.8519 - val_loss: 0.3991 - val_accuracy: 0.8611
#
# Epoch 00081: val_accuracy did not improve from 0.87037
# Epoch 82/110
# 54/54 [==============================] - 9s 161ms/step - loss: 0.3762 - accuracy: 0.8426 - val_loss: 0.4839 - val_accuracy: 0.7963
#
# Epoch 00082: val_accuracy did not improve from 0.87037
# Epoch 83/110
# 54/54 [==============================] - 8s 142ms/step - loss: 0.3871 - accuracy: 0.8542 - val_loss: 0.4542 - val_accuracy: 0.7685
#
# Epoch 00083: val_accuracy did not improve from 0.87037
# Epoch 84/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.3849 - accuracy: 0.8380 - val_loss: 0.4297 - val_accuracy: 0.8519
#
# Epoch 00084: val_accuracy did not improve from 0.87037
# Epoch 85/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.3709 - accuracy: 0.8380 - val_loss: 0.6875 - val_accuracy: 0.7500
#
# Epoch 00085: val_accuracy did not improve from 0.87037
# Epoch 86/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4264 - accuracy: 0.8333 - val_loss: 0.4673 - val_accuracy: 0.8333
#
# Epoch 00086: val_accuracy did not improve from 0.87037
# Epoch 87/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3509 - accuracy: 0.8449 - val_loss: 0.4025 - val_accuracy: 0.8148
#
# Epoch 00087: val_accuracy did not improve from 0.87037
# Epoch 88/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3496 - accuracy: 0.8611 - val_loss: 0.3969 - val_accuracy: 0.8241
#
# Epoch 00088: val_accuracy did not improve from 0.87037
# Epoch 89/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.3893 - accuracy: 0.8333 - val_loss: 0.3734 - val_accuracy: 0.8704
#
# Epoch 00089: val_accuracy did not improve from 0.87037
# Epoch 90/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.3698 - accuracy: 0.8333 - val_loss: 0.4419 - val_accuracy: 0.7778
#
# Epoch 00090: val_accuracy did not improve from 0.87037
# Epoch 91/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.3476 - accuracy: 0.8588 - val_loss: 0.3983 - val_accuracy: 0.8426
#
# Epoch 00091: val_accuracy did not improve from 0.87037
# Epoch 92/110
# 54/54 [==============================] - 9s 175ms/step - loss: 0.4044 - accuracy: 0.8542 - val_loss: 0.3081 - val_accuracy: 0.8889
#
# Epoch 00092: val_accuracy improved from 0.87037 to 0.88889, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_1.h5
# Epoch 93/110
# 54/54 [==============================] - 9s 159ms/step - loss: 0.3930 - accuracy: 0.8657 - val_loss: 0.4082 - val_accuracy: 0.8333
#
# Epoch 00093: val_accuracy did not improve from 0.88889
# Epoch 94/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.3727 - accuracy: 0.8657 - val_loss: 0.4715 - val_accuracy: 0.8241
#
# Epoch 00094: val_accuracy did not improve from 0.88889
# Epoch 95/110
# 54/54 [==============================] - 10s 194ms/step - loss: 0.3764 - accuracy: 0.8657 - val_loss: 0.5923 - val_accuracy: 0.7870
#
# Epoch 00095: val_accuracy did not improve from 0.88889
# Epoch 96/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.3667 - accuracy: 0.8565 - val_loss: 0.4302 - val_accuracy: 0.8519
#
# Epoch 00096: val_accuracy did not improve from 0.88889
# Epoch 97/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.4663 - accuracy: 0.8287 - val_loss: 0.3786 - val_accuracy: 0.8333
#
# Epoch 00097: val_accuracy did not improve from 0.88889
# Epoch 98/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.4250 - accuracy: 0.8218 - val_loss: 0.4595 - val_accuracy: 0.8426
#
# Epoch 00098: val_accuracy did not improve from 0.88889
# Epoch 99/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3600 - accuracy: 0.8542 - val_loss: 0.4012 - val_accuracy: 0.8241
#
# Epoch 00099: val_accuracy did not improve from 0.88889
# Epoch 100/110
# 54/54 [==============================] - 12s 216ms/step - loss: 0.3789 - accuracy: 0.8611 - val_loss: 0.3330 - val_accuracy: 0.8704
#
# Epoch 00100: val_accuracy did not improve from 0.88889
# Epoch 101/110
# 54/54 [==============================] - 10s 189ms/step - loss: 0.4081 - accuracy: 0.8310 - val_loss: 0.3702 - val_accuracy: 0.8889
#
# Epoch 00101: val_accuracy did not improve from 0.88889
# Epoch 102/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3742 - accuracy: 0.8565 - val_loss: 0.5122 - val_accuracy: 0.8241
#
# Epoch 00102: val_accuracy did not improve from 0.88889
# Epoch 103/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.3661 - accuracy: 0.8727 - val_loss: 0.4334 - val_accuracy: 0.8333
#
# Epoch 00103: val_accuracy did not improve from 0.88889
# Epoch 104/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3758 - accuracy: 0.8495 - val_loss: 0.4298 - val_accuracy: 0.8056
#
# Epoch 00104: val_accuracy did not improve from 0.88889
# Epoch 105/110
# 54/54 [==============================] - 9s 170ms/step - loss: 0.3507 - accuracy: 0.8495 - val_loss: 0.3658 - val_accuracy: 0.8611
#
# Epoch 00105: val_accuracy did not improve from 0.88889
# Epoch 106/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4380 - accuracy: 0.8333 - val_loss: 0.4700 - val_accuracy: 0.8611
#
# Epoch 00106: val_accuracy did not improve from 0.88889
# Epoch 107/110
# 54/54 [==============================] - 10s 190ms/step - loss: 0.4204 - accuracy: 0.8356 - val_loss: 0.4095 - val_accuracy: 0.8519
#
# Epoch 00107: val_accuracy did not improve from 0.88889
# Epoch 108/110
# 54/54 [==============================] - 9s 169ms/step - loss: 0.3650 - accuracy: 0.8542 - val_loss: 0.4125 - val_accuracy: 0.8333
#
# Epoch 00108: val_accuracy did not improve from 0.88889
# Epoch 109/110
# 54/54 [==============================] - 8s 147ms/step - loss: 0.3995 - accuracy: 0.8356 - val_loss: 0.4055 - val_accuracy: 0.8241
#
# Epoch 00109: val_accuracy did not improve from 0.88889
# Epoch 110/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.3499 - accuracy: 0.8704 - val_loss: 0.3884 - val_accuracy: 0.8333
#
# Epoch 00110: val_accuracy did not improve from 0.88889
# 14/14 [==============================] - 2s 138ms/step - loss: 0.5066 - accuracy: 0.8148
#
# Fold number 2
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Found 60 validated image filenames belonging to 3 classes.
# Epoch 1/110
# 54/54 [==============================] - 13s 194ms/step - loss: 1.0307 - accuracy: 0.5116 - val_loss: 1.1636 - val_accuracy: 0.3611
#
# Epoch 00001: val_accuracy improved from -inf to 0.36111, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 2/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.8359 - accuracy: 0.6505 - val_loss: 0.9059 - val_accuracy: 0.5648
#
# Epoch 00002: val_accuracy improved from 0.36111 to 0.56481, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 3/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.7688 - accuracy: 0.6620 - val_loss: 0.7741 - val_accuracy: 0.6389
#
# Epoch 00003: val_accuracy improved from 0.56481 to 0.63889, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 4/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.6451 - accuracy: 0.7292 - val_loss: 0.7529 - val_accuracy: 0.6204
#
# Epoch 00004: val_accuracy did not improve from 0.63889
# Epoch 5/110
# 54/54 [==============================] - 8s 152ms/step - loss: 0.7173 - accuracy: 0.6898 - val_loss: 0.7072 - val_accuracy: 0.6759
#
# Epoch 00005: val_accuracy improved from 0.63889 to 0.67593, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 6/110
# 54/54 [==============================] - 9s 160ms/step - loss: 0.6116 - accuracy: 0.7245 - val_loss: 0.6760 - val_accuracy: 0.7037
#
# Epoch 00006: val_accuracy improved from 0.67593 to 0.70370, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 7/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.7256 - accuracy: 0.6782 - val_loss: 0.6312 - val_accuracy: 0.7130
#
# Epoch 00007: val_accuracy improved from 0.70370 to 0.71296, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 8/110
# 54/54 [==============================] - 9s 160ms/step - loss: 0.6275 - accuracy: 0.7292 - val_loss: 0.6167 - val_accuracy: 0.7500
#
# Epoch 00008: val_accuracy improved from 0.71296 to 0.75000, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 9/110
# 54/54 [==============================] - 8s 150ms/step - loss: 0.5773 - accuracy: 0.7500 - val_loss: 0.7324 - val_accuracy: 0.7037
#
# Epoch 00009: val_accuracy did not improve from 0.75000
# Epoch 10/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.5915 - accuracy: 0.7454 - val_loss: 0.6175 - val_accuracy: 0.7315
#
# Epoch 00010: val_accuracy did not improve from 0.75000
# Epoch 11/110
# 54/54 [==============================] - 9s 172ms/step - loss: 0.5620 - accuracy: 0.7847 - val_loss: 0.6397 - val_accuracy: 0.6667
#
# Epoch 00011: val_accuracy did not improve from 0.75000
# Epoch 12/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.5117 - accuracy: 0.8032 - val_loss: 0.6108 - val_accuracy: 0.7130
#
# Epoch 00012: val_accuracy did not improve from 0.75000
# Epoch 13/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.5447 - accuracy: 0.7755 - val_loss: 0.5517 - val_accuracy: 0.7500
#
# Epoch 00013: val_accuracy did not improve from 0.75000
# Epoch 14/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.5642 - accuracy: 0.7731 - val_loss: 0.7519 - val_accuracy: 0.7222
#
# Epoch 00014: val_accuracy did not improve from 0.75000
# Epoch 15/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.5729 - accuracy: 0.7569 - val_loss: 0.5586 - val_accuracy: 0.7778
#
# Epoch 00015: val_accuracy improved from 0.75000 to 0.77778, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 16/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.5558 - accuracy: 0.7454 - val_loss: 0.5532 - val_accuracy: 0.7778
#
# Epoch 00016: val_accuracy did not improve from 0.77778
# Epoch 17/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.5721 - accuracy: 0.7546 - val_loss: 0.5118 - val_accuracy: 0.8056
#
# Epoch 00017: val_accuracy improved from 0.77778 to 0.80556, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 18/110
# 54/54 [==============================] - 9s 165ms/step - loss: 0.5292 - accuracy: 0.7870 - val_loss: 0.6123 - val_accuracy: 0.7685
#
# Epoch 00018: val_accuracy did not improve from 0.80556
# Epoch 19/110
# 54/54 [==============================] - 9s 161ms/step - loss: 0.5072 - accuracy: 0.7894 - val_loss: 0.6506 - val_accuracy: 0.7407
#
# Epoch 00019: val_accuracy did not improve from 0.80556
# Epoch 20/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.5198 - accuracy: 0.8102 - val_loss: 0.6013 - val_accuracy: 0.7315
#
# Epoch 00020: val_accuracy did not improve from 0.80556
# Epoch 21/110
# 54/54 [==============================] - 9s 165ms/step - loss: 0.5996 - accuracy: 0.7384 - val_loss: 0.5757 - val_accuracy: 0.7500
#
# Epoch 00021: val_accuracy did not improve from 0.80556
# Epoch 22/110
# 54/54 [==============================] - 8s 152ms/step - loss: 0.5165 - accuracy: 0.7731 - val_loss: 0.5332 - val_accuracy: 0.7407
#
# Epoch 00022: val_accuracy did not improve from 0.80556
# Epoch 23/110
# 54/54 [==============================] - 8s 152ms/step - loss: 0.5004 - accuracy: 0.7963 - val_loss: 0.6658 - val_accuracy: 0.7222
#
# Epoch 00023: val_accuracy did not improve from 0.80556
# Epoch 24/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.4601 - accuracy: 0.8194 - val_loss: 0.5967 - val_accuracy: 0.7222
#
# Epoch 00024: val_accuracy did not improve from 0.80556
# Epoch 25/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4978 - accuracy: 0.7870 - val_loss: 0.5420 - val_accuracy: 0.7778
#
# Epoch 00025: val_accuracy did not improve from 0.80556
# Epoch 26/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.5261 - accuracy: 0.7778 - val_loss: 0.4718 - val_accuracy: 0.8333
#
# Epoch 00026: val_accuracy improved from 0.80556 to 0.83333, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 27/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4918 - accuracy: 0.8056 - val_loss: 0.5784 - val_accuracy: 0.7500
#
# Epoch 00027: val_accuracy did not improve from 0.83333
# Epoch 28/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.5276 - accuracy: 0.7963 - val_loss: 0.5331 - val_accuracy: 0.7778
#
# Epoch 00028: val_accuracy did not improve from 0.83333
# Epoch 29/110
# 54/54 [==============================] - 11s 197ms/step - loss: 0.5089 - accuracy: 0.7940 - val_loss: 0.5806 - val_accuracy: 0.7685
#
# Epoch 00029: val_accuracy did not improve from 0.83333
# Epoch 30/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.4714 - accuracy: 0.7986 - val_loss: 0.5621 - val_accuracy: 0.7778
#
# Epoch 00030: val_accuracy did not improve from 0.83333
# Epoch 31/110
# 54/54 [==============================] - 9s 162ms/step - loss: 0.4765 - accuracy: 0.8102 - val_loss: 0.4916 - val_accuracy: 0.7870
#
# Epoch 00031: val_accuracy did not improve from 0.83333
# Epoch 32/110
# 54/54 [==============================] - 9s 159ms/step - loss: 0.4882 - accuracy: 0.7963 - val_loss: 0.4899 - val_accuracy: 0.7963
#
# Epoch 00032: val_accuracy did not improve from 0.83333
# Epoch 33/110
# 54/54 [==============================] - 8s 156ms/step - loss: 0.4621 - accuracy: 0.8009 - val_loss: 0.5640 - val_accuracy: 0.7500
#
# Epoch 00033: val_accuracy did not improve from 0.83333
# Epoch 34/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.4705 - accuracy: 0.8194 - val_loss: 0.6347 - val_accuracy: 0.7130
#
# Epoch 00034: val_accuracy did not improve from 0.83333
# Epoch 35/110
# 54/54 [==============================] - 11s 194ms/step - loss: 0.5599 - accuracy: 0.7523 - val_loss: 0.4462 - val_accuracy: 0.8148
#
# Epoch 00035: val_accuracy did not improve from 0.83333
# Epoch 36/110
# 54/54 [==============================] - 11s 209ms/step - loss: 0.4932 - accuracy: 0.8009 - val_loss: 0.6027 - val_accuracy: 0.7685
#
# Epoch 00036: val_accuracy did not improve from 0.83333
# Epoch 37/110
# 54/54 [==============================] - 11s 204ms/step - loss: 0.5720 - accuracy: 0.7778 - val_loss: 0.4500 - val_accuracy: 0.8333
#
# Epoch 00037: val_accuracy did not improve from 0.83333
# Epoch 38/110
# 54/54 [==============================] - 13s 244ms/step - loss: 0.4498 - accuracy: 0.8125 - val_loss: 0.5672 - val_accuracy: 0.7500
#
# Epoch 00038: val_accuracy did not improve from 0.83333
# Epoch 39/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.4508 - accuracy: 0.8287 - val_loss: 0.5696 - val_accuracy: 0.7407
#
# Epoch 00039: val_accuracy did not improve from 0.83333
# Epoch 40/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4548 - accuracy: 0.8056 - val_loss: 0.4977 - val_accuracy: 0.8333
#
# Epoch 00040: val_accuracy did not improve from 0.83333
# Epoch 41/110
# 54/54 [==============================] - 13s 243ms/step - loss: 0.4445 - accuracy: 0.8264 - val_loss: 0.6096 - val_accuracy: 0.7315
#
# Epoch 00041: val_accuracy did not improve from 0.83333
# Epoch 42/110
# 54/54 [==============================] - 9s 163ms/step - loss: 0.4744 - accuracy: 0.8056 - val_loss: 0.6177 - val_accuracy: 0.7222
#
# Epoch 00042: val_accuracy did not improve from 0.83333
# Epoch 43/110
# 54/54 [==============================] - 9s 168ms/step - loss: 0.4613 - accuracy: 0.8102 - val_loss: 0.4968 - val_accuracy: 0.8241
#
# Epoch 00043: val_accuracy did not improve from 0.83333
# Epoch 44/110
# 54/54 [==============================] - 10s 176ms/step - loss: 0.4512 - accuracy: 0.8148 - val_loss: 0.5976 - val_accuracy: 0.7130
#
# Epoch 00044: val_accuracy did not improve from 0.83333
# Epoch 45/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.4203 - accuracy: 0.8287 - val_loss: 0.5085 - val_accuracy: 0.8056
#
# Epoch 00045: val_accuracy did not improve from 0.83333
# Epoch 46/110
# 54/54 [==============================] - 9s 172ms/step - loss: 0.3833 - accuracy: 0.8241 - val_loss: 0.5371 - val_accuracy: 0.7778
#
# Epoch 00046: val_accuracy did not improve from 0.83333
# Epoch 47/110
# 54/54 [==============================] - 9s 174ms/step - loss: 0.4462 - accuracy: 0.8287 - val_loss: 0.5364 - val_accuracy: 0.7593
#
# Epoch 00047: val_accuracy did not improve from 0.83333
# Epoch 48/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.5160 - accuracy: 0.7847 - val_loss: 0.4737 - val_accuracy: 0.7963
#
# Epoch 00048: val_accuracy did not improve from 0.83333
# Epoch 49/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.4344 - accuracy: 0.8171 - val_loss: 0.5949 - val_accuracy: 0.7778
#
# Epoch 00049: val_accuracy did not improve from 0.83333
# Epoch 50/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3907 - accuracy: 0.8495 - val_loss: 0.5230 - val_accuracy: 0.7778
#
# Epoch 00050: val_accuracy did not improve from 0.83333
# Epoch 51/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4582 - accuracy: 0.8218 - val_loss: 0.4424 - val_accuracy: 0.8426
#
# Epoch 00051: val_accuracy improved from 0.83333 to 0.84259, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 52/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.4573 - accuracy: 0.8032 - val_loss: 0.5289 - val_accuracy: 0.7500
#
# Epoch 00052: val_accuracy did not improve from 0.84259
# Epoch 53/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4371 - accuracy: 0.8241 - val_loss: 0.4925 - val_accuracy: 0.8148
#
# Epoch 00053: val_accuracy did not improve from 0.84259
# Epoch 54/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4489 - accuracy: 0.8171 - val_loss: 0.5134 - val_accuracy: 0.7963
#
# Epoch 00054: val_accuracy did not improve from 0.84259
# Epoch 55/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4331 - accuracy: 0.8310 - val_loss: 0.4983 - val_accuracy: 0.8056
#
# Epoch 00055: val_accuracy did not improve from 0.84259
# Epoch 56/110
# 54/54 [==============================] - 9s 162ms/step - loss: 0.4324 - accuracy: 0.8403 - val_loss: 0.5703 - val_accuracy: 0.6944
#
# Epoch 00056: val_accuracy did not improve from 0.84259
# Epoch 57/110
# 54/54 [==============================] - 9s 157ms/step - loss: 0.4416 - accuracy: 0.8079 - val_loss: 0.6280 - val_accuracy: 0.7593
#
# Epoch 00057: val_accuracy did not improve from 0.84259
# Epoch 58/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4475 - accuracy: 0.8310 - val_loss: 0.5199 - val_accuracy: 0.7963
#
# Epoch 00058: val_accuracy did not improve from 0.84259
# Epoch 59/110
# 54/54 [==============================] - 11s 201ms/step - loss: 0.4515 - accuracy: 0.8171 - val_loss: 0.5703 - val_accuracy: 0.7778
#
# Epoch 00059: val_accuracy did not improve from 0.84259
# Epoch 60/110
# 54/54 [==============================] - 11s 202ms/step - loss: 0.4478 - accuracy: 0.8241 - val_loss: 0.5495 - val_accuracy: 0.7407
#
# Epoch 00060: val_accuracy did not improve from 0.84259
# Epoch 61/110
# 54/54 [==============================] - 11s 194ms/step - loss: 0.4054 - accuracy: 0.8403 - val_loss: 0.4939 - val_accuracy: 0.7778
#
# Epoch 00061: val_accuracy did not improve from 0.84259
# Epoch 62/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4406 - accuracy: 0.8403 - val_loss: 0.6092 - val_accuracy: 0.7685
#
# Epoch 00062: val_accuracy did not improve from 0.84259
# Epoch 63/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4173 - accuracy: 0.8310 - val_loss: 0.5509 - val_accuracy: 0.7685
#
# Epoch 00063: val_accuracy did not improve from 0.84259
# Epoch 64/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3905 - accuracy: 0.8426 - val_loss: 0.5526 - val_accuracy: 0.7593
#
# Epoch 00064: val_accuracy did not improve from 0.84259
# Epoch 65/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3993 - accuracy: 0.8449 - val_loss: 0.4895 - val_accuracy: 0.7870
#
# Epoch 00065: val_accuracy did not improve from 0.84259
# Epoch 66/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3712 - accuracy: 0.8380 - val_loss: 0.4254 - val_accuracy: 0.8148
#
# Epoch 00066: val_accuracy did not improve from 0.84259
# Epoch 67/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3828 - accuracy: 0.8542 - val_loss: 0.4505 - val_accuracy: 0.8333
#
# Epoch 00067: val_accuracy did not improve from 0.84259
# Epoch 68/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3866 - accuracy: 0.8426 - val_loss: 0.4503 - val_accuracy: 0.8426
#
# Epoch 00068: val_accuracy did not improve from 0.84259
# Epoch 69/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.4348 - accuracy: 0.8241 - val_loss: 0.5311 - val_accuracy: 0.7963
#
# Epoch 00069: val_accuracy did not improve from 0.84259
# Epoch 70/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.3461 - accuracy: 0.8519 - val_loss: 0.3650 - val_accuracy: 0.8611
#
# Epoch 00070: val_accuracy improved from 0.84259 to 0.86111, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_2.h5
# Epoch 71/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3939 - accuracy: 0.8403 - val_loss: 0.4942 - val_accuracy: 0.8148
#
# Epoch 00071: val_accuracy did not improve from 0.86111
# Epoch 72/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4000 - accuracy: 0.8495 - val_loss: 0.5043 - val_accuracy: 0.8333
#
# Epoch 00072: val_accuracy did not improve from 0.86111
# Epoch 73/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4358 - accuracy: 0.8310 - val_loss: 0.4931 - val_accuracy: 0.8056
#
# Epoch 00073: val_accuracy did not improve from 0.86111
# Epoch 74/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4529 - accuracy: 0.8218 - val_loss: 0.5823 - val_accuracy: 0.7685
#
# Epoch 00074: val_accuracy did not improve from 0.86111
# Epoch 75/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.3549 - accuracy: 0.8426 - val_loss: 0.5792 - val_accuracy: 0.7685
#
# Epoch 00075: val_accuracy did not improve from 0.86111
# Epoch 76/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.4132 - accuracy: 0.8310 - val_loss: 0.5173 - val_accuracy: 0.7870
#
# Epoch 00076: val_accuracy did not improve from 0.86111
# Epoch 77/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.3980 - accuracy: 0.8333 - val_loss: 0.4927 - val_accuracy: 0.8333
#
# Epoch 00077: val_accuracy did not improve from 0.86111
# Epoch 78/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.3610 - accuracy: 0.8634 - val_loss: 0.4824 - val_accuracy: 0.8241
#
# Epoch 00078: val_accuracy did not improve from 0.86111
# Epoch 79/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3929 - accuracy: 0.8472 - val_loss: 0.4727 - val_accuracy: 0.8241
#
# Epoch 00079: val_accuracy did not improve from 0.86111
# Epoch 80/110
# 54/54 [==============================] - 9s 159ms/step - loss: 0.3737 - accuracy: 0.8356 - val_loss: 0.4632 - val_accuracy: 0.7963
#
# Epoch 00080: val_accuracy did not improve from 0.86111
# Epoch 81/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3572 - accuracy: 0.8542 - val_loss: 0.5205 - val_accuracy: 0.7778
#
# Epoch 00081: val_accuracy did not improve from 0.86111
# Epoch 82/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3968 - accuracy: 0.8634 - val_loss: 0.4749 - val_accuracy: 0.8241
#
# Epoch 00082: val_accuracy did not improve from 0.86111
# Epoch 83/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.3421 - accuracy: 0.8750 - val_loss: 0.4582 - val_accuracy: 0.7870
#
# Epoch 00083: val_accuracy did not improve from 0.86111
# Epoch 84/110
# 54/54 [==============================] - 10s 179ms/step - loss: 0.3549 - accuracy: 0.8519 - val_loss: 0.4665 - val_accuracy: 0.8148
#
# Epoch 00084: val_accuracy did not improve from 0.86111
# Epoch 85/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3960 - accuracy: 0.8287 - val_loss: 0.5346 - val_accuracy: 0.7778
#
# Epoch 00085: val_accuracy did not improve from 0.86111
# Epoch 86/110
# 54/54 [==============================] - 11s 194ms/step - loss: 0.4099 - accuracy: 0.8171 - val_loss: 0.4289 - val_accuracy: 0.8519
#
# Epoch 00086: val_accuracy did not improve from 0.86111
# Epoch 87/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.3795 - accuracy: 0.8565 - val_loss: 0.5291 - val_accuracy: 0.7778
#
# Epoch 00087: val_accuracy did not improve from 0.86111
# Epoch 88/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3695 - accuracy: 0.8403 - val_loss: 0.5202 - val_accuracy: 0.7130
#
# Epoch 00088: val_accuracy did not improve from 0.86111
# Epoch 89/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4248 - accuracy: 0.8380 - val_loss: 0.4631 - val_accuracy: 0.7870
#
# Epoch 00089: val_accuracy did not improve from 0.86111
# Epoch 90/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3697 - accuracy: 0.8657 - val_loss: 0.3689 - val_accuracy: 0.8611
#
# Epoch 00090: val_accuracy did not improve from 0.86111
# Epoch 91/110
# 54/54 [==============================] - 9s 164ms/step - loss: 0.3926 - accuracy: 0.8588 - val_loss: 0.4549 - val_accuracy: 0.7963
#
# Epoch 00091: val_accuracy did not improve from 0.86111
# Epoch 92/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.4355 - accuracy: 0.8125 - val_loss: 0.4915 - val_accuracy: 0.7778
#
# Epoch 00092: val_accuracy did not improve from 0.86111
# Epoch 93/110
# 54/54 [==============================] - 9s 160ms/step - loss: 0.3954 - accuracy: 0.8472 - val_loss: 0.5314 - val_accuracy: 0.7407
#
# Epoch 00093: val_accuracy did not improve from 0.86111
# Epoch 94/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3955 - accuracy: 0.8495 - val_loss: 0.4200 - val_accuracy: 0.8241
#
# Epoch 00094: val_accuracy did not improve from 0.86111
# Epoch 95/110
# 54/54 [==============================] - 9s 167ms/step - loss: 0.3662 - accuracy: 0.8565 - val_loss: 0.3955 - val_accuracy: 0.8333
#
# Epoch 00095: val_accuracy did not improve from 0.86111
# Epoch 96/110
# 54/54 [==============================] - 10s 189ms/step - loss: 0.3978 - accuracy: 0.8449 - val_loss: 0.4335 - val_accuracy: 0.7963
#
# Epoch 00096: val_accuracy did not improve from 0.86111
# Epoch 97/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3118 - accuracy: 0.8773 - val_loss: 0.5211 - val_accuracy: 0.7870
#
# Epoch 00097: val_accuracy did not improve from 0.86111
# Epoch 98/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3540 - accuracy: 0.8588 - val_loss: 0.5067 - val_accuracy: 0.7870
#
# Epoch 00098: val_accuracy did not improve from 0.86111
# Epoch 99/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3797 - accuracy: 0.8565 - val_loss: 0.4391 - val_accuracy: 0.8333
#
# Epoch 00099: val_accuracy did not improve from 0.86111
# Epoch 100/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.3435 - accuracy: 0.8588 - val_loss: 0.4526 - val_accuracy: 0.8241
#
# Epoch 00100: val_accuracy did not improve from 0.86111
# Epoch 101/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3510 - accuracy: 0.8449 - val_loss: 0.4215 - val_accuracy: 0.8519
#
# Epoch 00101: val_accuracy did not improve from 0.86111
# Epoch 102/110
# 54/54 [==============================] - 10s 180ms/step - loss: 0.3265 - accuracy: 0.8843 - val_loss: 0.5143 - val_accuracy: 0.8241
#
# Epoch 00102: val_accuracy did not improve from 0.86111
# Epoch 103/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3492 - accuracy: 0.8704 - val_loss: 0.4232 - val_accuracy: 0.8148
#
# Epoch 00103: val_accuracy did not improve from 0.86111
# Epoch 104/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.3629 - accuracy: 0.8657 - val_loss: 0.5371 - val_accuracy: 0.7870
#
# Epoch 00104: val_accuracy did not improve from 0.86111
# Epoch 105/110
# 54/54 [==============================] - 9s 171ms/step - loss: 0.3590 - accuracy: 0.8588 - val_loss: 0.5164 - val_accuracy: 0.8241
#
# Epoch 00105: val_accuracy did not improve from 0.86111
# Epoch 106/110
# 54/54 [==============================] - 8s 150ms/step - loss: 0.3249 - accuracy: 0.8866 - val_loss: 0.4318 - val_accuracy: 0.8056
#
# Epoch 00106: val_accuracy did not improve from 0.86111
# Epoch 107/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3578 - accuracy: 0.8449 - val_loss: 0.4608 - val_accuracy: 0.8241
#
# Epoch 00107: val_accuracy did not improve from 0.86111
# Epoch 108/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.4008 - accuracy: 0.8495 - val_loss: 0.4225 - val_accuracy: 0.7778
#
# Epoch 00108: val_accuracy did not improve from 0.86111
# Epoch 109/110
# 54/54 [==============================] - 10s 193ms/step - loss: 0.3556 - accuracy: 0.8519 - val_loss: 0.4757 - val_accuracy: 0.7963
#
# Epoch 00109: val_accuracy did not improve from 0.86111
# Epoch 110/110
# 54/54 [==============================] - 11s 194ms/step - loss: 0.3325 - accuracy: 0.8634 - val_loss: 0.7905 - val_accuracy: 0.6389
#
# Epoch 00110: val_accuracy did not improve from 0.86111
# 14/14 [==============================] - 2s 138ms/step - loss: 0.4659 - accuracy: 0.8241
#
# Fold number 3
# Found 432 validated image filenames belonging to 3 classes.
# Found 108 validated image filenames belonging to 3 classes.
# Found 60 validated image filenames belonging to 3 classes.
# Epoch 1/110
# 54/54 [==============================] - 14s 193ms/step - loss: 1.1494 - accuracy: 0.4815 - val_loss: 1.0728 - val_accuracy: 0.3796
#
# Epoch 00001: val_accuracy improved from -inf to 0.37963, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 2/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.8842 - accuracy: 0.5926 - val_loss: 0.8599 - val_accuracy: 0.6574
#
# Epoch 00002: val_accuracy improved from 0.37963 to 0.65741, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_3.h5
# Epoch 3/110
# 54/54 [==============================] - 9s 175ms/step - loss: 0.8065 - accuracy: 0.6505 - val_loss: 0.7862 - val_accuracy: 0.6296
#
# Epoch 00003: val_accuracy did not improve from 0.65741
# Epoch 4/110
# 54/54 [==============================] - 8s 145ms/step - loss: 0.7374 - accuracy: 0.6782 - val_loss: 0.7564 - val_accuracy: 0.6389
#
# Epoch 00004: val_accuracy did not improve from 0.65741
# Epoch 5/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.7567 - accuracy: 0.6551 - val_loss: 0.7812 - val_accuracy: 0.6574
#
# Epoch 00005: val_accuracy did not improve from 0.65741
# Epoch 6/110
# 54/54 [==============================] - 10s 188ms/step - loss: 0.6660 - accuracy: 0.7106 - val_loss: 0.8520 - val_accuracy: 0.6574
#
# ...
# Epoch 33/110
# 54/54 [==============================] - 12s 229ms/step - loss: 0.4956 - accuracy: 0.7824 - val_loss: 0.4200 - val_accuracy: 0.8519
#
# Epoch 00033: val_accuracy did not improve from 0.87963
# Epoch 34/110
# 54/54 [==============================] - 11s 205ms/step - loss: 0.5052 - accuracy: 0.7824 - val_loss: 0.3620 - val_accuracy: 0.8519
#
# Epoch 00034: val_accuracy did not improve from 0.87963
# Epoch 35/110
# 54/54 [==============================] - 11s 194ms/step - loss: 0.4819 - accuracy: 0.7963 - val_loss: 0.3485 - val_accuracy: 0.8519
#
# Epoch 00035: val_accuracy did not improve from 0.87963
# Epoch 36/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4461 - accuracy: 0.8079 - val_loss: 0.3836 - val_accuracy: 0.8426
#
# Epoch 00036: val_accuracy did not improve from 0.87963
# Epoch 37/110
# 54/54 [==============================] - 10s 188ms/step - loss: 0.5267 - accuracy: 0.7917 - val_loss: 0.3999 - val_accuracy: 0.8148
#
# Epoch 00037: val_accuracy did not improve from 0.87963
# Epoch 38/110
# 54/54 [==============================] - 10s 185ms/step - loss: 0.4758 - accuracy: 0.8148 - val_loss: 0.3982 - val_accuracy: 0.8241
#
# Epoch 00038: val_accuracy did not improve from 0.87963
# Epoch 39/110
# 54/54 [==============================] - 9s 164ms/step - loss: 0.4809 - accuracy: 0.7940 - val_loss: 0.4022 - val_accuracy: 0.8333
#
# Epoch 00039: val_accuracy did not improve from 0.87963
# Epoch 40/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.5381 - accuracy: 0.7755 - val_loss: 0.3315 - val_accuracy: 0.8519
#
# Epoch 00040: val_accuracy did not improve from 0.87963
# Epoch 41/110
# 54/54 [==============================] - 11s 205ms/step - loss: 0.4730 - accuracy: 0.8171 - val_loss: 0.3843 - val_accuracy: 0.8056
#
# Epoch 00041: val_accuracy did not improve from 0.87963
# Epoch 42/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4725 - accuracy: 0.8056 - val_loss: 0.4840 - val_accuracy: 0.8241
#
# Epoch 00042: val_accuracy did not improve from 0.87963
# Epoch 43/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.4449 - accuracy: 0.8148 - val_loss: 0.4648 - val_accuracy: 0.8333
#
# Epoch 00043: val_accuracy did not improve from 0.87963
# Epoch 44/110
# 54/54 [==============================] - 10s 190ms/step - loss: 0.4578 - accuracy: 0.8287 - val_loss: 0.4085 - val_accuracy: 0.8426
#
# Epoch 00044: val_accuracy did not improve from 0.87963
# Epoch 45/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4275 - accuracy: 0.8194 - val_loss: 0.3591 - val_accuracy: 0.8611
#
# Epoch 00045: val_accuracy did not improve from 0.87963
# Epoch 46/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4315 - accuracy: 0.8472 - val_loss: 0.3651 - val_accuracy: 0.8889
#
# Epoch 00046: val_accuracy improved from 0.87963 to 0.88889, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 47/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4637 - accuracy: 0.8032 - val_loss: 0.3854 - val_accuracy: 0.8056
#
# Epoch 00047: val_accuracy did not improve from 0.88889
# Epoch 48/110
# 54/54 [==============================] - 10s 177ms/step - loss: 0.4694 - accuracy: 0.8125 - val_loss: 0.4174 - val_accuracy: 0.8333
#
# Epoch 00048: val_accuracy did not improve from 0.88889
# Epoch 49/110
# 54/54 [==============================] - 10s 183ms/step - loss: 0.4417 - accuracy: 0.8125 - val_loss: 0.4345 - val_accuracy: 0.8426
#
# Epoch 00049: val_accuracy did not improve from 0.88889
# Epoch 50/110
# 54/54 [==============================] - 11s 205ms/step - loss: 0.4031 - accuracy: 0.8218 - val_loss: 0.4007 - val_accuracy: 0.8426
#
# Epoch 00050: val_accuracy did not improve from 0.88889
# Epoch 51/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4328 - accuracy: 0.8102 - val_loss: 0.4334 - val_accuracy: 0.8148
#
# Epoch 00051: val_accuracy did not improve from 0.88889
# Epoch 52/110
# 54/54 [==============================] - 12s 229ms/step - loss: 0.4015 - accuracy: 0.8542 - val_loss: 0.3586 - val_accuracy: 0.8333
#
# Epoch 00052: val_accuracy did not improve from 0.88889
# Epoch 53/110
# 54/54 [==============================] - 12s 215ms/step - loss: 0.4402 - accuracy: 0.8125 - val_loss: 0.3726 - val_accuracy: 0.8519
#
# Epoch 00053: val_accuracy did not improve from 0.88889
# Epoch 54/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.4715 - accuracy: 0.8079 - val_loss: 0.3395 - val_accuracy: 0.8704
#
# Epoch 00054: val_accuracy did not improve from 0.88889
# Epoch 55/110
# 54/54 [==============================] - 14s 251ms/step - loss: 0.4295 - accuracy: 0.8079 - val_loss: 0.3330 - val_accuracy: 0.8704
#
# Epoch 00055: val_accuracy did not improve from 0.88889
# Epoch 56/110
# 54/54 [==============================] - 12s 222ms/step - loss: 0.4711 - accuracy: 0.8102 - val_loss: 0.4628 - val_accuracy: 0.8333
#
# Epoch 00056: val_accuracy did not improve from 0.88889
# Epoch 57/110
# 54/54 [==============================] - 14s 266ms/step - loss: 0.4470 - accuracy: 0.8194 - val_loss: 0.3729 - val_accuracy: 0.8426
#
# Epoch 00057: val_accuracy did not improve from 0.88889
# Epoch 58/110
# 54/54 [==============================] - 13s 242ms/step - loss: 0.4591 - accuracy: 0.8102 - val_loss: 0.3427 - val_accuracy: 0.8796
#
# Epoch 00058: val_accuracy did not improve from 0.88889
# Epoch 59/110
# 54/54 [==============================] - 12s 224ms/step - loss: 0.4773 - accuracy: 0.8009 - val_loss: 0.3881 - val_accuracy: 0.8333
#
# Epoch 00059: val_accuracy did not improve from 0.88889
# Epoch 60/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.4349 - accuracy: 0.8356 - val_loss: 0.3371 - val_accuracy: 0.8796
#
# Epoch 00060: val_accuracy did not improve from 0.88889
# Epoch 61/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.4506 - accuracy: 0.8102 - val_loss: 0.3145 - val_accuracy: 0.8611
#
# Epoch 00061: val_accuracy did not improve from 0.88889
# Epoch 62/110
# 54/54 [==============================] - 10s 193ms/step - loss: 0.4361 - accuracy: 0.8287 - val_loss: 0.4127 - val_accuracy: 0.8148
#
# Epoch 00062: val_accuracy did not improve from 0.88889
# Epoch 63/110
# 54/54 [==============================] - 11s 197ms/step - loss: 0.4096 - accuracy: 0.8056 - val_loss: 0.3797 - val_accuracy: 0.8333
#
# Epoch 00063: val_accuracy did not improve from 0.88889
# Epoch 64/110
# 54/54 [==============================] - 12s 227ms/step - loss: 0.4094 - accuracy: 0.8356 - val_loss: 0.4568 - val_accuracy: 0.7778
#
# Epoch 00064: val_accuracy did not improve from 0.88889
# Epoch 65/110
# 54/54 [==============================] - 11s 206ms/step - loss: 0.4193 - accuracy: 0.8310 - val_loss: 0.5224 - val_accuracy: 0.7870
#
# Epoch 00065: val_accuracy did not improve from 0.88889
# Epoch 66/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4493 - accuracy: 0.8218 - val_loss: 0.3234 - val_accuracy: 0.8704
#
# Epoch 00066: val_accuracy did not improve from 0.88889
# Epoch 67/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3723 - accuracy: 0.8542 - val_loss: 0.3397 - val_accuracy: 0.8519
#
# Epoch 00067: val_accuracy did not improve from 0.88889
# Epoch 68/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.4742 - accuracy: 0.7963 - val_loss: 0.5137 - val_accuracy: 0.8148
#
# Epoch 00068: val_accuracy did not improve from 0.88889
# Epoch 69/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.4251 - accuracy: 0.8241 - val_loss: 0.3195 - val_accuracy: 0.9074
#
# Epoch 00069: val_accuracy improved from 0.88889 to 0.90741, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 70/110
# 54/54 [==============================] - 9s 164ms/step - loss: 0.3738 - accuracy: 0.8519 - val_loss: 0.4872 - val_accuracy: 0.7963
#
# Epoch 00070: val_accuracy did not improve from 0.90741
# Epoch 71/110
# 54/54 [==============================] - 10s 178ms/step - loss: 0.4284 - accuracy: 0.8264 - val_loss: 0.4004 - val_accuracy: 0.8426
#
# Epoch 00071: val_accuracy did not improve from 0.90741
# Epoch 72/110
# 54/54 [==============================] - 11s 201ms/step - loss: 0.4048 - accuracy: 0.8148 - val_loss: 0.3189 - val_accuracy: 0.8889
#
# Epoch 00072: val_accuracy did not improve from 0.90741
# Epoch 73/110
# 54/54 [==============================] - 10s 189ms/step - loss: 0.4220 - accuracy: 0.8287 - val_loss: 0.4406 - val_accuracy: 0.8519
#
# Epoch 00073: val_accuracy did not improve from 0.90741
# Epoch 74/110
# 54/54 [==============================] - 11s 202ms/step - loss: 0.4040 - accuracy: 0.8380 - val_loss: 0.3217 - val_accuracy: 0.8519
#
# Epoch 00074: val_accuracy did not improve from 0.90741
# Epoch 75/110
# 54/54 [==============================] - 10s 189ms/step - loss: 0.4216 - accuracy: 0.8380 - val_loss: 0.3463 - val_accuracy: 0.8519
#
# Epoch 00075: val_accuracy did not improve from 0.90741
# Epoch 76/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4340 - accuracy: 0.8194 - val_loss: 0.3962 - val_accuracy: 0.8426
#
# Epoch 00076: val_accuracy did not improve from 0.90741
# Epoch 77/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.4324 - accuracy: 0.8241 - val_loss: 0.3751 - val_accuracy: 0.8241
#
# Epoch 00077: val_accuracy did not improve from 0.90741
# Epoch 78/110
# 54/54 [==============================] - 12s 214ms/step - loss: 0.3706 - accuracy: 0.8519 - val_loss: 0.3704 - val_accuracy: 0.8426
#
# Epoch 00078: val_accuracy did not improve from 0.90741
# Epoch 79/110
# 54/54 [==============================] - 12s 217ms/step - loss: 0.4133 - accuracy: 0.8171 - val_loss: 0.3933 - val_accuracy: 0.8333
#
# Epoch 00079: val_accuracy did not improve from 0.90741
# Epoch 80/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.3482 - accuracy: 0.8611 - val_loss: 0.3749 - val_accuracy: 0.8611
#
# Epoch 00080: val_accuracy did not improve from 0.90741
# Epoch 81/110
# 54/54 [==============================] - 10s 194ms/step - loss: 0.4308 - accuracy: 0.8218 - val_loss: 0.4151 - val_accuracy: 0.8704
#
# Epoch 00081: val_accuracy did not improve from 0.90741
# Epoch 82/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.3857 - accuracy: 0.8495 - val_loss: 0.3544 - val_accuracy: 0.8519
#
# Epoch 00082: val_accuracy did not improve from 0.90741
# Epoch 83/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3882 - accuracy: 0.8403 - val_loss: 0.4133 - val_accuracy: 0.8241
#
# Epoch 00083: val_accuracy did not improve from 0.90741
# Epoch 84/110
# 54/54 [==============================] - 13s 242ms/step - loss: 0.4332 - accuracy: 0.8333 - val_loss: 0.3188 - val_accuracy: 0.8796
#
# Epoch 00084: val_accuracy did not improve from 0.90741
# Epoch 85/110
# 54/54 [==============================] - 12s 210ms/step - loss: 0.4083 - accuracy: 0.8472 - val_loss: 0.3708 - val_accuracy: 0.8426
#
# Epoch 00085: val_accuracy did not improve from 0.90741
# Epoch 86/110
# 54/54 [==============================] - 10s 192ms/step - loss: 0.3896 - accuracy: 0.8449 - val_loss: 0.2811 - val_accuracy: 0.9167
#
# Epoch 00086: val_accuracy improved from 0.90741 to 0.91667, saving model to C:/Users/user/Desktop/Model/saved_models_1\model_5.h5
# Epoch 87/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3736 - accuracy: 0.8657 - val_loss: 0.4923 - val_accuracy: 0.7963
#
# Epoch 00087: val_accuracy did not improve from 0.91667
# Epoch 88/110
# 54/54 [==============================] - 10s 190ms/step - loss: 0.3888 - accuracy: 0.8356 - val_loss: 0.6353 - val_accuracy: 0.7963
#
# Epoch 00088: val_accuracy did not improve from 0.91667
# Epoch 89/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3427 - accuracy: 0.8495 - val_loss: 0.4852 - val_accuracy: 0.8241
#
# Epoch 00089: val_accuracy did not improve from 0.91667
# Epoch 90/110
# 54/54 [==============================] - 10s 188ms/step - loss: 0.3765 - accuracy: 0.8519 - val_loss: 0.3456 - val_accuracy: 0.8611
#
# Epoch 00090: val_accuracy did not improve from 0.91667
# Epoch 91/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.3959 - accuracy: 0.8472 - val_loss: 0.2814 - val_accuracy: 0.9074
#
# Epoch 00091: val_accuracy did not improve from 0.91667
# Epoch 92/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3745 - accuracy: 0.8542 - val_loss: 0.5504 - val_accuracy: 0.7870
#
# Epoch 00092: val_accuracy did not improve from 0.91667
# Epoch 93/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.3873 - accuracy: 0.8542 - val_loss: 0.4667 - val_accuracy: 0.8241
#
# Epoch 00093: val_accuracy did not improve from 0.91667
# Epoch 94/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3779 - accuracy: 0.8519 - val_loss: 0.2715 - val_accuracy: 0.8889
#
# Epoch 00094: val_accuracy did not improve from 0.91667
# Epoch 95/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4263 - accuracy: 0.8449 - val_loss: 0.3931 - val_accuracy: 0.8241
#
# Epoch 00095: val_accuracy did not improve from 0.91667
# Epoch 96/110
# 54/54 [==============================] - 10s 190ms/step - loss: 0.4045 - accuracy: 0.8171 - val_loss: 0.3775 - val_accuracy: 0.8148
#
# Epoch 00096: val_accuracy did not improve from 0.91667
# Epoch 97/110
# 54/54 [==============================] - 11s 201ms/step - loss: 0.3664 - accuracy: 0.8634 - val_loss: 0.2893 - val_accuracy: 0.8704
#
# Epoch 00097: val_accuracy did not improve from 0.91667
# Epoch 98/110
# 54/54 [==============================] - 11s 198ms/step - loss: 0.3817 - accuracy: 0.8449 - val_loss: 0.3858 - val_accuracy: 0.8426
#
# Epoch 00098: val_accuracy did not improve from 0.91667
# Epoch 99/110
# 54/54 [==============================] - 13s 231ms/step - loss: 0.3322 - accuracy: 0.8727 - val_loss: 0.3927 - val_accuracy: 0.8426
#
# Epoch 00099: val_accuracy did not improve from 0.91667
# Epoch 100/110
# 54/54 [==============================] - 10s 191ms/step - loss: 0.3910 - accuracy: 0.8426 - val_loss: 0.2912 - val_accuracy: 0.8611
#
# Epoch 00100: val_accuracy did not improve from 0.91667
# Epoch 101/110
# 54/54 [==============================] - 10s 187ms/step - loss: 0.4455 - accuracy: 0.8264 - val_loss: 0.3770 - val_accuracy: 0.8704
#
# Epoch 00101: val_accuracy did not improve from 0.91667
# Epoch 102/110
# 54/54 [==============================] - 10s 181ms/step - loss: 0.4091 - accuracy: 0.8426 - val_loss: 0.2598 - val_accuracy: 0.9167
#
# Epoch 00102: val_accuracy did not improve from 0.91667
# Epoch 103/110
# 54/54 [==============================] - 10s 193ms/step - loss: 0.3432 - accuracy: 0.8681 - val_loss: 0.4513 - val_accuracy: 0.8426
#
# Epoch 00103: val_accuracy did not improve from 0.91667
# Epoch 104/110
# 54/54 [==============================] - 8s 154ms/step - loss: 0.3724 - accuracy: 0.8611 - val_loss: 0.5239 - val_accuracy: 0.7870
#
# Epoch 00104: val_accuracy did not improve from 0.91667
# Epoch 105/110
# 54/54 [==============================] - 10s 175ms/step - loss: 0.3989 - accuracy: 0.8426 - val_loss: 0.5586 - val_accuracy: 0.7963
#
# Epoch 00105: val_accuracy did not improve from 0.91667
# Epoch 106/110
# 54/54 [==============================] - 9s 173ms/step - loss: 0.4393 - accuracy: 0.8264 - val_loss: 0.3406 - val_accuracy: 0.8519
#
# Epoch 00106: val_accuracy did not improve from 0.91667
# Epoch 107/110
# 54/54 [==============================] - 9s 169ms/step - loss: 0.3934 - accuracy: 0.8356 - val_loss: 0.3612 - val_accuracy: 0.8519
#
# Epoch 00107: val_accuracy did not improve from 0.91667
# Epoch 108/110
# 54/54 [==============================] - 10s 184ms/step - loss: 0.3729 - accuracy: 0.8449 - val_loss: 0.3471 - val_accuracy: 0.8704
#
# Epoch 00108: val_accuracy did not improve from 0.91667
# Epoch 109/110
# 54/54 [==============================] - 10s 186ms/step - loss: 0.3690 - accuracy: 0.8588 - val_loss: 0.2993 - val_accuracy: 0.8611
#
# Epoch 00109: val_accuracy did not improve from 0.91667
# Epoch 110/110
# 54/54 [==============================] - 10s 182ms/step - loss: 0.3886 - accuracy: 0.8310 - val_loss: 0.3217 - val_accuracy: 0.8796
#
# Epoch 00110: val_accuracy did not improve from 0.91667
# 14/14 [==============================] - 2s 140ms/step - loss: 0.3870 - accuracy: 0.8426

# %%
#stopper

# %% [markdown]
# ### Display Values Per Combination of Parameters

# %% [markdown]
# We will put the combination of parameters and the resulting means of accuracy and loss together in a dataframe in order to display it nicely.

# %%
#append means of accuracy and loss sets per combo
for x in range(len(val_acc_arr)):
    val_acc_means.append(np.mean(val_acc_arr[x]))                                
    val_loss_means.append(np.mean(val_loss_arr[x]))
    
    train_acc_means.append(np.mean(train_acc_arr[x]))                              
    train_loss_means.append(np.mean(train_loss_arr[x]))                             

    test_acc_means.append(np.mean(test_acc_arr[x]))                               
    test_loss_means.append(np.mean(test_loss_arr[x])) 
    
df_hyperparam = pd.DataFrame(list(zip(param_arr[0],param_arr[1],param_arr[2],
                                      train_acc_means, train_loss_means,
                                      val_acc_means,val_loss_means,
                                      test_acc_means, test_loss_means))
                             ,columns=['batch size','number of epoch', 'learning rate', 
                                       'train accuracy', 'train loss',
                                       'val accuracy', 'val loss',
                                       'test accuracy', 'test loss'])

df_hyperparam = df_hyperparam.sort_values(ascending=False,by = 'val accuracy')

#df_hyperparam.to_excel("hyperparam_result.xlsx")

df_hyperparam
# Out:
#    batch size  number of epoch  learning rate  train accuracy  train loss  \
# 0           8              110         0.0001         0.81008     0.46244
#
#    val accuracy  val loss  test accuracy  test loss
# 0      0.831481  0.448223            0.3   2.924491

# %%
#stopper

# %% [markdown]
# ### Each fold results of a selected model

# %% [markdown]
# Below are the validation accuracy and validation loss per fold and their average of the best combination.

# %%
comb_no = 0
fold_num = [*range(1,6)]

fold_eval = pd.DataFrame(list(zip(fold_num,train_acc_arr[comb_no],train_loss_arr[comb_no],
                                  val_acc_arr[comb_no],val_loss_arr[comb_no],
                                  test_acc_arr[comb_no],test_loss_arr[comb_no]))
                         ,columns=['fold','Training Accuracy','Training Loss',
                                   'Validation Accuracy','Validation Loss',
                                   'Test Accuracy','Test Loss'])

fold_eval.set_index('fold', inplace=True)
fold_eval.loc['mean'] = fold_eval.mean()

#fold_eval.to_excel('fold_eval.xlsx')
fold_eval
# Out:
#       Training Accuracy  Training Loss  Validation Accuracy  Validation Loss  \
# fold
# 1              0.805787       0.473651             0.814815         0.506618
# 2              0.812605       0.458815             0.824074         0.465934
# 3              0.817003       0.449040             0.814815         0.503182
# 4              0.813300       0.452947             0.861111         0.378426
# 5              0.801705       0.477746             0.842593         0.386953
# mean           0.810080       0.462440             0.831481         0.448223
#
#       Test Accuracy  Test Loss
# fold
# 1          0.250000   2.969953
# 2          0.333333   2.828281
# 3          0.300000   3.236290
# 4          0.333333   2.546813
# 5          0.283333   3.041116
# mean       0.300000   2.924491

# %%
stopper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15016/2329210996.py in <module>
# ----> 1 stopper
#
# NameError: name 'stopper' is not defined

# %% [markdown]
# ## Model Prediction and Evaluation

# %% [markdown]
# Load the images in the test set and predict what class it is in all models of the best combination. There are three values of confidence level. The one with the highest confidence level is the predicted class of the image. The order of classes is [0 1 2]. The results will be feed to the eval function defined below in order to get the metrics.

# %%
#make the labels to integer to get the model metrics
yt = pd.to_numeric(y_test['label'])

# %% [markdown]
# The content displayed are the metrics, roc auc of each class (balut/penoy,salted,table), and confusion matrix per fold, as well as the sum and mean of those confusion matrices and roc auc of each class for all folds.

# %%
#Metrics
def evaluate(yhat_probs, 
             yhat_classes, 
             total_acc,
             total_loss,
             total_precision, 
             total_recall,
             tot_acc_per_class,
             tot_prec_per_class,
             tot_rec_per_class,
             matrix_sum,
             fold_num,
             fpr_total,
             tpr_total):

    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(yt, yhat_classes)
    total_acc.append(accuracy)
    print('Accuracy: %f' % accuracy)
    matrix = confusion_matrix(yt, yhat_classes)
    accuracy2 = matrix.diagonal()/matrix.sum(axis=1)
    tot_acc_per_class.append(accuracy2)
    print('Accuracy per class: ' + str(accuracy2))
    # loss
    loss = log_loss(yt, yhat_probs)
    total_loss.append(loss)
    print('Loss: %f' % loss)
    # precision tp / (tp + fp)
    precision = precision_score(yt, yhat_classes, average="weighted")
    total_precision.append(precision)
    print('Precision: %f' % precision)
    precision2 = precision_score(yt, yhat_classes, average=None)
    tot_prec_per_class.append(precision2)
    print('Precision per class: ' + str(precision2))
    # recall: tp / (tp + fn)
    recall = recall_score(yt, yhat_classes, average="weighted")
    total_recall.append(recall)
    print('Recall: %f' % recall)
    recall2 = recall_score(yt, yhat_classes, average=None)
    tot_rec_per_class.append(recall2)
    print('Recall per class: ' + str(recall2))
    
    #ROC AUC
    #-------------------------------------------------------------------------------
    # Binarize the true label
    ytbin = label_binarize(yt, classes=[0, 1, 2])
    n_classes = ytbin.shape[1]

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
      
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(ytbin[:, i], yhat_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
     
        if fold_num == 0:
            fpr_total.append([])

        fpr_total[i].append(fpr[i])
        
        if fold_num == 0:
            tpr_total.append([])

        tpr_total[i].append(tpr[i]) 

    # Compute micro-average ROC curve and ROC area
    fpr["macro"], tpr["macro"], _ = roc_curve(ytbin.ravel(), yhat_probs.ravel())
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams["axes.edgecolor"] = 'black'
    plt.rcParams["axes.linewidth"]  = 1.25
    
    #balut-penoy
    plt.figure()
    lw = 2
    plt.plot(fpr[0], tpr[0], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[0])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Balut-Penoy Fold ' + str(fold_num+1))
    plt.legend(loc="lower right")
    plt.show()

    #salted egg
    plt.figure()
    lw = 2
    plt.plot(fpr[1], tpr[1], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[1])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Salted Egg Fold ' + str(fold_num+1))
    plt.legend(loc="lower right")
    plt.show()

    #table egg
    plt.figure()
    lw = 2
    plt.plot(fpr[2], tpr[2], color='darkorange',
             lw=lw, label='ROC curve (area = %0.4f)' % roc_auc[2])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Table Egg Fold ' + str(fold_num+1))
    plt.legend(loc="lower right")
    plt.show()
    #-------------------------------------------------------------------------------
    
    #confusion matrix
    matrix = confusion_matrix(yt, yhat_classes)
    
    if len(total_acc) == 1:
        matrix_sum = matrix
    elif len(total_acc) > 1:
        matrix_sum = [[matrix_sum[i][j] + matrix[i][j]  
                       for j in range(len(matrix_sum[0]))] 
                      for i in range(len(matrix_sum))]
    
    df_cm = pd.DataFrame(matrix, range(matrix.shape[0]), range(matrix.shape[1]))
    df_cm = df_cm.rename(columns={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'}, 
                         index={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'})
    
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title('Confusion Matrix Fold ' + str(fold_num+1))
    plt.show()
    
    return total_acc, total_loss, total_precision, total_recall, tot_acc_per_class, tot_prec_per_class, tot_rec_per_class, matrix_sum, fpr_total, tpr_total

# %% [markdown]
# ### Metrics, Confusion Matrix, and ROC AUC per Class per Fold

# %%
fold = 5

modelname = "saved_models_1"
#modelname = "saved_models_"+str(model_no+3)

#for fold number and average string
fold_ave = []

#for metrics values
total_acc = []
total_loss = []
total_precision = []
total_recall = []

tot_acc_per_class = []
tot_prec_per_class = []
tot_rec_per_class = []

#for confusion matrix sum of folds
matrix_sum = np.array([])

#for roc auc of folds per class
fpr_bp = []
tpr_bp = []

fpr_se = []
tpr_se = []

fpr_te = []
tpr_te = []

fpr_total = []
tpr_total = []

#for validating misclassified images
yhat_classes_total = []

for fold_num in range(fold):
    
    full_model = create_model()
    
    #load the weights of bet model
    model_dir = gen_dir + "/"+modelname+"/model_"+str(fold_num+1)+".h5"
    full_model.load_weights(model_dir)

    test_set = directory + "/ToBeUsed/test_set"

    testX = []

    for img_path in X_test['filename']:
        img = im.load_img(img_path, target_size=(224,224))
        x = im.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        x = x.reshape(224,224,3)
        testX.append(x)

    testX = np.array(testX)    

    # predict probabilities for test set, y_test
    yhat_probs = full_model.predict(testX, verbose=0)

    # predict crisp classes for test set
    yhat_classes = yhat_probs.argmax(axis=-1)
    
    yhat_classes_total.append(yhat_classes)
    
    print("fold "+str(fold_num+1) +" metrics:")
    total_acc, total_loss, total_precision, total_recall, tot_acc_per_class, tot_prec_per_class, tot_rec_per_class, matrix_sum, fpr_total, tpr_total  = evaluate(yhat_probs,
                                                                                                                                                               yhat_classes,
                                                                                                                                                               total_acc,
                                                                                                                                                               total_loss,
                                                                                                                                                               total_precision,
                                                                                                                                                               total_recall,
                                                                                                                                                               tot_acc_per_class,
                                                                                                                                                               tot_prec_per_class,
                                                                                                                                                               tot_rec_per_class,
                                                                                                                                                               matrix_sum,
                                                                                                                                                               fold_num,
                                                                                                                                                               fpr_total,
                                                                                                                                                               tpr_total)
    
    fold_ave.append(str(fold_num+1))
    
    print('')

# %% [markdown]
# ### Overall Metrics

# %%
fold_ave.append("Ave:")
total_acc.append(np.mean(total_acc))
total_loss.append(np.mean(total_loss))
total_precision.append(np.mean(total_precision))
total_recall.append(np.mean(total_recall))

df_eval = pd.DataFrame(data = list(zip(fold_ave,total_acc,total_loss,total_precision,total_recall)), 
                       columns=["Fold","Accuracy","Loss","Precision","Recall"])

#set fold_ave as the index
df_eval.set_index("Fold",inplace=True)

df_eval.to_excel('best_model_accuracy_fold.xlsx')

# %% [markdown]
# ### Average metrics per class

# %%
fold = 5

tot_acc_per_class_mean = [0,0,0]
tot_prec_per_class_mean = [0,0,0]
tot_rec_per_class_mean = [0,0,0]

for y in range(len(tot_acc_per_class)):
    tot_acc_per_class_mean[0] += tot_acc_per_class[y][0]
    tot_acc_per_class_mean[1] += tot_acc_per_class[y][1]
    tot_acc_per_class_mean[2] += tot_acc_per_class[y][2]
    
    tot_prec_per_class_mean[0] += tot_prec_per_class[y][0]
    tot_prec_per_class_mean[1] += tot_prec_per_class[y][1]
    tot_prec_per_class_mean[2] += tot_prec_per_class[y][2]
    
    tot_rec_per_class_mean[0] += tot_rec_per_class[y][0]
    tot_rec_per_class_mean[1] += tot_rec_per_class[y][1]
    tot_rec_per_class_mean[2] += tot_rec_per_class[y][2]

for x in range(len(tot_acc_per_class_mean)):
    tot_acc_per_class_mean[x] = tot_acc_per_class_mean[x]/fold
    tot_prec_per_class_mean[x] = tot_prec_per_class_mean[x]/fold
    tot_rec_per_class_mean[x] = tot_rec_per_class_mean[x]/fold

# %%
label = ['Balut/Penoy','Salted','Table']

df_eval_per_class = pd.DataFrame(data = list(zip(label,tot_acc_per_class_mean,tot_prec_per_class_mean,tot_rec_per_class_mean)), 
                       columns=["Class","Accuracy","Precision","Recall"])

#set fold_ave as the index
df_eval_per_class.set_index("Class",inplace=True)

df_eval_per_class

# %% [markdown]
# ### Confusion Matrix Sum of Folds and its Average

# %%
#confusion Matrix sum of folds
matrix_sum = np.array(matrix_sum)

df_cm = pd.DataFrame(matrix_sum, range(matrix_sum.shape[0]), range(matrix_sum.shape[1]))
df_cm = df_cm.rename(columns={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'}, 
                     index={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'})

# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Confusion Matrix Sum of Folds")
plt.show()

#confusion matrix ave of sum of folds
matrix_ave = [[matrix_sum[i][j]/fold
               for j in range(len(matrix_sum[0]))] 
              for i in range(len(matrix_sum))]

matrix_ave = np.array(matrix_ave)

#print(matrix_ave)

df_cm = pd.DataFrame(matrix_ave, range(matrix_ave.shape[0]), range(matrix_ave.shape[1]))
df_cm = df_cm.rename(columns={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'}, 
                     index={0:'Balut/Penoy', 1:'Salted Egg', 2:'Table Egg'})

sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt=".1f") # font size
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Confusion Matrix Average of Sum of Folds")
plt.show()

# %% [markdown]
# ### ROC AUC of all folds per class

# %%
#ROC AUC
fpr_total = np.array(fpr_total)
tpr_total = np.array(tpr_total)

classes = ["Balut/Penoy","Salted Egg","Table Egg"]

for x in range(len(fpr_total)):
    
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    
    for i in range(fold):
        fpr[i] = fpr_total[x][i]
        tpr[i] = tpr_total[x][i]
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(fold)]))
    
    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(fold):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= fold
   
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    plt.rcParams['axes.facecolor'] = 'white'
    plt.rcParams["axes.edgecolor"] = 'black'
    plt.rcParams["axes.linewidth"]  = 1.25

    # Plot all ROC curves
    plt.figure(figsize=(12, 8))
    lw = 2
   
    colors = cycle(['brown', 'darkorange', 'cornflowerblue', 'green', 'red'])
    for i, color in zip(range(fold), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of fold {0} (area = {1:0.4f})'
                 ''.format(i, roc_auc[i]))
    
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC of all folds for class ' + classes[x])
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Validating Misclassified Images

# %% [markdown]
# We will check whether or not the predicted classes of the images match with the true classes that they have. We will display the correct and incorrect predictions.

# %%
for yhat_classes in yhat_classes_total:
    print(yhat_classes.shape, yt.shape)

# %% [markdown]
# We will get the images from the directories stored under the filename column.

# %%
testX2 = []

for img_path in X_test['filename']:
    img = cv2.imread(img_path)
    testX2.append(img)

testX2 = np.array(testX2)

# %% [markdown]
# ### Correct predictions

# %%
for x in range(len(yhat_classes_total)):
    print("Fold " + str(x+1))
    
    correct = np.where(yhat_classes_total[x]==yt)[0]

    print ("Found %d correct labels" % len(correct))

    plt.figure(figsize=(20,60))
    for i, correct in enumerate(correct[:6]):
        plt.subplot(3,2,i+1)
        RGB_img = cv2.cvtColor(testX2[correct], cv2.COLOR_BGR2RGB)
        plt.imshow(RGB_img) #, interpolation='none') #, cmap='gray')
        plt.title("Predict {0}, Class {1}".format(str(yhat_classes_total[x][correct]),str(yt.values[correct])))
        plt.grid(False)
        plt.axis('off')
    
    plt.show()

# %% [markdown]
# ### Incorrect predictions

# %%
for x in range(len(yhat_classes_total)):
    print("Fold " + str(x+1))
    
    incorrect = np.where(yhat_classes_total[x]!=yt)[0]
    
    print ("Found %d incorrect labels" % len(incorrect))
    
    plt.figure(figsize=(20,60))
    for i, incorrect in enumerate(incorrect[:6]):
        plt.subplot(3,2,i+1)
        RGB_img = cv2.cvtColor(testX2[incorrect], cv2.COLOR_BGR2RGB)
        plt.imshow(RGB_img) #, interpolation='none') #, cmap='gray')
        plt.title("Predicted {0}, Class {1}".format(str(yhat_classes_total[x][incorrect]), str(yt.values[incorrect])))
        plt.grid(False)
        plt.axis('off')
    
    plt.show()
